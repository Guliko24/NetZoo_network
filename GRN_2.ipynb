# %% [markdown]
# <a href="https://colab.research.google.com/github/Guliko24/NetZoo_network/blob/main/GRN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is a block of code working with single files from MCF7 and MDA-MB-231 cell lines

# %%
#import all the packages as needed
import pandas as pd
import networkx as nx

# %%
# prompt: let's load Gdrive onto notebook

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Navigate to your Google Drive files
# %cd /content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets
# Out:
# /content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets

# %% [markdown]
# #let's convert CTCF-genes file into some adjancy matrix for future use
#
# ---

# %%
# Load the CSV file into a DataFrame
df_MCF7 = pd.read_csv('/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_CTCF_targets_edges.csv')
df_MCF7_all_TF=pd.read_csv('/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_TF_genes_weighted_nodes150.csv')
# Display the DataFrame
print(df_MCF7)
print(df_MCF7_all_TF)
# Out:
#     Source  Target  Edge weight
# 0     CTCF   NACAD    12.263211
# 1     CTCF     AMT    11.245753
# 2     CTCF   TTC27    10.059604
# 3     CTCF    XYLB     9.888435
# 4     CTCF   THTPA     7.854461
# ..     ...     ...          ...
# 145   CTCF     CTH     3.792667
# 146   CTCF   CENPK     3.790138
# 147   CTCF  B3GAT1     3.775499
# 148   CTCF   REXO1     3.772165
# 149   CTCF   GPR20     3.765080
#
# [150 rows x 3 columns]
#       Source Target  Edge weight
# 0       IRX6  MEOX2    64.130060
# 1       IRX4  MEOX2    63.920394
# 2       IRX6   FIGN    60.464314
# 3       IRX4   FIGN    60.087284
# 4     ZNF180  TTC27    59.879850
# ..       ...    ...          ...
# 145   ZNF235  TTC27    32.200000
# 146  CREB3L2   FIGN    32.199281
# 147   LIN28A   FIGN    32.102345
# 148  CREB3L1   FIGN    32.045289
# 149     ETV5  MEOX2    31.962014
#
# [150 rows x 3 columns]

# %%
# Pivot the data to create the adjacency matrix
adjacency_matrix_MCF7= df_MCF7.pivot(index='Source', columns='Target', values='Edge weight').fillna(0)

# Display the adjacency matrix
print(adjacency_matrix_MCF7)
# Out:
# Target     ACKR3    ADGRF2        AMT    APPBP2  ARHGAP35      ASNS     ATMIN  \
# Source
# CTCF    6.194519  5.257484  11.245753  3.807179  5.737962  3.924574  3.903627
#
# Target   B3GALT6    B3GAT1    BRICD5  ...     WDR18     WDR33     WDR38  \
# Source                                ...
# CTCF    3.844181  3.775499  4.419022  ...  4.558751  4.904655  5.150136
#
# Target     WDR55      XYLB    ZBTB8B     ZG16B    ZNF250    ZNF736    ZNF75A
# Source
# CTCF    3.855257  9.888435  3.848419  3.909762  3.925584  5.928496  4.052673
#
# [1 rows x 150 columns]

# %%
# Pivot the data to create the adjacency matrix
adjacency_matrix_MDAMB231= df_MDAMB231.pivot(index='Source', columns='Target', values='Edge weight').fillna(0)

# Display the adjacency matrix
print(adjacency_matrix_MDAMB231)
# Out:
# Target      ABT1     ACKR3     ACOT9      ADD1    ADGRF2       AMT     AP5S1  \
# Source
# CTCF    5.220769  5.893049  5.565166  5.615662  7.285473  8.483121  5.286063
#
# Target   ARHGDIA    ATP10B    B3GAT1  ...   ZBTB8OS     ZC3H3    ZMYM6  \
# Source                                ...
# CTCF    5.220882  5.355004  4.957393  ...  5.056614  4.973887  5.11226
#
# Target    ZNF212   ZNF705A   ZNF705E    ZNF736    ZNF746    ZNF75A    ZNF776
# Source
# CTCF    5.516392  5.246773  4.973955  6.305415  5.079719  5.213597  6.117051
#
# [1 rows x 150 columns]

# %%
# Create a directed graph with weights directly from the edge list
G = nx.from_pandas_edgelist(df_MCF7, source='Source', target='Target', edge_attr='Edge weight', create_using=nx.DiGraph())

# Check the graph's nodes and edges
print("Nodes:", G.nodes())
print("Edges:", G.edges(data=True))
# Out:
# Nodes: ['CTCF', 'NACAD', 'AMT', 'TTC27', 'XYLB', 'THTPA', 'PLEKHG2', 'DTL', 'NTM', 'CDRT15L2', 'RFC1', 'POM121L2', 'ACKR3', 'CNDP1', 'UVRAG', 'TMEM106C', 'MPZL3', 'ZNF736', 'KLHL35', 'ELF3', 'ARHGAP35', 'MATK', 'INMT', 'MECP2', 'SNX5', 'NAGK', 'CDRT15', 'PRMT7', 'SLC19A1', 'ADGRF2', 'PEX14', 'MTERF1', 'WDR38', 'EXOC3', 'GALNT14', 'DNAJA2', 'CLDN5', 'RNF141', 'IDI1', 'PROZ', 'WDR33', 'EHD4', 'FCHSD2', 'SIRPB1', 'C1QTNF9', 'CLUL1', 'CIDEB', 'LCK', 'MYT1', 'RPL32', 'WDR18', 'TPRA1', 'IRF9', 'C4orf46', 'RANBP1', 'PYCARD', 'CCDC103', 'DDX5', 'TNKS1BP1', 'PDCD2', 'ITPK1', 'CRYBG3', 'BRICD5', 'FAM76B', 'SSR4', 'TMC7', 'PGAM5', 'DOK3', 'MMP28', 'CHST7', 'HGD', 'CCAR2', 'MYDGF', 'CAPRIN2', 'GGTLC1', 'TUSC2', 'TNFRSF14', 'ERI1', 'SMIM5', 'CCS', 'JMJD4', 'CDK10', 'CRYAA', 'SPR', 'RHBG', 'KIF18B', 'PCSK6', 'IFIT1', 'STUB1', 'MRGPRF', 'GPT', 'SPOCD1', 'PTPRE', 'SLBP', 'HCLS1', 'SOWAHB', 'GATA2', 'NUP88', 'RECQL5', 'TTC31', 'GSTT4', 'ICMT', 'GGT1', 'MPDU1', 'COMT', 'ZNF75A', 'MAML1', 'VBP1', 'RAB32', 'CRYAA2', 'TUT1', 'PAPOLA', 'LCE2D', 'OFD1', 'GGT2', 'SUPT7L', 'IRF7', 'NPDC1', 'CFAP65', 'NXF1', 'ZNF250', 'ASNS', 'PGAM1', 'LRRK1', 'HNRNPUL1', 'CRELD2', 'THYN1', 'ZG16B', 'ATMIN', 'TRIM10', 'CLPTM1L', 'UPB1', 'TM7SF2', 'DEFA4', 'WDR55', 'MSMP', 'HNF4G', 'ZBTB8B', 'SENP3', 'B3GALT6', 'IL1RAP', 'CSNK2A3', 'PEX5', 'PLPP7', 'UBE2F', 'APPBP2', 'CTH', 'CENPK', 'B3GAT1', 'REXO1', 'GPR20']
# Edges: [('CTCF', 'NACAD', {'Edge weight': 12.26321061}), ('CTCF', 'AMT', {'Edge weight': 11.24575334}), ('CTCF', 'TTC27', {'Edge weight': 10.05960444}), ('CTCF', 'XYLB', {'Edge weight': 9.888434704}), ('CTCF', 'THTPA', {'Edge weight': 7.854461143}), ('CTCF', 'PLEKHG2', {'Edge weight': 7.242546382}), ('CTCF', 'DTL', {'Edge weight': 7.079825212}), ('CTCF', 'NTM', {'Edge weight': 6.751905697}), ('CTCF', 'CDRT15L2', {'Edge weight': 6.570658667}), ('CTCF', 'RFC1', {'Edge weight': 6.479835307}), ('CTCF', 'POM121L2', {'Edge weight': 6.415607082}), ('CTCF', 'ACKR3', {'Edge weight': 6.194518649}), ('CTCF', 'CNDP1', {'Edge weight': 6.147601457}), ('CTCF', 'UVRAG', {'Edge weight': 6.144642947}), ('CTCF', 'TMEM106C', {'Edge weight': 6.053289051}), ('CTCF', 'MPZL3', {'Edge weight': 5.970519876}), ('CTCF', 'ZNF736', {'Edge weight': 5.928495591}), ('CTCF', 'KLHL35', {'Edge weight': 5.875107579}), ('CTCF', 'ELF3', {'Edge weight': 5.833135736}), ('CTCF', 'ARHGAP35', {'Edge weight': 5.737962016}), ('CTCF', 'MATK', {'Edge weight': 5.617754884}), ('CTCF', 'INMT', {'Edge weight': 5.483703718}), ('CTCF', 'MECP2', {'Edge weight': 5.478913369}), ('CTCF', 'SNX5', {'Edge weight': 5.334873845}), ('CTCF', 'NAGK', {'Edge weight': 5.331094114}), ('CTCF', 'CDRT15', {'Edge weight': 5.330021319}), ('CTCF', 'PRMT7', {'Edge weight': 5.28563352}), ('CTCF', 'SLC19A1', {'Edge weight': 5.262836676}), ('CTCF', 'ADGRF2', {'Edge weight': 5.25748374}), ('CTCF', 'PEX14', {'Edge weight': 5.244555586}), ('CTCF', 'MTERF1', {'Edge weight': 5.161205282}), ('CTCF', 'WDR38', {'Edge weight': 5.150135929}), ('CTCF', 'EXOC3', {'Edge weight': 5.13520316}), ('CTCF', 'GALNT14', {'Edge weight': 5.028381857}), ('CTCF', 'DNAJA2', {'Edge weight': 4.962781568}), ('CTCF', 'CLDN5', {'Edge weight': 4.952933558}), ('CTCF', 'RNF141', {'Edge weight': 4.926065594}), ('CTCF', 'IDI1', {'Edge weight': 4.919275664}), ('CTCF', 'PROZ', {'Edge weight': 4.913760593}), ('CTCF', 'WDR33', {'Edge weight': 4.904654867}), ('CTCF', 'EHD4', {'Edge weight': 4.8730601}), ('CTCF', 'FCHSD2', {'Edge weight': 4.860749565}), ('CTCF', 'SIRPB1', {'Edge weight': 4.826498179}), ('CTCF', 'C1QTNF9', {'Edge weight': 4.787044575}), ('CTCF', 'CLUL1', {'Edge weight': 4.784811436}), ('CTCF', 'CIDEB', {'Edge weight': 4.758721639}), ('CTCF', 'LCK', {'Edge weight': 4.746933949}), ('CTCF', 'MYT1', {'Edge weight': 4.732110604}), ('CTCF', 'RPL32', {'Edge weight': 4.68976057}), ('CTCF', 'WDR18', {'Edge weight': 4.558750649}), ('CTCF', 'TPRA1', {'Edge weight': 4.543565005}), ('CTCF', 'IRF9', {'Edge weight': 4.477852503}), ('CTCF', 'C4orf46', {'Edge weight': 4.476551804}), ('CTCF', 'RANBP1', {'Edge weight': 4.463310947}), ('CTCF', 'PYCARD', {'Edge weight': 4.452061638}), ('CTCF', 'CCDC103', {'Edge weight': 4.44698447}), ('CTCF', 'DDX5', {'Edge weight': 4.44587959}), ('CTCF', 'TNKS1BP1', {'Edge weight': 4.444193483}), ('CTCF', 'PDCD2', {'Edge weight': 4.432143172}), ('CTCF', 'ITPK1', {'Edge weight': 4.427522081}), ('CTCF', 'CRYBG3', {'Edge weight': 4.424935065}), ('CTCF', 'BRICD5', {'Edge weight': 4.419022364}), ('CTCF', 'FAM76B', {'Edge weight': 4.398911496}), ('CTCF', 'SSR4', {'Edge weight': 4.398353806}), ('CTCF', 'TMC7', {'Edge weight': 4.391277836}), ('CTCF', 'PGAM5', {'Edge weight': 4.384187385}), ('CTCF', 'DOK3', {'Edge weight': 4.361056903}), ('CTCF', 'MMP28', {'Edge weight': 4.343911666}), ('CTCF', 'CHST7', {'Edge weight': 4.333940537}), ('CTCF', 'HGD', {'Edge weight': 4.316244853}), ('CTCF', 'CCAR2', {'Edge weight': 4.308987869}), ('CTCF', 'MYDGF', {'Edge weight': 4.292820389}), ('CTCF', 'CAPRIN2', {'Edge weight': 4.279082899}), ('CTCF', 'GGTLC1', {'Edge weight': 4.270579238}), ('CTCF', 'TUSC2', {'Edge weight': 4.268269907}), ('CTCF', 'TNFRSF14', {'Edge weight': 4.256606633}), ('CTCF', 'ERI1', {'Edge weight': 4.25259234}), ('CTCF', 'SMIM5', {'Edge weight': 4.251312918}), ('CTCF', 'CCS', {'Edge weight': 4.217617263}), ('CTCF', 'JMJD4', {'Edge weight': 4.194858958}), ('CTCF', 'CDK10', {'Edge weight': 4.193333343}), ('CTCF', 'CRYA ...

# %%
import matplotlib.pyplot as plt

# Set a layout for the graph
pos = nx.spring_layout(G)

# Draw the graph
nx.draw(G, pos, with_labels=True, node_size=700, node_color="lightblue")

# Draw edge labels to show weights
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.show()

# %%
#let's try running another file with TF-genes

# %%
# Create a directed graph with weights directly from the edge list
G = nx.from_pandas_edgelist(df_MCF7_all_TF, source='Source', target='Target', edge_attr='Edge weight', create_using=nx.DiGraph())

# Check the graph's nodes and edges
print("Nodes:", G.nodes())
print("Edges:", G.edges(data=True))
# Out:
# Nodes: ['IRX6', 'MEOX2', 'IRX4', 'FIGN', 'ZNF180', 'TTC27', 'ZHX1', 'ZNF432', 'ZNF880', 'KDM2B', 'E4F1', 'PRDM9', 'ZBTB7B', 'ZNF383', 'ZNF341', 'ZNF385D', 'SCN1A', 'SIM1', 'GMEB1', 'TFDP3', 'NPAS1', 'NPAS3', 'CREM', 'SIM2', 'ATF6', 'ZNF287', 'NAIF1', 'HIF3A', 'EPAS1', 'ZNF571', 'SIX2', 'FOXK1', 'ZNF529', 'BARHL2', 'GMEB2', 'PODN', 'ZNF774', 'OVOL2', 'ZNF784', 'ZBTB2', 'RUNX2', 'ZNF792', 'XBP1', 'SIX4', 'MYBL2', 'ZNF846', 'NR5A2', 'TERF2', 'MTRNR2L1', 'HOXB1', 'MLX', 'PAX3', 'ZNF467', 'NKX6-2', 'PAX9', 'PROX2', 'ASCL2', 'FOXN2', 'ZNF444', 'RAB40A', 'ZNF501', 'ZNF148', 'ZNF283', 'RUNX3', 'ZNF71', 'CREB3L4', 'CREB3L1', 'IP6K2', 'CREBZF', 'LBX2', 'CREBL2', 'HOXA4', 'HIF1A', 'LHX8', 'NANOG', 'PAX8', 'ZFP57', 'LIN28A', 'HOXA2', 'ZBTB32', 'ZNF484', 'NFYA', 'PRSS3', 'TET1', 'SMAD5', 'KCNE1B', 'ETV5', 'TBX3', 'PROX1', 'ZNF263', 'CREB3L2', 'PAX1', 'LIN28B', 'LHX6', 'RFX6', 'ARNT', 'ARNTL2', 'ZNF267', 'HOXC11', 'HOXA5', 'ZNF304', 'ZNF235']
# Edges: [('IRX6', 'MEOX2', {'Edge weight': 64.13006049}), ('IRX6', 'FIGN', {'Edge weight': 60.46431409}), ('IRX6', 'SCN1A', {'Edge weight': 44.4363919}), ('IRX6', 'PODN', {'Edge weight': 39.59363071}), ('IRX6', 'RAB40A', {'Edge weight': 35.70807572}), ('MEOX2', 'MEOX2', {'Edge weight': 32.69678206}), ('IRX4', 'MEOX2', {'Edge weight': 63.92039414}), ('IRX4', 'FIGN', {'Edge weight': 60.08728435}), ('IRX4', 'SCN1A', {'Edge weight': 43.79222584}), ('IRX4', 'PODN', {'Edge weight': 39.54660926}), ('IRX4', 'RAB40A', {'Edge weight': 35.21648943}), ('ZNF180', 'TTC27', {'Edge weight': 59.87985029}), ('ZHX1', 'FIGN', {'Edge weight': 57.88618888}), ('ZHX1', 'MEOX2', {'Edge weight': 57.72539242}), ('ZHX1', 'SCN1A', {'Edge weight': 37.67282147}), ('ZHX1', 'PODN', {'Edge weight': 33.88862042}), ('ZNF432', 'TTC27', {'Edge weight': 55.04352906}), ('ZNF880', 'TTC27', {'Edge weight': 54.27055805}), ('KDM2B', 'MEOX2', {'Edge weight': 49.45204761}), ('KDM2B', 'FIGN', {'Edge weight': 49.43493209}), ('KDM2B', 'SCN1A', {'Edge weight': 32.94005769}), ('E4F1', 'MEOX2', {'Edge weight': 48.18789047}), ('E4F1', 'FIGN', {'Edge weight': 46.91270523}), ('PRDM9', 'TTC27', {'Edge weight': 47.30134524}), ('ZBTB7B', 'TTC27', {'Edge weight': 46.63201082}), ('ZNF383', 'TTC27', {'Edge weight': 46.03739995}), ('ZNF341', 'TTC27', {'Edge weight': 45.75288347}), ('ZNF385D', 'MEOX2', {'Edge weight': 45.10192799}), ('ZNF385D', 'FIGN', {'Edge weight': 43.35260725}), ('SIM1', 'MEOX2', {'Edge weight': 43.0681093}), ('SIM1', 'FIGN', {'Edge weight': 41.34789946}), ('GMEB1', 'TFDP3', {'Edge weight': 42.67734926}), ('GMEB1', 'FIGN', {'Edge weight': 33.32462217}), ('GMEB1', 'MEOX2', {'Edge weight': 32.50135497}), ('NPAS1', 'MEOX2', {'Edge weight': 42.58098396}), ('NPAS1', 'FIGN', {'Edge weight': 40.73623635}), ('NPAS3', 'MEOX2', {'Edge weight': 42.37866116}), ('NPAS3', 'FIGN', {'Edge weight': 40.55128098}), ('CREM', 'MEOX2', {'Edge weight': 42.17796378}), ('CREM', 'FIGN', {'Edge weight': 41.85674045}), ('SIM2', 'MEOX2', {'Edge weight': 42.07394236}), ('SIM2', 'FIGN', {'Edge weight': 40.22998899}), ('ATF6', 'FIGN', {'Edge weight': 41.95812325}), ('ATF6', 'MEOX2', {'Edge weight': 37.96987852}), ('ZNF287', 'TTC27', {'Edge weight': 41.92650203}), ('ZNF287', 'IP6K2', {'Edge weight': 34.69668122}), ('NAIF1', 'FIGN', {'Edge weight': 41.64239588}), ('NAIF1', 'MEOX2', {'Edge weight': 40.58651403}), ('HIF3A', 'MEOX2', {'Edge weight': 41.63183584}), ('HIF3A', 'FIGN', {'Edge weight': 39.7687658}), ('EPAS1', 'MEOX2', {'Edge weight': 41.52796458}), ('EPAS1', 'FIGN', {'Edge weight': 39.86449028}), ('ZNF571', 'TTC27', {'Edge weight': 41.38853681}), ('SIX2', 'MEOX2', {'Edge weight': 41.08916057}), ('SIX2', 'FIGN', {'Edge weight': 39.34492189}), ('FOXK1', 'FIGN', {'Edge weight': 40.29324567}), ('FOXK1', 'MEOX2', {'Edge weight': 38.40155739}), ('ZNF529', 'TTC27', {'Edge weight': 40.22918509}), ('BARHL2', 'FIGN', {'Edge weight': 40.06281519}), ('BARHL2', 'MEOX2', {'Edge weight': 34.03877387}), ('GMEB2', 'FIGN', {'Edge weight': 40.01242128}), ('GMEB2', 'MEOX2', {'Edge weight': 34.74236467}), ('ZNF774', 'TTC27', {'Edge weight': 38.96429854}), ('OVOL2', 'MEOX2', {'Edge weight': 38.58704123}), ('OVOL2', 'FIGN', {'Edge weight': 36.56408606}), ('ZNF784', 'FIGN', {'Edge weight': 38.4337596}), ('ZNF784', 'MEOX2', {'Edge weight': 33.86446224}), ('ZBTB2', 'MEOX2', {'Edge weight': 38.39728229}), ('ZBTB2', 'FIGN', {'Edge weight': 35.77564107}), ('RUNX2', 'FIGN', {'Edge weight': 38.37454645}), ('RUNX2', 'MEOX2', {'Edge weight': 35.99145641}), ('ZNF792', 'TTC27', {'Edge weight': 38.34104578}), ('XBP1', 'MEOX2', {'Edge weight': 38.28465295}), ('XBP1', 'FIGN', {'Edge weight': 36.74521801}), ('SIX4', 'MEOX2', {'Edge weight': 37.59602441}), ('SIX4', 'FIGN', {'Edge weight': 33.57229999}), ('MYBL2', 'FIGN', {'Edge weight': 37.56421295}), ('MYBL2', 'MEOX2', {'Edge weight': 35.56235554}), ('ZNF846', 'MEOX2', {'Edge weight': 37.28208455}), ('ZNF846', 'FIGN', {'Edge weight': 35.46746955}), ('NR5A2', 'FIGN', {'Edge weight': ...

# %%
import matplotlib.pyplot as plt

# Set a layout for the graph
pos = nx.spring_layout(G)

# Draw the graph
nx.draw(G, pos, with_labels=True, node_size=700, node_color="lightblue")

# Draw edge labels to show weights
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.show()

# %%
import matplotlib.pyplot as plt

# Set a layout for the graph
pos = nx.spring_layout(G)

# Separate the nodes into "Source" and "Target"
source_nodes = set(df_MCF7_all_TF['Source'])
target_nodes = set(df_MCF7_all_TF['Target'])

# Draw the graph with different colors for source and target nodes
nx.draw(G, pos, with_labels=True, node_size=700, nodelist=source_nodes, node_color="blue")
nx.draw(G, pos, with_labels=True, node_size=700, nodelist=target_nodes, node_color="red")

# Draw edge labels to show weights
edge_labels = nx.get_edge_attributes(G, 'Edge weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.show()
