# %% [markdown]
# <a href="https://colab.research.google.com/github/Guliko24/NetZoo_network/blob/main/GRN_31_combined_graphs_MCF7_vs_MDA_simulations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import all the packages as needed
import pandas as pd
import networkx as nx

# %%
# prompt: let's load Gdrive onto notebook

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Navigate to your Google Drive files
# %cd /content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets
# Out:
# /content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets

# %%
import numpy as np
import pandas as pd

def log_scale_dataframe(df):
    """Applies log scaling transformation to a TF-gene interaction DataFrame."""
    return np.sign(df) * np.log1p(np.abs(df))

def reverse_log_scale_dataframe(scaled_df):
    """Reverses log scaling transformation for a DataFrame."""
    return np.sign(scaled_df) * (np.expm1(np.abs(scaled_df)))


def filter_by_threshold(matrix: pd.DataFrame, threshold: float, mode: str = 'greater') -> pd.DataFrame:
    """
    Filter the matrix based on a threshold.
    Parameters:
        matrix: The TF vs Genes interaction matrix.
        threshold: The threshold value for filtering.
        mode: 'greater' to keep values greater than threshold, 'less' to keep values less than threshold.
    """
    if mode == 'greater':
        return matrix[matrix > threshold].fillna(0)
    elif mode == 'less':
        return matrix[matrix < threshold].fillna(0)
    else:
        raise ValueError("Mode must be either 'greater' or 'less'")

def binarize_matrix(matrix: pd.DataFrame, threshold: float) -> pd.DataFrame:
    """
    Binarize the matrix based on a threshold.
    Values greater than or equal to the threshold become 1, otherwise 0.
    """
    binary_matrix = (matrix >= threshold).astype(int)
    return binary_matrix

def rank_interactions(matrix: pd.DataFrame, top_n: int = 5) -> pd.DataFrame:
    """
    Rank the top N interactions for each transcription factor.
    Parameters:
        matrix: The TF vs Genes interaction matrix.
        top_n: Number of top interactions to return for each TF.
    """
    ranked_interactions = pd.DataFrame()
    for tf in matrix.index:
        top_genes = matrix.loc[tf].nlargest(top_n)
        ranked_interactions = pd.concat([ranked_interactions, top_genes], axis=1)
    return ranked_interactions.T

def aggregate_interactions(matrix: pd.DataFrame, axis: int = 0) -> pd.Series:
    """
    Aggregate interaction strengths.
    Parameters:
        axis: 0 to aggregate across genes (per TF), 1 to aggregate across TFs (per Gene).
    """
    return matrix.sum(axis=axis)

def construct_interaction_network(matrix: pd.DataFrame, threshold: float) -> pd.DataFrame:
    """
    Construct an interaction network by keeping only interactions above a threshold.
    Returns a DataFrame representing edges in the network.
    """
    filtered_matrix = filter_by_threshold(matrix, threshold, mode='greater')
    edges = []
    for tf in filtered_matrix.index:
        for gene in filtered_matrix.columns:
            if filtered_matrix.loc[tf, gene] > 0:
                edges.append((tf, gene, filtered_matrix.loc[tf, gene]))
    network_df = pd.DataFrame(edges, columns=['TF', 'Gene', 'Interaction_Strength'])
    return network_df

def split_positive_negative_matrices(matrix: pd.DataFrame) -> (pd.DataFrame, pd.DataFrame):
    """
    Split the matrix into two DataFrames: one for positive values and one for negative values.
    Ensure that the matrix values are numeric by coercing errors and replacing non-numeric values with NaN.
    Retain the index and columns in both matrices.
    """
    matrix_numeric = matrix.apply(pd.to_numeric, errors='coerce')
    positive_matrix = matrix_numeric.where(matrix_numeric > 0).fillna(0)
    negative_matrix = matrix_numeric.where(matrix_numeric < 0).fillna(0)
    positive_matrix.index = matrix.index
    positive_matrix.columns = matrix.columns
    negative_matrix.index = matrix.index
    negative_matrix.columns = matrix.columns
    return positive_matrix, negative_matrix

def check_repeated_indices_columns(matrix: pd.DataFrame):
    """
    Check for repeated transcription factors (rows) and genes (columns) in the matrix.
    """
    repeated_rows = matrix.index[matrix.index.duplicated()].unique()
    repeated_columns = matrix.columns[matrix.columns.duplicated()].unique()

    print("Repeated Rows (TFs):")
    if len(repeated_rows) > 0:
        print(repeated_rows)
    else:
        print("No repeated rows found.")

    print("\nRepeated Columns (Genes):")
    if len(repeated_columns) > 0:
        print(repeated_columns)
    else:
        print("No repeated columns found.")

# %% [markdown]
# # **1. Let's process the gene expression data set GSE73857 dataset for MCF7 and MDA-MB231 cells**

# %% [markdown]
# *the* oridinal *gene* expression count file had ENSEMBL id for genes instead of their names, so I use R studio and Biomart package to find the gene names and add as an additional column, however it seems that there are unannotated genes which we need to remove later on.
# the data set also had experimental duplicates for MCF7 and triplicates for MDA-MB231 cells so I averaged them. I could have done student-T test and find significantly different genes, but I went ahead with averaging and calculating fold-change.

# %%
import pandas as pd

# Load RNA-seq data
df = pd.read_csv("/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/GSE73857_MCF7_MDA_gene_expression.txt", sep="\t")  # Replace with your RNA-seq file



# Step 1: Remove the `ensembl.id` column
if "ensembl.id" in df.columns:
    df.drop(columns=["ensembl.id"], inplace=True)

# Step 2: Move the `gene_name` column to be the first column
if "gene_name" in df.columns:
    gene_name_column = df.pop("gene_name")  # Remove and retrieve `gene.name` column
    df.insert(0, "gene_name", gene_name_column)  # Insert it as the first column

# Step 3: Set `gene_name` as the index
df.set_index("gene_name", inplace=True)


# Step 1: Calculate averages
MCF7_average = df.iloc[:, [0, 1]].mean(axis=1)
MDA_MB231_average = df.iloc[:, [2, 3, 4]].mean(axis=1)

# Step 2: Drop the original columns
df.drop(df.columns[[0, 1, 2, 3, 4]], axis=1, inplace=True)

# Step 3: Add the new averaged columns
df["MCF7"] = MCF7_average
df["MDA-MB231"] = MDA_MB231_average

# Step 1: Remove rows where both `MCF7` and `MDA-MB231` have zero expression
MCF7_MDA_filtered_expression = df[(df["MCF7"] != 0) | (df["MDA-MB231"] != 0)]

# %%
MCF7_MDA_filtered_expression.head()
# Out:
#                MCF7    MDA-MB231
# gene_name
# TSPAN6      494.000  1198.373333
# DPM1       4458.000  2367.000000
# SCYL3       851.405   406.156667
# FIRRM      1408.270  1153.816667
# FGR           0.000     0.333333

# %%
MCF7_MDA_filtered_expression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40677 entries, TSPAN6 to nan
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MCF7       40677 non-null  float64
#  1   MDA-MB231  40677 non-null  float64
# dtypes: float64(2)
# memory usage: 953.4+ KB

# %% [markdown]
# # **2. Lets check whether there are differently expressed genes between two cell line so I could narrow down my graphs, by checking the fold change:**

# %%
import pandas as pd
import numpy as np



# Step 1: Separate rows with zero expression for further investigation
zero_expression_genes = MCF7_MDA_filtered_expression[
    (MCF7_MDA_filtered_expression['MCF7'] == 0) | (MCF7_MDA_filtered_expression['MDA-MB231'] == 0)
].copy()

# Save genes with zero expression to a new file
zero_expression_genes.to_csv("zero_expression_genes.tsv", sep="\t", index=False)

# Step 2: Filter out rows with zero expression from the original DataFrame
MCF7_MDA_filtered_expression_no_zeros = MCF7_MDA_filtered_expression[
    (MCF7_MDA_filtered_expression['MCF7'] != 0) & (MCF7_MDA_filtered_expression['MDA-MB231'] != 0)
].copy()

# Step 3: Calculate fold change and log2 fold change
MCF7_MDA_filtered_expression_no_zeros['fold_change'] =MCF7_MDA_filtered_expression_no_zeros['MDA-MB231'] / MCF7_MDA_filtered_expression_no_zeros['MCF7']
MCF7_MDA_filtered_expression_no_zeros.replace([np.inf, -np.inf], np.nan, inplace=True)  # Replace inf with NaN
MCF7_MDA_filtered_expression_no_zeros.dropna(subset=['fold_change'], inplace=True)  # Drop rows with NaN in fold_change
MCF7_MDA_filtered_expression_no_zeros['log2_fold_change'] = np.log2(MCF7_MDA_filtered_expression_no_zeros['fold_change'])

# Step 4: Filter for significant fold change (e.g., >2 or <0.5)
significant_genes = MCF7_MDA_filtered_expression_no_zeros[
    (MCF7_MDA_filtered_expression_no_zeros['fold_change'] > 2) | (MCF7_MDA_filtered_expression_no_zeros['fold_change'] < 0.5)
]

# Save the cleaned DataFrame and significant genes to new files
MCF7_MDA_filtered_expression_no_zeros.to_csv("cleaned_gene_expression.tsv", sep="\t", index=False)
significant_genes.to_csv("significant_genes.tsv", sep="\t", index=False)

print("Files generated:")
print("1. 'zero_expression_genes.tsv' for further investigation.") #####this is an important file as it may show which genes switched on/off
print("2. 'cleaned_gene_expression.tsv' with cleaned data.")#####this is a file which has zero expression genes removed
print("3. 'significant_genes.tsv' with significant fold change.")####this is a file which as 2 fold change and 0.5 fold chane between 2 cell lines
# Out:
# Files generated:
# 1. 'zero_expression_genes.tsv' for further investigation.
# 2. 'cleaned_gene_expression.tsv' with cleaned data.
# 3. 'significant_genes.tsv' with significant fold change.

# %%
significant_genes.head()
# Out:
#               MCF7    MDA-MB231  fold_change  log2_fold_change
# gene_name
# TSPAN6     494.000  1198.373333     2.425857          1.278494
# SCYL3      851.405   406.156667     0.477043         -1.067809
# CFH          1.000   840.653333   840.653333          9.715367
# STPG1      119.010   406.240000     3.413495          1.771249
# NIPAL3     563.490  2629.426667     4.666324          2.222286

# %%
# Remove rows with NaN in the index (gene names)
# Remove rows with NaN in the index (if gene names are in the index)
significant_genes_cleaned = significant_genes[~significant_genes.index.isnull()]

# Save the cleaned significant genes to a new file
significant_genes_cleaned.to_csv("significant_genes_cleaned.tsv", sep="\t")

print("Significant genes with NaN in gene names removed. Saved to 'significant_genes_cleaned.tsv'.")
# Out:
# Significant genes with NaN in gene names removed. Saved to 'significant_genes_cleaned.tsv'.

# %%
significant_genes_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10031 entries, TSPAN6 to LOC730668
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MCF7              10031 non-null  float64
#  1   MDA-MB231         10031 non-null  float64
#  2   fold_change       10031 non-null  float64
#  3   log2_fold_change  10031 non-null  float64
# dtypes: float64(4)
# memory usage: 391.8+ KB

# %% [markdown]
# # **3. Let's modify our TF-Gene matrices per cell line keeping only the genes found in significant_genes_cleaned**

# %%
#let's read the MCF7_TF_Genes dataset and make changes
df_MCF7_TF_Genes = pd.read_csv('/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/ACH-000019_TF_vs_Genes_total expression.csv', index_col=0)
df_MDA_MB231_TF_Genes=pd.read_csv('/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/ACH-000768.csv', index_col=0)
#df_gene_expression=pd.read_csv('/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/CCLE_expression_withinSample.csv', index_col=0)
#

# %%
# Step 1: Load the TF-genes matrix and the filtered gene list
#df_MCF7_TF_Genes ===matrix
#df_MDA_MB231_TF_Genes ===matrix
#MCF7_MDA_filtered_expression===gene expression file



# Extract the gene names from df_filtered
filtered_genes = set(significant_genes_cleaned.index)  # Assuming `gene_name` is the column with gene names

# Step 3: Filter the columns of the TF-genes matrix
MCF7_filtered_tf_gene_matrix = df_MCF7_TF_Genes.loc[:, df_MCF7_TF_Genes.columns.isin(filtered_genes)]
MDA_MB231_filtered_tf_gene_matrix = df_MDA_MB231_TF_Genes.loc[:, df_MDA_MB231_TF_Genes.columns.isin(filtered_genes)]

# %%
MCF7_filtered_tf_gene_matrix.info()
MDA_MB231_filtered_tf_gene_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1132 entries, AHR to ZSCAN9
# Columns: 6445 entries, A1BG to TMEM92
# dtypes: float64(6445)
# memory usage: 55.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1132 entries, AHR to ZSCAN9
# Columns: 7229 entries, A1BG to ZZZ3
# dtypes: float64(7229)
# memory usage: 62.4+ MB

# %% [markdown]
# # **4. Lets approach this slightly differently; lets rank genes based on log2_fold_change in the significant_genes_cleaned file. Then select top 300 upregulated genes and top 300 downregulated genes and only then use these for graph construction**

# %%
import pandas as pd


# Sort genes by log2 fold change (descending)
ranked_genes = significant_genes_cleaned.sort_values(
    by="log2_fold_change", ascending=False
)

# Save the ranked genes to a new file
ranked_genes.to_csv("ranked_significant_genes_cleaned.csv", index=False)

# Display top upregulated and downregulated genes
top_upregulated = ranked_genes.head(300)  # Top 300 overexpressed genes
top_downregulated = ranked_genes.tail(300)  # Top 300 downexpressed genes

print("Top 300 Upregulated Genes:")
print(top_upregulated)

print("\nTop 300 Downregulated Genes:")
print(top_downregulated)
# Out:
# Top 300 Upregulated Genes:
#            MCF7    MDA-MB231  fold_change  log2_fold_change
# gene_name
# TNFRSF10D   0.5  2168.643333  4337.286667         12.082577
# CD40        0.5  1843.333333  3686.666667         11.848101
# ATP10D      0.5  1417.743333  2835.486667         11.469381
# STAC        0.5  1268.000000  2536.000000         11.308339
# TCEAL9      1.0  2219.333333  2219.333333         11.115911
# ...         ...          ...          ...               ...
# GCNT2      27.5  4943.076667   179.748242          7.489834
# APOL1       4.5   806.653333   179.256296          7.485880
# MCAM       21.0  3759.760000   179.036190          7.484107
# KLRC2       0.5    89.486667   178.973333          7.483601
# ME3        12.0  2131.666667   177.638889          7.472804
#
# [300 rows x 4 columns]
#
# Top 300 Downregulated Genes:
#                MCF7  MDA-MB231  fold_change  log2_fold_change
# gene_name
# HUNK        203.500   1.236667     0.006077         -7.362428
# RUBCNL      110.000   0.666667     0.006061         -7.366322
# HOXA4       110.215   0.666667     0.006049         -7.369139
# HOXC13      886.945   5.333333     0.006013         -7.377663
# PDIA2       112.000   0.666667     0.005952         -7.392317
# ...             ...        ...          ...               ...
# RBBP8NL     737.000   0.333333     0.000452        -11.110483
# H2AC25      780.080   0.333333     0.000427        -11.192441
# XYLT1       845.000   0.333333     0.000394        -11.307770
# IRX2        952.190   0.336667     0.000354        -11.465713
# CEACAM5    1614.075   0.373333     0.000231        -12.077956
#
# [300 rows x 4 columns]

# %% [markdown]
# # **5. Filter the TF-Gene matrix to contain top 300 upregulated and top 300 downregulated genes per cell line**

# %%
# Ensure gene names are not used as index
if top_upregulated.index.name == 'gene_name':
    top_upregulated.reset_index(inplace=True)
if top_downregulated.index.name == 'gene_name':
    top_downregulated.reset_index(inplace=True)

# %%
# Combine the two lists
combined_genes_upregulated_downregulated = pd.concat([top_upregulated, top_downregulated], ignore_index=True)

combined_genes_upregulated_downregulated.head()
# Out:
#    gene_name  MCF7    MDA-MB231  fold_change  log2_fold_change
# 0  TNFRSF10D   0.5  2168.643333  4337.286667         12.082577
# 1       CD40   0.5  1843.333333  3686.666667         11.848101
# 2     ATP10D   0.5  1417.743333  2835.486667         11.469381
# 3       STAC   0.5  1268.000000  2536.000000         11.308339
# 4     TCEAL9   1.0  2219.333333  2219.333333         11.115911

# %%
combined_genes_upregulated_downregulated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gene_name         600 non-null    object
#  1   MCF7              600 non-null    float64
#  2   MDA-MB231         600 non-null    float64
#  3   fold_change       600 non-null    float64
#  4   log2_fold_change  600 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 23.6+ KB

# %% [markdown]
# # The files we generate below may be important in the future if we want to split positive and negative graphs per cell line again

# %%
import pandas as pd
#df_MCF7_TF_Genes ===matrix
#df_MDA_MB231_TF_Genes ===matrix
#top_upregulated = ranked_genes.head(300)  # Top 300 overexpressed genes
#top_downregulated = ranked_genes.tail(300)  # Top 300 downexpressed genes



# Filter the TF-Gene matrix for upregulated genes
#MCF7_upregulated_matrix = df_MCF7_TF_Genes.loc[:, df_MCF7_TF_Genes.columns.isin(top_upregulated)]
#MDA_MB231_upregulated_matrix = df_MDA_MB231_TF_Genes.loc[:, df_MDA_MB231_TF_Genes.columns.isin(top_upregulated)]

# Filter the TF-Gene matrix for downregulated genes
#MCF7_downregulated_matrix = df_MCF7_TF_Genes.loc[:, df_MCF7_TF_Genes.columns.isin(top_downregulated)]
#MDA_MB231_downregulated_matrix = df_MDA_MB231_TF_Genes.loc[:, df_MDA_MB231_TF_Genes.columns.isin(top_downregulated)]


# Save the filtered matrices
#MCF7_upregulated_matrix.to_csv("MCF7_upregulated_tf_gene_matrix.tsv", sep="\t")
#MCF7_downregulated_matrix.to_csv("MCF7_downregulated_tf_gene_matrix.tsv", sep="\t")
#MDA_MB231_upregulated_matrix.to_csv("MDA_MB231_upregulated_tf_gene_matrix.tsv", sep="\t")
#MDA_MB231_downregulated_matrix.to_csv("MDA_MB231_downregulated_tf_gene_matrix.tsv", sep="\t")

#print("Filtered matrices saved.")

# %% [markdown]
# # **BUILDING GRAPHS**:
# -> lets combine top 300 upregulated and top 300 downregulated genes
#
# -> filter the Tf-gene matrix based on these genes per cell line (MCf7 and MDA_MB231)
#
# -> build the graphs with NetworkX and visualize
#
# -> Do GSP with PyGSP

# %% [markdown]
# # **1) Combine gene list and fiter the matrix**

# %%
import pandas as pd



# combined gene list is 'combined_genes_upregulated_downregulated'
# Filter the matrices using the combined gene list
selected_genes = combined_genes_upregulated_downregulated['gene_name'].tolist()


# Filter the matrices to keep only the selected genes as columns
filtered_matrix_mcf7_combined_edges = df_MCF7_TF_Genes.loc[:, df_MCF7_TF_Genes.columns.isin(selected_genes)]
filtered_matrix_mda_combined_edges= df_MDA_MB231_TF_Genes.loc[:, df_MDA_MB231_TF_Genes.columns.isin(selected_genes)]

# Save the filtered matrices for reference
filtered_matrix_mcf7_combined_edges.to_csv("filtered_matrix_mcf7_combined_edges.tsv", sep="\t")
filtered_matrix_mda_combined_edges.to_csv("filtered_matrix_mda_combined_edges.tsv", sep="\t")

print("Filtered matrices saved.")
# Out:
# Filtered matrices saved.

# %%
filtered_matrix_mcf7_combined_edges.head()
# Out:
#         ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# Row
# AHR  -1.089553 -0.795315  0.219303 -0.853007  0.399470 -1.630741  0.290181
# AHRR -0.986674 -0.700822  0.392719 -0.701782  0.527235 -1.661367  0.493583
# AIRE  0.265959 -1.189028 -0.789297  1.062564 -1.320127  2.068158 -1.493547
# ALX1  0.388290 -1.544013 -1.692139 -1.567756 -1.144992  0.850550 -1.189983
# ALX3 -1.169286 -1.528565 -1.913900 -1.577865 -1.383676  0.547645 -0.422447
#
#       ADAMTS19     ADCY1     ADCY5  ...      TLR4    TM4SF1   TM4SF18  \
# Row                                 ...
# AHR  -1.703381 -1.947731 -2.183788  ... -1.020596 -1.899293 -1.735155
# AHRR -1.492458 -1.692178 -1.953388  ... -1.257743 -1.675511 -1.762027
# AIRE  0.400128  0.110629  1.216715  ... -0.363425 -1.296714  0.111233
# ALX1 -1.292651 -1.751564 -1.385865  ...  1.290326 -0.197852  1.397905
# ALX3 -1.874142 -2.057815 -2.036447  ...  1.891228 -1.729117  0.000001
#
#        TMEM125   TMEM156  TMEM178B    TMEM26   TMEM30B    TMEM71    TMEM92
# Row
# AHR  -0.464616 -0.088311  0.546081 -1.327963 -1.899040 -1.944349 -0.818321
# AHRR -0.336651 -0.162217  0.729568 -1.273587 -1.976856 -1.943266 -0.680559
# AIRE -0.754813  0.276227 -0.464796  2.755469  0.743904  0.603933 -0.703877
# ALX1 -2.600899  2.596896 -1.944171  1.328845  2.033929 -0.070829 -2.532883
# ALX3 -1.674775  0.283685 -1.568709  2.271090  1.326684 -0.644946 -2.533361
#
# [5 rows x 483 columns]

# %%
filtered_matrix_mcf7_combined_edges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1132 entries, AHR to ZSCAN9
# Columns: 483 entries, ABCA12 to TMEM92
# dtypes: float64(483)
# memory usage: 4.2+ MB

# %%
filtered_matrix_mda_combined_edges.head()
# Out:
#         ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# Row
# AHR   0.304008 -0.667807  1.200416 -0.936033  0.182179 -1.235324 -1.395829
# AHRR  0.247151 -0.587696  1.293375 -0.796551  0.328368 -1.308294 -1.069268
# AIRE  0.874790 -1.013267  0.275668  0.100357 -1.201515  2.453961 -2.109349
# ALX1  1.901858 -1.362818 -0.506440 -1.288876 -1.512983  1.082257 -2.706565
# ALX3  0.740310 -1.202866 -0.330167 -1.513954 -1.692206  0.859158 -2.328144
#
#       ADAMTS19     ADCY1     ADCY5  ...    ZNF501    ZNF502   ZNF518B  \
# Row                                 ...
# AHR  -0.644775 -2.041014 -1.388207  ... -2.349634 -2.064601 -1.247681
# AHRR -0.484905 -1.789929 -1.243058  ... -2.141010 -2.002920 -1.431786
# AIRE -0.805395 -0.436276  1.693876  ... -1.956179  1.233329  0.527247
# ALX1 -0.351387 -1.688240 -0.205509  ... -3.467904 -0.405839  0.920343
# ALX3 -1.254828 -2.147329 -0.570023  ... -3.229053  0.866085  0.700537
#
#         ZNF521    ZNF577    ZNF630    ZNF655     ZNF71    ZNF711    ZNF732
# Row
# AHR  -1.421086 -0.907489 -1.347365 -1.693050 -1.362386 -2.278187  0.146711
# AHRR -1.178416 -0.893068 -1.137283 -1.451020 -1.081178 -2.225300  0.240623
# AIRE -0.029944  0.523460 -1.969279 -2.275027 -2.057922 -0.475194  1.937781
# ALX1 -1.910685 -0.323486 -0.789209 -0.803448 -2.291393  1.893416 -0.187331
# ALX3 -1.929038 -0.656320 -1.514953 -2.219323 -2.912750  2.325852  0.511644
#
# [5 rows x 535 columns]

# %%
filtered_matrix_mda_combined_edges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1132 entries, AHR to ZSCAN9
# Columns: 535 entries, ABCA12 to ZNF732
# dtypes: float64(535)
# memory usage: 4.6+ MB

# %% [markdown]
# # We still have 1132 entries for TFs, let's trim this down based on the article we found at https://www.academia.edu/62149166/Identification_of_novel_dysregulated_key_genes_in_Breast_cancer_through_high_throughput_ChIP_Seq_data_analysis .
# # I have generated a csv file with 20 TF from this article and added CTCF to the list as I have an interest in it

# %%
import pandas as pd
import os

# File paths
tf_file = "/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/Breast_Cancer_TFs.csv"
ppi_file = "/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/ppi_complete.txt"
output_file = "filtered_ppi.tsv"

# Validate file paths
if not os.path.exists(tf_file):
    raise FileNotFoundError(f"TF file not found: {tf_file}")
if not os.path.exists(ppi_file):
    raise FileNotFoundError(f"PPI file not found: {ppi_file}")

# Load the TF file (CSV format)
print(f"Loading TF file: {tf_file}")
tf_df = pd.read_csv(tf_file)

# Check if the expected column exists
if 'Gene/Transcription Factor' not in tf_df.columns:
    raise KeyError("Column 'Gene/Transcription Factor' not found in TF file.")

# Get the list of transcription factors
tf_list = tf_df['Gene/Transcription Factor'].str.strip().str.upper().tolist()

# Load the PPI file (TXT format)
print(f"Loading PPI file: {ppi_file}")
ppi_df = pd.read_csv(ppi_file, sep="\t", header=None, names=["Protein1", "Protein2", "InteractionStrength"])

# Ensure the expected columns are present
if not all(col in ppi_df.columns for col in ["Protein1", "Protein2", "InteractionStrength"]):
    raise KeyError("Columns 'Protein1', 'Protein2', or 'InteractionStrength' not found in PPI file.")

# Convert PPI proteins to uppercase for case-insensitive matching
ppi_df['Protein1'] = ppi_df['Protein1'].str.strip().str.upper()
ppi_df['Protein2'] = ppi_df['Protein2'].str.strip().str.upper()


# Filter the PPI dataframe to retain rows where Protein1  in the TF list
print("Filtering PPI data...")
filtered_ppi_df = ppi_df[
    (ppi_df['Protein1'].isin(tf_list))
]

#lets try to remove zero interactions to see how small the file will be
filtered_ppi_minus_zero_df = filtered_ppi_df[filtered_ppi_df['InteractionStrength'] != 0]

# Reset the index after filtering
filtered_ppi_minus_zero_df.reset_index(drop=True, inplace=True)
# Save the filtered PPI to a new file
#print(f"Saving filtered PPI to file: {output_file}")
filtered_ppi_df.to_csv(output_file, sep="\t", index=False, header=True)
filtered_ppi_minus_zero_df.to_csv("filtered_ppi_minus_zero.tsv", sep="\t", index=False, header=True)
print(f"Filtered PPI file saved successfully to {output_file}")
# Out:
# Loading TF file: /content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/Breast_Cancer_TFs.csv
# Loading PPI file: /content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/MCF7_raw/ppi_complete.txt
# Filtering PPI data...
# Filtered PPI file saved successfully to filtered_ppi.tsv

# %%
tf_list
# Out:
# ['SOX2',
#  'PPRAG',
#  'CREB1',
#  'STAT5A',
#  'NR2C2',
#  'LEF1',
#  'CREBBP',
#  'ZBED1',
#  'RXRA',
#  'ATF1',
#  'MAFA',
#  'ZNF766',
#  'NFKB1',
#  'NFKB2',
#  'REL',
#  'CENPB',
#  'NPAS4',
#  'ZBTB7A',
#  'PATZ1',
#  'MZF1',
#  'CTCF']

# %% [markdown]
# ## Lets trim our matrices so that they contain the list of TFs from filtered_ppi_minus_zero.df file

# %% [markdown]
# # Lets filter matrix on 20TF and its interacting partners

# %% [markdown]
# # **For MCF7 and MDA**

# %%
import pandas as pd

# Assuming you have already loaded your TF-gene matrix and PPI data frame
# tf_gene_matrix is your TF-gene matrix
# filtered_ppi_minus_zero_df is your PPI data frame
#HERE I decided to expand a little and pull out 18TFs from both protein1 or protein2 in ppi file

# Step 1: Extract unique TFs from both Protein1 and Protein2 columns
unique_tfs_protein1 = filtered_ppi_minus_zero_df['Protein1'].unique()
unique_tfs_protein2 = filtered_ppi_minus_zero_df['Protein2'].unique()

# Step 2: Combine the two lists and remove duplicates
unique_tfs = pd.unique(np.concatenate([unique_tfs_protein1, unique_tfs_protein2]))

# Step 3: Filter the TF-gene matrix to include only rows where the index (TF names) is in unique_tfs
filtered_matrix_mcf7_combined_edges_ppi_TFs = filtered_matrix_mcf7_combined_edges[filtered_matrix_mcf7_combined_edges.index.isin(unique_tfs)]

#Step 4: Name the index column as 'TF'
filtered_matrix_mcf7_combined_edges_ppi_TFs.index.name = 'TF'

# Step 5: Reset the index to make 'TF' a regular column
filtered_matrix_mcf7_combined_edges_ppi_TFs = filtered_matrix_mcf7_combined_edges_ppi_TFs.reset_index()

# Now filtered_tf_gene_matrix contains only the TFs mentioned in either Protein1 or Protein2 of the PPI file
#print(filtered_matrix_mcf7_combined_edges_ppi_TFs)
filtered_matrix_mcf7_combined_edges_ppi_TFs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Columns: 484 entries, TF to TMEM92
# dtypes: float64(483), object(1)
# memory usage: 3.2+ MB

# %%
import pandas as pd

# Assuming you have already loaded your TF-gene matrix and PPI data frame
# tf_gene_matrix is your TF-gene matrix
# filtered_ppi_minus_zero_df is your PPI data frame
#HERE I decided to expand a little and pull out 18TFs from both protein1 or protein2 in ppi file

# Step 1: Extract unique TFs from both Protein1 and Protein2 columns
unique_tfs_protein1 = filtered_ppi_minus_zero_df['Protein1'].unique()
unique_tfs_protein2 = filtered_ppi_minus_zero_df['Protein2'].unique()

# Step 2: Combine the two lists and remove duplicates
unique_tfs = pd.unique(np.concatenate([unique_tfs_protein1, unique_tfs_protein2]))

# Step 3: Filter the TF-gene matrix to include only rows where the index (TF names) is in unique_tfs
filtered_matrix_mda_combined_edges_ppi_TFs = filtered_matrix_mda_combined_edges[filtered_matrix_mda_combined_edges.index.isin(unique_tfs)]

#Step 4: Name the index column as 'TF'
filtered_matrix_mda_combined_edges_ppi_TFs.index.name = 'TF'

# Step 5: Reset the index to make 'TF' a regular column
filtered_matrix_mda_combined_edges_ppi_TFs = filtered_matrix_mda_combined_edges_ppi_TFs.reset_index()

# Now filtered_tf_gene_matrix contains only the TFs mentioned in either Protein1 or Protein2 of the PPI file
#print(filtered_matrix_mda_combined_edges_ppi_TFs)
filtered_matrix_mda_combined_edges_ppi_TFs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Columns: 536 entries, TF to ZNF732
# dtypes: float64(535), object(1)
# memory usage: 3.5+ MB

# %%
filtered_matrix_mda_combined_edges_ppi_TFs.head()
# Out:
#      TF    ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# 0   AHR  0.304008 -0.667807  1.200416 -0.936033  0.182179 -1.235324 -1.395829
# 1  AHRR  0.247151 -0.587696  1.293375 -0.796551  0.328368 -1.308294 -1.069268
# 2  AIRE  0.874790 -1.013267  0.275668  0.100357 -1.201515  2.453961 -2.109349
# 3  ALX1  1.901858 -1.362818 -0.506440 -1.288876 -1.512983  1.082257 -2.706565
# 4  ALX3  0.740310 -1.202866 -0.330167 -1.513954 -1.692206  0.859158 -2.328144
#
#    ADAMTS19     ADCY1  ...    ZNF501    ZNF502   ZNF518B    ZNF521    ZNF577  \
# 0 -0.644775 -2.041014  ... -2.349634 -2.064601 -1.247681 -1.421086 -0.907489
# 1 -0.484905 -1.789929  ... -2.141010 -2.002920 -1.431786 -1.178416 -0.893068
# 2 -0.805395 -0.436276  ... -1.956179  1.233329  0.527247 -0.029944  0.523460
# 3 -0.351387 -1.688240  ... -3.467904 -0.405839  0.920343 -1.910685 -0.323486
# 4 -1.254828 -2.147329  ... -3.229053  0.866085  0.700537 -1.929038 -0.656320
#
#      ZNF630    ZNF655     ZNF71    ZNF711    ZNF732
# 0 -1.347365 -1.693050 -1.362386 -2.278187  0.146711
# 1 -1.137283 -1.451020 -1.081178 -2.225300  0.240623
# 2 -1.969279 -2.275027 -2.057922 -0.475194  1.937781
# 3 -0.789209 -0.803448 -2.291393  1.893416 -0.187331
# 4 -1.514953 -2.219323 -2.912750  2.325852  0.511644
#
# [5 rows x 536 columns]

# %%
filtered_matrix_mcf7_combined_edges_ppi_TFs.head()
# Out:
#      TF    ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# 0   AHR -1.089553 -0.795315  0.219303 -0.853007  0.399470 -1.630741  0.290181
# 1  AHRR -0.986674 -0.700822  0.392719 -0.701782  0.527235 -1.661367  0.493583
# 2  AIRE  0.265959 -1.189028 -0.789297  1.062564 -1.320127  2.068158 -1.493547
# 3  ALX1  0.388290 -1.544013 -1.692139 -1.567756 -1.144992  0.850550 -1.189983
# 4  ALX3 -1.169286 -1.528565 -1.913900 -1.577865 -1.383676  0.547645 -0.422447
#
#    ADAMTS19     ADCY1  ...      TLR4    TM4SF1   TM4SF18   TMEM125   TMEM156  \
# 0 -1.703381 -1.947731  ... -1.020596 -1.899293 -1.735155 -0.464616 -0.088311
# 1 -1.492458 -1.692178  ... -1.257743 -1.675511 -1.762027 -0.336651 -0.162217
# 2  0.400128  0.110629  ... -0.363425 -1.296714  0.111233 -0.754813  0.276227
# 3 -1.292651 -1.751564  ...  1.290326 -0.197852  1.397905 -2.600899  2.596896
# 4 -1.874142 -2.057815  ...  1.891228 -1.729117  0.000001 -1.674775  0.283685
#
#    TMEM178B    TMEM26   TMEM30B    TMEM71    TMEM92
# 0  0.546081 -1.327963 -1.899040 -1.944349 -0.818321
# 1  0.729568 -1.273587 -1.976856 -1.943266 -0.680559
# 2 -0.464796  2.755469  0.743904  0.603933 -0.703877
# 3 -1.944171  1.328845  2.033929 -0.070829 -2.532883
# 4 -1.568709  2.271090  1.326684 -0.644946 -2.533361
#
# [5 rows x 484 columns]

# %%
import numpy as np
import pandas as pd

def normalize_to_neg1_pos1(df):
    """Normalizes TF-gene interaction strengths to the range [-1,1], keeping the TF column intact."""
    df_normalized = df.copy()
    numeric_data = df.iloc[:, 1:]  # Exclude TF names

    w_min, w_max = numeric_data.min().min(), numeric_data.max().max()

    # Apply min-max normalization to [-1,1]
    df_normalized.iloc[:, 1:] = 2 * (numeric_data - w_min) / (w_max - w_min) - 1

    return df_normalized, w_min, w_max  # Return min/max for reversibility

def denormalize_from_neg1_pos1(df_normalized, w_min, w_max):
    """Reverses the normalization process to restore original values."""
    df_recovered = df_normalized.copy()
    df_recovered.iloc[:, 1:] = ((df_recovered.iloc[:, 1:] + 1) * (w_max - w_min) / 2) + w_min
    return df_recovered

# %%
#lets normalize the MCF7 and MDA matrices
# Example usage
df_normalized_MCF7, w_min, w_max = normalize_to_neg1_pos1(filtered_matrix_mcf7_combined_edges_ppi_TFs)
print("Normalized DataFrame  MCF7 (-1 to 1):\n", df_normalized_MCF7.head())

df_recovered_MCF7= denormalize_from_neg1_pos1(df_normalized_MCF7, w_min, w_max)
print("\nRecovered DataFrame MCF7 :\n", df_recovered_MCF7.head())

# Verify accuracy
assert np.allclose(filtered_matrix_mcf7_combined_edges_ppi_TFs.iloc[:, 1:].values,
                   df_recovered_MCF7.iloc[:, 1:].values, atol=1e-6)

df_normalized_MDA, w_min, w_max = normalize_to_neg1_pos1(filtered_matrix_mda_combined_edges_ppi_TFs)
print("Normalized DataFrame MDA (-1 to 1):\n", df_normalized_MCF7.head())
df_recovered_MDA= denormalize_from_neg1_pos1(df_normalized_MDA, w_min, w_max)
print("\nRecovered DataFrame MDA:\n", df_recovered_MDA.head())

# Verify accuracy
assert np.allclose(filtered_matrix_mda_combined_edges_ppi_TFs.iloc[:, 1:].values,
                   df_recovered_MDA.iloc[:, 1:].values, atol=1e-6)
# Out:
# Normalized DataFrame  MCF7 (-1 to 1):
#       TF    ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# 0   AHR  0.067639  0.083570  0.138503  0.080446  0.148258  0.038339  0.142340
# 1  AHRR  0.073209  0.088686  0.147892  0.088634  0.155175  0.036680  0.153353
# 2  AIRE  0.141029  0.062254  0.083896  0.184159  0.055156  0.238603  0.045766
# 3  ALX1  0.147652  0.043034  0.035014  0.041749  0.064638  0.172680  0.062202
# 4  ALX3  0.063322  0.043870  0.023008  0.041201  0.051715  0.156280  0.103758
#
#    ADAMTS19     ADCY1  ...      TLR4    TM4SF1   TM4SF18   TMEM125   TMEM156  \
# 0  0.034406  0.021176  ...  0.071373  0.023799  0.032685  0.101474  0.121848
# 1  0.045825  0.035012  ...  0.058533  0.035915  0.031230  0.108403  0.117847
# 2  0.148293  0.132619  ...  0.106953  0.056423  0.132652  0.085763  0.141585
# 3  0.056643  0.031797  ...  0.196490  0.115918  0.202315 -0.014187  0.267230
# 4  0.025160  0.015216  ...  0.229024  0.033012  0.126630  0.035954  0.141989
#
#    TMEM178B    TMEM26   TMEM30B    TMEM71    TMEM92
# 0  0.156195  0.054731  0.023812  0.021359  0.082324
# 1  0.166130  0.057675  0.019599  0.021418  0.089783
# 2  0.101465  0.275815  0.166906  0.159328  0.088521
# 3  0.021369  0.198576  0.236750  0.122795 -0.010505
# 4  0.041697  0.249590  0.198458  0.091711 -0.010531
#
# [5 rows x 484 columns]
#
# Recovered DataFrame MCF7 :
#       TF    ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# 0   AHR -1.089553 -0.795315  0.219303 -0.853007  0.399470 -1.630741  0.290181
# 1  AHRR -0.986674 -0.700822  0.392719 -0.701782  0.527235 -1.661367  0.493583
# 2  AIRE  0.265959 -1.189028 -0.789297  1.062564 -1.320127  2.068158 -1.493547
# 3  ALX1  0.388290 -1.544013 -1.692139 -1.567756 -1.144992  0.850550 -1.189983
# 4  ALX3 -1.169286 -1.528565 -1.913900 -1.577865 -1.383676  0.547645 -0.422447
#
#    ADAMTS19     ADCY1  ...      TLR4    TM4SF1   TM4SF18   TMEM125   TMEM156  \
# 0 -1.703381 -1.947731  ... -1.020596 -1.899293 -1.735155 -0.464616 -0.088311
# 1 -1.492458 -1.692178  ... -1.257743 -1.675511 -1.762027 -0.336651 -0.162217
# 2  0.400128  0.110629  ... -0.363425 -1.296714  0.111233 -0.754813  0.276227
# 3 -1.292651 -1.751564  ...  1.290326 -0.197852  1.397905 -2.600899  2.596896
# 4 -1.874142 -2.057815  ...  1.891228 -1.729117  0.000001 -1.674775  0.283685
#
#    TMEM178B    TMEM26   TMEM30B    TMEM71    TMEM92
# 0  0.546081 -1.327963 -1.899040 -1.944349 -0.818321
# 1  0.729568 -1.273587 -1.976856 -1.943266 -0.680559
# 2 -0.464796  2.755469  0.743904  0.603933 -0.703877
# 3 -1.944171  1.328845  2.033929 -0.070829 -2.532883
# 4 -1.568709  2.271090  1.326684 -0.644946 -2.533361
#
# [5 rows x 484 columns]
# Normalized DataFrame MDA (-1 to 1):
#       TF    ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# 0   AHR  0.067639  0.083570  0.138503  0.080446  0.148258  0.038339  0.142340
# 1  AHRR  0.073209  0.088686  0.147892  0.088634  0.155175  0.036680  0.153353
# 2  AIRE  0.141029  0.062254  0.083896  0.184159  0.055156  0.238603  0.045766
# 3  ALX1  0.147652  0.043034  0.035014  0.041749  0.064638  0.172680  0.062202
# 4  ALX3  0.063322  0.043870  0.023008  0.041201  0.051715  0.156280  0.103758
#
#    ADAMTS19     ADCY1  ...      TLR4    TM4SF1   TM4SF18   TMEM125   TMEM156  \
# 0  0.034406  0.021176  ...  0.071373  0.023799  0.032685  0.101474  0.121848
# 1  0.045825  0.035012  ...  0.058533  0.035915  0.031230  0.108403  0.117847
# 2  0.148293  0.132619  ...  0.106953  0.056423  0.132652  0.085763  0.141585
# 3  0.056643  0.031797  ...  0.196490  0.115918  0.202315 -0.014187  0.267230
# 4  0.025160  0.015216  ...  0.229024  0.033012  0.126630  0.035954  0.141989
#
#    TMEM178B    TMEM26   TMEM30B    TMEM71    TMEM92
# 0  0.156195  0.054731  0.023812  0.021359  0.082324
# 1  0.166130  0.057675  0.019599  0.021418  0.089783
# 2  0.101465  0.275815  0.166906  0.159328  0.088521
# 3  0.021369  0.198576  0.236750  0.122795 -0.010505
# 4  0.041697  0.249590  0.198458  0.091711 -0.010531
#
# [5 rows x 484 columns]
#
# Recovered DataFrame MDA:
#       TF    ABCA12     ACKR3     ACOT4     ACSL5   ADAMTS1  ADAMTS12  ADAMTS16  \
# 0   AHR  0.304008 -0.667807  1.200416 -0.936033  0.182179 -1.235324 -1.395829
# 1  AHRR  0.247151 -0.587696  1.293375 -0.796551  0.328368 -1.308294 -1.069268
# 2  AIRE  0.874790 -1.013267  0.275668  0.100357 -1.201515  2.453961 -2.109349
# 3  ALX1  1.901858 -1.362818 -0.506440 -1.288876 -1.512983  1.082257 -2.706565
# 4  ALX3  0.740310 -1.202866 -0.330167 -1.513954 -1.692206  0.859158 -2.328144
#
#    ADAMTS19     ADCY1  ...    ZNF501    ZNF502   ZNF518B    ZNF521    ZNF577  \
# 0 -0.644775 -2.041014  ... -2.349634 -2.064601 -1.247681 -1.421086 -0.907489
# 1 -0.484905 -1.789929  ... -2.141010 -2.002920 -1.431786 -1.178416 -0.893068
# 2 -0.805395 -0.436276  ... -1.956179  1.233329  0.527247 -0.029944  0.523460
# 3 -0.351387 -1.688240  ... -3.467904 -0.405839  0.920343 -1.910685 -0.323486
# 4 -1.254828 -2.147329  ... -3.229053  0.866085  0.700537 -1.929038 -0.656320
#
#      ZNF630    ZNF655     ZNF71    ZNF711    ZNF732
# 0 -1.347365 -1.693050 -1.362386 -2.278187  0.146711
# 1 -1.137283 -1.451020 -1.081178 -2.225300  0.240623
# 2 -1.969279 -2.275027 -2.057922 -0.475194  1.937781
# 3 -0.789209 -0.803448 -2.291393  1.893416 -0.187331
# 4 -1.514953 -2.219323 -2.912750  2.325852  0.511644
#
# [5 rows x 536 columns]

# %% [markdown]
# Let's load the ppi file and add it to the graphs

# %%
import pandas as pd

# Load the PPI file
ppi_file = "/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/filtered_ppi_minus_zero.tsv"  # Replace with your file path
ppi_df = pd.read_csv(ppi_file, sep="\t")  # Adjust separator if needed

# Inspect the PPI DataFrame
print(ppi_df.head())
# Out:
#   Protein1 Protein2  InteractionStrength
# 0     ATF1    AKAP8                0.156
# 1     ATF1       AR                0.352
# 2     ATF1     ARNT                0.153
# 3     ATF1    ASH1L                0.269
# 4     ATF1     ATF2                0.905

# %% [markdown]
# # **2. Build Graphs with Annonated Edges for each cell line** using min-max normalized matrix

# %% [markdown]
# **MCF7** **GRAPH**

# %%
import networkx as nx


# Create a directed graph for MCF7
G_mcf7 = nx.DiGraph()

# Check if 'TF' is the index and reset it if necessary
if 'TF' not in df_normalized_MCF7.columns:
    df_normalized_MCF7 = df_normalized_MCF7.reset_index()

# Iterate over rows in the DataFrame
for _, row in df_normalized_MCF7.iterrows():
    tf = row['TF']  # Transcription factor (First column)

    # Iterate through all genes (ignoring the first column)
    for gene, weight in row.iloc[1:].items():
        if weight > 0:
            edge_type = "positive"  # Activation
        elif weight < 0:
            edge_type = "negative"  # Repression
        else:
            continue  # Skip zero values

        # Add edge to the graph
        G_mcf7.add_edge(tf, gene, weight=weight, type=edge_type)

# %% [markdown]
# **MDA_MB231 GRAPH**

# %%
import networkx as nx


# Create a directed graph for MDA
G_mda = nx.DiGraph()

# Check if 'TF' is the index and reset it if necessary
if 'TF' not in df_normalized_MDA.columns:
    df_normalized_MDA = df_normalized_MDA.reset_index()

# Iterate over rows in the DataFrame
for _, row in df_normalized_MDA.iterrows():
    tf = row['TF']  # Transcription factor (First column)

    # Iterate through all genes (ignoring the first column)
    for gene, weight in row.iloc[1:].items():
        if weight > 0:
            edge_type = "positive"  # Activation
        elif weight < 0:
            edge_type = "negative"  # Repression
        else:
            continue  # Skip zero values

        # Add edge to the graph
        G_mda.add_edge(tf, gene, weight=weight, type=edge_type)

# %% [markdown]
# Let's try adding the ppi file to the existing graphs

# %%
import networkx as nx

# Ensure the graph is directed (if applicable)
G_mcf7_ppi= G_mcf7  # Replace with G_mda if working with MDA-MB-231

# Add PPI interactions to the graph
for _, row in ppi_df.iterrows():
    protein1 = row["Protein1"]
    protein2 = row["Protein2"]
    interaction_strength = row.get("InteractionStrength", 1.0)  # Default to 1.0 if no strength column exists

    # Only add edges if both proteins exist in the graph
    if G_mcf7_ppi.has_node(protein1) and G_mcf7_ppi.has_node(protein2):
        G_mcf7_ppi.add_edge(protein1, protein2, weight=interaction_strength)

print(f"Added PPI interactions for existing nodes only.")
# Out:
# Added PPI interactions for existing nodes only.

# %%
import networkx as nx

# Ensure the graph is directed (if applicable)
G_mda_ppi= G_mda  # Replace with G_mda if working with MDA-MB-231

# Add PPI interactions to the graph
for _, row in ppi_df.iterrows():
    protein1 = row["Protein1"]
    protein2 = row["Protein2"]
    interaction_strength = row.get("InteractionStrength", 1.0)  # Default to 1.0 if no strength column exists

    # Only add edges if both proteins exist in the graph
    if G_mda_ppi.has_node(protein1) and G_mda_ppi.has_node(protein2):
        G_mda_ppi.add_edge(protein1, protein2, weight=interaction_strength)

print(f"Added PPI interactions for existing nodes only.")
# Out:
# Added PPI interactions for existing nodes only.

# %% [markdown]
# # **3. Visualize Graphs**

# %%
import matplotlib.pyplot as plt
import networkx as nx

def visualize_graph(graph, title):
    # Define edge colors based on annotations
    edge_colors = [
        "green" if graph[u][v]['type'] == "positive" else "red"
        for u, v in graph.edges
    ]

    # Draw the graph
    pos = nx.spring_layout(graph, seed=42)  # Spring layout for better visualization
    nx.draw(
        graph, pos, with_labels=True, edge_color=edge_colors, node_size=500, font_size=10
    )

    # Add a legend for edge colors
    plt.title(title)
    plt.show()

# Load the graphs
#G_mcf7_ppi = nx.read_graphml("mcf7_graph_with_annotations.graphml")
#G_mda_ppi = nx.read_graphml("mda_mb231_graph_with_annotations.graphml")

# Visualize MCF7 graph
#visualize_graph(G_mcf7, "MCF7 Graph")

# Visualize MDA-MB231 graph
#visualize_graph(G_mda, "MDA-MB231 Graph")

# %% [markdown]
# LETS CONTINUE WITH BASIC GRAPH ANALYSIS:
#
# 1) **Analyze** **basic** **graph** **properties**

# %%
# Number of Nodes and Edges
num_nodes_mcf7 = G_mcf7.number_of_nodes()
num_edges_mcf7 = G_mcf7.number_of_edges()
print(f"Number of nodes MCF7: {num_nodes_mcf7}")
print(f"Number of edges MCF7: {num_edges_mcf7}")

num_nodes_mda = G_mda.number_of_nodes()
num_edges_mda = G_mda.number_of_edges()
print(f"Number of nodes MDA: {num_nodes_mda}")
print(f"Number of edges MDA: {num_edges_mda}")
# Out:
# Number of nodes MCF7: 1309
# Number of edges MCF7: 418852
# Number of nodes MDA: 1354
# Number of edges MDA: 463501

# %%
# Number of Nodes and Edges with added ppi file
num_nodes_mcf7 = G_mcf7_ppi.number_of_nodes()
num_edges_mcf7 = G_mcf7_ppi.number_of_edges()
print(f"Number of nodes MCF7 with ppi: {num_nodes_mcf7}")
print(f"Number of edges MCF7 with ppi: {num_edges_mcf7}")

num_nodes_mda = G_mda_ppi.number_of_nodes()
num_edges_mda = G_mda_ppi.number_of_edges()
print(f"Number of nodes MDA with ppi: {num_nodes_mda}")
print(f"Number of edges MDA with ppi: {num_edges_mda}")
# Out:
# Number of nodes MCF7 with ppi: 1309
# Number of edges MCF7 with ppi: 418852
# Number of nodes MDA with ppi: 1354
# Number of edges MDA with ppi: 463501

# %%
# density= measure how dense is the graph
density_mcf7 = nx.density(G_mcf7)
print(f"Density MCF7: {density_mcf7}")

density_mda = nx.density(G_mda)
print(f"Density MDA: {density_mda}")
# Out:
# Density MCF7: 0.24463196454561809
# Density MDA: 0.2530079772397026

# %%
# density= measure how dense is the graph
density_mcf7_ppi = nx.density(G_mcf7_ppi)
print(f"Density MCF7 with ppi: {density_mcf7_ppi}")

density_mda_ppi = nx.density(G_mda_ppi)
print(f"Density MDA with ppi: {density_mda_ppi}")
# Out:
# Density MCF7 with ppi: 0.24463196454561809
# Density MDA with ppi: 0.2530079772397026

# %%
#connected components= check if the graph is weakly or strongly connected
is_weakly_connected_mcf7 = nx.is_weakly_connected(G_mcf7)
is_strongly_connected_mcf7 = nx.is_strongly_connected(G_mcf7)
print(f"Weakly connected MCF7: {is_weakly_connected_mcf7}")
print(f"Strongly connected MCF7 : {is_strongly_connected_mcf7}")


is_weakly_connected_mda = nx.is_weakly_connected(G_mda)
is_strongly_connected_mda = nx.is_strongly_connected(G_mda)
print(f"Weakly connected MDA: {is_weakly_connected_mda}")
print(f"Strongly connected MDA : {is_strongly_connected_mda}")
# Out:
# Weakly connected MCF7: True
# Strongly connected MCF7 : False
# Weakly connected MDA: True
# Strongly connected MDA : False

# %%
#connected components= check if the graph is weakly or strongly connected
is_weakly_connected_mcf7_ppi = nx.is_weakly_connected(G_mcf7_ppi)
is_strongly_connected_mcf7_ppi = nx.is_strongly_connected(G_mcf7_ppi)
print(f"Weakly connected MCF7 with ppi: {is_weakly_connected_mcf7_ppi}")
print(f"Strongly connected MCF7 with ppi : {is_strongly_connected_mcf7_ppi}")


is_weakly_connected_mda_ppi = nx.is_weakly_connected(G_mda_ppi)
is_strongly_connected_mda_ppi = nx.is_strongly_connected(G_mda_ppi)
print(f"Weakly connected MDA with ppi: {is_weakly_connected_mda_ppi}")
print(f"Strongly connected MDA with ppi: {is_strongly_connected_mda_ppi}")
# Out:
# Weakly connected MCF7 with ppi: True
# Strongly connected MCF7 with ppi : False
# Weakly connected MDA with ppi: True
# Strongly connected MDA with ppi: False

# %%
#Shortest path= analyze the shortest paths between nodes
shortest_path_lengths_mcf7_ppi = dict(nx.shortest_path_length(G_mcf7_ppi))
shortest_path_lengths_mda_ppi = dict(nx.shortest_path_length(G_mda_ppi))

# %% [markdown]
# # 2. Identify Suppopulations(Communities or Clusters)
# Subpopulations in a graph often refer to communities or clusters of nodes that are more densely connected among themselves than with the rest of the graph.:

# %%
#A)Weakly Connected Components:
#For directed graphs, weakly connected components are subgraphs where nodes are connected regardless of edge direction.
weakly_connected_components_mcf7_ppi= list(nx.weakly_connected_components(G_mcf7_ppi))
print(f"Number of weakly connected components MCF7 with ppi: {len(weakly_connected_components_mcf7_ppi)}")
weakly_connected_components_mda_ppi = list(nx.weakly_connected_components(G_mda_ppi))
print(f"Number of weakly connected components MDA  with ppi: {len(weakly_connected_components_mda_ppi)}")
# Out:
# Number of weakly connected components MCF7 with ppi: 1
# Number of weakly connected components MDA  with ppi: 1

# %%
#B)Strongly Connected Components:
#    Strongly connected components are subgraphs where every node is reachable from every other node, following edge directions.#
strongly_connected_components_mcf7_ppi= list(nx.strongly_connected_components(G_mcf7_ppi))
print(f"Number of strongly connected components MCF7: {len(strongly_connected_components_mcf7_ppi)}")
strongly_connected_components_mda_ppi= list(nx.strongly_connected_components(G_mda_ppi))
print(f"Number of strongly connected components MDA: {len(strongly_connected_components_mda_ppi)}")
# Out:
# Number of strongly connected components MCF7: 452
# Number of strongly connected components MDA: 497

# %%
#D)K-Cores:

#Identify k-cores, which are subgraphs where each node has at least degree k.
G_mcf7_ppi.remove_edges_from(nx.selfloop_edges(G_mcf7_ppi)) # Remove self-loops from G_mcf7
k_cores_mcf7_ppi = nx.k_core(G_mcf7_ppi)
print(f"Number of k-cores in MCF7: {k_cores_mcf7_ppi.number_of_nodes()}")

G_mda_ppi.remove_edges_from(nx.selfloop_edges(G_mda_ppi)) # Remove self-loops from G_mda
k_cores_mda_ppi = nx.k_core(G_mda_ppi)
print(f"Number of k-cores in MDA: {k_cores_mda_ppi.number_of_nodes()}")
# Out:
# Number of k-cores in MCF7: 1041
# Number of k-cores in MDA: 1090

# %%
#E) Cliques: Find cliques (fully connected subgraphs).
cliques_mcf7_ppi = list(nx.find_cliques(G_mcf7_ppi.to_undirected()))
cliques_mda_ppi = list(nx.find_cliques(G_mda_ppi.to_undirected()))

# %% [markdown]
# # **3 . Analyze Subpopulation Properties**

# %%
#Size of Subpopulations: Check the size of each community or component.
for i, component in enumerate(weakly_connected_components_mcf7_ppi):
    print(f"Component {i+1}: Size = {len(component)}")
#Density of Subpopulations: Calculate the density of each community or component
for i, component in enumerate(weakly_connected_components_mcf7_ppi):
    subgraph = G_mcf7_ppi.subgraph(component)
    print(f"Component {i+1}: Density = {nx.density(subgraph)}")
#Centrality Measures: Compute centrality measures (e.g., degree centrality, betweenness centrality) for nodes within each subpopulation.
for i, component in enumerate(weakly_connected_components_mcf7_ppi):
    subgraph = G_mcf7_ppi.subgraph(component)
    degree_centrality = nx.degree_centrality(subgraph)
    betweenness_centrality = nx.betweenness_centrality(subgraph)
    print(f"Component {i+1}: Degree Centrality = {degree_centrality}")
    print(f"Component {i+1}: Betweenness Centrality = {betweenness_centrality}")
#    Edge Types in Subpopulations:Analyze the distribution of edge types ("positive" or "negative") within each subpopulation
for i, component in enumerate(weakly_connected_components_mcf7_ppi):
        subgraph = G_mcf7_ppi.subgraph(component)
        edge_types = [data['type'] for _, _, data in subgraph.edges(data=True)]
        print(f"Component {i+1}: Edge Types = {edge_types}")
# Out:
# Component 1: Size = 1309
# Component 1: Density = 0.2446126907810664
# Component 1: Degree Centrality = {'AHR': 0.3761467889908257, 'ABCA12': 0.6567278287461774, 'ACKR3': 0.6567278287461774, 'ACOT4': 0.6567278287461774, 'ACSL5': 0.6567278287461774, 'ADAMTS1': 0.6567278287461774, 'ADAMTS12': 0.6567278287461774, 'ADAMTS16': 0.6567278287461774, 'ADAMTS19': 0.6567278287461774, 'ADCY1': 0.6567278287461774, 'ADCY5': 0.6567278287461774, 'ADD2': 0.6567278287461774, 'ADGRE1': 0.6567278287461774, 'ADGRF5': 0.6567278287461774, 'ADGRG5': 0.6567278287461774, 'ADRA2C': 0.6567278287461774, 'ADRB2': 0.6567278287461774, 'AGPAT4': 0.6567278287461774, 'AGPS': 0.6567278287461774, 'AGR3': 0.6567278287461774, 'AK7': 0.6567278287461774, 'AKR1B1': 0.6567278287461774, 'AKT3': 0.6567278287461774, 'ALDH2': 0.6567278287461774, 'ALDH3B2': 0.6567278287461774, 'ALOX15': 0.6567278287461774, 'ANK2': 0.6567278287461774, 'ANKRD1': 0.6567278287461774, 'ANKRD33B': 0.6567278287461774, 'ANKRD34B': 0.6567278287461774, 'ANO3': 0.6567278287461774, 'ANTXR2': 0.6567278287461774, 'ANXA8L1': 0.6567278287461774, 'APOBEC3C': 0.6567278287461774, 'APOL1': 0.6567278287461774, 'APOL3': 0.6567278287461774, 'APOL6': 0.6567278287461774, 'ARHGAP23': 0.6567278287461774, 'ARHGAP40': 0.6567278287461774, 'ARHGAP8': 0.6567278287461774, 'ARHGDIB': 0.6567278287461774, 'ARHGDIG': 0.6567278287461774, 'ASCL1': 1.0244648318042813, 'ASCL2': 1.0244648318042813, 'ATP10D': 0.6567278287461774, 'AXL': 0.6567278287461774, 'BATF3': 1.0244648318042813, 'BCAS1': 0.6567278287461774, 'BCAT1': 0.6567278287461774, 'BCHE': 0.6567278287461774, 'BEX4': 0.6567278287461774, 'BICC1': 0.6567278287461774, 'BICDL2': 0.6567278287461774, 'BIRC3': 0.6567278287461774, 'BMP5': 0.6567278287461774, 'BMP7': 0.6567278287461774, 'BPIFB1': 0.6567278287461774, 'BRINP2': 0.6567278287461774, 'BSPRY': 0.6567278287461774, 'BTNL9': 0.6567278287461774, 'C11orf52': 0.6567278287461774, 'C14orf132': 0.6567278287461774, 'C19orf81': 0.6567278287461774, 'C1orf210': 0.6567278287461774, 'C4BPB': 0.6567278287461774, 'CA8': 0.6567278287461774, 'CACNA1D': 0.6567278287461774, 'CACNA2D4': 0.6567278287461774, 'CACNG4': 0.6567278287461774, 'CALD1': 0.6567278287461774, 'CALML5': 0.6567278287461774, 'CAMK4': 0.6567278287461774, 'CAPN13': 0.6567278287461774, 'CAPN9': 0.6567278287461774, 'CARD11': 0.6567278287461774, 'CASP1': 0.6567278287461774, 'CASP4': 0.6567278287461774, 'CAVIN2': 0.6567278287461774, 'CAVIN3': 0.6567278287461774, 'CBFA2T3': 0.6567278287461774, 'CBLN4': 0.6567278287461774, 'CBS': 0.6567278287461774, 'CCBE1': 0.6567278287461774, 'CCDC120': 0.6567278287461774, 'CCDC170': 0.6567278287461774, 'CCDC63': 0.6567278287461774, 'CCDC83': 0.6567278287461774, 'CD274': 0.6567278287461774, 'CD40': 0.6567278287461774, 'CD96': 0.6567278287461774, 'CDC42EP3': 0.6567278287461774, 'CDCP1': 0.6567278287461774, 'CDH1': 0.6567278287461774, 'CDK15': 0.6567278287461774, 'CDKN2A': 0.6567278287461774, 'CEACAM5': 0.6567278287461774, 'CEACAM6': 0.6567278287461774, 'CELF2': 0.6567278287461774, 'CFH': 0.6567278287461774, 'CHDH': 0.6567278287461774, 'CHRM3': 0.6567278287461774, 'CHST2': 0.6567278287461774, 'CKMT1B': 0.6567278287461774, 'CLDN1': 0.6567278287461774, 'CLSTN2': 0.6567278287461774, 'CMTM7': 0.6567278287461774, 'CNN3': 0.6567278287461774, 'COL13A1': 0.6567278287461774, 'COL4A1': 0.6567278287461774, 'COL4A2': 0.6567278287461774, 'COL4A5': 0.6567278287461774, 'COL4A6': 0.6567278287461774, 'COL8A1': 0.6567278287461774, 'COX7B2': 0.6567278287461774, 'CPA4': 0.6567278287461774, 'CPED1': 0.6567278287461774, 'CPNE8': 0.6567278287461774, 'CPVL': 0.6567278287461774, 'CREB5': 1.0244648318042813, 'CST1': 0.6567278287461774, 'CST4': 0.6567278287461774, 'CT83': 0.6567278287461774, 'CTNND2': 0.6567278287461774, 'CXCL1': 0.6567278287461774, 'CXCL12': 0.6567278287461774, 'CXCL2': 0.6567278287461774, 'CXCL8': 0.6567278287461774, 'CYBRD1': 0.6567278287461774, 'CYP27A1': 0.6567278287461774, 'DAW1': 0.6567278287461774, 'DCDC2': 0.6567278287461774, 'DEGS2': 0.6567278287461774, 'DGKG': 0.6567278287461774, 'DIRAS2': 0.6567278287461774, 'DMRTA1' ...
# Component 1: Betweenness Centrality = {'AHR': 0.0, 'ABCA12': 0.0, 'ACKR3': 0.0, 'ACOT4': 0.0, 'ACSL5': 0.0, 'ADAMTS1': 0.0, 'ADAMTS12': 0.0, 'ADAMTS16': 0.0, 'ADAMTS19': 0.0, 'ADCY1': 0.0, 'ADCY5': 0.0, 'ADD2': 0.0, 'ADGRE1': 0.0, 'ADGRF5': 0.0, 'ADGRG5': 0.0, 'ADRA2C': 0.0, 'ADRB2': 0.0, 'AGPAT4': 0.0, 'AGPS': 0.0, 'AGR3': 0.0, 'AK7': 0.0, 'AKR1B1': 0.0, 'AKT3': 0.0, 'ALDH2': 0.0, 'ALDH3B2': 0.0, 'ALOX15': 0.0, 'ANK2': 0.0, 'ANKRD1': 0.0, 'ANKRD33B': 0.0, 'ANKRD34B': 0.0, 'ANO3': 0.0, 'ANTXR2': 0.0, 'ANXA8L1': 0.0, 'APOBEC3C': 0.0, 'APOL1': 0.0, 'APOL3': 0.0, 'APOL6': 0.0, 'ARHGAP23': 0.0, 'ARHGAP40': 0.0, 'ARHGAP8': 0.0, 'ARHGDIB': 0.0, 'ARHGDIG': 0.0, 'ASCL1': 0.0, 'ASCL2': 0.0, 'ATP10D': 0.0, 'AXL': 0.0, 'BATF3': 0.0, 'BCAS1': 0.0, 'BCAT1': 0.0, 'BCHE': 0.0, 'BEX4': 0.0, 'BICC1': 0.0, 'BICDL2': 0.0, 'BIRC3': 0.0, 'BMP5': 0.0, 'BMP7': 0.0, 'BPIFB1': 0.0, 'BRINP2': 0.0, 'BSPRY': 0.0, 'BTNL9': 0.0, 'C11orf52': 0.0, 'C14orf132': 0.0, 'C19orf81': 0.0, 'C1orf210': 0.0, 'C4BPB': 0.0, 'CA8': 0.0, 'CACNA1D': 0.0, 'CACNA2D4': 0.0, 'CACNG4': 0.0, 'CALD1': 0.0, 'CALML5': 0.0, 'CAMK4': 0.0, 'CAPN13': 0.0, 'CAPN9': 0.0, 'CARD11': 0.0, 'CASP1': 0.0, 'CASP4': 0.0, 'CAVIN2': 0.0, 'CAVIN3': 0.0, 'CBFA2T3': 0.0, 'CBLN4': 0.0, 'CBS': 0.0, 'CCBE1': 0.0, 'CCDC120': 0.0, 'CCDC170': 0.0, 'CCDC63': 0.0, 'CCDC83': 0.0, 'CD274': 0.0, 'CD40': 0.0, 'CD96': 0.0, 'CDC42EP3': 0.0, 'CDCP1': 0.0, 'CDH1': 0.0, 'CDK15': 0.0, 'CDKN2A': 0.0, 'CEACAM5': 0.0, 'CEACAM6': 0.0, 'CELF2': 0.0, 'CFH': 0.0, 'CHDH': 0.0, 'CHRM3': 0.0, 'CHST2': 0.0, 'CKMT1B': 0.0, 'CLDN1': 0.0, 'CLSTN2': 0.0, 'CMTM7': 0.0, 'CNN3': 0.0, 'COL13A1': 0.0, 'COL4A1': 0.0, 'COL4A2': 0.0, 'COL4A5': 0.0, 'COL4A6': 0.0, 'COL8A1': 0.0, 'COX7B2': 0.0, 'CPA4': 0.0, 'CPED1': 0.0, 'CPNE8': 0.0, 'CPVL': 0.0, 'CREB5': 0.0, 'CST1': 0.0, 'CST4': 0.0, 'CT83': 0.0, 'CTNND2': 0.0, 'CXCL1': 0.0, 'CXCL12': 0.0, 'CXCL2': 0.0, 'CXCL8': 0.0, 'CYBRD1': 0.0, 'CYP27A1': 0.0, 'DAW1': 0.0, 'DCDC2': 0.0, 'DEGS2': 0.0, 'DGKG': 0.0, 'DIRAS2': 0.0, 'DMRTA1': 0.0, 'DNAJC12': 0.0, 'DOCK8': 0.0, 'DOK7': 0.0, 'DRD1': 0.0, 'DSCAM': 0.0, 'EDIL3': 0.0, 'EHD3': 0.0, 'ELF5': 0.0, 'ELOVL2': 0.0, 'ELOVL4': 0.0, 'EMC10': 0.0, 'EMID1': 0.0, 'EMP1': 0.0, 'ENPP5': 0.0, 'ENTPD2': 0.0, 'ENTPD8': 0.0, 'EPN3': 0.0, 'EPPK1': 0.0, 'ERBB3': 0.0, 'ERBB4': 0.0, 'EREG': 0.0, 'ESR1': 0.0, 'ESRP1': 0.0, 'ETS1': 0.0, 'ETV1': 0.0, 'EVA1A': 0.0, 'EVC': 0.0, 'EVI2A': 0.0, 'EVI2B': 0.0, 'EVPLL': 0.0, 'EYA1': 0.0, 'EYA2': 0.0, 'F2RL3': 0.0, 'F3': 0.0, 'FAM110C': 0.0, 'FAM133A': 0.0, 'FAM171A1': 0.0, 'FAM178B': 0.0, 'FAM50B': 0.0, 'FAM83B': 0.0, 'FGF5': 0.0, 'FGFR2': 0.0, 'FLG': 0.0, 'FLNC': 0.0, 'FLRT3': 0.0, 'FOSL1': 0.0, 'FOXA2': 0.0, 'FOXI3': 0.0, 'FSD1': 0.0, 'FST': 0.0, 'FSTL1': 0.0, 'FUT9': 0.0, 'FXYD3': 0.0, 'FXYD5': 0.0, 'G0S2': 0.0, 'GABRA3': 0.0, 'GABRE': 0.0, 'GAL': 0.0, 'GBP1': 0.0, 'GBP3': 0.0, 'GCNT2': 0.0, 'GFRA1': 0.0, 'GJA1': 0.0, 'GLRA3': 0.0, 'GLRB': 0.0, 'GMFG': 0.0, 'GNA15': 0.0, 'GNG11': 0.0, 'GOLT1A': 0.0, 'GP2': 0.0, 'GPAT2': 0.0, 'GPC4': 0.0, 'GPR27': 0.0, 'GPR37L1': 0.0, 'GPX1': 0.0, 'GRHL2': 0.0, 'GRIK3': 0.0, 'GSC': 0.0, 'GSTM1': 0.0, 'GSTP1': 0.0, 'HAS2': 0.0, 'HENMT1': 0.0, 'HMGA2': 0.0, 'HMGCLL1': 0.0, 'HOXA10': 0.0, 'HOXA4': 0.0, 'HOXC13': 0.0, 'HOXD3': 0.0, 'HPDL': 0.0, 'HRH1': 0.0, 'HRNR': 0.0, 'HS3ST3A1': 0.0, 'HS6ST2': 0.0, 'HSH2D': 0.0, 'HTR1F': 0.0, 'HUNK': 0.0, 'ICAM2': 0.0, 'IFI16': 0.0, 'IFI44': 0.0, 'IFI44L': 0.0, 'IFIT3': 0.0, 'IGDCC3': 0.0, 'IGF2BP3': 0.0, 'IGFBP1': 0.0, 'IGFBP2': 0.0, 'IGFBP5': 0.0, 'IL1RAPL1': 0.0, 'IL31RA': 0.0, 'IL7R': 0.0, 'ILDR1': 0.0, 'ILDR2': 0.0, 'IQANK1': 0.0, 'IRF6': 0.0, 'IRX2': 0.0, 'IRX4': 0.0, 'ITGBL1': 0.0, 'KCNF1': 0.0, 'KCNJ3': 0.0, 'KCNQ3': 0.0, 'KCNQ5': 0.0, 'KCTD14': 0.0, 'KCTD15': 0.0, 'KCTD4': 0.0, 'KDF1': 0.0, 'KIAA0040': 0.0, 'KIF1A': 0.0, 'KIF26A': 0.0, 'KIRREL1': 0.0, 'KLHL9': 0.0, 'KLK11': 0.0, 'KLRC2': 0.0, 'KLRG2': 0.0, 'LAD1': 0.0, 'LAMA1': 0.0, 'LAMA4': 0.0, 'LAPTM5': 0.0, 'LARGE2': 0.0, 'LAYN': 0.0, 'LDHB': 0.0, 'LDOC1': 0.0, 'LHFPL6': 0.0, 'LHX1': 0.0, 'LHX2': 0 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-2276a71aa5ab> in <cell line: 0>()
#      16 for i, component in enumerate(weakly_connected_components_mcf7_ppi):
#      17         subgraph = G_mcf7_ppi.subgraph(component)
# ---> 18         edge_types = [data['type'] for _, _, data in subgraph.edges(data=True)]
#      19         print(f"Component {i+1}: Edge Types = {edge_types}")
#      20
#
# <ipython-input-52-2276a71aa5ab> in <listcomp>(.0)
#      16 for i, component in enumerate(weakly_connected_components_mcf7_ppi):
#      17         subgraph = G_mcf7_ppi.subgraph(component)
# ---> 18         edge_types = [data['type'] for _, _, data in subgraph.edges(data=True)]
#      19         print(f"Component {i+1}: Edge Types = {edge_types}")
#      20
#
# KeyError: 'type'

# %%
#Size of Subpopulations: Check the size of each community or component.
for i, component in enumerate(weakly_connected_components_mda_ppi):
    print(f"Component {i+1}: Size = {len(component)}")
#Density of Subpopulations: Calculate the density of each community or component
for i, component in enumerate(weakly_connected_components_mda_ppi):
    subgraph = G_mda_ppi.subgraph(component)
    print(f"Component {i+1}: Density = {nx.density(subgraph)}")
#Centrality Measures: Compute centrality measures (e.g., degree centrality, betweenness centrality) for nodes within each subpopulation.
for i, component in enumerate(weakly_connected_components_mda_ppi):
    subgraph = G_mda_ppi.subgraph(component)
    degree_centrality = nx.degree_centrality(subgraph)
    betweenness_centrality = nx.betweenness_centrality(subgraph)
    print(f"Component {i+1}: Degree Centrality = {degree_centrality}")
    print(f"Component {i+1}: Betweenness Centrality = {betweenness_centrality}")
#    Edge Types in Subpopulations:Analyze the distribution of edge types ("positive" or "negative") within each subpopulation
    for i, component in enumerate(weakly_connected_components_mda_ppi):
        subgraph = G_mda_ppi.subgraph(component)
        edge_types = [data['type'] for _, _, data in subgraph.edges(data=True)]
        print(f"Component {i+1}: Edge Types = {edge_types}")

# %% [markdown]
#  4: **Identify** **Key** **Nodes** or **Hubs**
#
# Key nodes (hubs) are often critical in biological networks

# %%
# Degree distribution
#calculate the in-degree, out-degree, and total degree of nodes
in_degrees_mcf7 = dict(G_mcf7.in_degree())
out_degrees_mcf7 = dict(G_mcf7.out_degree())
total_degrees_mcf7 = dict(G_mcf7.degree())

in_degrees_mda = dict(G_mda.in_degree())
out_degrees_mda = dict(G_mda.out_degree())
total_degrees_mda = dict(G_mda.degree())

# %%
# Degree distribution
#calculate the in-degree, out-degree, and total degree of nodes
in_degrees_mcf7_ppi = dict(G_mcf7_ppi.in_degree())
out_degrees_mcf7_ppi = dict(G_mcf7_ppi.out_degree())
total_degrees_mcf7_ppi = dict(G_mcf7_ppi.degree())

in_degrees_mda_ppi = dict(G_mda_ppi.in_degree())
out_degrees_mda_ppi = dict(G_mda_ppi.out_degree())
total_degrees_mda_ppi = dict(G_mda_ppi.degree())

# %%
#High-Degree Nodes:
#Identify nodes with the highest degree (in-degree, out-degree, or total degree).
top_degree_nodes_mcf7 = sorted(total_degrees_mcf7.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top degree nodes: {top_degree_nodes_mcf7}")
#Betweenness Centrality:
#Identify nodes with high betweenness centrality (bridges between communities).
betweenness_mcf7= nx.betweenness_centrality(G_mcf7)
top_betweenness_nodes_mcf7 = sorted(betweenness_mcf7.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top betweenness nodes: {top_betweenness_nodes_mcf7}")

#Eigenvector Centrality:
#Identify influential nodes based on their connections to other influential nodes.
eigenvector_centrality_mcf7 = nx.eigenvector_centrality(G_mcf7)
top_eigenvector_nodes_mcf7 = sorted(eigenvector_centrality_mcf7.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top eigenvector centrality nodes: {top_eigenvector_nodes_mcf7}")
# Out:
# Top degree nodes: [('SOX2', 1917), ('ASCL1', 1340), ('ASCL2', 1340), ('BATF3', 1340), ('CREB5', 1340), ('DMRTA1', 1340), ('ELF5', 1340), ('ESR1', 1340), ('ETS1', 1340), ('ETV1', 1340)]
# Top betweenness nodes: [('SOX2', 0.40764684994132505), ('LEF1', 0.019627958756279328), ('CREB1', 0.015162674030241578), ('ZBTB7A', 0.014496476048796898), ('CTCF', 0.011560490296526718), ('NFKB2', 0.010648180518889635), ('NFKB1', 0.010535908840178245), ('RXRA', 0.009960862857190077), ('REL', 0.007884522656898447), ('STAT5A', 0.006966021354117197)]
# Top eigenvector centrality nodes: [('ABCA12', 0.04555161737923692), ('ACKR3', 0.04555161737923692), ('ACOT4', 0.04555161737923692), ('ACSL5', 0.04555161737923692), ('ADAMTS1', 0.04555161737923692), ('ADAMTS12', 0.04555161737923692), ('ADAMTS16', 0.04555161737923692), ('ADAMTS19', 0.04555161737923692), ('ADCY1', 0.04555161737923692), ('ADCY5', 0.04555161737923692)]

# %%
#High-Degree Nodes:
#Identify nodes with the highest degree (in-degree, out-degree, or total degree).
top_degree_nodes_mcf7_ppi = sorted(total_degrees_mcf7_ppi.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top degree nodes: {top_degree_nodes_mcf7}")
#Betweenness Centrality:
#Identify nodes with high betweenness centrality (bridges between communities).
betweenness_mcf7_ppi= nx.betweenness_centrality(G_mcf7_ppi)
top_betweenness_nodes_mcf7_ppi = sorted(betweenness_mcf7.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top betweenness nodes: {top_betweenness_nodes_mcf7_ppi}")

#Eigenvector Centrality:
#Identify influential nodes based on their connections to other influential nodes.
eigenvector_centrality_mcf7_ppi = nx.eigenvector_centrality(G_mcf7_ppi)
top_eigenvector_nodes_mcf7_ppi= sorted(eigenvector_centrality_mcf7_ppi.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top eigenvector centrality nodes: {top_eigenvector_nodes_mcf7_ppi}")
# Out:
# Top degree nodes: [('SOX2', 1917), ('ASCL1', 1340), ('ASCL2', 1340), ('BATF3', 1340), ('CREB5', 1340), ('DMRTA1', 1340), ('ELF5', 1340), ('ESR1', 1340), ('ETS1', 1340), ('ETV1', 1340)]
# Top betweenness nodes: [('SOX2', 0.40764684994132505), ('LEF1', 0.019627958756279328), ('CREB1', 0.015162674030241578), ('ZBTB7A', 0.014496476048796898), ('CTCF', 0.011560490296526718), ('NFKB2', 0.010648180518889635), ('NFKB1', 0.010535908840178245), ('RXRA', 0.009960862857190077), ('REL', 0.007884522656898447), ('STAT5A', 0.006966021354117197)]
# Top eigenvector centrality nodes: [('ABCA12', 0.04555161737923692), ('ACKR3', 0.04555161737923692), ('ACOT4', 0.04555161737923692), ('ACSL5', 0.04555161737923692), ('ADAMTS1', 0.04555161737923692), ('ADAMTS12', 0.04555161737923692), ('ADAMTS16', 0.04555161737923692), ('ADAMTS19', 0.04555161737923692), ('ADCY1', 0.04555161737923692), ('ADCY5', 0.04555161737923692)]

# %%
#High-Degree Nodes:
#Identify nodes with the highest degree (in-degree, out-degree, or total degree).
top_degree_nodes_mda = sorted(total_degrees_mda.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top degree nodes: {top_degree_nodes_mda}")
#Betweenness Centrality:
#Identify nodes with high betweenness centrality (bridges between communities).
betweenness_mda= nx.betweenness_centrality(G_mda)
top_betweenness_nodes_mda = sorted(betweenness_mda.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top betweenness nodes: {top_betweenness_nodes_mda}")

#Eigenvector Centrality:
#Identify influential nodes based on their connections to other influential nodes.
eigenvector_centrality_mda = nx.eigenvector_centrality(G_mda)
top_eigenvector_nodes_mda = sorted(eigenvector_centrality_mda.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top eigenvector centrality nodes: {top_eigenvector_nodes_mda}")
# Out:
# Top degree nodes: [('SOX2', 1963), ('ASCL1', 1392), ('ASCL2', 1392), ('BATF3', 1392), ('CREB5', 1392), ('DMRTA1', 1392), ('ELF5', 1392), ('ESR1', 1392), ('ETS1', 1392), ('ETV1', 1392)]
# Top betweenness nodes: [('SOX2', 0.3777256444869529), ('LEF1', 0.018339083208081978), ('CREB1', 0.014169635285844995), ('ZBTB7A', 0.013455358217184372), ('CTCF', 0.01071108291689435), ('NFKB2', 0.009949943708526428), ('NFKB1', 0.009843624679385004), ('RXRA', 0.009216220513809997), ('REL', 0.007368587565237825), ('STAT5A', 0.006509524602019898)]
# Top eigenvector centrality nodes: [('ABCA12', 0.043284707875449725), ('ACKR3', 0.043284707875449725), ('ACOT4', 0.043284707875449725), ('ACSL5', 0.043284707875449725), ('ADAMTS1', 0.043284707875449725), ('ADAMTS12', 0.043284707875449725), ('ADAMTS16', 0.043284707875449725), ('ADAMTS19', 0.043284707875449725), ('ADCY1', 0.043284707875449725), ('ADCY5', 0.043284707875449725)]

# %%
#High-Degree Nodes:
#Identify nodes with the highest degree (in-degree, out-degree, or total degree).
top_degree_nodes_mda_ppi = sorted(total_degrees_mda_ppi.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top degree nodes: {top_degree_nodes_mda_ppi}")
#Betweenness Centrality:
#Identify nodes with high betweenness centrality (bridges between communities).
betweenness_mda_ppi = nx.betweenness_centrality(G_mda_ppi)
top_betweenness_nodes_mda_ppi = sorted(betweenness_mda_ppi.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top betweenness nodes: {top_betweenness_nodes_mda_ppi}")

#Eigenvector Centrality:
#Identify influential nodes based on their connections to other influential nodes.
eigenvector_centrality_mda_ppi = nx.eigenvector_centrality(G_mda_ppi)
top_eigenvector_nodes_mda_ppi = sorted(eigenvector_centrality_mda_ppi.items(), key=lambda x: x[1], reverse=True)[:10]
print(f"Top eigenvector centrality nodes: {top_eigenvector_nodes_mda_ppi}")
# Out:
# Top degree nodes: [('SOX2', 1963), ('ASCL1', 1392), ('ASCL2', 1392), ('BATF3', 1392), ('CREB5', 1392), ('DMRTA1', 1392), ('ELF5', 1392), ('ESR1', 1392), ('ETS1', 1392), ('ETV1', 1392)]
# Top betweenness nodes: [('SOX2', 0.3777256444869529), ('LEF1', 0.018339083208081978), ('CREB1', 0.014169635285844995), ('ZBTB7A', 0.013455358217184372), ('CTCF', 0.01071108291689435), ('NFKB2', 0.009949943708526428), ('NFKB1', 0.009843624679385004), ('RXRA', 0.009216220513809997), ('REL', 0.007368587565237825), ('STAT5A', 0.006509524602019898)]
# Top eigenvector centrality nodes: [('ABCA12', 0.043284707875449725), ('ACKR3', 0.043284707875449725), ('ACOT4', 0.043284707875449725), ('ACSL5', 0.043284707875449725), ('ADAMTS1', 0.043284707875449725), ('ADAMTS12', 0.043284707875449725), ('ADAMTS16', 0.043284707875449725), ('ADAMTS19', 0.043284707875449725), ('ADCY1', 0.043284707875449725), ('ADCY5', 0.043284707875449725)]

# %% [markdown]
# # 5.Export Results for further analysis

# %%
nx.write_graphml(G_mcf7_ppi, "mcf7_ppi_graph.graphml")
#expoert subpopulations
with open("subpopulations_mcf7.txt", "w") as f:
    for i, component in enumerate(weakly_connected_components_mcf7_ppi):
        f.write(f"Component {i+1}: {component}\n")
nx.write_graphml(G_mda_ppi, "mda_graph.graphml")
#expoert subpopulations
with open("subpopulations_mda.txt", "w") as f:
    for i, component in enumerate(weakly_connected_components_mda_ppi):
        f.write(f"Component {i+1}: {component}\n")

# %% [markdown]
# # Let's install PyGPS (suggested by Ortega) and use it for signal processing:

# %%
pip install pygsp
# Out:
# Collecting pygsp
#   Downloading PyGSP-0.5.1-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pygsp) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pygsp) (1.14.1)
# Downloading PyGSP-0.5.1-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.6 MB/s eta 0:00:00
# Installing collected packages: pygsp
# Successfully installed pygsp-0.5.1

# %% [markdown]
# # **1. Convert NetworkX Graph to PyGSP Graph**

# %%
#I decided to use PyGSP package so few adjustments will be required
import networkx as nx
import pygsp as pg
from networkx import to_scipy_sparse_array

# Extract adjacency matrix from NetworkX graph
# Extract adjacency matrix from NetworkX graph as a sparse array
G_mcf7_ppi.remove_edges_from(nx.selfloop_edges(G_mcf7_ppi))##### remove the loop here
adjacency_matrix_mcf7_ppi = to_scipy_sparse_array(G_mcf7_ppi, weight=" Edge weight")

# Create PyGSP graph
gsp_graph_mcf7_ppi= pg.graphs.Graph(adjacency_matrix_mcf7_ppi)

# Display basic graph info
print(f"PyGSP Graph MCF7 with {gsp_graph_mcf7_ppi.N} nodes and {gsp_graph_mcf7_ppi.Ne} edges.")
# Out:
# PyGSP Graph MCF7 with 1309 nodes and 418819 edges.

# %%
## Extract adjacency matrix from NetworkX graph
# Extract adjacency matrix from NetworkX graph as a sparse array
G_mda_ppi.remove_edges_from(nx.selfloop_edges(G_mda_ppi))##### remove the loop here
adjacency_matrix_mda_ppi = to_scipy_sparse_array(G_mda_ppi, weight=" Edge weight")

# Create PyGSP graph
gsp_graph_mda_ppi= pg.graphs.Graph(adjacency_matrix_mda_ppi)

# Display basic graph info
print(f"PyGSP Graph MDA with {gsp_graph_mda_ppi.N} nodes and {gsp_graph_mda_ppi.Ne} edges.")
# Out:
# PyGSP Graph MDA with 1354 nodes and 463461 edges.

# %% [markdown]
# # **2.Compute the Laplacian Matrix**

# %%
# Compute Laplacian (default is combinatorial)
gsp_graph_mcf7_ppi.compute_laplacian(lap_type="combinatorial")
laplacian_mcf7_ppi = gsp_graph_mcf7_ppi.L

print("Laplacian Matrix MCF7 with ppi:")
print(laplacian_mcf7_ppi.toarray())  # Display dense matrix for small graphs
# Out:
# Laplacian Matrix MCF7 with ppi:
# [[246.   -0.5  -0.5 ...   0.    0.    0. ]
#  [ -0.5 429.5   0.  ...  -0.5  -0.5  -0.5]
#  [ -0.5   0.  429.5 ...  -0.5  -0.5  -0.5]
#  ...
#  [  0.   -0.5  -0.5 ... 242.    0.    0. ]
#  [  0.   -0.5  -0.5 ...   0.  242.    0. ]
#  [  0.   -0.5  -0.5 ...   0.    0.  242. ]]

# %%
# Compute Laplacian (default is combinatorial)
gsp_graph_mda_ppi.compute_laplacian(lap_type="combinatorial")
laplacian_mda_ppi = gsp_graph_mda_ppi.L

print("Laplacian Matrix Neg:")
print(laplacian_mda_ppi.toarray())  # Display dense matrix for small graphs
# Out:
# Laplacian Matrix Neg:
# [[272.   -0.5  -0.5 ...   0.    0.    0. ]
#  [ -0.5 429.5   0.  ...  -0.5  -0.5  -0.5]
#  [ -0.5   0.  429.5 ...  -0.5  -0.5  -0.5]
#  ...
#  [  0.   -0.5  -0.5 ... 268.    0.    0. ]
#  [  0.   -0.5  -0.5 ...   0.  268.    0. ]
#  [  0.   -0.5  -0.5 ...   0.    0.  268. ]]

# %% [markdown]
# # 3. Assign Graph Signal
# Assign RNa-seq data as the graph signal

# %%
import pandas as pd

# Load RNA-seq data
rna_seq_data = pd.read_csv("/content/drive/MyDrive/Essex_MSc_AI_24-25/MSc_Project_24/Data_to_work_with/GRAND_datasets/significant_genes_cleaned.tsv", sep='\t')  # Replace with your RNA-seq file
# Columns: gene, expression


# Extract nodes for G_mcf7 and G_mda
mcf7_genes_ppi = set(G_mcf7_ppi.nodes)
mda_genes_ppi = set(G_mda_ppi.nodes)
all_genes_in_graph = mcf7_genes_ppi.union(mda_genes_ppi)

# Filter RNA-seq data for genes in G_mcf7 and G_mda
mcf7_rna_seq = rna_seq_data[rna_seq_data['gene_name'].isin(mcf7_genes_ppi)]
mda_rna_seq = rna_seq_data[rna_seq_data['gene_name'].isin(mda_genes_ppi)]

# Create dictionaries for each graph
# Assign expression = 0 for genes not present in the RNA-seq data
expression_dict_mcf7_ppi = {gene: 0 for gene in mcf7_genes_ppi}  # Initialize all genes with expression = 0
expression_dict_mcf7_ppi.update(zip(mcf7_rna_seq['gene_name'], mcf7_rna_seq['MCF7']))  # Update with RNA-seq values

expression_dict_mda_ppi = {gene: 0 for gene in mda_genes_ppi}  # Initialize all genes with expression = 0
expression_dict_mda_ppi.update(zip(mda_rna_seq['gene_name'], mda_rna_seq['MDA-MB231']))  # Update with RNA-seq values

# Assign expression values to nodes in G_mcf7 and G_mda
nx.set_node_attributes(G_mcf7_ppi, expression_dict_mcf7_ppi, name='expression')
nx.set_node_attributes(G_mda_ppi, expression_dict_mda_ppi, name='expression')

# Verify attributes are set correctly
print("G_mcf7 node attributes:")
for node, data in G_mcf7_ppi.nodes(data=True):
    print(node, data)

print("\nG_mda node attributes:")
for node, data in G_mda_ppi.nodes(data=True):
    print(node, data)
# Out:
# G_mcf7 node attributes:
# AHR {'expression': 0}
# ABCA12 {'expression': 1181.5}
# ACKR3 {'expression': 3749.0}
# ACOT4 {'expression': 512.5}
# ACSL5 {'expression': 9.0}
# ADAMTS1 {'expression': 8.5}
# ADAMTS12 {'expression': 4.0}
# ADAMTS16 {'expression': 0.5}
# ADAMTS19 {'expression': 4024.375}
# ADCY1 {'expression': 19748.925}
# ADCY5 {'expression': 2689.5}
# ADD2 {'expression': 3.5}
# ADGRE1 {'expression': 0.5}
# ADGRF5 {'expression': 7.26}
# ADGRG5 {'expression': 162.0}
# ADRA2C {'expression': 980.5}
# ADRB2 {'expression': 5.0}
# AGPAT4 {'expression': 0.5}
# AGPS {'expression': 16.5}
# AGR3 {'expression': 1294.5}
# AK7 {'expression': 1026.99}
# AKR1B1 {'expression': 8.440000000000001}
# AKT3 {'expression': 7.515000000000001}
# ALDH2 {'expression': 12.185}
# ALDH3B2 {'expression': 1051.145}
# ALOX15 {'expression': 740.8399999999999}
# ANK2 {'expression': 5.5}
# ANKRD1 {'expression': 33.0}
# ANKRD33B {'expression': 1.5}
# ANKRD34B {'expression': 245.5}
# ANO3 {'expression': 1.0}
# ANTXR2 {'expression': 10.5}
# ANXA8L1 {'expression': 0.59}
# APOBEC3C {'expression': 4.0}
# APOL1 {'expression': 4.5}
# APOL3 {'expression': 2.0}
# APOL6 {'expression': 6.0}
# ARHGAP23 {'expression': 12.145}
# ARHGAP40 {'expression': 1.0}
# ARHGAP8 {'expression': 960.935}
# ARHGDIB {'expression': 40.5}
# ARHGDIG {'expression': 191.28}
# ASCL1 {'expression': 296.71500000000003}
# ASCL2 {'expression': 608.0}
# ATP10D {'expression': 0.5}
# AXL {'expression': 84.5}
# BATF3 {'expression': 1.0}
# BCAS1 {'expression': 1788.56}
# BCAT1 {'expression': 16.5}
# BCHE {'expression': 0.5}
# BEX4 {'expression': 77.57}
# BICC1 {'expression': 1.0}
# BICDL2 {'expression': 1483.825}
# BIRC3 {'expression': 13.02}
# BMP5 {'expression': 1808.0}
# BMP7 {'expression': 14484.17}
# BPIFB1 {'expression': 124.005}
# BRINP2 {'expression': 1036.5}
# BSPRY {'expression': 1852.0}
# BTNL9 {'expression': 170.0}
# C11orf52 {'expression': 481.5}
# C14orf132 {'expression': 1137.565}
# C19orf81 {'expression': 126.5}
# C1orf210 {'expression': 456.3}
# C4BPB {'expression': 2.0}
# CA8 {'expression': 439.0}
# CACNA1D {'expression': 262.265}
# CACNA2D4 {'expression': 3.5}
# CACNG4 {'expression': 13121.5}
# CALD1 {'expression': 7.0}
# CALML5 {'expression': 829.5}
# CAMK4 {'expression': 2.5}
# CAPN13 {'expression': 943.5}
# CAPN9 {'expression': 645.085}
# CARD11 {'expression': 8.5}
# CASP1 {'expression': 0.5}
# CASP4 {'expression': 7.5}
# CAVIN2 {'expression': 4.0}
# CAVIN3 {'expression': 2.5}
# CBFA2T3 {'expression': 4054.51}
# CBLN4 {'expression': 72.0}
# CBS {'expression': 1491.34}
# CCBE1 {'expression': 4.865}
# CCDC120 {'expression': 1054.0}
# CCDC170 {'expression': 2723.5}
# CCDC63 {'expression': 154.5}
# CCDC83 {'expression': 440.5}
# CD274 {'expression': 4.0}
# CD40 {'expression': 0.5}
# CD96 {'expression': 6.5}
# CDC42EP3 {'expression': 30.815}
# CDCP1 {'expression': 10.5}
# CDH1 {'expression': 42451.98}
# CDK15 {'expression': 1.5}
# CDKN2A {'expression': 65.66499999999999}
# CEACAM5 {'expression': 1614.075}
# CEACAM6 {'expression': 687.895}
# CELF2 {'expression': 3.0}
# CFH {'expression': 1.0}
# CHDH {'expression': 909.935}
# CHRM3 {'expression': 2.0}
# CHST2 {'expression': 3.5}
# CKMT1B {'expression': 704.6700000000001}
# CLDN1 {'expression': 3.0}
# CLSTN2 {'expression': 1451.5}
# CMTM7 {'expression': 9.3}
# CNN3 {'expression': 45.0}
# COL13A1 {'expression': 12.0}
# COL4A1 {'expression': 5.0}
# COL4A2 {'expression': 42.0}
# COL4A5 {'expression': 2259.0}
# COL4A6 {'expression': 94.0}
# COL8A1 {'expression': 4.5}
# COX7B2 {'expression': 1.0}
# CPA4 {'expression': 1.055}
# CPED1 {'expression': 4.55}
# CPNE8 {'expression': 1.0}
# CPVL {'expression': 2.0}
# CREB5 {'expression': 3.0}
# CST1 {'expression': 1.0}
# CST4 {'expression': 1.5}
# CT83 {'expression': 0.5}
# CTNND2 {'expression': 1769.0}
# CXCL1 {'expression': 0.5}
# CXCL12 {'expression': 772.0}
# CXCL2 {'expression': 0.5}
# CXCL8 {'expression': 1.0}
# CYBRD1 {'expression': 7.5}
# CYP27A1 {'expression': 1.5}
# DAW1 {'expression': 0.5}
# DCDC2 {'expression': 1119.645}
# DEGS2 {'expression': 1857.91}
# DGKG {'expression': 0.5}
# DIRAS2 {'expression': 146.5}
# DMRTA1 {'expression': 143.5}
# DNAJC12 {'expression': 339.0}
# DOCK8 {'expression': 1328.76}
# DOK7 {'expression': 1191.5}
# DRD1 {'expression': 287.5}
# DSCAM {'expression': 5994.0}
# EDIL3 {'expression': 7.5}
# EHD3 {'expression': 187.61}
# ELF5 {'expression': 137.5}
# ELOVL2 {'expression': 2531.5}
# ELOVL4 {'expression': 174.5}
# EMC10 {'expression': 5768.675}
# EMID1 {'expression': 314.5}
# EMP1 {'expression': 33.0}
# ENPP5 {'expression': 344.515}
# ENTPD2 {'expression': 728.5}
# ENTPD8 {'expression': 567.5}
# EPN3 {'expression': 2727.3}
# EPPK1 {'expression': 8488.57}
# ERBB3 {'expression': 11822.0}
# ERBB4 {'expression': 1829.5}
# EREG {'expression': 7.5}
# ESR1 {'expression': 13965.5}
# ESRP1 {'expression': 8080.0}
# ETS1 {'expression': 23.0}
# ETV1 {'expression': 4.5}
# EVA1A {'expression': 2.0}
# EVC {'expression': 2.5}
# EVI2A {'expression': 7.5}
# EVI2B {'expression': 4.5}
# EVPLL {'expression': 73.23}
# EYA1 {'expression': 0.5}
# EYA2 {'expression': 154.0}
# F2RL3 {'expression': 1.0}
# F3 {'expression': 119.595}
# FAM110C {'expression': 888.5}
# FAM133A {'expression': 0.5}
# FAM171A1 {'expression': 17.0}
# FAM178B {'expression': 237.465}
# FAM50B {'expression': 338.5}
# FAM83B {'expression': 2939.5}
# FGF5 {'expression': 11.5}
# FGFR2 {'expression': 472.5}
# FLG {'expression': 3.65}
# FLNC {'expression': 54.010000000000005}
# FLRT3 {'expression': 1065.0}
# FOSL1 {'expression': 64.0}
# FOXA2 {'expression': 4.5}
# FOXI3 {'expression': 81.57499999999999}
# FSD1 {'expression': 249.515}
# FST {'expression': 5.0}
# FSTL1 {'expression': 27.0}
# FUT9 {'expression': 924.5}
# FXYD3 {'expression': 9192.0}
# FXYD5 {'expression': 32.0}
# G0S2 {'expression': 1.5}
# GABRA3 {'expression': 0.5}
# GABRE {'expression': 0.5}
# GAL {'expression': 700.5}
# GBP1 {'expression': 3.135}
# GBP3 {'expression': 18.93}
# GCNT2 {'expression': 27.5}
# GFRA1 {'expression': 44219.5}
# GJA1 {'expression': 7.35}
# GLRA3 {'expression': 649.0}
# GLRB {'expression': 2.0}
# GMFG {'expression': 3.5}
# GNA15 {'expression': 4.5}
# GNG11 {'expression': 1.5}
# GOLT1A {'expression': 249.5}
# GP2 {'expression': 105.5}
# GPAT2 {'expression': 1.64}
# GPC4 {'expression': 912.0}
# GPR27 {'expression': 505.0}
# GPR37L1 {'expression': 1552.785}
# GPX1 {'expression': 8.0}
# GRHL2 {'expression': 6683.0}
# GRIK3 {'expression': 286.5}
# GSC {'expression': 270.5}
# GSTM1 {'expression': 8.475}
# GSTP1 {'expression': 1.5}
# HAS2 {'expression': 2.0}
# HENMT1 {'expression': 2042.62}
# HMGA2 {'expression': 10.5}
# HMGCLL1 {'expression': 837.0}
# HOXA10 {'expression': 404.215}
# HOXA4 {'expression': 110.215}
# HOXC13 {'expression': 886.9449999999999}
# HOXD3 {'expression': 1.5}
# HPDL {'expression': 550.0}
# HRH1 {'expression': 6.5}
# HRNR {'expression': 1.5}
# HS3ST3A1 {'expression': 736.24}
# HS6ST2 {'expression': 216.5}
# HSH2D {'expression': 1529.72}
# HTR1F {'expression': 0.5}
# HUNK {'expression': 203.5}
# ICAM2 {'expression': 1.3}
# IFI16 {'expression': 1.5}
# IFI44 {'expression': 7.5}
# IFI44L {'expression': 1.0}
# IFIT3 {'expression': 12.510000000000002}
# IGDCC3 {'expression': 544.0}
# IGF2BP3 {'expression': 5.585}
# IGFBP1 {'expression': 1.0}
# IGFBP2 {'expression': 3947.5}
# IGFBP5 {'expression': 1178.5}
# IL1RAPL1 {'expression': 0.5}
# IL31RA {'expression': 2.0}
# IL7R {'expression': 4.95}
# ILDR1 {'expression': 501.0}
# ILDR2 {'expression': 2.0}
# IQANK1 {'expression': 4166.845}
# IRF6 {'expression': 591.5}
# IRX2 {'expression': 952.19}
# IRX4 {'expression': 317.72}
# ITGBL1 {'expression': 1.5}
# KCNF1 {'expression': 118.0}
# KCNJ3 {'expression': 2125.5}
# KCNQ3 {'expression': 1.0}
# KCNQ5 {'expression': 3.5}
# KCTD14 {'expression': 6.32}
# KCTD15 {'expression': 1739.5}
# KCTD4 {'expression': 1.0}
# KDF1 {'expression': 609.0}
# KIAA0040 {'expression': 373.5}
# KIF1A {'expression': 763.005}
# KIF26A {'expression': 949.5}
# KIRREL1 {'expression': 6.5}
# KLHL9 {'expression': 1325.0}
# KLK11 {'expression': 520.77}
# KLRC2 {'expression': 0.5}
# KLRG2 {'expression': 176.0}
# LAD1 {'expression': 3463.495}
# LAMA1 {'expression': 0.5}
# LAMA4 {'expression': 2.0}
# LAPTM5 {'expression': 10.0}
# LARGE2 {'expression': 358.5}
# LAYN {'expression': 3.5}
# LDHB {'expression': 103.0}
# LDOC1 {'expression': 6003.5}
# LHFPL6 {'expression': 4.0}
# LHX1 {'expression': 319.315}
# LHX2 {'expression': 305.435}
# LIMCH1 {'expression': 66.5}
# LIMS2 {'expression': 2.0}
# LPAR1 {'expression': 5.0}
# LRP3 {'expression': 1727.8}
# LRRC10B {'expression': 461.5}
# LY96 {'expression': 0.5}
# LYPD3 {'expression': 4367.0}
# LYPD6B {'expression': 689.0}
# LYPD8 {'expression': 0.5}
# MACC1 {'expression': 753.5899999999999}
# MAGEA3 {'expression': 0.5}
# MAGEC1 {'expression': 6.5}
# MAGEC2 {'expression': 8.5}
# MAGEH1 {'expression': 448.5}
# MAL2 {'expression': 17172.78}
# MALRD1 {'expression': 425.5}
# MARVELD3 {'expression': 1178.935}
# MCAM {'expression': 21.0}
# MDFIC {'expression': 1.5}
# ME3 {'expression': 12.0}
# MGMT {'expression': 1093.0}
# MME {'expression': 104.0}
# MMEL1 {'expression': 150.94}
# MMP1 {'expression': 5.0}
# MMP14 {'expression': 51.0}
# MPP1 {'expression': 2.0}
# MPP4 {'expression': 4.5}
# MSI1 {'expression': 523.5}
# MSN {'expression': 121.925}
# MSRB3 {'expression': 5.525}
# MT1E {'expression': 9.0}
# MUC15 {'expression': 0.5}
# MYH14 {'expression': 7061.855}
# MYH15 {'expression': 0.5}
# MYL9 {'expression': 4.5}
# N4BP3 {'expression': 3147.0}
# NAP1L2 {'expression': 225.5}
# NAV3 {'expression': 24.0}
# NBPF4 {'expression': 238.63}
# NBPF6 {'expression': 417.245}
# NECAB1 {'expression': 3946.675}
# NECTIN4 {'expression': 951.0}
# NETO2 {'expression': 1110.0}
# NINJ2 {'expression': 1.0}
# NLRP1 {'expression': 4.5}
# NLRP3 {'expression': 1.515}
# NMNAT3 {'expression': 60.14}
# NNMT {'expression': 0.5}
# NOG {'expression': 0.5}
# NOVA1 {'expression': 510.0}
# NPNT {'expression': 3554.035}
# NRG1 {'expression': 5.5}
# NRK {'expression': 64.5}
# NRROS {'expression': 1.03}
# NTN1 {'expression': 1039.0}
# NUP210L {'expression': 633.0}
# OLFM1 {'expression': 3131.5}
# OOEP {'expression': 56.235}
# OVOL1 {'expression': 772.29}
# OVOL2 {'expression': 145.0}
# P3H2 {'expression': 8.0}
# PALM3 {'expression': 224.5}
# PCDH10 {'expression': 4885.0}
# PCDH8 {'expression': 72.0}
# PCDHA11 {'expression': 773.73}
# PCDHA12 {'expression': 323.515}
# PCDHAC2 {'expression': 302.025}
# PCDHGB5 {'expression': 1590.13}
# PCP4 {'expression': 712.5}
# PCSK1N {'expression': 1027.0}
# PCSK2 {'expression': 726.5}
# PDCD1LG2 {'expression': 0.5}
# PDE10A {'expression': 3.5}
# PDE4B {'expression': 0.5}
# PDGFRB {'expression': 0.5}
# PDIA2 {'expression': 112.0}
# PDLIM4 {'expression': 0.5}
# PDZD4 {'expression': 708.5}
# PDZRN3 {'expression': 290.81}
# PEG10 {'expression': 20.5}
# PGR {'expression': 2616.0}
# PHYHD1 {'expression': 3.0}
# PID1 {'expression': 1.0}
# PKP1 {'expression': 1287.0}
# PLA2G4A {'expression': 0.5}
# PLA2G4F {'expression': 241.5}
# PLCL2 {'expression': 2.5}
# PLCXD3 {'expression': 252.0}
# PLPPR5 {'expression': 176.5}
# PLS3 {'expression': 15.0}
# PNMA2 {'expression': 8.504999999999999}
# PNMA8A {'expression': 3.0700000000000003}
# POPDC3 {'expression': 4.0}
# PPARGC1A {'expression': 0.5}
# PPL {'expression': 4755.0}
# PPP4R3C {'expression': 0.5}
# PRDM8 {'expression': 2.5}
# PRDM9 {'expression': 1.0}
# PREX1 {'expression': 9755.5}
# PRKAA2 {'expression': 2.0}
# PROM2 {'expression': 1955.415}
# PRR15L {'expression': 2358.5}
# PRSS2 {'expression': 0.5}
# PRSS8 {'expression': 3366.135}
# PSAT1 {'expression': 15.5}
# PSMB8 {'expression': 12.5}
# PTPRM {'expression': 5.5}
# PTX3 {'expression': 3.0}
# QPRT {'expression': 1449.315}
# RAB17 {'expression': 2428.245}
# RAB25 {'expression': 2984.5}
# RAB34 {'expression': 13.0}
# RAB38 {'expression': 0.5}
# RAC2 {'expression': 8.0}
# RAMP3 {'expression': 2250.5}
# RASAL1 {'expression': 1079.545}
# RBBP8NL {'expression': 737.0}
# RBMS3 {'expression': 1.0}
# RBP7 {'expression': 71.5}
# RCSD1 {'expression': 2.5}
# REG4 {'expression': 235.5}
# RET {'expression': 5778.0}
# RFPL4AL1 {'expression': 0.5}
# RIMS4 {'expression': 559.26}
# RIPPLY3 {'expression': 443.32}
# RNF217 {'expression': 1.5}
# RNF223 {'expression': 1204.0}
# RNF43 {'expression': 3252.685}
# ROBO4 {'expression': 3.185}
# ROR1 {'expression': 4.5}
# RPS6KA6 {'expression': 391.565}
# RUBCNL {'expression': 110.0}
# RYR2 {'expression': 4.0}
# S100A14 {'expression': 11503.0}
# SAMD9L {'expression': 1.0}
# SCUBE2 {'expression': 4083.5}
# SDHAF3 {'expression': 1.0}
# SERPINE1 {'expression': 45.5}
# SFMBT2 {'expression': 589.0}
# SGCG {'expression': 274.5}
# SH3RF3 {'expression': 2.0}
# SHC2 {'expression': 66.0}
# SHISA3 {'expression': 1.0}
# SHISA9 {'expression': 824.5}
# SLAMF7 {'expression': 2.015}
# SLC17A9 {'expression': 12.5}
# SLC18B1 {'expression': 1.0}
# SLC24A3 {'expression': 2631.2}
# SLC27A6 {'expression': 534.0}
# SLC2A10 {'expression': 2506.5}
# SLC2A3 {'expression': 3.86}
# SLC35F3 {'expression': 3.0}
# SLC43A3 {'expression': 24.875}
# SLC4A4 {'expression': 0.5}
# SLC6A14 {'expression': 5494.24}
# SLC9A2 {'expression': 2277.5}
# SLCO1B3 {'expression': 2.5}
# SLFN12 {'expression': 2.5}
# SLITRK6 {'expression': 1279.5}
# SMIM22 {'expression': 701.665}
# SMOC2 {'expression': 67.0}
# SMTNL2 {'expression': 132.0}
# SNPH {'expression': 0.5}
# SOD3 {'expression': 1.0}
# SORBS2 {'expression': 2.0}
# SORCS1 {'expression': 282.0}
# SOX2 {'expression': 716.97}
# SOX3 {'expression': 691.0}
# SPAG16 {'expression': 2.0}
# SPANXB1 {'expression': 7.555}
# SPANXC {'expression': 1.56}
# SPARC {'expression': 8.5}
# SPESP1 {'expression': 138.6}
# SPINT1 {'expression': 3621.37}
# SPSB4 {'expression': 75.5}
# SPTSSB {'expression': 71375.5}
# SPX {'expression': 0.5}
# SRGN {'expression': 16.5}
# ST6GALNAC3 {'expression': 0.5}
# STAC {'expression': 0.5}
# STK31 {'expression': 2.5}
# STK33 {'expression': 3.0}
# SULF1 {'expression': 2108.0}
# SULF2 {'expression': 64968.94500000001}
# SULT2B1 {'expression': 1699.0}
# SYK {'expression': 775.5}
# SYT10 {'expression': 561.5}
# SYTL5 {'expression': 5805.0}
# TBX2 {'expression': 10104.5}
# TBX3 {'expression': 273.0}
# TCEAL9 {'expression': 1.0}
# TDRD5 {'expression': 281.5}
# TFCP2 {'expression': 3.5}
# TH {'expression': 191.5}
# THNSL2 {'expression': 735.5}
# TLE4 {'expression': 710.26}
# TLR4 {'expression': 2.0}
# TM4SF1 {'expression': 48.0}
# TM4SF18 {'expression': 5.5}
# TMEM125 {'expression': 623.5}
# TMEM156 {'expression': 8.0}
# TMEM178B {'expression': 1482.5}
# TMEM26 {'expression': 485.095}
# TMEM30B {'expression': 4239.81}
# TMEM71 {'expression': 1.0}
# TMEM92 {'expression': 1.0}
# AHRR {'expression': 0}
# AIRE {'expression': 0}
# ALX1 {'expression': 0}
# ALX3 {'expression': 2.55}
# ALX4 {'expression': 0}
# AR {'expression': 0}
# ARGFX {'expression': 0}
# ARID3A {'expression': 1360.36}
# ARID3B {'expression': 0}
# ARID5A {'expression': 0}
# ARID5B {'expression': 1756.5}
# ARNT {'expression': 3488.0}
# ARNT2 {'expression': 2226.21}
# ARNTL {'expression': 0}
# ARNTL2 {'expression': 0}
# ARX {'expression': 44.0}
# ASCL3 {'expression': 0}
# ASCL4 {'expression': 0}
# ATF1 {'expression': 0}
# ATF2 {'expression': 1435.4450000000002}
# ATF3 {'expression': 73.0}
# ATF4 {'expression': 5797.11}
# ATF5 {'expression': 0}
# ATF6 {'expression': 1613.5}
# ATF6B {'expression': 0}
# ATF7 {'expression': 0}
# ATOH1 {'expression': 0}
# ATOH7 {'expression': 8.0}
# BACH1 {'expression': 597.5}
# BACH2 {'expression': 10.0}
# BARHL1 {'expression': 2.5}
# BARHL2 {'expression': 0}
# BARX1 {'expression': 2.0}
# BARX2 {'expression': 407.0}
# BATF {'expression': 386.0}
# BCL11A {'expression': 0}
# BCL11B {'expression': 86.0}
# BCL6 {'expression': 0}
# BCL6B {'expression': 0}
# BHLHA15 {'expression': 5.0}
# BHLHE22 {'expression': 0}
# BHLHE40 {'expression': 740.0}
# BHLHE41 {'expression': 21.0}
# BPTF {'expression': 16436.115}
# BSX {'expression': 0}
# CDC5L {'expression': 0}
# CDX1 {'expression': 0}
# CDX2 {'expression': 0}
# CDX4 {'expression': 0}
# CEBPA {'expression': 705.56}
# CEBPB {'expression': 0}
# CEBPD {'expression': 0}
# CEBPE {'expression': 0}
# CEBPG {'expression': 0}
# CEBPZ {'expression': 2840.3950000000004}
# CENPB {'expression': 0}
# CIC {'expression': 0}
# CLOCK {'expression': 0}
# CPEB1 {'expression': 9.5}
# CREB1 {'expression': 0}
# CREB3 {'expression': 0}
# CREB3L1 {'expression': 44.0}
# CREB3L2 {'expression': 2230.5}
# CREB3L4 {'expression': 1883.745}
# CREBL2 {'expression': 0}
# CREBZF {'expression': 9441.5}
# CREM {'expression': 0}
# CRX {'expression': 0.51}
# CTCF {'expression': 0}
# CTCFL {'expression': 0}
# CUX1 {'expression': 13676.0}
# CUX2 {'expression': 6.0}
# CXXC1 {'expression': 0}
# DBP {'expression': 588.92}
# DBX1 {'expression': 0}
# DBX2 {'expression': 0}
# DDIT3 {'expression': 282.58000000000004}
# DLX1 {'expression': 271.0}
# DLX2 {'expression': 0}
# DLX3 {'expression': 341.5}
# DLX4 {'expression': 215.5}
# DLX5 {'expression': 1.5}
# DLX6 {'expression': 0}
# DMRT1 {'expression': 0}
# DMRT2 {'expression': 30.0}
# DMRT3 {'expression': 0}
# DMRTA2 {'expression': 1.0}
# DMRTC2 {'expression': 0}
# DNMT1 {'expression': 0}
# DPF1 {'expression': 0}
# DPF3 {'expression': 31.0}
# DPRX {'expression': 0}
# DRGX {'expression': 0}
# DUX4 {'expression': 0.5}
# E2F1 {'expression': 0}
# E2F2 {'expression': 1496.5}
# E2F3 {'expression': 1856.495}
# E2F4 {'expression': 0}
# E2F5 {'expression': 0}
# E2F6 {'expression': 0}
# E2F7 {'expression': 1952.0}
# E2F8 {'expression': 0}
# E4F1 {'expression': 0}
# EBF1 {'expression': 0}
# EBF2 {'expression': 6.0}
# EGR1 {'expression': 0}
# EGR2 {'expression': 1.5}
# EGR3 {'expression': 339.08500000000004}
# EGR4 {'expression': 1.0}
# EHF {'expression': 1.0}
# ELF1 {'expression': 5000.46}
# ELF2 {'expression': 0}
# ELF3 {'expression': 4358.7}
# ELF4 {'expression': 0}
# ELK1 {'expression': 0}
# ELK3 {'expression': 472.73}
# ELK4 {'expression': 0}
# EMX1 {'expression': 41.815}
# EMX2 {'expression': 0}
# EN1 {'expression': 0}
# EN2 {'expression': 0}
# EOMES {'expression': 0}
# EPAS1 {'expression': 0}
# ERF {'expression': 0}
# ERG {'expression': 17.0}
# ESR2 {'expression': 0}
# ESRRA {'expression': 0}
# ESRRB {'expression': 6.5}
# ESRRG {'expression': 38.5}
# ESX1 {'expression': 0}
# ETS2 {'expression': 741.0}
# ETV2 {'expression': 29.0}
# ETV3 {'expression': 0}
# ETV4 {'expression': 77.5}
# ETV5 {'expression': 87.0}
# ETV6 {'expression': 444.5}
# ETV7 {'expression': 1.5}
# EVX1 {'expression': 1.5}
# EVX2 {'expression': 0}
# FEV {'expression': 0}
# FEZF1 {'expression': 0}
# FEZF2 {'expression': 0}
# FIGLA {'expression': 0}
# FLI1 {'expression': 0.5}
# FOS {'expression': 0}
# FOSB {'expression': 41.0}
# FOSL2 {'expression': 0}
# FOXA1 {'expression': 13178.5}
# FOXA3 {'expression': 6.0}
# FOXB1 {'expression': 0}
# FOXB2 {'expression': 0}
# FOXC1 {'expression': 0}
# FOXC2 {'expression': 0.5}
# FOXD1 {'expression': 174.34}
# FOXD2 {'expression': 0}
# FOXD3 {'expression': 32.37}
# FOXD4 {'expression': 11.7}
# FOXD4L1 {'expression': 4.85}
# FOXD4L3 {'expression': 0}
# FOXD4L4 {'expression': 0}
# FOXD4L5 {'expression': 8.29}
# FOXD4L6 {'expression': 1.065}
# FOXE1 {'expression': 0.5}
# FOXE3 {'expression': 0}
# FOXF1 {'expression': 0}
# FOXF2 {'expression': 0}
# FOXG1 {'expression': 0}
# FOXH1 {'expression': 25.615}
# FOXI1 {'expression': 35.505}
# FOXI2 {'expression': 0}
# FOXJ1 {'expression': 7.0}
# FOXJ2 {'expression': 0}
# FOXJ3 {'expression': 0}
# FOXK1 {'expression': 0}
# FOXK2 {'expression': 0}
# FOXL1 {'expression': 2.01}
# FOXL2 {'expression': 0}
# FOXM1 {'expression': 5104.13}
# FOXN1 {'expression': 30.5}
# FOXN2 {'expression': 1050.5}
# FOXN3 {'expression': 0}
# FOXN4 {'expression': 0}
# FOXO1 {'expression': 0}
# FOXO3 {'expression': 5330.8}
# FOXO4 {'expression': 0}
# FOXO6 {'expression': 298.0}
# FOXP1 {'expression': 0}
# FOXP2 {'expression': 5.63}
# FOXP3 {'expression': 32.57}
# FOXP4 {'expression': 0}
# FOXQ1 {'expression': 3.0}
# FOXR1 {'expression': 3.0}
# FOXR2 {'expression': 0}
# FOXS1 {'expression': 0}
# GABPA {'expression': 0}
# GATA1 {'expression': 2.0}
# GATA2 {'expression': 1479.5}
# GATA3 {'expression': 48436.5}
# GATA4 {'expression': 0}
# GATA5 {'expression': 0}
# GATA6 {'expression': 358.58000000000004}
# GBX1 {'expression': 2.5}
# GBX2 {'expression': 0}
# GCM1 {'expression': 0.5}
# GCM2 {'expression': 2.0}
# GFI1 {'expression': 53.5}
# GFI1B {'expression': 0}
# GLI1 {'expression': 1.5}
# GLI2 {'expression': 2.5}
# GLI3 {'expression': 0}
# GLI4 {'expression': 0}
# GLIS1 {'expression': 0.5}
# GLIS2 {'expression': 0}
# GLIS3 {'expression': 17.0}
# GMEB1 {'expression': 0}
# GMEB2 {'expression': 0}
# GRHL1 {'expression': 1840.085}
# GSC2 {'expression': 0}
# GSX1 {'expression': 0}
# GSX2 {'expression': 0}
# GTF3A {'expression': 0}
# HAND1 {'expression': 0}
# HAND2 {'expression': 1.0}
# HBP1 {'expression': 2285.495}
# HDX {'expression': 3.0}
# HELT {'expression': 0}
# HES1 {'expression': 0}
# HES3 {'expression': 0}
# HES4 {'expression': 1161.5}
# HES5 {'expression': 0}
# HES6 {'expression': 1414.0}
# HES7 {'expression': 0.5}
# HESX1 {'expression': 25.0}
# HEY1 {'expression': 0}
# HEY2 {'expression': 332.0}
# HEYL {'expression': 45.5}
# HHEX {'expression': 276.0}
# HIC1 {'expression': 35.045}
# HIF1A {'expression': 0}
# HIF3A {'expression': 0}
# HINFP {'expression': 0}
# HIVEP1 {'expression': 0}
# HIVEP2 {'expression': 0}
# HIVEP3 {'expression': 928.0}
# HLF {'expression': 47.5}
# HLX {'expression': 0.5}
# HMBOX1 {'expression': 0}
# HMG20B {'expression': 0}
# HMGA1 {'expression': 4606.04}
# HMX1 {'expression': 0}
# HMX2 {'expression': 0}
# HMX3 {'expression': 0}
# HNF1A {'expression': 0}
# HNF1B {'expression': 0}
# HNF4A {'expression': 0}
# HNF4G {'expression': 5.0}
# HOMEZ {'expression': 0}
# HOXA1 {'expression': 0}
# HOXA11 {'expression': 0}
# HOXA13 {'expression': 0}
# HOXA2 {'expression': 0}
# HOXA3 {'expression': 15.07}
# HOXA5 {'expression': 0}
# HOXA6 {'expression': 0}
# HOXA7 {'expression': 66.34}
# HOXA9 {'expression': 5.0}
# HOXB1 {'expression': 2.5}
# HOXB13 {'expression': 5.0}
# HOXB2 {'expression': 27.78}
# HOXB3 {'expression': 36.61}
# HOXB4 {'expression': 1.5}
# HOXB5 {'expression': 0.5}
# HOXB6 {'expression': 15.475}
# HOXB7 {'expression': 282.94}
# HOXB8 {'expression': 0.5}
# HOXB9 {'expression': 24.0}
# HOXC12 {'expression': 0}
# HOXC4 {'expression': 32.035}
# HOXC5 {'expression': 8.4}
# HOXC6 {'expression': 241.535}
# HOXC8 {'expression': 16.0}
# HOXC9 {'expression': 185.5}
# HOXD1 {'expression': 4.0}
# HOXD10 {'expression': 0}
# HOXD11 {'expression': 0}
# HOXD12 {'expression': 0}
# HOXD13 {'expression': 0}
# HOXD4 {'expression': 0}
# HOXD8 {'expression': 0}
# HOXD9 {'expression': 2.0}
# HSF1 {'expression': 0}
# HSF2 {'expression': 0}
# IKZF1 {'expression': 0}
# IKZF2 {'expression': 1176.0}
# IKZF3 {'expression': 0}
# IKZF4 {'expression': 0}
# INSM1 {'expression': 0}
# IRF1 {'expression': 272.9}
# IRF2 {'expression': 0}
# IRF3 {'expression': 0}
# IRF4 {'expression': 0}
# IRF5 {'expression': 414.5}
# IRF7 {'expression': 0}
# IRF8 {'expression': 0}
# IRF9 {'expression': 0}
# IRX1 {'expression': 0}
# IRX3 {'expression': 0}
# IRX5 {'expression': 602.6800000000001}
# IRX6 {'expression': 0}
# ISL1 {'expression': 0}
# ISL2 {'expression': 0}
# JDP2 {'expression': 0}
# JUN {'expression': 1819.0}
# JUNB {'expression': 2414.24}
# JUND {'expression': 5398.0}
# KDM2B {'expression': 0}
# KLF1 {'expression': 0}
# KLF10 {'expression': 0}
# KLF11 {'expression': 0}
# KLF12 {'expression': 0}
# KLF13 {'expression': 0}
# KLF14 {'expression': 1.5}
# KLF15 {'expression': 10.0}
# KLF16 {'expression': 768.955}
# KLF17 {'expression': 0.5}
# KLF2 {'expression': 96.5}
# KLF3 {'expression': 2626.75}
# KLF4 {'expression': 0}
# KLF5 {'expression': 0}
# KLF6 {'expression': 1342.5}
# KLF7 {'expression': 0}
# KLF8 {'expression': 102.5}
# KLF9 {'expression': 1071.5}
# KMT2A {'expression': 0}
# LBX1 {'expression': 0}
# LCOR {'expression': 0}
# LEF1 {'expression': 27.5}
# LHX3 {'expression': 0}
# LHX4 {'expression': 589.485}
# LHX5 {'expression': 0}
# LHX6 {'expression': 104.0}
# LHX8 {'expression': 0}
# LHX9 {'expression': 0}
# LIN28A {'expression': 0}
# LIN28B {'expression': 0}
# LMX1A {'expression': 0}
# LMX1B {'expression': 3646.05}
# LYL1 {'expression': 1.5}
# MAF {'expression': 41.5}
# MAFA {'expression': 225.5}
# MAFB {'expression': 474.0}
# MAFF {'expression': 53.5}
# MAFG {'expression': 1397.955}
# MAFK {'expression': 0}
# MAX {'expression': 0}
# MAZ {'expression': 19778.64}
# MBD2 {'expression': 0}
# MBNL2 {'expression': 764.0}
# MECOM {'expression': 585.0}
# MECP2 {'expression': 0}
# MEF2A {'expression': 0}
# MEF2C {'expression': 2.5}
# MEF2D {'expression': 0}
# MEIS1 {'expression': 556.385}
# MEIS2 {'expression': 0}
# MEOX1 {'expression': 0}
# MEOX2 {'expression': 0}
# MESP1 {'expression': 199.0}
# MESP2 {'expression': 21.5}
# MGA {'expression': 0}
# MITF {'expression': 83.0}
# MIXL1 {'expression': 0}
# MLX {'expression': 0}
# MLXIPL {'expression': 306.0}
# MNT {'expression': 0}
# MNX1 {'expression': 524.5}
# MSC {'expression': 0}
# MSGN1 {'expression': 0}
# MSX1 {'expression': 62.5}
# MSX2 {'expression': 1593.99}
# MXD3 {'expression': 1318.8449999999998}
# MXI1 {'expression': 0}
# MYB {'expression': 3067.76}
# MYBL1 {'expression': 0}
# MYBL2 {'expression': 0}
# MYC {'expression': 1691.5}
# MYCL {'expression': 224.0}
# MYCN {'expression': 0}
# MYF5 {'expression': 0}
# MYF6 {'expression': 0}
# MYNN {'expression': 0}
# MYOD1 {'expression': 0}
# MYOG {'expression': 0}
# MYRF {'expression': 75.0}
# MYT1L {'expression': 1.0}
# MZF1 {'expression': 0}
# NAIF1 {'expression': 0}
# NANOG {'expression': 0}
# NEUROD1 {'expression': 0}
# NEUROD2 {'expression': 0}
# NEUROD4 {'expression': 0}
# NEUROD6 {'expression': 0}
# NEUROG1 {'expression': 0}
# NEUROG2 {'expression': 0}
# NEUROG3 {'expression': 0}
# NFAT5 {'expression': 0}
# NFATC1 {'expression': 415.5}
# NFATC2 {'expression': 0}
# NFATC3 {'expression': 0}
# NFATC4 {'expression': 0}
# NFE2 {'expression': 0}
# NFE2L1 {'expression': 0}
# NFE2L2 {'expression': 0}
# NFE2L3 {'expression': 620.0550000000001}
# NFIA {'expression': 11.0}
# NFIB {'expression': 0}
# NFIC {'expression': 0}
# NFIL3 {'expression': 0}
# NFIX {'expression': 227.28}
# NFKB1 {'expression': 0}
# NFKB2 {'expression': 903.01}
# NFYA {'expression': 0}
# NFYB {'expression': 0}
# NFYC {'expression': 0}
# NHLH1 {'expression': 0}
# NHLH2 {'expression': 0}
# NKX1-2 {'expression': 0}
# NKX2-1 {'expression': 1.0}
# NKX2-2 {'expression': 0}
# NKX2-3 {'expression': 0}
# NKX2-4 {'expression': 0}
# NKX2-5 {'expression': 0}
# NKX2-6 {'expression': 0}
# NKX2-8 {'expression': 8.0}
# NKX3-1 {'expression': 92.5}
# NKX3-2 {'expression': 0}
# NKX6-1 {'expression': 2.0}
# NKX6-2 {'expression': 0}
# NKX6-3 {'expression': 0}
# NOBOX {'expression': 0}
# NOTO {'expression': 0}
# NPAS1 {'expression': 19.5}
# NPAS2 {'expression': 321.59}
# NPAS3 {'expression': 0}
# NR0B1 {'expression': 0}
# NR1D1 {'expression': 123.47}
# NR1D2 {'expression': 0}
# NR1H2 {'expression': 0}
# NR1H3 {'expression': 0}
# NR1H4 {'expression': 0}
# NR1I2 {'expression': 0}
# NR1I3 {'expression': 7.84}
# NR2C1 {'expression': 0}
# NR2C2 {'expression': 0}
# NR2E1 {'expression': 0}
# NR2E3 {'expression': 33.5}
# NR2F1 {'expression': 36.21}
# NR2F2 {'expression': 18510.0}
# NR2F6 {'expression': 0}
# NR3C1 {'expression': 1673.455}
# NR3C2 {'expression': 10.5}
# NR4A1 {'expression': 355.34}
# NR4A2 {'expression': 803.5}
# NR4A3 {'expression': 226.5}
# NR5A1 {'expression': 0}
# NR5A2 {'expression': 111.5}
# NR6A1 {'expression': 0}
# NRF1 {'expression': 0}
# NRL {'expression': 0}
# OLIG1 {'expression': 0}
# OLIG2 {'expression': 0}
# OLIG3 {'expression': 0}
# ONECUT1 {'expression': 40.0}
# ONECUT2 {'expression': 463.0}
# ONECUT3 {'expression': 0.5}
# OSR1 {'expression': 5.5}
# OSR2 {'expression': 2290.5}
# OTP {'expression': 7.0}
# OTX1 {'expression': 0}
# OTX2 {'expression': 0}
# PATZ1 {'expression': 3322.0}
# PAX1 {'expression': 0}
# PAX2 {'expression': 1.5}
# PAX3 {'expression': 0}
# PAX4 {'expression': 0}
# PAX5 {'expression': 98.5}
# PAX6 {'expression': 30.0}
# PAX7 {'expression': 0}
# PAX8 {'expression': 0}
# PAX9 {'expression': 589.84}
# PBX1 {'expression': 5848.0}
# PBX2 {'expression': 0}
# PBX3 {'expression': 1949.0}
# PBX4 {'expression': 0}
# PDX1 {'expression': 0}
# PHOX2A {'expression': 0}
# PHOX2B {'expression': 0}
# PITX1 {'expression': 460.0}
# PITX2 {'expression': 0}
# PITX3 {'expression': 29.0}
# PKNOX1 {'expression': 0}
# PKNOX2 {'expression': 5.5}
# PLAG1 {'expression': 10.0}
# PLAGL1 {'expression': 147.0}
# POU1F1 {'expression': 0}
# POU2F1 {'expression': 0}
# POU2F2 {'expression': 36.0}
# POU2F3 {'expression': 55.5}
# POU3F1 {'expression': 0}
# POU3F2 {'expression': 22.5}
# POU3F3 {'expression': 0}
# POU3F4 {'expression': 0}
# POU4F1 {'expression': 0}
# POU4F2 {'expression': 0}
# POU4F3 {'expression': 0}
# POU5F1 {'expression': 0}
# POU5F1B {'expression': 4.555}
# POU6F1 {'expression': 12.5}
# POU6F2 {'expression': 0}
# PPARA {'expression': 0}
# PPARD {'expression': 0}
# PPARG {'expression': 394.0}
# PRDM1 {'expression': 4.5}
# PRDM14 {'expression': 0}
# PRDM16 {'expression': 173.5}
# PRDM6 {'expression': 349.9}
# PROP1 {'expression': 0}
# PROX1 {'expression': 0}
# PRRX1 {'expression': 0}
# PRRX2 {'expression': 64.5}
# PTF1A {'expression': 0}
# RARA {'expression': 2399.685}
# RARB {'expression': 4.5}
# RARG {'expression': 3692.29}
# RAX {'expression': 0}
# RBPJ {'expression': 2904.8900000000003}
# RBPJL {'expression': 1.0}
# REL {'expression': 0}
# RELA {'expression': 0}
# RELB {'expression': 53.5}
# REST {'expression': 0}
# RFX2 {'expression': 0}
# RFX3 {'expression': 0}
# RFX4 {'expression': 0.5}
# RFX5 {'expression': 0}
# RFX6 {'expression': 0}
# RFX7 {'expression': 0}
# RORA {'expression': 0}
# RORB {'expression': 1.0}
# RORC {'expression': 117.24}
# RREB1 {'expression': 2786.5}
# RUNX1 {'expression': 0}
# RUNX2 {'expression': 370.0}
# RUNX3 {'expression': 2.0}
# RXRA {'expression': 13546.5}
# RXRB {'expression': 0}
# RXRG {'expression': 0}
# SCRT1 {'expression': 11.5}
# SCRT2 {'expression': 0}
# SHOX {'expression': 0.5}
# SHOX2 {'expression': 28.5}
# SIM1 {'expression': 202.5}
# SIM2 {'expression': 160.0}
# SIX1 {'expression': 481.5}
# SIX2 {'expression': 0}
# SIX3 {'expression': 0}
# SIX4 {'expression': 0}
# SIX5 {'expression': 706.05}
# SIX6 {'expression': 0}
# SKOR1 {'expression': 0}
# SKOR2 {'expression': 0}
# SMAD1 {'expression': 0}
# SMAD3 {'expression': 4715.0}
# SMAD4 {'expression': 0}
# SMAD5 {'expression': 0}
# SMAD9 {'expression': 32.645}
# SNAI1 {'expression': 27.5}
# SNAI2 {'expression': 23.0}
# SOX1 {'expression': 0}
# SOX10 {'expression': 0}
# SOX11 {'expression': 0}
# SOX12 {'expression': 2394.0}
# SOX13 {'expression': 0}
# SOX14 {'expression': 0}
# SOX15 {'expression': 0}
# SOX17 {'expression': 0}
# SOX18 {'expression': 113.5}
# SOX21 {'expression': 1.51}
# SOX30 {'expression': 0}
# SOX4 {'expression': 4609.5}
# SOX5 {'expression': 0.5}
# SOX6 {'expression': 0}
# SOX7 {'expression': 7.27}
# SOX8 {'expression': 0}
# SOX9 {'expression': 578.0}
# SP1 {'expression': 0}
# SP2 {'expression': 0}
# SP3 {'expression': 0}
# SP4 {'expression': 0}
# SP5 {'expression': 2.5}
# SP6 {'expression': 402.98}
# SP7 {'expression': 0}
# SP8 {'expression': 0}
# SP9 {'expression': 0}
# SPDEF {'expression': 5197.0}
# SPI1 {'expression': 0}
# SPIB {'expression': 8.02}
# SPZ1 {'expression': 0}
# SREBF1 {'expression': 12348.18}
# SREBF2 {'expression': 0}
# SRF {'expression': 0}
# STAT1 {'expression': 0}
# STAT2 {'expression': 0}
# STAT3 {'expression': 2930.4300000000003}
# STAT4 {'expression': 0}
# STAT5A {'expression': 32.230000000000004}
# STAT5B {'expression': 0}
# STAT6 {'expression': 440.325}
# T {'expression': 0}
# TAL1 {'expression': 0}
# TAL2 {'expression': 3.5}
# TBP {'expression': 0}
# TBPL2 {'expression': 0.5}
# TBR1 {'expression': 0}
# TBX1 {'expression': 9.425}
# TBX10 {'expression': 2.5}
# TBX15 {'expression': 6.5}
# TBX18 {'expression': 0}
# TBX19 {'expression': 0}
# TBX20 {'expression': 0}
# TBX21 {'expression': 0}
# TBX4 {'expression': 35.5}
# TBX5 {'expression': 3.0}
# TBX6 {'expression': 175.5}
# TCF12 {'expression': 1200.5}
# TCF15 {'expression': 0}
# TCF23 {'expression': 1.5}
# TCF3 {'expression': 0}
# TCF4 {'expression': 1.0}
# TCF7 {'expression': 53.0}
# TCF7L1 {'expression': 0}
# TCF7L2 {'expression': 397.0}
# TEAD1 {'expression': 4047.0}
# TEAD2 {'expression': 0}
# TEAD3 {'expression': 0}
# TEAD4 {'expression': 526.96}
# TEF {'expression': 1196.0}
# TERF2 {'expression': 0}
# TET1 {'expression': 0}
# TFAP2A {'expression': 1525.665}
# TFAP2B {'expression': 0}
# TFAP2C {'expression': 4442.0}
# TFAP2D {'expression': 0}
# TFAP2E {'expression': 15.5}
# TFAP4 {'expression': 0}
# TFCP2L1 {'expression': 11.5}
# TFDP1 {'expression': 4659.205}
# TFDP3 {'expression': 0}
# TFE3 {'expression': 0}
# TFEB {'expression': 0}
# TFEC {'expression': 1.5}
# TGIF1 {'expression': 0}
# TGIF2 {'expression': 0}
# TGIF2LX {'expression': 0}
# THAP1 {'expression': 0}
# THRA {'expression': 0}
# THRB {'expression': 980.5}
# TLX1 {'expression': 1.0}
# TLX2 {'expression': 0}
# TLX3 {'expression': 0}
# TOPORS {'expression': 0}
# TP53 {'expression': 0}
# TP63 {'expression': 24.0}
# TP73 {'expression': 923.12}
# TWIST1 {'expression': 0}
# TWIST2 {'expression': 0}
# UBP1 {'expression': 0}
# UNCX {'expression': 0}
# USF1 {'expression': 0}
# USF2 {'expression': 0}
# VAX1 {'expression': 0}
# VAX2 {'expression': 101.0}
# VDR {'expression': 0}
# VENTX {'expression': 3.5}
# VSX1 {'expression': 5.5}
# VSX2 {'expression': 1.0}
# WT1 {'expression': 0}
# XBP1 {'expression': 33344.7}
# XPA {'expression': 0}
# YBX1 {'expression': 0}
# YBX2 {'expression': 1905.44}
# YY1 {'expression': 0}
# YY2 {'expression': 0}
# ZBED1 {'expression': 0}
# ZBTB1 {'expression': 0}
# ZBTB12 {'expression': 0}
# ZBTB14 {'expression': 0}
# ZBTB18 {'expression': 32.5}
# ZBTB2 {'expression': 0}
# ZBTB20 {'expression': 0.5}
# ZBTB22 {'expression': 0}
# ZBTB3 {'expression': 304.625}
# ZBTB32 {'expression': 28.0}
# ZBTB33 {'expression': 0}
# ZBTB4 {'expression': 0}
# ZBTB42 {'expression': 1644.0}
# ZBTB43 {'expression': 0}
# ZBTB45 {'expression': 913.555}
# ZBTB48 {'expression': 0}
# ZBTB49 {'expression': 0}
# ZBTB6 {'expression': 0}
# ZBTB7A {'expression': 0}
# ZBTB7B {'expression': 2907.0}
# ZBTB7C {'expression': 0}
# ZEB1 {'expression': 36.22}
# ZEB2 {'expression': 4.58}
# ZFHX2 {'expression': 0}
# ZFHX3 {'expression': 5792.54}
# ZFHX4 {'expression': 1.0}
# ZFP1 {'expression': 1242.5}
# ZFP42 {'expression': 0}
# ZFP57 {'expression': 0}
# ZFP64 {'expression': 0}
# ZFX {'expression': 0}
# ZIC1 {'expression': 953.5}
# ZIC2 {'expression': 250.0}
# ZIC3 {'expression': 0}
# ZIC4 {'expression': 535.96}
# ZIC5 {'expression': 0}
# ZIM2 {'expression': 0}
# ZKSCAN1 {'expression': 5732.435}
# ZKSCAN2 {'expression': 0}
# ZKSCAN3 {'expression': 129.28}
# ZKSCAN7 {'expression': 6.390000000000001}
# ZNF114 {'expression': 0}
# ZNF132 {'expression': 52.5}
# ZNF135 {'expression': 0}
# ZNF141 {'expression': 0}
# ZNF143 {'expression': 0}
# ZNF146 {'expression': 0}
# ZNF148 {'expression': 0}
# ZNF174 {'expression': 0}
# ZNF18 {'expression': 311.915}
# ZNF182 {'expression': 0}
# ZNF184 {'expression': 0}
# ZNF2 {'expression': 0}
# ZNF202 {'expression': 411.5}
# ZNF219 {'expression': 0}
# ZNF232 {'expression': 0}
# ZNF235 {'expression': 266.485}
# ZNF248 {'expression': 765.815}
# ZNF250 {'expression': 0}
# ZNF263 {'expression': 0}
# ZNF274 {'expression': 0}
# ZNF276 {'expression': 2172.64}
# ZNF280A {'expression': 0}
# ZNF281 {'expression': 0}
# ZNF296 {'expression': 0}
# ZNF30 {'expression': 0}
# ZNF300 {'expression': 15.0}
# ZNF302 {'expression': 0}
# ZNF311 {'expression': 0}
# ZNF32 {'expression': 0}
# ZNF334 {'expression': 0}
# ZNF35 {'expression': 200.0}
# ZNF350 {'expression': 0}
# ZNF354C {'expression': 0}
# ZNF384 {'expression': 0}
# ZNF398 {'expression': 0}
# ZNF41 {'expression': 742.5}
# ZNF410 {'expression': 0}
# ZNF416 {'expression': 0}
# ZNF423 {'expression': 22.0}
# ZNF436 {'expression': 0}
# ZNF44 {'expression': 0}
# ZNF467 {'expression': 1355.0}
# ZNF487 {'expression': 167.0}
# ZNF501 {'expression': 0.5}
# ZNF513 {'expression': 127.475}
# ZNF519 {'expression': 0}
# ZNF524 {'expression': 0}
# ZNF529 {'expression': 247.82}
# ZNF534 {'expression': 0}
# ZNF552 {'expression': 417.86}
# ZNF554 {'expression': 0}
# ZNF571 {'expression': 0}
# ZNF589 {'expression': 0}
# ZNF594 {'expression': 0}
# ZNF597 {'expression': 0}
# ZNF641 {'expression': 817.755}
# ZNF649 {'expression': 0}
# ZNF653 {'expression': 0}
# ZNF655 {'expression': 8.515}
# ZNF667 {'expression': 0}
# ZNF675 {'expression': 747.645}
# ZNF691 {'expression': 0}
# ZNF692 {'expression': 0}
# ZNF7 {'expression': 0}
# ZNF707 {'expression': 0}
# ZNF711 {'expression': 107.39}
# ZNF730 {'expression': 93.835}
# ZNF74 {'expression': 0}
# ZNF740 {'expression': 0}
# ZNF75D {'expression': 1697.535}
# ZNF76 {'expression': 0}
# ZNF766 {'expression': 911.055}
# ZNF768 {'expression': 3321.375}
# ZNF776 {'expression': 0}
# ZNF777 {'expression': 0}
# ZNF785 {'expression': 910.52}
# ZNF787 {'expression': 0}
# ZNF79 {'expression': 0}
# ZNF790 {'expression': 0}
# ZNF8 {'expression': 0}
# ZNF860 {'expression': 0}
# ZSCAN1 {'expression': 0}
# ZSCAN10 {'expression': 0.5}
# ZSCAN16 {'expression': 0}
# ZSCAN22 {'expression': 0}
# ZSCAN26 {'expression': 0}
# ZSCAN29 {'expression': 0}
# ZSCAN30 {'expression': 121.625}
# ZSCAN4 {'expression': 0}
# ZSCAN5A {'expression': 150.95999999999998}
# ZSCAN9 {'expression': 0}
#
# G_mda node attributes:
# AHR {'expression': 0}
# ABCA12 {'expression': 3.333333333333333}
# ACKR3 {'expression': 4.0}
# ACOT4 {'expression': 2.6666666666666665}
# ACSL5 {'expression': 5231.849999999999}
# ADAMTS1 {'expression': 1691.3333333333333}
# ADAMTS12 {'expression': 1610.6666666666667}
# ADAMTS16 {'expression': 310.3333333333333}
# ADAMTS19 {'expression': 7.399999999999999}
# ADCY1 {'expression': 17.46}
# ADCY5 {'expression': 10.966666666666669}
# ADD2 {'expression': 2348.6666666666665}
# ADGRE1 {'expression': 120.66666666666669}
# ADGRF5 {'expression': 9675.113333333336}
# ADGRG5 {'expression': 0.3333333333333333}
# ADRA2C {'expression': 3.6666666666666665}
# ADRB2 {'expression': 2529.6666666666665}
# AGPAT4 {'expression': 610.3333333333334}
# AGPS {'expression': 6923.0}
# AGR3 {'expression': 0.6666666666666666}
# AK7 {'expression': 5.666666666666667}
# AKR1B1 {'expression': 5195.1033333333335}
# AKT3 {'expression': 2863.2100000000005}
# ALDH2 {'expression': 2863.0}
# ALDH3B2 {'expression': 0.68}
# ALOX15 {'expression': 1.6666666666666667}
# ANK2 {'expression': 1038.6666666666667}
# ANKRD1 {'expression': 19683.0}
# ANKRD33B {'expression': 373.41}
# ANKRD34B {'expression': 0.3333333333333333}
# ANO3 {'expression': 236.21}
# ANTXR2 {'expression': 10715.666666666666}
# ANXA8L1 {'expression': 163.82333333333332}
# APOBEC3C {'expression': 1283.6966666666667}
# APOL1 {'expression': 806.6533333333333}
# APOL3 {'expression': 550.68}
# APOL6 {'expression': 1919.493333333333}
# ARHGAP23 {'expression': 6119.333333333333}
# ARHGAP40 {'expression': 398.3333333333333}
# ARHGAP8 {'expression': 1.0}
# ARHGDIB {'expression': 9505.333333333334}
# ARHGDIG {'expression': 1.0}
# ASCL1 {'expression': 1.3333333333333333}
# ASCL2 {'expression': 0.6666666666666666}
# ATP10D {'expression': 1417.743333333333}
# AXL {'expression': 53569.41666666666}
# BATF3 {'expression': 323.3333333333333}
# BCAS1 {'expression': 5.333333333333333}
# BCAT1 {'expression': 7962.603333333333}
# BCHE {'expression': 816.6666666666666}
# BEX4 {'expression': 0.3333333333333333}
# BICC1 {'expression': 556.6666666666666}
# BICDL2 {'expression': 5.333333333333333}
# BIRC3 {'expression': 2386.6199999999994}
# BMP5 {'expression': 8.666666666666666}
# BMP7 {'expression': 10.333333333333334}
# BPIFB1 {'expression': 0.6666666666666666}
# BRINP2 {'expression': 2.0}
# BSPRY {'expression': 2.333333333333333}
# BTNL9 {'expression': 1.0}
# C11orf52 {'expression': 1.6666666666666667}
# C14orf132 {'expression': 2.0}
# C19orf81 {'expression': 0.6666666666666666}
# C1orf210 {'expression': 1.3333333333333333}
# C4BPB {'expression': 415.3333333333333}
# CA8 {'expression': 1.0}
# CACNA1D {'expression': 1.0}
# CACNA2D4 {'expression': 1312.6666666666667}
# CACNG4 {'expression': 13.996666666666664}
# CALD1 {'expression': 4827.0}
# CALML5 {'expression': 1.3333333333333333}
# CAMK4 {'expression': 973.0}
# CAPN13 {'expression': 2.0}
# CAPN9 {'expression': 2.333333333333333}
# CARD11 {'expression': 3599.67}
# CASP1 {'expression': 209.53}
# CASP4 {'expression': 2687.33}
# CAVIN2 {'expression': 5742.2733333333335}
# CAVIN3 {'expression': 2632.6666666666665}
# CBFA2T3 {'expression': 2.333333333333333}
# CBLN4 {'expression': 0.3333333333333333}
# CBS {'expression': 2.8166666666666664}
# CCBE1 {'expression': 2792.083333333333}
# CCDC120 {'expression': 4.0}
# CCDC170 {'expression': 1.6666666666666667}
# CCDC63 {'expression': 0.3333333333333333}
# CCDC83 {'expression': 1.0}
# CD274 {'expression': 958.3333333333334}
# CD40 {'expression': 1843.3333333333333}
# CD96 {'expression': 3278.333333333333}
# CDC42EP3 {'expression': 15019.783333333333}
# CDCP1 {'expression': 5995.329999999999}
# CDH1 {'expression': 35.333333333333336}
# CDK15 {'expression': 713.6833333333334}
# CDKN2A {'expression': 0.3333333333333333}
# CEACAM5 {'expression': 0.3733333333333333}
# CEACAM6 {'expression': 1.0266666666666666}
# CELF2 {'expression': 1514.3333333333333}
# CFH {'expression': 840.6533333333333}
# CHDH {'expression': 4.003333333333333}
# CHRM3 {'expression': 588.3266666666667}
# CHST2 {'expression': 736.9866666666667}
# CKMT1B {'expression': 1.096666666666667}
# CLDN1 {'expression': 685.3333333333334}
# CLSTN2 {'expression': 1.0033333333333332}
# CMTM7 {'expression': 2364.74}
# CNN3 {'expression': 20332.666666666668}
# COL13A1 {'expression': 10099.666666666666}
# COL4A1 {'expression': 3608.0}
# COL4A2 {'expression': 9611.136666666667}
# COL4A5 {'expression': 3.0}
# COL4A6 {'expression': 0.3333333333333333}
# COL8A1 {'expression': 1507.33}
# COX7B2 {'expression': 690.3333333333334}
# CPA4 {'expression': 725.0}
# CPED1 {'expression': 1170.8633333333337}
# CPNE8 {'expression': 1283.0}
# CPVL {'expression': 949.8666666666668}
# CREB5 {'expression': 1267.3333333333333}
# CST1 {'expression': 508.12000000000006}
# CST4 {'expression': 361.52}
# CT83 {'expression': 97.66666666666669}
# CTNND2 {'expression': 4.0}
# CXCL1 {'expression': 231.22}
# CXCL12 {'expression': 0.6666666666666666}
# CXCL2 {'expression': 117.55333333333331}
# CXCL8 {'expression': 1144.0}
# CYBRD1 {'expression': 4408.0}
# CYP27A1 {'expression': 284.0}
# DAW1 {'expression': 453.3333333333333}
# DCDC2 {'expression': 5.666666666666667}
# DEGS2 {'expression': 2.01}
# DGKG {'expression': 593.6666666666666}
# DIRAS2 {'expression': 0.3333333333333333}
# DMRTA1 {'expression': 0.3333333333333333}
# DNAJC12 {'expression': 1.3333333333333333}
# DOCK8 {'expression': 4.126666666666666}
# DOK7 {'expression': 3.6666666666666665}
# DRD1 {'expression': 0.3333333333333333}
# DSCAM {'expression': 17.0}
# EDIL3 {'expression': 7042.996666666667}
# EHD3 {'expression': 0.3333333333333333}
# ELF5 {'expression': 0.6666666666666666}
# ELOVL2 {'expression': 7.666666666666667}
# ELOVL4 {'expression': 0.3333333333333333}
# EMC10 {'expression': 8.01}
# EMID1 {'expression': 1.6666666666666667}
# EMP1 {'expression': 12112.0}
# ENPP5 {'expression': 0.6666666666666666}
# ENTPD2 {'expression': 0.3333333333333333}
# ENTPD8 {'expression': 2.6666666666666665}
# EPN3 {'expression': 8.333333333333334}
# EPPK1 {'expression': 24.10333333333333}
# ERBB3 {'expression': 67.33333333333333}
# ERBB4 {'expression': 6.0}
# EREG {'expression': 4359.666666666667}
# ESR1 {'expression': 34.333333333333336}
# ESRP1 {'expression': 24.666666666666668}
# ETS1 {'expression': 12376.483333333332}
# ETV1 {'expression': 2663.0}
# EVA1A {'expression': 1012.6666666666666}
# EVC {'expression': 1227.65}
# EVI2A {'expression': 2093.713333333333}
# EVI2B {'expression': 863.6233333333333}
# EVPLL {'expression': 0.35}
# EYA1 {'expression': 114.92666666666666}
# EYA2 {'expression': 0.3333333333333333}
# F2RL3 {'expression': 190.0}
# F3 {'expression': 24922.123333333333}
# FAM110C {'expression': 1.0}
# FAM133A {'expression': 1002.6666666666666}
# FAM171A1 {'expression': 3587.333333333333}
# FAM178B {'expression': 0.6666666666666666}
# FAM50B {'expression': 1.0}
# FAM83B {'expression': 2.6666666666666665}
# FGF5 {'expression': 6164.466666666667}
# FGFR2 {'expression': 1.6666666666666667}
# FLG {'expression': 2261.15}
# FLNC {'expression': 22592.41}
# FLRT3 {'expression': 1.3333333333333333}
# FOSL1 {'expression': 14956.01}
# FOXA2 {'expression': 1725.0}
# FOXI3 {'expression': 0.3333333333333333}
# FSD1 {'expression': 0.7066666666666667}
# FST {'expression': 2468.6666666666665}
# FSTL1 {'expression': 8757.0}
# FUT9 {'expression': 1.0}
# FXYD3 {'expression': 6.666666666666667}
# FXYD5 {'expression': 5812.666666666667}
# G0S2 {'expression': 2759.0}
# GABRA3 {'expression': 220.0}
# GABRE {'expression': 657.4966666666667}
# GAL {'expression': 0.3333333333333333}
# GBP1 {'expression': 2595.563333333333}
# GBP3 {'expression': 3596.0733333333337}
# GCNT2 {'expression': 4943.076666666667}
# GFRA1 {'expression': 29.33333333333333}
# GJA1 {'expression': 2115.8700000000003}
# GLRA3 {'expression': 2.333333333333333}
# GLRB {'expression': 364.0}
# GMFG {'expression': 649.3566666666667}
# GNA15 {'expression': 1575.6899999999998}
# GNG11 {'expression': 1708.6666666666667}
# GOLT1A {'expression': 1.0}
# GP2 {'expression': 0.3333333333333333}
# GPAT2 {'expression': 0.4533333333333333}
# GPC4 {'expression': 1.0}
# GPR27 {'expression': 0.3333333333333333}
# GPR37L1 {'expression': 6.343333333333334}
# GPX1 {'expression': 5315.536666666667}
# GRHL2 {'expression': 7.0}
# GRIK3 {'expression': 1.3333333333333333}
# GSC {'expression': 0.3333333333333333}
# GSTM1 {'expression': 2412.6}
# GSTP1 {'expression': 2090.333333333333}
# HAS2 {'expression': 681.9433333333333}
# HENMT1 {'expression': 1.0366666666666666}
# HMGA2 {'expression': 6927.193333333333}
# HMGCLL1 {'expression': 4.333333333333333}
# HOXA10 {'expression': 1.6666666666666667}
# HOXA4 {'expression': 0.6666666666666666}
# HOXC13 {'expression': 5.333333333333333}
# HOXD3 {'expression': 271.04}
# HPDL {'expression': 2.0}
# HRH1 {'expression': 2081.6666666666665}
# HRNR {'expression': 565.6666666666666}
# HS3ST3A1 {'expression': 0.3966666666666666}
# HS6ST2 {'expression': 0.3333333333333333}
# HSH2D {'expression': 6.863333333333333}
# HTR1F {'expression': 259.6666666666667}
# HUNK {'expression': 1.2366666666666666}
# ICAM2 {'expression': 810.0033333333334}
# IFI16 {'expression': 2266.0}
# IFI44 {'expression': 1540.0}
# IFI44L {'expression': 225.33333333333331}
# IFIT3 {'expression': 2559.74}
# IGDCC3 {'expression': 2.333333333333333}
# IGF2BP3 {'expression': 3004.28}
# IGFBP1 {'expression': 1217.6666666666667}
# IGFBP2 {'expression': 6.0}
# IGFBP5 {'expression': 2.0}
# IL1RAPL1 {'expression': 226.33333333333331}
# IL31RA {'expression': 461.3333333333333}
# IL7R {'expression': 2023.34}
# ILDR1 {'expression': 0.3333333333333333}
# ILDR2 {'expression': 551.0}
# IQANK1 {'expression': 8.643333333333333}
# IRF6 {'expression': 0.6666666666666666}
# IRX2 {'expression': 0.3366666666666666}
# IRX4 {'expression': 0.34}
# ITGBL1 {'expression': 1450.3366666666668}
# KCNF1 {'expression': 0.3333333333333333}
# KCNJ3 {'expression': 2.6666666666666665}
# KCNQ3 {'expression': 836.6666666666666}
# KCNQ5 {'expression': 2243.39}
# KCTD14 {'expression': 1781.0}
# KCTD15 {'expression': 2.6666666666666665}
# KCTD4 {'expression': 302.0}
# KDF1 {'expression': 1.3333333333333333}
# KIAA0040 {'expression': 2.0}
# KIF1A {'expression': 3.333333333333333}
# KIF26A {'expression': 1.6666666666666667}
# KIRREL1 {'expression': 4809.0}
# KLHL9 {'expression': 1.0}
# KLK11 {'expression': 1.336666666666667}
# KLRC2 {'expression': 89.48666666666668}
# KLRG2 {'expression': 1.0}
# LAD1 {'expression': 5.0}
# LAMA1 {'expression': 133.76666666666668}
# LAMA4 {'expression': 1065.65}
# LAPTM5 {'expression': 7871.333333333333}
# LARGE2 {'expression': 1.0}
# LAYN {'expression': 1336.6666666666667}
# LDHB {'expression': 45150.75666666668}
# LDOC1 {'expression': 12.333333333333334}
# LHFPL6 {'expression': 1059.3333333333333}
# LHX1 {'expression': 0.6666666666666666}
# LHX2 {'expression': 0.3333333333333333}
# LIMCH1 {'expression': 18359.0}
# LIMS2 {'expression': 395.69666666666666}
# LPAR1 {'expression': 1434.0}
# LRP3 {'expression': 8.09}
# LRRC10B {'expression': 0.3333333333333333}
# LY96 {'expression': 136.33333333333334}
# LYPD3 {'expression': 15.333333333333334}
# LYPD6B {'expression': 1.0}
# LYPD8 {'expression': 133.67}
# MACC1 {'expression': 4.0}
# MAGEA3 {'expression': 376.8666666666666}
# MAGEC1 {'expression': 3244.96}
# MAGEC2 {'expression': 7579.976666666666}
# MAGEH1 {'expression': 2.333333333333333}
# MAL2 {'expression': 100.33333333333331}
# MALRD1 {'expression': 1.3333333333333333}
# MARVELD3 {'expression': 6.010000000000001}
# MCAM {'expression': 3759.76}
# MDFIC {'expression': 2134.633333333333}
# ME3 {'expression': 2131.6666666666665}
# MGMT {'expression': 1.0}
# MME {'expression': 0.3333333333333333}
# MMEL1 {'expression': 0.3333333333333333}
# MMP1 {'expression': 2372.293333333333}
# MMP14 {'expression': 13636.333333333334}
# MPP1 {'expression': 591.0}
# MPP4 {'expression': 2121.6733333333336}
# MSI1 {'expression': 1.0}
# MSN {'expression': 42509.18333333333}
# MSRB3 {'expression': 1851.64}
# MT1E {'expression': 3125.58}
# MUC15 {'expression': 420.45666666666665}
# MYH14 {'expression': 6.666666666666667}
# MYH15 {'expression': 97.0}
# MYL9 {'expression': 1822.02}
# N4BP3 {'expression': 5.333333333333333}
# NAP1L2 {'expression': 0.3333333333333333}
# NAV3 {'expression': 5150.666666666667}
# NBPF4 {'expression': 0.4666666666666666}
# NBPF6 {'expression': 1.0}
# NECAB1 {'expression': 5.563333333333333}
# NECTIN4 {'expression': 2.0}
# NETO2 {'expression': 5.333333333333333}
# NINJ2 {'expression': 268.0433333333333}
# NLRP1 {'expression': 1144.0}
# NLRP3 {'expression': 311.09}
# NMNAT3 {'expression': 0.3333333333333333}
# NNMT {'expression': 343.3333333333333}
# NOG {'expression': 245.0}
# NOVA1 {'expression': 2.0}
# NPNT {'expression': 5.6433333333333335}
# NRG1 {'expression': 2781.0}
# NRK {'expression': 0.3333333333333333}
# NRROS {'expression': 464.72}
# NTN1 {'expression': 5.666666666666667}
# NUP210L {'expression': 2.6666666666666665}
# OLFM1 {'expression': 5.333333333333333}
# OOEP {'expression': 0.3333333333333333}
# OVOL1 {'expression': 2.356666666666667}
# OVOL2 {'expression': 0.3366666666666666}
# P3H2 {'expression': 4861.666666666667}
# PALM3 {'expression': 1.3333333333333333}
# PCDH10 {'expression': 27.0}
# PCDH8 {'expression': 0.3333333333333333}
# PCDHA11 {'expression': 1.1}
# PCDHA12 {'expression': 1.12}
# PCDHAC2 {'expression': 0.6666666666666666}
# PCDHGB5 {'expression': 5.079999999999999}
# PCP4 {'expression': 2.333333333333333}
# PCSK1N {'expression': 1.3333333333333333}
# PCSK2 {'expression': 2.333333333333333}
# PDCD1LG2 {'expression': 119.33333333333331}
# PDE10A {'expression': 1485.6666666666667}
# PDE4B {'expression': 136.0}
# PDGFRB {'expression': 124.0}
# PDIA2 {'expression': 0.6666666666666666}
# ...
# HOXB2 {'expression': 11.923333333333332}
# HOXB3 {'expression': 482.7033333333334}
# HOXB4 {'expression': 78.86999999999999}
# HOXB5 {'expression': 2.333333333333333}
# HOXB6 {'expression': 0.6666666666666666}
# HOXB7 {'expression': 50.0}
# HOXB8 {'expression': 30.0}
# HOXB9 {'expression': 690.6666666666666}
# HOXC12 {'expression': 0}
# HOXC4 {'expression': 12.183333333333332}
# HOXC5 {'expression': 36.64666666666667}
# HOXC6 {'expression': 120.44333333333331}
# HOXC8 {'expression': 63.66666666666666}
# HOXC9 {'expression': 16.0}
# HOXD1 {'expression': 48.09}
# HOXD10 {'expression': 0}
# HOXD11 {'expression': 0}
# HOXD12 {'expression': 0}
# HOXD13 {'expression': 0}
# HOXD4 {'expression': 0}
# HOXD8 {'expression': 0}
# HOXD9 {'expression': 0.3333333333333333}
# HSF1 {'expression': 0}
# HSF2 {'expression': 0}
# IKZF1 {'expression': 0}
# IKZF2 {'expression': 217.66666666666663}
# IKZF3 {'expression': 0}
# IKZF4 {'expression': 0}
# INSM1 {'expression': 0}
# IRF1 {'expression': 1276.4566666666667}
# IRF2 {'expression': 0}
# IRF3 {'expression': 0}
# IRF4 {'expression': 0}
# IRF5 {'expression': 135.33333333333334}
# IRF7 {'expression': 0}
# IRF8 {'expression': 0}
# IRF9 {'expression': 0}
# IRX1 {'expression': 0}
# IRX3 {'expression': 0}
# IRX5 {'expression': 86.98333333333333}
# IRX6 {'expression': 0}
# ISL1 {'expression': 0}
# ISL2 {'expression': 0}
# JDP2 {'expression': 0}
# JUN {'expression': 6262.666666666667}
# JUNB {'expression': 856.8266666666667}
# JUND {'expression': 909.6666666666666}
# KDM2B {'expression': 0}
# KLF1 {'expression': 0}
# KLF10 {'expression': 0}
# KLF11 {'expression': 0}
# KLF12 {'expression': 0}
# KLF13 {'expression': 0}
# KLF14 {'expression': 6.0}
# KLF15 {'expression': 50.0}
# KLF16 {'expression': 2074.9633333333336}
# KLF17 {'expression': 15.666666666666666}
# KLF2 {'expression': 578.0}
# KLF3 {'expression': 1186.3866666666663}
# KLF4 {'expression': 0}
# KLF5 {'expression': 0}
# KLF6 {'expression': 6472.333333333333}
# KLF7 {'expression': 0}
# KLF8 {'expression': 21.666666666666668}
# KLF9 {'expression': 185.66666666666663}
# KMT2A {'expression': 0}
# LBX1 {'expression': 0}
# LCOR {'expression': 0}
# LEF1 {'expression': 623.5633333333334}
# LHX3 {'expression': 0}
# LHX4 {'expression': 284.0133333333333}
# LHX5 {'expression': 0}
# LHX6 {'expression': 27.33333333333333}
# LHX8 {'expression': 0}
# LHX9 {'expression': 0}
# LIN28A {'expression': 0}
# LIN28B {'expression': 0}
# LMX1A {'expression': 0}
# LMX1B {'expression': 118.75333333333332}
# LYL1 {'expression': 37.0}
# MAF {'expression': 2.0}
# MAFA {'expression': 13.0}
# MAFB {'expression': 34.333333333333336}
# MAFF {'expression': 1395.6133333333337}
# MAFG {'expression': 4840.296666666666}
# MAFK {'expression': 0}
# MAX {'expression': 0}
# MAZ {'expression': 5696.986666666667}
# MBD2 {'expression': 0}
# MBNL2 {'expression': 2016.3333333333333}
# MECOM {'expression': 2526.6666666666665}
# MECP2 {'expression': 0}
# MEF2A {'expression': 0}
# MEF2C {'expression': 238.86333333333332}
# MEF2D {'expression': 0}
# MEIS1 {'expression': 72.0}
# MEIS2 {'expression': 0}
# MEOX1 {'expression': 0}
# MEOX2 {'expression': 0}
# MESP1 {'expression': 80.66666666666667}
# MESP2 {'expression': 3.0}
# MGA {'expression': 0}
# MITF {'expression': 754.6666666666666}
# MIXL1 {'expression': 0}
# MLX {'expression': 0}
# MLXIPL {'expression': 19.666666666666668}
# MNT {'expression': 0}
# MNX1 {'expression': 136.66666666666666}
# MSC {'expression': 0}
# MSGN1 {'expression': 0}
# MSX1 {'expression': 0.6666666666666666}
# MSX2 {'expression': 79.33333333333333}
# MXD3 {'expression': 515.2633333333334}
# MXI1 {'expression': 0}
# MYB {'expression': 77.66666666666667}
# MYBL1 {'expression': 0}
# MYBL2 {'expression': 0}
# MYC {'expression': 6442.333333333333}
# MYCL {'expression': 23.32333333333333}
# MYCN {'expression': 0}
# MYF5 {'expression': 0}
# MYF6 {'expression': 0}
# MYNN {'expression': 0}
# MYOD1 {'expression': 0}
# MYOG {'expression': 0}
# MYRF {'expression': 1118.5633333333333}
# MYT1L {'expression': 5.203333333333333}
# MZF1 {'expression': 0}
# NAIF1 {'expression': 0}
# NANOG {'expression': 0}
# NEUROD1 {'expression': 0}
# NEUROD2 {'expression': 0}
# NEUROD4 {'expression': 0}
# NEUROD6 {'expression': 0}
# NEUROG1 {'expression': 0}
# NEUROG2 {'expression': 0}
# NEUROG3 {'expression': 0}
# NFAT5 {'expression': 0}
# NFATC1 {'expression': 179.33333333333334}
# NFATC2 {'expression': 0}
# NFATC3 {'expression': 0}
# NFATC4 {'expression': 0}
# NFE2 {'expression': 0}
# NFE2L1 {'expression': 0}
# NFE2L2 {'expression': 0}
# NFE2L3 {'expression': 8407.39}
# NFIA {'expression': 482.3333333333333}
# NFIB {'expression': 0}
# NFIC {'expression': 0}
# NFIL3 {'expression': 0}
# NFIX {'expression': 2313.75}
# NFKB1 {'expression': 0}
# NFKB2 {'expression': 3219.66}
# NFYA {'expression': 0}
# NFYB {'expression': 0}
# NFYC {'expression': 0}
# NHLH1 {'expression': 0}
# NHLH2 {'expression': 0}
# NKX1-2 {'expression': 0}
# NKX2-1 {'expression': 529.5733333333334}
# NKX2-2 {'expression': 0}
# NKX2-3 {'expression': 0}
# NKX2-4 {'expression': 0}
# NKX2-5 {'expression': 0}
# NKX2-6 {'expression': 0}
# NKX2-8 {'expression': 42.333333333333336}
# NKX3-1 {'expression': 415.0}
# NKX3-2 {'expression': 0}
# NKX6-1 {'expression': 107.0}
# NKX6-2 {'expression': 0}
# NKX6-3 {'expression': 0}
# NOBOX {'expression': 0}
# NOTO {'expression': 0}
# NPAS1 {'expression': 61.66666666666666}
# NPAS2 {'expression': 4171.92}
# NPAS3 {'expression': 0}
# NR0B1 {'expression': 0}
# NR1D1 {'expression': 387.69666666666666}
# NR1D2 {'expression': 0}
# NR1H2 {'expression': 0}
# NR1H3 {'expression': 0}
# NR1H4 {'expression': 0}
# NR1I2 {'expression': 0}
# NR1I3 {'expression': 32.68333333333334}
# NR2C1 {'expression': 0}
# NR2C2 {'expression': 0}
# NR2E1 {'expression': 0}
# NR2E3 {'expression': 6.333333333333333}
# NR2F1 {'expression': 752.2566666666667}
# NR2F2 {'expression': 6808.333333333333}
# NR2F6 {'expression': 0}
# NR3C1 {'expression': 5867.653333333333}
# NR3C2 {'expression': 274.3333333333333}
# NR4A1 {'expression': 82.00333333333333}
# NR4A2 {'expression': 51.66666666666666}
# NR4A3 {'expression': 24.33333333333333}
# NR5A1 {'expression': 0}
# NR5A2 {'expression': 12.666666666666666}
# NR6A1 {'expression': 0}
# NRF1 {'expression': 0}
# NRL {'expression': 0}
# OLIG1 {'expression': 0}
# OLIG2 {'expression': 0}
# OLIG3 {'expression': 0}
# ONECUT1 {'expression': 11.333333333333334}
# ONECUT2 {'expression': 226.33333333333331}
# ONECUT3 {'expression': 1.6666666666666667}
# OSR1 {'expression': 261.0}
# OSR2 {'expression': 104.33333333333331}
# OTP {'expression': 1.0}
# OTX1 {'expression': 0}
# OTX2 {'expression': 0}
# PATZ1 {'expression': 1518.3333333333333}
# PAX1 {'expression': 0}
# PAX2 {'expression': 0.6666666666666666}
# PAX3 {'expression': 0}
# PAX4 {'expression': 0}
# PAX5 {'expression': 10.0}
# PAX6 {'expression': 90.33333333333331}
# PAX7 {'expression': 0}
# PAX8 {'expression': 0}
# PAX9 {'expression': 286.96}
# PBX1 {'expression': 97.66666666666669}
# PBX2 {'expression': 0}
# PBX3 {'expression': 840.6666666666666}
# PBX4 {'expression': 0}
# PDX1 {'expression': 0}
# PHOX2A {'expression': 0}
# PHOX2B {'expression': 0}
# PITX1 {'expression': 1643.4366666666665}
# PITX2 {'expression': 0}
# PITX3 {'expression': 3.6666666666666665}
# PKNOX1 {'expression': 0}
# PKNOX2 {'expression': 1.0}
# PLAG1 {'expression': 435.6666666666667}
# PLAGL1 {'expression': 2.6666666666666665}
# POU1F1 {'expression': 0}
# POU2F1 {'expression': 0}
# POU2F2 {'expression': 94.33333333333331}
# POU2F3 {'expression': 16.666666666666668}
# POU3F1 {'expression': 0}
# POU3F2 {'expression': 92.0}
# POU3F3 {'expression': 0}
# POU3F4 {'expression': 0}
# POU4F1 {'expression': 0}
# POU4F2 {'expression': 0}
# POU4F3 {'expression': 0}
# POU5F1 {'expression': 0}
# POU5F1B {'expression': 1.92}
# POU6F1 {'expression': 128.0}
# POU6F2 {'expression': 0}
# PPARA {'expression': 0}
# PPARD {'expression': 0}
# PPARG {'expression': 2565.6666666666665}
# PRDM1 {'expression': 24.666666666666668}
# PRDM14 {'expression': 0}
# PRDM16 {'expression': 6.0}
# PRDM6 {'expression': 37.2}
# PROP1 {'expression': 0}
# PROX1 {'expression': 0}
# PRRX1 {'expression': 0}
# PRRX2 {'expression': 1.6666666666666667}
# PTF1A {'expression': 0}
# RARA {'expression': 1116.49}
# RARB {'expression': 12.333333333333334}
# RARG {'expression': 858.6666666666666}
# RAX {'expression': 0}
# RBPJ {'expression': 7809.493333333333}
# RBPJL {'expression': 3.0}
# REL {'expression': 0}
# RELA {'expression': 0}
# RELB {'expression': 629.0}
# REST {'expression': 0}
# RFX2 {'expression': 0}
# RFX3 {'expression': 0}
# RFX4 {'expression': 11.436666666666667}
# RFX5 {'expression': 0}
# RFX6 {'expression': 0}
# RFX7 {'expression': 0}
# RORA {'expression': 0}
# RORB {'expression': 38.333333333333336}
# RORC {'expression': 14.666666666666666}
# RREB1 {'expression': 1376.0}
# RUNX1 {'expression': 0}
# RUNX2 {'expression': 879.0566666666667}
# RUNX3 {'expression': 8.333333333333334}
# RXRA {'expression': 2533.6666666666665}
# RXRB {'expression': 0}
# RXRG {'expression': 0}
# SCRT1 {'expression': 1.0}
# SCRT2 {'expression': 0}
# SHOX {'expression': 1.6666666666666667}
# SHOX2 {'expression': 990.52}
# SIM1 {'expression': 1.3333333333333333}
# SIM2 {'expression': 373.3333333333333}
# SIX1 {'expression': 1654.0}
# SIX2 {'expression': 0}
# SIX3 {'expression': 0}
# SIX4 {'expression': 0}
# SIX5 {'expression': 245.53666666666663}
# SIX6 {'expression': 0}
# SKOR1 {'expression': 0}
# SKOR2 {'expression': 0}
# SMAD1 {'expression': 0}
# SMAD3 {'expression': 12848.0}
# SMAD4 {'expression': 0}
# SMAD5 {'expression': 0}
# SMAD9 {'expression': 114.72666666666667}
# SNAI1 {'expression': 197.33333333333331}
# SNAI2 {'expression': 604.0}
# SOX1 {'expression': 0}
# SOX10 {'expression': 0}
# SOX11 {'expression': 0}
# SOX12 {'expression': 948.3333333333334}
# SOX13 {'expression': 0}
# SOX14 {'expression': 0}
# SOX15 {'expression': 0}
# SOX17 {'expression': 0}
# SOX18 {'expression': 33.666666666666664}
# SOX21 {'expression': 10.333333333333334}
# SOX30 {'expression': 0}
# SOX4 {'expression': 791.6666666666666}
# SOX5 {'expression': 26.666666666666668}
# SOX6 {'expression': 0}
# SOX7 {'expression': 15.666666666666666}
# SOX8 {'expression': 0}
# SOX9 {'expression': 3656.6666666666665}
# SP1 {'expression': 0}
# SP2 {'expression': 0}
# SP3 {'expression': 0}
# SP4 {'expression': 0}
# SP5 {'expression': 254.99666666666667}
# SP6 {'expression': 168.33333333333334}
# SP7 {'expression': 0}
# SP8 {'expression': 0}
# SP9 {'expression': 0}
# SPDEF {'expression': 144.66666666666666}
# SPI1 {'expression': 0}
# SPIB {'expression': 21.57333333333333}
# SPZ1 {'expression': 0}
# SREBF1 {'expression': 3117.0933333333337}
# SREBF2 {'expression': 0}
# SRF {'expression': 0}
# STAT1 {'expression': 0}
# STAT2 {'expression': 0}
# STAT3 {'expression': 7944.2}
# STAT4 {'expression': 0}
# STAT5A {'expression': 1392.2666666666669}
# STAT5B {'expression': 0}
# STAT6 {'expression': 6576.53}
# T {'expression': 0}
# TAL1 {'expression': 0}
# TAL2 {'expression': 9.0}
# TBP {'expression': 0}
# TBPL2 {'expression': 1.3333333333333333}
# TBR1 {'expression': 0}
# TBX1 {'expression': 259.25}
# TBX10 {'expression': 0.3333333333333333}
# TBX15 {'expression': 27.33333333333333}
# TBX18 {'expression': 0}
# TBX19 {'expression': 0}
# TBX20 {'expression': 0}
# TBX21 {'expression': 0}
# TBX4 {'expression': 1.6666666666666667}
# TBX5 {'expression': 1.0}
# TBX6 {'expression': 16.666666666666668}
# TCF12 {'expression': 3708.3333333333335}
# TCF15 {'expression': 0}
# TCF23 {'expression': 5.666666666666667}
# TCF3 {'expression': 0}
# TCF4 {'expression': 4.333333333333333}
# TCF7 {'expression': 226.39}
# TCF7L1 {'expression': 0}
# TCF7L2 {'expression': 935.3633333333332}
# TEAD1 {'expression': 11924.333333333334}
# TEAD2 {'expression': 0}
# TEAD3 {'expression': 0}
# TEAD4 {'expression': 2038.83}
# TEF {'expression': 240.33333333333331}
# TERF2 {'expression': 0}
# TET1 {'expression': 0}
# TFAP2A {'expression': 138.96333333333334}
# TFAP2B {'expression': 0}
# TFAP2C {'expression': 754.6666666666666}
# TFAP2D {'expression': 0}
# TFAP2E {'expression': 46.66666666666666}
# TFAP4 {'expression': 0}
# TFCP2L1 {'expression': 452.3333333333333}
# TFDP1 {'expression': 10864.673333333334}
# TFDP3 {'expression': 0}
# TFE3 {'expression': 0}
# TFEB {'expression': 0}
# TFEC {'expression': 13.333333333333334}
# TGIF1 {'expression': 0}
# TGIF2 {'expression': 0}
# TGIF2LX {'expression': 0}
# THAP1 {'expression': 0}
# THRA {'expression': 0}
# THRB {'expression': 107.33333333333331}
# TLX1 {'expression': 6.0}
# TLX2 {'expression': 0}
# TLX3 {'expression': 0}
# TOPORS {'expression': 0}
# TP53 {'expression': 0}
# TP63 {'expression': 8.0}
# TP73 {'expression': 110.88}
# TWIST1 {'expression': 0}
# TWIST2 {'expression': 0}
# UBP1 {'expression': 0}
# UNCX {'expression': 0}
# USF1 {'expression': 0}
# USF2 {'expression': 0}
# VAX1 {'expression': 0}
# VAX2 {'expression': 36.333333333333336}
# VDR {'expression': 0}
# VENTX {'expression': 1.6666666666666667}
# VSX1 {'expression': 16.666666666666668}
# VSX2 {'expression': 0.3333333333333333}
# WT1 {'expression': 0}
# XBP1 {'expression': 3090.353333333333}
# XPA {'expression': 0}
# YBX1 {'expression': 0}
# YY1 {'expression': 0}
# YY2 {'expression': 0}
# ZBED1 {'expression': 0}
# ZBTB1 {'expression': 0}
# ZBTB12 {'expression': 0}
# ZBTB14 {'expression': 0}
# ZBTB18 {'expression': 2511.0}
# ZBTB2 {'expression': 0}
# ZBTB20 {'expression': 79.33333333333333}
# ZBTB22 {'expression': 0}
# ZBTB3 {'expression': 152.02}
# ZBTB32 {'expression': 4.0}
# ZBTB33 {'expression': 0}
# ZBTB4 {'expression': 0}
# ZBTB42 {'expression': 148.33333333333334}
# ZBTB43 {'expression': 0}
# ZBTB45 {'expression': 438.31}
# ZBTB48 {'expression': 0}
# ZBTB49 {'expression': 0}
# ZBTB6 {'expression': 0}
# ZBTB7A {'expression': 0}
# ZBTB7B {'expression': 665.0}
# ZBTB7C {'expression': 0}
# ZEB1 {'expression': 2821.613333333333}
# ZFHX2 {'expression': 0}
# ZFHX3 {'expression': 1849.466666666667}
# ZFHX4 {'expression': 38.0}
# ZFP1 {'expression': 518.3333333333334}
# ZFP42 {'expression': 0}
# ZFP57 {'expression': 0}
# ZFP64 {'expression': 0}
# ZFX {'expression': 0}
# ZIC2 {'expression': 997.0}
# ZIC3 {'expression': 0}
# ZIC5 {'expression': 0}
# ZIM2 {'expression': 0}
# ZKSCAN1 {'expression': 2697.73}
# ZKSCAN2 {'expression': 0}
# ZKSCAN3 {'expression': 502.0566666666666}
# ZKSCAN7 {'expression': 1.0}
# ZNF114 {'expression': 0}
# ZNF132 {'expression': 242.0}
# ZNF135 {'expression': 0}
# ZNF141 {'expression': 0}
# ZNF143 {'expression': 0}
# ZNF146 {'expression': 0}
# ZNF148 {'expression': 0}
# ZNF174 {'expression': 0}
# ZNF18 {'expression': 95.65333333333332}
# ZNF182 {'expression': 0}
# ZNF184 {'expression': 0}
# ZNF2 {'expression': 0}
# ZNF202 {'expression': 1062.3333333333333}
# ZNF219 {'expression': 0}
# ZNF232 {'expression': 0}
# ZNF235 {'expression': 66.16333333333334}
# ZNF248 {'expression': 373.42}
# ZNF250 {'expression': 0}
# ZNF263 {'expression': 0}
# ZNF274 {'expression': 0}
# ZNF276 {'expression': 1078.3466666666666}
# ZNF280A {'expression': 0}
# ZNF281 {'expression': 0}
# ZNF296 {'expression': 0}
# ZNF30 {'expression': 0}
# ZNF300 {'expression': 4.0}
# ZNF302 {'expression': 0}
# ZNF311 {'expression': 0}
# ZNF32 {'expression': 0}
# ZNF334 {'expression': 0}
# ZNF35 {'expression': 651.32}
# ZNF350 {'expression': 0}
# ZNF354C {'expression': 0}
# ZNF384 {'expression': 0}
# ZNF398 {'expression': 0}
# ZNF41 {'expression': 329.6666666666667}
# ZNF410 {'expression': 0}
# ZNF416 {'expression': 0}
# ZNF423 {'expression': 0.3333333333333333}
# ZNF436 {'expression': 0}
# ZNF44 {'expression': 0}
# ZNF467 {'expression': 87.33333333333333}
# ZNF487 {'expression': 33.333333333333336}
# ZNF513 {'expression': 360.54}
# ZNF519 {'expression': 0}
# ZNF524 {'expression': 0}
# ZNF529 {'expression': 496.18666666666667}
# ZNF534 {'expression': 0}
# ZNF552 {'expression': 201.5233333333333}
# ZNF554 {'expression': 0}
# ZNF571 {'expression': 0}
# ZNF589 {'expression': 0}
# ZNF594 {'expression': 0}
# ZNF597 {'expression': 0}
# ZNF641 {'expression': 93.00333333333332}
# ZNF649 {'expression': 0}
# ZNF653 {'expression': 0}
# ZNF667 {'expression': 0}
# ZNF675 {'expression': 348.59}
# ZNF691 {'expression': 0}
# ZNF692 {'expression': 0}
# ZNF7 {'expression': 0}
# ZNF707 {'expression': 0}
# ZNF730 {'expression': 1.7033333333333334}
# ZNF74 {'expression': 0}
# ZNF740 {'expression': 0}
# ZNF75D {'expression': 366.0}
# ZNF76 {'expression': 0}
# ZNF766 {'expression': 339.0166666666667}
# ZNF768 {'expression': 1550.84}
# ZNF776 {'expression': 0}
# ZNF777 {'expression': 0}
# ZNF785 {'expression': 164.66333333333333}
# ZNF787 {'expression': 0}
# ZNF79 {'expression': 0}
# ZNF790 {'expression': 0}
# ZNF8 {'expression': 0}
# ZNF860 {'expression': 0}
# ZSCAN1 {'expression': 0}
# ZSCAN10 {'expression': 1.6666666666666667}
# ZSCAN16 {'expression': 0}
# ZSCAN22 {'expression': 0}
# ZSCAN26 {'expression': 0}
# ZSCAN29 {'expression': 0}
# ZSCAN30 {'expression': 1053.3566666666668}
# ZSCAN4 {'expression': 0}
# ZSCAN5A {'expression': 303.93333333333334}
# ZSCAN9 {'expression': 0}

# %%
import numpy as np

def identify_highly_expressed_genes(graph, threshold):
    """
    Identify genes with expression levels above a given threshold.
    """
    return {
        node: data['expression']
        for node, data in graph.nodes(data=True)
        if data['expression'] > threshold
    }

# Set a threshold for high expression (e.g., top 10% of expression values)
threshold_mcf7 = np.percentile(list(expression_dict_mcf7_ppi.values()), 90)
threshold_mda = np.percentile(list(expression_dict_mda_ppi.values()), 90)

# Find highly expressed genes in G_mcf7 and G_mda
highly_expressed_mcf7_ppi = identify_highly_expressed_genes(G_mcf7_ppi, threshold_mcf7)
highly_expressed_mda_ppi = identify_highly_expressed_genes(G_mda_ppi, threshold_mda)

print("Highly expressed genes in G_mcf7:")
print(highly_expressed_mcf7_ppi)

print("\nHighly expressed genes in G_mda:")
print(highly_expressed_mda_ppi)

def compare_expression_profiles(graph1, graph2):
    """
    Compare expression profiles between two graphs for common genes,
    excluding genes with zero expression in both graphs.
    """
    common_genes = set(graph1.nodes).intersection(set(graph2.nodes))
    return {
        gene: (graph1.nodes[gene]['expression'], graph2.nodes[gene]['expression'])
        for gene in common_genes
        if not (graph1.nodes[gene]['expression'] == 0 and graph2.nodes[gene]['expression'] == 0)
    }

# Compare expression profiles between G_mcf7 and G_mda
expression_comparison = compare_expression_profiles(G_mcf7_ppi, G_mda_ppi)

print("\nExpression comparison for common genes:")
for gene, (exp_mcf7_ppi, exp_mda_ppi) in expression_comparison.items():
    print(f"{gene}: MCF7 = {exp_mcf7_ppi}, MDA-MB231 = {exp_mda_ppi}")

def differential_expression_analysis(graph1, graph2, fold_change_threshold=2.0):
    """
    Perform differential expression analysis between two graphs.
    Genes are considered differentially expressed if the fold change exceeds the threshold,
    excluding genes with zero expression in both cell lines and avoiding infinite fold changes.
    """
    common_genes = set(graph1.nodes).intersection(set(graph2.nodes))
    differentially_expressed_genes = {}

    for gene in common_genes:
        exp_mcf7_ppi = graph1.nodes[gene]['expression']
        exp_mda_ppi = graph2.nodes[gene]['expression']

        # Exclude genes with zero expression in both cell lines
        if exp_mcf7_ppi == 0 and exp_mda_ppi == 0:
            continue

        # Compute fold change while avoiding division by zero
        if highly_expressed_mda_ppi == 0:
            continue  # Exclude cases leading to infinite fold change

        fold_change = exp_mcf7_ppi / exp_mda_ppi

        # Check if fold change exceeds the threshold
        if abs(fold_change) > fold_change_threshold:
            differentially_expressed_genes[gene] = (exp_mcf7_ppi, exp_mda_ppi, fold_change)

    return differentially_expressed_genes

# Perform differential expression analysis
differentially_expressed_genes = differential_expression_analysis(G_mcf7_ppi, G_mda_ppi, fold_change_threshold=2)

print("\nDifferentially expressed genes (fold change > 2.0):")
for gene, (exp_mcf7_ppi, exp_mda_ppi, fold_change) in differentially_expressed_genes.items():
    print(f"{gene}: MCF7 = {exp_mcf7_ppi}, MDA-MB231 = {exp_mda_ppi}, Fold Change = {fold_change:.2f}")
# Out:
# Highly expressed genes in G_mcf7:
# {'ACKR3': 3749.0, 'ADAMTS19': 4024.375, 'ADCY1': 19748.925, 'ADCY5': 2689.5, 'BCAS1': 1788.56, 'BMP5': 1808.0, 'BMP7': 14484.17, 'BSPRY': 1852.0, 'CACNG4': 13121.5, 'CBFA2T3': 4054.51, 'CCDC170': 2723.5, 'CDH1': 42451.98, 'CEACAM5': 1614.075, 'COL4A5': 2259.0, 'CTNND2': 1769.0, 'DEGS2': 1857.91, 'DSCAM': 5994.0, 'ELOVL2': 2531.5, 'EMC10': 5768.675, 'EPN3': 2727.3, 'EPPK1': 8488.57, 'ERBB3': 11822.0, 'ERBB4': 1829.5, 'ESR1': 13965.5, 'ESRP1': 8080.0, 'FAM83B': 2939.5, 'FXYD3': 9192.0, 'GFRA1': 44219.5, 'GRHL2': 6683.0, 'HENMT1': 2042.62, 'IGFBP2': 3947.5, 'IQANK1': 4166.845, 'KCNJ3': 2125.5, 'KCTD15': 1739.5, 'LAD1': 3463.495, 'LDOC1': 6003.5, 'LRP3': 1727.8, 'LYPD3': 4367.0, 'MAL2': 17172.78, 'MYH14': 7061.855, 'N4BP3': 3147.0, 'NECAB1': 3946.675, 'NPNT': 3554.035, 'OLFM1': 3131.5, 'PCDH10': 4885.0, 'PCDHGB5': 1590.13, 'PGR': 2616.0, 'PPL': 4755.0, 'PREX1': 9755.5, 'PROM2': 1955.415, 'PRR15L': 2358.5, 'PRSS8': 3366.135, 'RAB17': 2428.245, 'RAB25': 2984.5, 'RAMP3': 2250.5, 'RET': 5778.0, 'RNF43': 3252.685, 'S100A14': 11503.0, 'SCUBE2': 4083.5, 'SLC24A3': 2631.2, 'SLC2A10': 2506.5, 'SLC6A14': 5494.24, 'SLC9A2': 2277.5, 'SPINT1': 3621.37, 'SPTSSB': 71375.5, 'SULF1': 2108.0, 'SULF2': 64968.94500000001, 'SULT2B1': 1699.0, 'SYTL5': 5805.0, 'TBX2': 10104.5, 'TMEM30B': 4239.81, 'ARID5B': 1756.5, 'ARNT': 3488.0, 'ARNT2': 2226.21, 'ATF4': 5797.11, 'ATF6': 1613.5, 'BPTF': 16436.115, 'CEBPZ': 2840.3950000000004, 'CREB3L2': 2230.5, 'CREB3L4': 1883.745, 'CREBZF': 9441.5, 'CUX1': 13676.0, 'E2F3': 1856.495, 'E2F7': 1952.0, 'ELF1': 5000.46, 'ELF3': 4358.7, 'FOXA1': 13178.5, 'FOXM1': 5104.13, 'FOXO3': 5330.8, 'GATA3': 48436.5, 'GRHL1': 1840.085, 'HBP1': 2285.495, 'HMGA1': 4606.04, 'JUN': 1819.0, 'JUNB': 2414.24, 'JUND': 5398.0, 'KLF3': 2626.75, 'LMX1B': 3646.05, 'MAZ': 19778.64, 'MSX2': 1593.99, 'MYB': 3067.76, 'MYC': 1691.5, 'NR2F2': 18510.0, 'NR3C1': 1673.455, 'OSR2': 2290.5, 'PATZ1': 3322.0, 'PBX1': 5848.0, 'PBX3': 1949.0, 'RARA': 2399.685, 'RARG': 3692.29, 'RBPJ': 2904.8900000000003, 'RREB1': 2786.5, 'RXRA': 13546.5, 'SMAD3': 4715.0, 'SOX12': 2394.0, 'SOX4': 4609.5, 'SPDEF': 5197.0, 'SREBF1': 12348.18, 'STAT3': 2930.4300000000003, 'TEAD1': 4047.0, 'TFAP2C': 4442.0, 'TFDP1': 4659.205, 'XBP1': 33344.7, 'YBX2': 1905.44, 'ZBTB42': 1644.0, 'ZBTB7B': 2907.0, 'ZFHX3': 5792.54, 'ZKSCAN1': 5732.435, 'ZNF276': 2172.64, 'ZNF75D': 1697.535, 'ZNF768': 3321.375}
#
# Highly expressed genes in G_mda:
# {'ACSL5': 5231.849999999999, 'ADD2': 2348.6666666666665, 'ADGRF5': 9675.113333333336, 'ADRB2': 2529.6666666666665, 'AGPS': 6923.0, 'AKR1B1': 5195.1033333333335, 'AKT3': 2863.2100000000005, 'ALDH2': 2863.0, 'ANKRD1': 19683.0, 'ANTXR2': 10715.666666666666, 'ARHGAP23': 6119.333333333333, 'ARHGDIB': 9505.333333333334, 'AXL': 53569.41666666666, 'BCAT1': 7962.603333333333, 'BIRC3': 2386.6199999999994, 'CALD1': 4827.0, 'CARD11': 3599.67, 'CASP4': 2687.33, 'CAVIN2': 5742.2733333333335, 'CAVIN3': 2632.6666666666665, 'CCBE1': 2792.083333333333, 'CD96': 3278.333333333333, 'CDC42EP3': 15019.783333333333, 'CDCP1': 5995.329999999999, 'CMTM7': 2364.74, 'CNN3': 20332.666666666668, 'COL13A1': 10099.666666666666, 'COL4A1': 3608.0, 'COL4A2': 9611.136666666667, 'CYBRD1': 4408.0, 'EDIL3': 7042.996666666667, 'EMP1': 12112.0, 'EREG': 4359.666666666667, 'ETS1': 12376.483333333332, 'ETV1': 2663.0, 'F3': 24922.123333333333, 'FAM171A1': 3587.333333333333, 'FGF5': 6164.466666666667, 'FLG': 2261.15, 'FLNC': 22592.41, 'FOSL1': 14956.01, 'FST': 2468.6666666666665, 'FSTL1': 8757.0, 'FXYD5': 5812.666666666667, 'G0S2': 2759.0, 'GBP1': 2595.563333333333, 'GBP3': 3596.0733333333337, 'GCNT2': 4943.076666666667, 'GPX1': 5315.536666666667, 'GSTM1': 2412.6, 'HMGA2': 6927.193333333333, 'IFI16': 2266.0, 'IFIT3': 2559.74, 'IGF2BP3': 3004.28, 'KCNQ5': 2243.39, 'KIRREL1': 4809.0, 'LAPTM5': 7871.333333333333, 'LDHB': 45150.75666666668, 'LIMCH1': 18359.0, 'MAGEC1': 3244.96, 'MAGEC2': 7579.976666666666, 'MCAM': 3759.76, 'MMP1': 2372.293333333333, 'MMP14': 13636.333333333334, 'MSN': 42509.18333333333, 'MT1E': 3125.58, 'NAV3': 5150.666666666667, 'NRG1': 2781.0, 'P3H2': 4861.666666666667, 'PEG10': 6469.666666666667, 'PLS3': 10141.333333333334, 'PSAT1': 6883.993333333335, 'PSMB8': 2744.5533333333333, 'PTPRM': 4150.31, 'PTX3': 5203.0, 'RAB34': 5513.0, 'RAC2': 5697.333333333333, 'ROR1': 2789.6666666666665, 'SERPINE1': 22507.666666666668, 'SLC17A9': 4596.666666666667, 'SLC43A3': 14502.79, 'SPANXB1': 4093.9833333333336, 'SPARC': 5381.943333333334, 'SRGN': 11416.333333333334, 'TM4SF1': 16488.666666666668, 'TM4SF18': 3147.713333333333, 'TMEM156': 2366.6666666666665, 'TMPRSS15': 3228.6666666666665, 'TNC': 3523.333333333333, 'VIM': 172192.89666666667, 'ZNF655': 3935.466666666667, 'ATF2': 3205.9500000000003, 'ATF4': 11878.776666666668, 'ATF6': 4243.0, 'BACH1': 2439.226666666667, 'BPTF': 4165.54, 'CEBPZ': 7425.546666666666, 'CREB3L2': 5660.0, 'CREBZF': 3241.333333333333, 'CUX1': 4844.0, 'E2F3': 3975.99, 'E2F7': 5912.0, 'ELK3': 7458.956666666666, 'ETV4': 3266.476666666667, 'ETV5': 3645.3333333333335, 'FOXM1': 10497.236666666666, 'FOXN2': 2548.6666666666665, 'FOXO3': 2431.556666666667, 'HMGA1': 53282.52, 'JUN': 6262.666666666667, 'KLF6': 6472.333333333333, 'MAFG': 4840.296666666666, 'MAZ': 5696.986666666667, 'MECOM': 2526.6666666666665, 'MYC': 6442.333333333333, 'NFE2L3': 8407.39, 'NFIX': 2313.75, 'NFKB2': 3219.66, 'NPAS2': 4171.92, 'NR2F2': 6808.333333333333, 'NR3C1': 5867.653333333333, 'PPARG': 2565.6666666666665, 'RBPJ': 7809.493333333333, 'RXRA': 2533.6666666666665, 'SMAD3': 12848.0, 'SOX9': 3656.6666666666665, 'SREBF1': 3117.0933333333337, 'STAT3': 7944.2, 'STAT6': 6576.53, 'TCF12': 3708.3333333333335, 'TEAD1': 11924.333333333334, 'TFDP1': 10864.673333333334, 'XBP1': 3090.353333333333, 'ZBTB18': 2511.0, 'ZEB1': 2821.613333333333, 'ZKSCAN1': 2697.73}
#
# Expression comparison for common genes:
# COL4A5: MCF7 = 2259.0, MDA-MB231 = 3.0
# ZFHX3: MCF7 = 5792.54, MDA-MB231 = 1849.466666666667
# IRX5: MCF7 = 602.6800000000001, MDA-MB231 = 86.98333333333333
# ZKSCAN7: MCF7 = 6.390000000000001, MDA-MB231 = 1.0
# RARA: MCF7 = 2399.685, MDA-MB231 = 1116.49
# AXL: MCF7 = 84.5, MDA-MB231 = 53569.41666666666
# PLCXD3: MCF7 = 252.0, MDA-MB231 = 0.3333333333333333
# SPX: MCF7 = 0.5, MDA-MB231 = 94.33333333333331
# PCP4: MCF7 = 712.5, MDA-MB231 = 2.333333333333333
# FOXA3: MCF7 = 6.0, MDA-MB231 = 2.6666666666666665
# RELB: MCF7 = 53.5, MDA-MB231 = 629.0
# GLIS1: MCF7 = 0.5, MDA-MB231 = 3.0
# OTP: MCF7 = 7.0, MDA-MB231 = 1.0
# CST1: MCF7 = 1.0, MDA-MB231 = 508.12000000000006
# THNSL2: MCF7 = 735.5, MDA-MB231 = 1.3333333333333333
# GPC4: MCF7 = 912.0, MDA-MB231 = 1.0
# HNF4G: MCF7 = 5.0, MDA-MB231 = 111.33333333333331
# NRG1: MCF7 = 5.5, MDA-MB231 = 2781.0
# CPA4: MCF7 = 1.055, MDA-MB231 = 725.0
# CDH1: MCF7 = 42451.98, MDA-MB231 = 35.333333333333336
# ACSL5: MCF7 = 9.0, MDA-MB231 = 5231.849999999999
# OLFM1: MCF7 = 3131.5, MDA-MB231 = 5.333333333333333
# CCDC63: MCF7 = 154.5, MDA-MB231 = 0.3333333333333333
# ZNF552: MCF7 = 417.86, MDA-MB231 = 201.5233333333333
# NTN1: MCF7 = 1039.0, MDA-MB231 = 5.666666666666667
# SLC2A10: MCF7 = 2506.5, MDA-MB231 = 13.333333333333334
# KCNJ3: MCF7 = 2125.5, MDA-MB231 = 2.6666666666666665
# FGFR2: MCF7 = 472.5, MDA-MB231 = 1.6666666666666667
# MAFF: MCF7 = 53.5, MDA-MB231 = 1395.6133333333337
# PBX1: MCF7 = 5848.0, MDA-MB231 = 97.66666666666669
# HES4: MCF7 = 1161.5, MDA-MB231 = 214.0
# PTPRM: MCF7 = 5.5, MDA-MB231 = 4150.31
# S100A14: MCF7 = 11503.0, MDA-MB231 = 17.666666666666668
# FOXA2: MCF7 = 4.5, MDA-MB231 = 1725.0
# COL13A1: MCF7 = 12.0, MDA-MB231 = 10099.666666666666
# ZIC1: MCF7 = 953.5, MDA-MB231 = 3.333333333333333
# RAB38: MCF7 = 0.5, MDA-MB231 = 129.0
# TBX4: MCF7 = 35.5, MDA-MB231 = 1.6666666666666667
# CREB3L1: MCF7 = 44.0, MDA-MB231 = 826.3333333333334
# ALDH2: MCF7 = 12.185, MDA-MB231 = 2863.0
# GBP1: MCF7 = 3.135, MDA-MB231 = 2595.563333333333
# C1orf210: MCF7 = 456.3, MDA-MB231 = 1.3333333333333333
# CREB3L2: MCF7 = 2230.5, MDA-MB231 = 5660.0
# SIX5: MCF7 = 706.05, MDA-MB231 = 245.53666666666663
# PREX1: MCF7 = 9755.5, MDA-MB231 = 37.0
# GSC: MCF7 = 270.5, MDA-MB231 = 0.3333333333333333
# SPINT1: MCF7 = 3621.37, MDA-MB231 = 9.0
# GAL: MCF7 = 700.5, MDA-MB231 = 0.3333333333333333
# NKX2-1: MCF7 = 1.0, MDA-MB231 = 529.5733333333334
# MAFG: MCF7 = 1397.955, MDA-MB231 = 4840.296666666666
# RAB17: MCF7 = 2428.245, MDA-MB231 = 4.333333333333333
# QPRT: MCF7 = 1449.315, MDA-MB231 = 6.0
# MARVELD3: MCF7 = 1178.935, MDA-MB231 = 6.010000000000001
# CAVIN2: MCF7 = 4.0, MDA-MB231 = 5742.2733333333335
# CREBZF: MCF7 = 9441.5, MDA-MB231 = 3241.333333333333
# BATF3: MCF7 = 1.0, MDA-MB231 = 323.3333333333333
# KCNQ3: MCF7 = 1.0, MDA-MB231 = 836.6666666666666
# SLFN12: MCF7 = 2.5, MDA-MB231 = 1401.496666666667
# KLF17: MCF7 = 0.5, MDA-MB231 = 15.666666666666666
# CT83: MCF7 = 0.5, MDA-MB231 = 97.66666666666669
# IFI44L: MCF7 = 1.0, MDA-MB231 = 225.33333333333331
# IRF6: MCF7 = 591.5, MDA-MB231 = 0.6666666666666666
# DEGS2: MCF7 = 1857.91, MDA-MB231 = 2.01
# ELF3: MCF7 = 4358.7, MDA-MB231 = 113.13
# HOXC13: MCF7 = 886.9449999999999, MDA-MB231 = 5.333333333333333
# MYT1L: MCF7 = 1.0, MDA-MB231 = 5.203333333333333
# G0S2: MCF7 = 1.5, MDA-MB231 = 2759.0
# PDE4B: MCF7 = 0.5, MDA-MB231 = 136.0
# MALRD1: MCF7 = 425.5, MDA-MB231 = 1.3333333333333333
# PDE10A: MCF7 = 3.5, MDA-MB231 = 1485.6666666666667
# EPN3: MCF7 = 2727.3, MDA-MB231 = 8.333333333333334
# KLF9: MCF7 = 1071.5, MDA-MB231 = 185.66666666666663
# SYK: MCF7 = 775.5, MDA-MB231 = 1.0
# ETS2: MCF7 = 741.0, MDA-MB231 = 1817.3333333333333
# HOXA7: MCF7 = 66.34, MDA-MB231 = 1.3333333333333333
# NR4A1: MCF7 = 355.34, MDA-MB231 = 82.00333333333333
# KLK11: MCF7 = 520.77, MDA-MB231 = 1.336666666666667
# LDHB: MCF7 = 103.0, MDA-MB231 = 45150.75666666668
# MYC: MCF7 = 1691.5, MDA-MB231 = 6442.333333333333
# LMX1B: MCF7 = 3646.05, MDA-MB231 = 118.75333333333332
# PDIA2: MCF7 = 112.0, MDA-MB231 = 0.6666666666666666
# IRF1: MCF7 = 272.9, MDA-MB231 = 1276.4566666666667
# MAZ: MCF7 = 19778.64, MDA-MB231 = 5696.986666666667
# ATF6: MCF7 = 1613.5, MDA-MB231 = 4243.0
# SOX9: MCF7 = 578.0, MDA-MB231 = 3656.6666666666665
# PITX3: MCF7 = 29.0, MDA-MB231 = 3.6666666666666665
# SLITRK6: MCF7 = 1279.5, MDA-MB231 = 3.6666666666666665
# HOXB13: MCF7 = 5.0, MDA-MB231 = 1.67
# CALD1: MCF7 = 7.0, MDA-MB231 = 4827.0
# MESP2: MCF7 = 21.5, MDA-MB231 = 3.0
# NBPF6: MCF7 = 417.245, MDA-MB231 = 1.0
# GLI1: MCF7 = 1.5, MDA-MB231 = 6.0
# PCSK2: MCF7 = 726.5, MDA-MB231 = 2.333333333333333
# ZNF35: MCF7 = 200.0, MDA-MB231 = 651.32
# ATF2: MCF7 = 1435.4450000000002, MDA-MB231 = 3205.9500000000003
# CXCL1: MCF7 = 0.5, MDA-MB231 = 231.22
# KCNQ5: MCF7 = 3.5, MDA-MB231 = 2243.39
# CNN3: MCF7 = 45.0, MDA-MB231 = 20332.666666666668
# CBFA2T3: MCF7 = 4054.51, MDA-MB231 = 2.333333333333333
# GLIS3: MCF7 = 17.0, MDA-MB231 = 407.2266666666666
# HUNK: MCF7 = 203.5, MDA-MB231 = 1.2366666666666666
# PCDH10: MCF7 = 4885.0, MDA-MB231 = 27.0
# TBPL2: MCF7 = 0.5, MDA-MB231 = 1.3333333333333333
# CUX1: MCF7 = 13676.0, MDA-MB231 = 4844.0
# LPAR1: MCF7 = 5.0, MDA-MB231 = 1434.0
# LAD1: MCF7 = 3463.495, MDA-MB231 = 5.0
# HOXC9: MCF7 = 185.5, MDA-MB231 = 16.0
# RUNX2: MCF7 = 370.0, MDA-MB231 = 879.0566666666667
# PDLIM4: MCF7 = 0.5, MDA-MB231 = 1010.6666666666666
# DBP: MCF7 = 588.92, MDA-MB231 = 45.76666666666667
# CREB3L4: MCF7 = 1883.745, MDA-MB231 = 183.56333333333336
# C19orf81: MCF7 = 126.5, MDA-MB231 = 0.6666666666666666
# ZKSCAN3: MCF7 = 129.28, MDA-MB231 = 502.0566666666666
# TBX5: MCF7 = 3.0, MDA-MB231 = 1.0
# SLC18B1: MCF7 = 1.0, MDA-MB231 = 450.3333333333333
# STAT3: MCF7 = 2930.4300000000003, MDA-MB231 = 7944.2
# HOXD1: MCF7 = 4.0, MDA-MB231 = 48.09
# ZNF785: MCF7 = 910.52, MDA-MB231 = 164.66333333333333
# AGPAT4: MCF7 = 0.5, MDA-MB231 = 610.3333333333334
# HEYL: MCF7 = 45.5, MDA-MB231 = 167.66666666666666
# ZNF675: MCF7 = 747.645, MDA-MB231 = 348.59
# SCUBE2: MCF7 = 4083.5, MDA-MB231 = 13.666666666666666
# MBNL2: MCF7 = 764.0, MDA-MB231 = 2016.3333333333333
# DCDC2: MCF7 = 1119.645, MDA-MB231 = 5.666666666666667
# E2F7: MCF7 = 1952.0, MDA-MB231 = 5912.0
# NLRP3: MCF7 = 1.515, MDA-MB231 = 311.09
# KLRG2: MCF7 = 176.0, MDA-MB231 = 1.0
# KCTD4: MCF7 = 1.0, MDA-MB231 = 302.0
# MSX1: MCF7 = 62.5, MDA-MB231 = 0.6666666666666666
# EHF: MCF7 = 1.0, MDA-MB231 = 6.333333333333333
# NFIX: MCF7 = 227.28, MDA-MB231 = 2313.75
# LHFPL6: MCF7 = 4.0, MDA-MB231 = 1059.3333333333333
# EVC: MCF7 = 2.5, MDA-MB231 = 1227.65
# IKZF2: MCF7 = 1176.0, MDA-MB231 = 217.66666666666663
# ZIC4: MCF7 = 535.96, MDA-MB231 = 0.6666666666666666
# NR3C2: MCF7 = 10.5, MDA-MB231 = 274.3333333333333
# ZSCAN5A: MCF7 = 150.95999999999998, MDA-MB231 = 303.93333333333334
# ITGBL1: MCF7 = 1.5, MDA-MB231 = 1450.3366666666668
# BPTF: MCF7 = 16436.115, MDA-MB231 = 4165.54
# CASP4: MCF7 = 7.5, MDA-MB231 = 2687.33
# GSTP1: MCF7 = 1.5, MDA-MB231 = 2090.333333333333
# FOXN2: MCF7 = 1050.5, MDA-MB231 = 2548.6666666666665
# ADRA2C: MCF7 = 980.5, MDA-MB231 = 3.6666666666666665
# TCF7L2: MCF7 = 397.0, MDA-MB231 = 935.3633333333332
# BCL11B: MCF7 = 86.0, MDA-MB231 = 12.0
# TBX3: MCF7 = 273.0, MDA-MB231 = 1.0
# DLX4: MCF7 = 215.5, MDA-MB231 = 36.333333333333336
# CCDC83: MCF7 = 440.5, MDA-MB231 = 1.0
# HLF: MCF7 = 47.5, MDA-MB231 = 8.666666666666666
# IL7R: MCF7 = 4.95, MDA-MB231 = 2023.34
# SPANXB1: MCF7 = 7.555, MDA-MB231 = 4093.9833333333336
# MSN: MCF7 = 121.925, MDA-MB231 = 42509.18333333333
# PAX5: MCF7 = 98.5, MDA-MB231 = 10.0
# CCDC170: MCF7 = 2723.5, MDA-MB231 = 1.6666666666666667
# SOX3: MCF7 = 691.0, MDA-MB231 = 1.6666666666666667
# SERPINE1: MCF7 = 45.5, MDA-MB231 = 22507.666666666668
# IFI16: MCF7 = 1.5, MDA-MB231 = 2266.0
# EMX1: MCF7 = 41.815, MDA-MB231 = 5.333333333333333
# ARHGAP23: MCF7 = 12.145, MDA-MB231 = 6119.333333333333
# CA8: MCF7 = 439.0, MDA-MB231 = 1.0
# TBX10: MCF7 = 2.5, MDA-MB231 = 0.3333333333333333
# MAGEH1: MCF7 = 448.5, MDA-MB231 = 2.333333333333333
# PCSK1N: MCF7 = 1027.0, MDA-MB231 = 1.3333333333333333
# GRHL1: MCF7 = 1840.085, MDA-MB231 = 104.68
# FUT9: MCF7 = 924.5, MDA-MB231 = 1.0
# DIRAS2: MCF7 = 146.5, MDA-MB231 = 0.3333333333333333
# HMGA1: MCF7 = 4606.04, MDA-MB231 = 53282.52
# FOXP3: MCF7 = 32.57, MDA-MB231 = 3.3366666666666664
# TCF4: MCF7 = 1.0, MDA-MB231 = 4.333333333333333
# GATA2: MCF7 = 1479.5, MDA-MB231 = 591.3333333333334
# ADCY5: MCF7 = 2689.5, MDA-MB231 = 10.966666666666669
# EHD3: MCF7 = 187.61, MDA-MB231 = 0.3333333333333333
# NINJ2: MCF7 = 1.0, MDA-MB231 = 268.0433333333333
# SOX5: MCF7 = 0.5, MDA-MB231 = 26.666666666666668
# FAM178B: MCF7 = 237.465, MDA-MB231 = 0.6666666666666666
# KCTD14: MCF7 = 6.32, MDA-MB231 = 1781.0
# SCRT1: MCF7 = 11.5, MDA-MB231 = 1.0
# HHEX: MCF7 = 276.0, MDA-MB231 = 600.0
# IL1RAPL1: MCF7 = 0.5, MDA-MB231 = 226.33333333333331
# SORBS2: MCF7 = 2.0, MDA-MB231 = 397.15
# ZBTB3: MCF7 = 304.625, MDA-MB231 = 152.02
# C4BPB: MCF7 = 2.0, MDA-MB231 = 415.3333333333333
# DUX4: MCF7 = 0.5, MDA-MB231 = 1.6766666666666667
# FOXO3: MCF7 = 5330.8, MDA-MB231 = 2431.556666666667
# LRP3: MCF7 = 1727.8, MDA-MB231 = 8.09
# ZNF235: MCF7 = 266.485, MDA-MB231 = 66.16333333333334
# EVA1A: MCF7 = 2.0, MDA-MB231 = 1012.6666666666666
# FLG: MCF7 = 3.65, MDA-MB231 = 2261.15
# CUX2: MCF7 = 6.0, MDA-MB231 = 2.0
# TMEM71: MCF7 = 1.0, MDA-MB231 = 1173.0
# FOXL1: MCF7 = 2.01, MDA-MB231 = 1.0
# ACKR3: MCF7 = 3749.0, MDA-MB231 = 4.0
# PSMB8: MCF7 = 12.5, MDA-MB231 = 2744.5533333333333
# DNAJC12: MCF7 = 339.0, MDA-MB231 = 1.3333333333333333
# MYB: MCF7 = 3067.76, MDA-MB231 = 77.66666666666667
# TMEM156: MCF7 = 8.0, MDA-MB231 = 2366.6666666666665
# CPVL: MCF7 = 2.0, MDA-MB231 = 949.8666666666668
# SLC6A14: MCF7 = 5494.24, MDA-MB231 = 21.026666666666667
# GRHL2: MCF7 = 6683.0, MDA-MB231 = 7.0
# HMGCLL1: MCF7 = 837.0, MDA-MB231 = 4.333333333333333
# NMNAT3: MCF7 = 60.14, MDA-MB231 = 0.3333333333333333
# ADD2: MCF7 = 3.5, MDA-MB231 = 2348.6666666666665
# HIC1: MCF7 = 35.045, MDA-MB231 = 204.8933333333333
# STK31: MCF7 = 2.5, MDA-MB231 = 627.6666666666666
# DLX5: MCF7 = 1.5, MDA-MB231 = 0.3333333333333333
# RORB: MCF7 = 1.0, MDA-MB231 = 38.333333333333336
# ANTXR2: MCF7 = 10.5, MDA-MB231 = 10715.666666666666
# ETV4: MCF7 = 77.5, MDA-MB231 = 3266.476666666667
# SP5: MCF7 = 2.5, MDA-MB231 = 254.99666666666667
# NKX6-1: MCF7 = 2.0, MDA-MB231 = 107.0
# APOL6: MCF7 = 6.0, MDA-MB231 = 1919.493333333333
# ANO3: MCF7 = 1.0, MDA-MB231 = 236.21
# CBS: MCF7 = 1491.34, MDA-MB231 = 2.8166666666666664
# HOXB6: MCF7 = 15.475, MDA-MB231 = 0.6666666666666666
# BEX4: MCF7 = 77.57, MDA-MB231 = 0.3333333333333333
# IGF2BP3: MCF7 = 5.585, MDA-MB231 = 3004.28
# ZNF202: MCF7 = 411.5, MDA-MB231 = 1062.3333333333333
# JUNB: MCF7 = 2414.24, MDA-MB231 = 856.8266666666667
# TCEAL9: MCF7 = 1.0, MDA-MB231 = 2219.333333333333
# FOXN1: MCF7 = 30.5, MDA-MB231 = 1.3333333333333333
# NRROS: MCF7 = 1.03, MDA-MB231 = 464.72
# OSR2: MCF7 = 2290.5, MDA-MB231 = 104.33333333333331
# SMOC2: MCF7 = 67.0, MDA-MB231 = 0.3333333333333333
# PRKAA2: MCF7 = 2.0, MDA-MB231 = 730.3333333333334
# IFIT3: MCF7 = 12.510000000000002, MDA-MB231 = 2559.74
# CCBE1: MCF7 = 4.865, MDA-MB231 = 2792.083333333333
# HOXB9: MCF7 = 24.0, MDA-MB231 = 690.6666666666666
# ASCL2: MCF7 = 608.0, MDA-MB231 = 0.6666666666666666
# LYPD3: MCF7 = 4367.0, MDA-MB231 = 15.333333333333334
# RAB34: MCF7 = 13.0, MDA-MB231 = 5513.0
# ENTPD2: MCF7 = 728.5, MDA-MB231 = 0.3333333333333333
# GATA6: MCF7 = 358.58000000000004, MDA-MB231 = 1039.8166666666668
# GLRA3: MCF7 = 649.0, MDA-MB231 = 2.333333333333333
# TLE4: MCF7 = 710.26, MDA-MB231 = 1.6666666666666667
# COX7B2: MCF7 = 1.0, MDA-MB231 = 690.3333333333334
# ADRB2: MCF7 = 5.0, MDA-MB231 = 2529.6666666666665
# ALDH3B2: MCF7 = 1051.145, MDA-MB231 = 0.68
# IRX4: MCF7 = 317.72, MDA-MB231 = 0.34
# GMFG: MCF7 = 3.5, MDA-MB231 = 649.3566666666667
# FST: MCF7 = 5.0, MDA-MB231 = 2468.6666666666665
# SPDEF: MCF7 = 5197.0, MDA-MB231 = 144.66666666666666
# NECTIN4: MCF7 = 951.0, MDA-MB231 = 2.0
# PPARGC1A: MCF7 = 0.5, MDA-MB231 = 126.0
# HTR1F: MCF7 = 0.5, MDA-MB231 = 259.6666666666667
# HOXC4: MCF7 = 32.035, MDA-MB231 = 12.183333333333332
# CMTM7: MCF7 = 9.3, MDA-MB231 = 2364.74
# EYA2: MCF7 = 154.0, MDA-MB231 = 0.3333333333333333
# FOXE1: MCF7 = 0.5, MDA-MB231 = 1.6666666666666667
# CEACAM5: MCF7 = 1614.075, MDA-MB231 = 0.3733333333333333
# RYR2: MCF7 = 4.0, MDA-MB231 = 939.6666666666666
# LHX1: MCF7 = 319.315, MDA-MB231 = 0.6666666666666666
# CST4: MCF7 = 1.5, MDA-MB231 = 361.52
# ETV5: MCF7 = 87.0, MDA-MB231 = 3645.3333333333335
# KLF14: MCF7 = 1.5, MDA-MB231 = 6.0
# COL4A1: MCF7 = 5.0, MDA-MB231 = 3608.0
# CXCL12: MCF7 = 772.0, MDA-MB231 = 0.6666666666666666
# PRDM1: MCF7 = 4.5, MDA-MB231 = 24.666666666666668
# NLRP1: MCF7 = 4.5, MDA-MB231 = 1144.0
# SOX12: MCF7 = 2394.0, MDA-MB231 = 948.3333333333334
# N4BP3: MCF7 = 3147.0, MDA-MB231 = 5.333333333333333
# FOXI3: MCF7 = 81.57499999999999, MDA-MB231 = 0.3333333333333333
# SPAG16: MCF7 = 2.0, MDA-MB231 = 492.6666666666667
# HOXC8: MCF7 = 16.0, MDA-MB231 = 63.66666666666666
# SREBF1: MCF7 = 12348.18, MDA-MB231 = 3117.0933333333337
# ZKSCAN1: MCF7 = 5732.435, MDA-MB231 = 2697.73
# SGCG: MCF7 = 274.5, MDA-MB231 = 0.6666666666666666
# HOXB1: MCF7 = 2.5, MDA-MB231 = 0.3333333333333333
# KLHL9: MCF7 = 1325.0, MDA-MB231 = 1.0
# CHST2: MCF7 = 3.5, MDA-MB231 = 736.9866666666667
# ANKRD1: MCF7 = 33.0, MDA-MB231 = 19683.0
# PRDM16: MCF7 = 173.5, MDA-MB231 = 6.0
# PLCL2: MCF7 = 2.5, MDA-MB231 = 543.3333333333334
# POU5F1B: MCF7 = 4.555, MDA-MB231 = 1.92
# PAX9: MCF7 = 589.84, MDA-MB231 = 286.96
# MAL2: MCF7 = 17172.78, MDA-MB231 = 100.33333333333331
# ZNF766: MCF7 = 911.055, MDA-MB231 = 339.0166666666667
# ZNF75D: MCF7 = 1697.535, MDA-MB231 = 366.0
# IL31RA: MCF7 = 2.0, MDA-MB231 = 461.3333333333333
# BACH2: MCF7 = 10.0, MDA-MB231 = 121.42666666666666
# DOCK8: MCF7 = 1328.76, MDA-MB231 = 4.126666666666666
# ELF1: MCF7 = 5000.46, MDA-MB231 = 1417.5
# IRX2: MCF7 = 952.19, MDA-MB231 = 0.3366666666666666
# FAM110C: MCF7 = 888.5, MDA-MB231 = 1.0
# ELOVL2: MCF7 = 2531.5, MDA-MB231 = 7.666666666666667
# HESX1: MCF7 = 25.0, MDA-MB231 = 10.666666666666666
# PAX2: MCF7 = 1.5, MDA-MB231 = 0.6666666666666666
# SPSB4: MCF7 = 75.5, MDA-MB231 = 0.3333333333333333
# SLCO1B3: MCF7 = 2.5, MDA-MB231 = 1682.6733333333332
# PDCD1LG2: MCF7 = 0.5, MDA-MB231 = 119.33333333333331
# MPP1: MCF7 = 2.0, MDA-MB231 = 591.0
# PDGFRB: MCF7 = 0.5, MDA-MB231 = 124.0
# HOXB3: MCF7 = 36.61, MDA-MB231 = 482.7033333333334
# CYP27A1: MCF7 = 1.5, MDA-MB231 = 284.0
# HOXA3: MCF7 = 15.07, MDA-MB231 = 0.3333333333333333
# GP2: MCF7 = 105.5, MDA-MB231 = 0.3333333333333333
# BTNL9: MCF7 = 170.0, MDA-MB231 = 1.0
# GFRA1: MCF7 = 44219.5, MDA-MB231 = 29.33333333333333
# PLA2G4F: MCF7 = 241.5, MDA-MB231 = 0.6666666666666666
# ZNF529: MCF7 = 247.82, MDA-MB231 = 496.18666666666667
# PCDHA12: MCF7 = 323.515, MDA-MB231 = 1.12
# ROR1: MCF7 = 4.5, MDA-MB231 = 2789.6666666666665
# CFH: MCF7 = 1.0, MDA-MB231 = 840.6533333333333
# TM4SF18: MCF7 = 5.5, MDA-MB231 = 3147.713333333333
# VENTX: MCF7 = 3.5, MDA-MB231 = 1.6666666666666667
# KLF3: MCF7 = 2626.75, MDA-MB231 = 1186.3866666666663
# FOXD4L1: MCF7 = 4.85, MDA-MB231 = 42.45
# IRF5: MCF7 = 414.5, MDA-MB231 = 135.33333333333334
# ZBTB20: MCF7 = 0.5, MDA-MB231 = 79.33333333333333
# FOXD4L6: MCF7 = 1.065, MDA-MB231 = 4.806666666666667
# ZBTB45: MCF7 = 913.555, MDA-MB231 = 438.31
# ANKRD34B: MCF7 = 245.5, MDA-MB231 = 0.3333333333333333
# MXD3: MCF7 = 1318.8449999999998, MDA-MB231 = 515.2633333333334
# FOXO6: MCF7 = 298.0, MDA-MB231 = 20.33333333333333
# AKT3: MCF7 = 7.515000000000001, MDA-MB231 = 2863.2100000000005
# IQANK1: MCF7 = 4166.845, MDA-MB231 = 8.643333333333333
# NPAS1: MCF7 = 19.5, MDA-MB231 = 61.66666666666666
# CALML5: MCF7 = 829.5, MDA-MB231 = 1.3333333333333333
# TCF12: MCF7 = 1200.5, MDA-MB231 = 3708.3333333333335
# TMEM178B: MCF7 = 1482.5, MDA-MB231 = 2.0
# GPAT2: MCF7 = 1.64, MDA-MB231 = 0.4533333333333333
# SHOX: MCF7 = 0.5, MDA-MB231 = 1.6666666666666667
# SHOX2: MCF7 = 28.5, MDA-MB231 = 990.52
# GRIK3: MCF7 = 286.5, MDA-MB231 = 1.3333333333333333
# MGMT: MCF7 = 1093.0, MDA-MB231 = 1.0
# PLAGL1: MCF7 = 147.0, MDA-MB231 = 2.6666666666666665
# CDCP1: MCF7 = 10.5, MDA-MB231 = 5995.329999999999
# NR4A2: MCF7 = 803.5, MDA-MB231 = 51.66666666666666
# BMP7: MCF7 = 14484.17, MDA-MB231 = 10.333333333333334
# ETV6: MCF7 = 444.5, MDA-MB231 = 1060.3333333333333
# BACH1: MCF7 = 597.5, MDA-MB231 = 2439.226666666667
# TFCP2L1: MCF7 = 11.5, MDA-MB231 = 452.3333333333333
# CAMK4: MCF7 = 2.5, MDA-MB231 = 973.0
# NRK: MCF7 = 64.5, MDA-MB231 = 0.3333333333333333
# ZNF641: MCF7 = 817.755, MDA-MB231 = 93.00333333333332
# VAX2: MCF7 = 101.0, MDA-MB231 = 36.333333333333336
# SOX2: MCF7 = 716.97, MDA-MB231 = 3.333333333333333
# LDOC1: MCF7 = 6003.5, MDA-MB231 = 12.333333333333334
# SHISA3: MCF7 = 1.0, MDA-MB231 = 434.6666666666667
# TFEC: MCF7 = 1.5, MDA-MB231 = 13.333333333333334
# SLC2A3: MCF7 = 3.86, MDA-MB231 = 1237.32
# NUP210L: MCF7 = 633.0, MDA-MB231 = 2.6666666666666665
# PRRX2: MCF7 = 64.5, MDA-MB231 = 1.6666666666666667
# P3H2: MCF7 = 8.0, MDA-MB231 = 4861.666666666667
# FSD1: MCF7 = 249.515, MDA-MB231 = 0.7066666666666667
# FXYD5: MCF7 = 32.0, MDA-MB231 = 5812.666666666667
# BHLHA15: MCF7 = 5.0, MDA-MB231 = 0.3333333333333333
# MEF2C: MCF7 = 2.5, MDA-MB231 = 238.86333333333332
# HAND2: MCF7 = 1.0, MDA-MB231 = 0.3333333333333333
# RAB25: MCF7 = 2984.5, MDA-MB231 = 5.0
# CD274: MCF7 = 4.0, MDA-MB231 = 958.3333333333334
# LARGE2: MCF7 = 358.5, MDA-MB231 = 1.0
# DGKG: MCF7 = 0.5, MDA-MB231 = 593.6666666666666
# HOXD9: MCF7 = 2.0, MDA-MB231 = 0.3333333333333333
# ZBTB32: MCF7 = 28.0, MDA-MB231 = 4.0
# NFE2L3: MCF7 = 620.0550000000001, MDA-MB231 = 8407.39
# LIMCH1: MCF7 = 66.5, MDA-MB231 = 18359.0
# CEBPA: MCF7 = 705.56, MDA-MB231 = 146.61666666666665
# SYTL5: MCF7 = 5805.0, MDA-MB231 = 10.0
# AGPS: MCF7 = 16.5, MDA-MB231 = 6923.0
# CBLN4: MCF7 = 72.0, MDA-MB231 = 0.3333333333333333
# SOX4: MCF7 = 4609.5, MDA-MB231 = 791.6666666666666
# POU2F3: MCF7 = 55.5, MDA-MB231 = 16.666666666666668
# GFI1: MCF7 = 53.5, MDA-MB231 = 14.0
# ICAM2: MCF7 = 1.3, MDA-MB231 = 810.0033333333334
# CHDH: MCF7 = 909.935, MDA-MB231 = 4.003333333333333
# FOXH1: MCF7 = 25.615, MDA-MB231 = 8.536666666666667
# ASCL1: MCF7 = 296.71500000000003, MDA-MB231 = 1.3333333333333333
# PLPPR5: MCF7 = 176.5, MDA-MB231 = 0.3333333333333333
# ONECUT3: MCF7 = 0.5, MDA-MB231 = 1.6666666666666667
# MMP14: MCF7 = 51.0, MDA-MB231 = 13636.333333333334
# BHLHE41: MCF7 = 21.0, MDA-MB231 = 198.72333333333336
# CXCL2: MCF7 = 0.5, MDA-MB231 = 117.55333333333331
# NNMT: MCF7 = 0.5, MDA-MB231 = 343.3333333333333
# SLC9A2: MCF7 = 2277.5, MDA-MB231 = 1.6666666666666667
# POU2F2: MCF7 = 36.0, MDA-MB231 = 94.33333333333331
# ETV2: MCF7 = 29.0, MDA-MB231 = 12.666666666666666
# ZNF513: MCF7 = 127.475, MDA-MB231 = 360.54
# CREB5: MCF7 = 3.0, MDA-MB231 = 1267.3333333333333
# HOXA9: MCF7 = 5.0, MDA-MB231 = 0.3333333333333333
# MSX2: MCF7 = 1593.99, MDA-MB231 = 79.33333333333333
# ATOH7: MCF7 = 8.0, MDA-MB231 = 1.6666666666666667
# PEG10: MCF7 = 20.5, MDA-MB231 = 6469.666666666667
# HIVEP3: MCF7 = 928.0, MDA-MB231 = 418.0
# KIF1A: MCF7 = 763.005, MDA-MB231 = 3.333333333333333
# VSX1: MCF7 = 5.5, MDA-MB231 = 16.666666666666668
# ETV7: MCF7 = 1.5, MDA-MB231 = 7.0
# ENTPD8: MCF7 = 567.5, MDA-MB231 = 2.6666666666666665
# NR1D1: MCF7 = 123.47, MDA-MB231 = 387.69666666666666
# ILDR2: MCF7 = 2.0, MDA-MB231 = 551.0
# BCAT1: MCF7 = 16.5, MDA-MB231 = 7962.603333333333
# LAYN: MCF7 = 3.5, MDA-MB231 = 1336.6666666666667
# GOLT1A: MCF7 = 249.5, MDA-MB231 = 1.0
# IGFBP5: MCF7 = 1178.5, MDA-MB231 = 2.0
# E2F3: MCF7 = 1856.495, MDA-MB231 = 3975.99
# NR4A3: MCF7 = 226.5, MDA-MB231 = 24.33333333333333
# DLX1: MCF7 = 271.0, MDA-MB231 = 74.33333333333333
# CAVIN3: MCF7 = 2.5, MDA-MB231 = 2632.6666666666665
# SNAI1: MCF7 = 27.5, MDA-MB231 = 197.33333333333331
# SLC27A6: MCF7 = 534.0, MDA-MB231 = 0.3333333333333333
# GBP3: MCF7 = 18.93, MDA-MB231 = 3596.0733333333337
# CDC42EP3: MCF7 = 30.815, MDA-MB231 = 15019.783333333333
# RFX4: MCF7 = 0.5, MDA-MB231 = 11.436666666666667
# KLRC2: MCF7 = 0.5, MDA-MB231 = 89.48666666666668
# ARHGAP40: MCF7 = 1.0, MDA-MB231 = 398.3333333333333
# HOXB5: MCF7 = 0.5, MDA-MB231 = 2.333333333333333
# CASP1: MCF7 = 0.5, MDA-MB231 = 209.53
# TBX2: MCF7 = 10104.5, MDA-MB231 = 16.333333333333332
# RCSD1: MCF7 = 2.5, MDA-MB231 = 1161.6666666666667
# LHX2: MCF7 = 305.435, MDA-MB231 = 0.3333333333333333
# NR2F2: MCF7 = 18510.0, MDA-MB231 = 6808.333333333333
# BCHE: MCF7 = 0.5, MDA-MB231 = 816.6666666666666
# ZNF276: MCF7 = 2172.64, MDA-MB231 = 1078.3466666666666
# COL4A2: MCF7 = 42.0, MDA-MB231 = 9611.136666666667
# DAW1: MCF7 = 0.5, MDA-MB231 = 453.3333333333333
# PKP1: MCF7 = 1287.0, MDA-MB231 = 4.333333333333333
# PRDM6: MCF7 = 349.9, MDA-MB231 = 37.2
# SMAD3: MCF7 = 4715.0, MDA-MB231 = 12848.0
# ZEB1: MCF7 = 36.22, MDA-MB231 = 2821.613333333333
# HES6: MCF7 = 1414.0, MDA-MB231 = 256.0
# F2RL3: MCF7 = 1.0, MDA-MB231 = 190.0
# RBPJL: MCF7 = 1.0, MDA-MB231 = 3.0
# ENPP5: MCF7 = 344.515, MDA-MB231 = 0.6666666666666666
# DOK7: MCF7 = 1191.5, MDA-MB231 = 3.6666666666666665
# NR3C1: MCF7 = 1673.455, MDA-MB231 = 5867.653333333333
# MUC15: MCF7 = 0.5, MDA-MB231 = 420.45666666666665
# HOXB2: MCF7 = 27.78, MDA-MB231 = 11.923333333333332
# RAC2: MCF7 = 8.0, MDA-MB231 = 5697.333333333333
# NFKB2: MCF7 = 903.01, MDA-MB231 = 3219.66
# SOX21: MCF7 = 1.51, MDA-MB231 = 10.333333333333334
# SULT2B1: MCF7 = 1699.0, MDA-MB231 = 8.0
# TCF7: MCF7 = 53.0, MDA-MB231 = 226.39
# GLI2: MCF7 = 2.5, MDA-MB231 = 397.6666666666667
# AK7: MCF7 = 1026.99, MDA-MB231 = 5.666666666666667
# HENMT1: MCF7 = 2042.62, MDA-MB231 = 1.0366666666666666
# ZNF132: MCF7 = 52.5, MDA-MB231 = 242.0
# PRSS8: MCF7 = 3366.135, MDA-MB231 = 3.56
# MYL9: MCF7 = 4.5, MDA-MB231 = 1822.02
# BATF: MCF7 = 386.0, MDA-MB231 = 45.333333333333336
# ST6GALNAC3: MCF7 = 0.5, MDA-MB231 = 156.66666666666666
# ELOVL4: MCF7 = 174.5, MDA-MB231 = 0.3333333333333333
# MLXIPL: MCF7 = 306.0, MDA-MB231 = 19.666666666666668
# ZNF41: MCF7 = 742.5, MDA-MB231 = 329.6666666666667
# BSPRY: MCF7 = 1852.0, MDA-MB231 = 2.333333333333333
# GATA3: MCF7 = 48436.5, MDA-MB231 = 310.6666666666667
# MPP4: MCF7 = 4.5, MDA-MB231 = 2121.6733333333336
# ESRRG: MCF7 = 38.5, MDA-MB231 = 2.6666666666666665
# ZNF501: MCF7 = 0.5, MDA-MB231 = 157.33333333333334
# APOBEC3C: MCF7 = 4.0, MDA-MB231 = 1283.6966666666667
# RBP7: MCF7 = 71.5, MDA-MB231 = 0.3333333333333333
# PCDH8: MCF7 = 72.0, MDA-MB231 = 0.3333333333333333
# DMRTA2: MCF7 = 1.0, MDA-MB231 = 3.333333333333333
# HOXB4: MCF7 = 1.5, MDA-MB231 = 78.86999999999999
# ATF4: MCF7 = 5797.11, MDA-MB231 = 11878.776666666668
# RXRA: MCF7 = 13546.5, MDA-MB231 = 2533.6666666666665
# DPF3: MCF7 = 31.0, MDA-MB231 = 284.6666666666667
# BIRC3: MCF7 = 13.02, MDA-MB231 = 2386.6199999999994
# CEACAM6: MCF7 = 687.895, MDA-MB231 = 1.0266666666666666
# SLC17A9: MCF7 = 12.5, MDA-MB231 = 4596.666666666667
# GABRA3: MCF7 = 0.5, MDA-MB231 = 220.0
# SULF1: MCF7 = 2108.0, MDA-MB231 = 4.666666666666667
# SHISA9: MCF7 = 824.5, MDA-MB231 = 4.0
# SNAI2: MCF7 = 23.0, MDA-MB231 = 604.0
# LYPD6B: MCF7 = 689.0, MDA-MB231 = 1.0
# SPARC: MCF7 = 8.5, MDA-MB231 = 5381.943333333334
# RREB1: MCF7 = 2786.5, MDA-MB231 = 1376.0
# FOXM1: MCF7 = 5104.13, MDA-MB231 = 10497.236666666666
# EMID1: MCF7 = 314.5, MDA-MB231 = 1.6666666666666667
# MMEL1: MCF7 = 150.94, MDA-MB231 = 0.3333333333333333
# GPX1: MCF7 = 8.0, MDA-MB231 = 5315.536666666667
# KIAA0040: MCF7 = 373.5, MDA-MB231 = 2.0
# TBX6: MCF7 = 175.5, MDA-MB231 = 16.666666666666668
# MSI1: MCF7 = 523.5, MDA-MB231 = 1.0
# ALOX15: MCF7 = 740.8399999999999, MDA-MB231 = 1.6666666666666667
# HOXC6: MCF7 = 241.535, MDA-MB231 = 120.44333333333331
# CACNA1D: MCF7 = 262.265, MDA-MB231 = 1.0
# NPAS2: MCF7 = 321.59, MDA-MB231 = 4171.92
# PNMA2: MCF7 = 8.504999999999999, MDA-MB231 = 1711.1233333333332
# TMEM30B: MCF7 = 4239.81, MDA-MB231 = 4.203333333333333
# OVOL1: MCF7 = 772.29, MDA-MB231 = 2.356666666666667
# FOXI1: MCF7 = 35.505, MDA-MB231 = 0.3333333333333333
# FAM171A1: MCF7 = 17.0, MDA-MB231 = 3587.333333333333
# SLC43A3: MCF7 = 24.875, MDA-MB231 = 14502.79
# GCM1: MCF7 = 0.5, MDA-MB231 = 1.6666666666666667
# SOX18: MCF7 = 113.5, MDA-MB231 = 33.666666666666664
# ONECUT2: MCF7 = 463.0, MDA-MB231 = 226.33333333333331
# ARID3A: MCF7 = 1360.36, MDA-MB231 = 165.06666666666666
# COL8A1: MCF7 = 4.5, MDA-MB231 = 1507.33
# ELF5: MCF7 = 137.5, MDA-MB231 = 0.6666666666666666
# ADGRF5: MCF7 = 7.26, MDA-MB231 = 9675.113333333336
# TFAP2A: MCF7 = 1525.665, MDA-MB231 = 138.96333333333334
# SMTNL2: MCF7 = 132.0, MDA-MB231 = 0.3333333333333333
# NKX2-8: MCF7 = 8.0, MDA-MB231 = 42.333333333333336
# SYT10: MCF7 = 561.5, MDA-MB231 = 1.0
# FAM83B: MCF7 = 2939.5, MDA-MB231 = 2.6666666666666665
# RAMP3: MCF7 = 2250.5, MDA-MB231 = 3.333333333333333
# CELF2: MCF7 = 3.0, MDA-MB231 = 1514.3333333333333
# LEF1: MCF7 = 27.5, MDA-MB231 = 623.5633333333334
# KLF16: MCF7 = 768.955, MDA-MB231 = 2074.9633333333336
# RNF223: MCF7 = 1204.0, MDA-MB231 = 1.6666666666666667
# CPNE8: MCF7 = 1.0, MDA-MB231 = 1283.0
# HEY2: MCF7 = 332.0, MDA-MB231 = 26.33333333333333
# MYH14: MCF7 = 7061.855, MDA-MB231 = 6.666666666666667
# SHC2: MCF7 = 66.0, MDA-MB231 = 0.3333333333333333
# F3: MCF7 = 119.595, MDA-MB231 = 24922.123333333333
# PRDM9: MCF7 = 1.0, MDA-MB231 = 646.8000000000001
# AKR1B1: MCF7 = 8.440000000000001, MDA-MB231 = 5195.1033333333335
# CD96: MCF7 = 6.5, MDA-MB231 = 3278.333333333333
# ZBTB18: MCF7 = 32.5, MDA-MB231 = 2511.0
# ARNT2: MCF7 = 2226.21, MDA-MB231 = 569.7966666666666
# ESR1: MCF7 = 13965.5, MDA-MB231 = 34.333333333333336
# MAFB: MCF7 = 474.0, MDA-MB231 = 34.333333333333336
# CAPN13: MCF7 = 943.5, MDA-MB231 = 2.0
# KDF1: MCF7 = 609.0, MDA-MB231 = 1.3333333333333333
# DRD1: MCF7 = 287.5, MDA-MB231 = 0.3333333333333333
# TM4SF1: MCF7 = 48.0, MDA-MB231 = 16488.666666666668
# PCDHA11: MCF7 = 773.73, MDA-MB231 = 1.1
# ELK3: MCF7 = 472.73, MDA-MB231 = 7458.956666666666
# ATP10D: MCF7 = 0.5, MDA-MB231 = 1417.743333333333
# PITX1: MCF7 = 460.0, MDA-MB231 = 1643.4366666666665
# COL4A6: MCF7 = 94.0, MDA-MB231 = 0.3333333333333333
# MAGEA3: MCF7 = 0.5, MDA-MB231 = 376.8666666666666
# STK33: MCF7 = 3.0, MDA-MB231 = 591.6666666666666
# SAMD9L: MCF7 = 1.0, MDA-MB231 = 1132.3333333333333
# RIPPLY3: MCF7 = 443.32, MDA-MB231 = 1.6666666666666667
# BRINP2: MCF7 = 1036.5, MDA-MB231 = 2.0
# ACOT4: MCF7 = 512.5, MDA-MB231 = 2.6666666666666665
# GABRE: MCF7 = 0.5, MDA-MB231 = 657.4966666666667
# CAPN9: MCF7 = 645.085, MDA-MB231 = 2.333333333333333
# RBMS3: MCF7 = 1.0, MDA-MB231 = 778.3333333333334
# KLF6: MCF7 = 1342.5, MDA-MB231 = 6472.333333333333
# JUN: MCF7 = 1819.0, MDA-MB231 = 6262.666666666667
# MAGEC2: MCF7 = 8.5, MDA-MB231 = 7579.976666666666
# HAS2: MCF7 = 2.0, MDA-MB231 = 681.9433333333333
# GCM2: MCF7 = 2.0, MDA-MB231 = 0.6666666666666666
# FOXR1: MCF7 = 3.0, MDA-MB231 = 1.0
# SRGN: MCF7 = 16.5, MDA-MB231 = 11416.333333333334
# XBP1: MCF7 = 33344.7, MDA-MB231 = 3090.353333333333
# SDHAF3: MCF7 = 1.0, MDA-MB231 = 395.6666666666667
# BARX1: MCF7 = 2.0, MDA-MB231 = 0.3333333333333333
# ARHGAP8: MCF7 = 960.935, MDA-MB231 = 1.0
# ERBB4: MCF7 = 1829.5, MDA-MB231 = 6.0
# LIMS2: MCF7 = 2.0, MDA-MB231 = 395.69666666666666
# FLNC: MCF7 = 54.010000000000005, MDA-MB231 = 22592.41
# FOXD4: MCF7 = 11.7, MDA-MB231 = 42.71666666666667
# LYPD8: MCF7 = 0.5, MDA-MB231 = 133.67
# EMC10: MCF7 = 5768.675, MDA-MB231 = 8.01
# ZSCAN30: MCF7 = 121.625, MDA-MB231 = 1053.3566666666668
# CACNA2D4: MCF7 = 3.5, MDA-MB231 = 1312.6666666666667
# LY96: MCF7 = 0.5, MDA-MB231 = 136.33333333333334
# MITF: MCF7 = 83.0, MDA-MB231 = 754.6666666666666
# FOXQ1: MCF7 = 3.0, MDA-MB231 = 225.33333333333331
# MNX1: MCF7 = 524.5, MDA-MB231 = 136.66666666666666
# ETS1: MCF7 = 23.0, MDA-MB231 = 12376.483333333332
# NECAB1: MCF7 = 3946.675, MDA-MB231 = 5.563333333333333
# GCNT2: MCF7 = 27.5, MDA-MB231 = 4943.076666666667
# IFI44: MCF7 = 7.5, MDA-MB231 = 1540.0
# C14orf132: MCF7 = 1137.565, MDA-MB231 = 2.0
# ANXA8L1: MCF7 = 0.59, MDA-MB231 = 163.82333333333332
# GJA1: MCF7 = 7.35, MDA-MB231 = 2115.8700000000003
# HBP1: MCF7 = 2285.495, MDA-MB231 = 887.4200000000001
# ZNF18: MCF7 = 311.915, MDA-MB231 = 95.65333333333332
# FGF5: MCF7 = 11.5, MDA-MB231 = 6164.466666666667
# FOSB: MCF7 = 41.0, MDA-MB231 = 92.66666666666669
# POPDC3: MCF7 = 4.0, MDA-MB231 = 1014.3333333333334
# FOXJ1: MCF7 = 7.0, MDA-MB231 = 1.0
# NBPF4: MCF7 = 238.63, MDA-MB231 = 0.4666666666666666
# FOXD1: MCF7 = 174.34, MDA-MB231 = 1.7133333333333336
# ESRRB: MCF7 = 6.5, MDA-MB231 = 1.0
# TCF23: MCF7 = 1.5, MDA-MB231 = 5.666666666666667
# NAV3: MCF7 = 24.0, MDA-MB231 = 5150.666666666667
# ARX: MCF7 = 44.0, MDA-MB231 = 0.3333333333333333
# DMRTA1: MCF7 = 143.5, MDA-MB231 = 0.3333333333333333
# ADAMTS19: MCF7 = 4024.375, MDA-MB231 = 7.399999999999999
# ZFHX4: MCF7 = 1.0, MDA-MB231 = 38.0
# MAGEC1: MCF7 = 6.5, MDA-MB231 = 3244.96
# IGFBP1: MCF7 = 1.0, MDA-MB231 = 1217.6666666666667
# HRH1: MCF7 = 6.5, MDA-MB231 = 2081.6666666666665
# OOEP: MCF7 = 56.235, MDA-MB231 = 0.3333333333333333
# NR2F1: MCF7 = 36.21, MDA-MB231 = 752.2566666666667
# LYL1: MCF7 = 1.5, MDA-MB231 = 37.0
# TFAP2E: MCF7 = 15.5, MDA-MB231 = 46.66666666666666
# KLF8: MCF7 = 102.5, MDA-MB231 = 21.666666666666668
# BPIFB1: MCF7 = 124.005, MDA-MB231 = 0.6666666666666666
# TFCP2: MCF7 = 3.5, MDA-MB231 = 1758.0
# CLSTN2: MCF7 = 1451.5, MDA-MB231 = 1.0033333333333332
# BICC1: MCF7 = 1.0, MDA-MB231 = 556.6666666666666
# GLRB: MCF7 = 2.0, MDA-MB231 = 364.0
# THRB: MCF7 = 980.5, MDA-MB231 = 107.33333333333331
# PDZRN3: MCF7 = 290.81, MDA-MB231 = 1.0
# BHLHE40: MCF7 = 740.0, MDA-MB231 = 1856.0
# JUND: MCF7 = 5398.0, MDA-MB231 = 909.6666666666666
# DDIT3: MCF7 = 282.58000000000004, MDA-MB231 = 772.2833333333334
# ADGRE1: MCF7 = 0.5, MDA-MB231 = 120.66666666666669
# PGR: MCF7 = 2616.0, MDA-MB231 = 2.6666666666666665
# ATF3: MCF7 = 73.0, MDA-MB231 = 478.6666666666667
# ADAMTS16: MCF7 = 0.5, MDA-MB231 = 310.3333333333333
# EVI2B: MCF7 = 4.5, MDA-MB231 = 863.6233333333333
# RFPL4AL1: MCF7 = 0.5, MDA-MB231 = 127.62333333333332
# EGR4: MCF7 = 1.0, MDA-MB231 = 0.3333333333333333
# ZEB2: MCF7 = 4.58, MDA-MB231 = 1039.62
# ONECUT1: MCF7 = 40.0, MDA-MB231 = 11.333333333333334
# ZNF467: MCF7 = 1355.0, MDA-MB231 = 87.33333333333333
# FLI1: MCF7 = 0.5, MDA-MB231 = 3.333333333333333
# CCDC120: MCF7 = 1054.0, MDA-MB231 = 4.0
# SIM1: MCF7 = 202.5, MDA-MB231 = 1.3333333333333333
# PPL: MCF7 = 4755.0, MDA-MB231 = 16.0
# SLC4A4: MCF7 = 0.5, MDA-MB231 = 97.0
# HS3ST3A1: MCF7 = 736.24, MDA-MB231 = 0.3966666666666666
# CTNND2: MCF7 = 1769.0, MDA-MB231 = 4.0
# IGFBP2: MCF7 = 3947.5, MDA-MB231 = 6.0
# TLR4: MCF7 = 2.0, MDA-MB231 = 1185.3333333333333
# LHX6: MCF7 = 104.0, MDA-MB231 = 27.33333333333333
# LAMA1: MCF7 = 0.5, MDA-MB231 = 133.76666666666668
# ANK2: MCF7 = 5.5, MDA-MB231 = 1038.6666666666667
# APOL3: MCF7 = 2.0, MDA-MB231 = 550.68
# EVI2A: MCF7 = 7.5, MDA-MB231 = 2093.713333333333
# FSTL1: MCF7 = 27.0, MDA-MB231 = 8757.0
# EGR3: MCF7 = 339.08500000000004, MDA-MB231 = 12.0
# ABCA12: MCF7 = 1181.5, MDA-MB231 = 3.333333333333333
# MYCL: MCF7 = 224.0, MDA-MB231 = 23.32333333333333
# CDK15: MCF7 = 1.5, MDA-MB231 = 713.6833333333334
# RARG: MCF7 = 3692.29, MDA-MB231 = 858.6666666666666
# ARHGDIB: MCF7 = 40.5, MDA-MB231 = 9505.333333333334
# TMEM26: MCF7 = 485.095, MDA-MB231 = 0.3333333333333333
# POU6F1: MCF7 = 12.5, MDA-MB231 = 128.0
# TBX1: MCF7 = 9.425, MDA-MB231 = 259.25
# NETO2: MCF7 = 1110.0, MDA-MB231 = 5.333333333333333
# FOXP2: MCF7 = 5.63, MDA-MB231 = 127.12666666666668
# BMP5: MCF7 = 1808.0, MDA-MB231 = 8.666666666666666
# EPPK1: MCF7 = 8488.57, MDA-MB231 = 24.10333333333333
# TP73: MCF7 = 923.12, MDA-MB231 = 110.88
# DLX3: MCF7 = 341.5, MDA-MB231 = 17.333333333333332
# PSAT1: MCF7 = 15.5, MDA-MB231 = 6883.993333333335
# BARHL1: MCF7 = 2.5, MDA-MB231 = 6.0
# HPDL: MCF7 = 550.0, MDA-MB231 = 2.0
# HMGA2: MCF7 = 10.5, MDA-MB231 = 6927.193333333333
# MYRF: MCF7 = 75.0, MDA-MB231 = 1118.5633333333333
# ZNF711: MCF7 = 107.39, MDA-MB231 = 0.3333333333333333
# NPNT: MCF7 = 3554.035, MDA-MB231 = 5.6433333333333335
# LHX4: MCF7 = 589.485, MDA-MB231 = 284.0133333333333
# ARHGDIG: MCF7 = 191.28, MDA-MB231 = 1.0
# NKX3-1: MCF7 = 92.5, MDA-MB231 = 415.0
# EVPLL: MCF7 = 73.23, MDA-MB231 = 0.35
# ZFP1: MCF7 = 1242.5, MDA-MB231 = 518.3333333333334
# TAL2: MCF7 = 3.5, MDA-MB231 = 9.0
# DSCAM: MCF7 = 5994.0, MDA-MB231 = 17.0
# PAX6: MCF7 = 30.0, MDA-MB231 = 90.33333333333331
# ERG: MCF7 = 17.0, MDA-MB231 = 0.3333333333333333
# STAC: MCF7 = 0.5, MDA-MB231 = 1268.0
# PCDHGB5: MCF7 = 1590.13, MDA-MB231 = 5.079999999999999
# ROBO4: MCF7 = 3.185, MDA-MB231 = 1989.3333333333333
# BCAS1: MCF7 = 1788.56, MDA-MB231 = 5.333333333333333
# REG4: MCF7 = 235.5, MDA-MB231 = 0.6666666666666666
# SORCS1: MCF7 = 282.0, MDA-MB231 = 1.0
# ADAMTS12: MCF7 = 4.0, MDA-MB231 = 1610.6666666666667
# SPIB: MCF7 = 8.02, MDA-MB231 = 21.57333333333333
# KCTD15: MCF7 = 1739.5, MDA-MB231 = 2.6666666666666665
# EBF2: MCF7 = 6.0, MDA-MB231 = 1.3333333333333333
# SULF2: MCF7 = 64968.94500000001, MDA-MB231 = 51.86333333333334
# HOXD3: MCF7 = 1.5, MDA-MB231 = 271.04
# TEF: MCF7 = 1196.0, MDA-MB231 = 240.33333333333331
# ZIC2: MCF7 = 250.0, MDA-MB231 = 997.0
# NR2E3: MCF7 = 33.5, MDA-MB231 = 6.333333333333333
# HOXB7: MCF7 = 282.94, MDA-MB231 = 50.0
# FOXC2: MCF7 = 0.5, MDA-MB231 = 1.763333333333333
# RET: MCF7 = 5778.0, MDA-MB231 = 3.0
# ZSCAN10: MCF7 = 0.5, MDA-MB231 = 1.6666666666666667
# LAMA4: MCF7 = 2.0, MDA-MB231 = 1065.65
# EMP1: MCF7 = 33.0, MDA-MB231 = 12112.0
# CPEB1: MCF7 = 9.5, MDA-MB231 = 2.04
# SH3RF3: MCF7 = 2.0, MDA-MB231 = 875.0
# RNF43: MCF7 = 3252.685, MDA-MB231 = 3.6666666666666665
# PTX3: MCF7 = 3.0, MDA-MB231 = 5203.0
# CLDN1: MCF7 = 3.0, MDA-MB231 = 685.3333333333334
# GNG11: MCF7 = 1.5, MDA-MB231 = 1708.6666666666667
# NR1I3: MCF7 = 7.84, MDA-MB231 = 32.68333333333334
# RARB: MCF7 = 4.5, MDA-MB231 = 12.333333333333334
# GPR27: MCF7 = 505.0, MDA-MB231 = 0.3333333333333333
# ADAMTS1: MCF7 = 8.5, MDA-MB231 = 1691.3333333333333
# CD40: MCF7 = 0.5, MDA-MB231 = 1843.3333333333333
# MAF: MCF7 = 41.5, MDA-MB231 = 2.0
# TP63: MCF7 = 24.0, MDA-MB231 = 8.0
# PBX3: MCF7 = 1949.0, MDA-MB231 = 840.6666666666666
# PROM2: MCF7 = 1955.415, MDA-MB231 = 7.0
# NFATC1: MCF7 = 415.5, MDA-MB231 = 179.33333333333334
# CHRM3: MCF7 = 2.0, MDA-MB231 = 588.3266666666667
# ALX3: MCF7 = 2.55, MDA-MB231 = 0.5833333333333334
# PHYHD1: MCF7 = 3.0, MDA-MB231 = 992.8033333333332
# CRX: MCF7 = 0.51, MDA-MB231 = 2.0
# PKNOX2: MCF7 = 5.5, MDA-MB231 = 1.0
# MSRB3: MCF7 = 5.525, MDA-MB231 = 1851.64
# PCDHAC2: MCF7 = 302.025, MDA-MB231 = 0.6666666666666666
# FXYD3: MCF7 = 9192.0, MDA-MB231 = 6.666666666666667
# PPARG: MCF7 = 394.0, MDA-MB231 = 2565.6666666666665
# YBX2: MCF7 = 1905.44, MDA-MB231 = 3.0
# TBX15: MCF7 = 6.5, MDA-MB231 = 27.33333333333333
# HOXB8: MCF7 = 0.5, MDA-MB231 = 30.0
# EGR2: MCF7 = 1.5, MDA-MB231 = 38.66666666666666
# SLC24A3: MCF7 = 2631.2, MDA-MB231 = 4.333333333333333
# RUBCNL: MCF7 = 110.0, MDA-MB231 = 0.6666666666666666
# BARX2: MCF7 = 407.0, MDA-MB231 = 3.333333333333333
# ETV1: MCF7 = 4.5, MDA-MB231 = 2663.0
# SMAD9: MCF7 = 32.645, MDA-MB231 = 114.72666666666667
# MT1E: MCF7 = 9.0, MDA-MB231 = 3125.58
# ZNF248: MCF7 = 765.815, MDA-MB231 = 373.42
# SIM2: MCF7 = 160.0, MDA-MB231 = 373.3333333333333
# RBPJ: MCF7 = 2904.8900000000003, MDA-MB231 = 7809.493333333333
# TDRD5: MCF7 = 281.5, MDA-MB231 = 0.6666666666666666
# RASAL1: MCF7 = 1079.545, MDA-MB231 = 1.0
# ADGRG5: MCF7 = 162.0, MDA-MB231 = 0.3333333333333333
# CPED1: MCF7 = 4.55, MDA-MB231 = 1170.8633333333337
# ZNF655: MCF7 = 8.515, MDA-MB231 = 3935.466666666667
# CXCL8: MCF7 = 1.0, MDA-MB231 = 1144.0
# RUNX3: MCF7 = 2.0, MDA-MB231 = 8.333333333333334
# SPANXC: MCF7 = 1.56, MDA-MB231 = 724.36
# APOL1: MCF7 = 4.5, MDA-MB231 = 806.6533333333333
# ZBTB42: MCF7 = 1644.0, MDA-MB231 = 148.33333333333334
# EDIL3: MCF7 = 7.5, MDA-MB231 = 7042.996666666667
# ERBB3: MCF7 = 11822.0, MDA-MB231 = 67.33333333333333
# PRSS2: MCF7 = 0.5, MDA-MB231 = 401.8666666666666
# RBBP8NL: MCF7 = 737.0, MDA-MB231 = 0.3333333333333333
# ME3: MCF7 = 12.0, MDA-MB231 = 2131.6666666666665
# KIRREL1: MCF7 = 6.5, MDA-MB231 = 4809.0
# TLX1: MCF7 = 1.0, MDA-MB231 = 6.0
# SMIM22: MCF7 = 701.665, MDA-MB231 = 1.02
# ANKRD33B: MCF7 = 1.5, MDA-MB231 = 373.41
# STAT5A: MCF7 = 32.230000000000004, MDA-MB231 = 1392.2666666666669
# CDKN2A: MCF7 = 65.66499999999999, MDA-MB231 = 0.3333333333333333
# SFMBT2: MCF7 = 589.0, MDA-MB231 = 0.6666666666666666
# SNPH: MCF7 = 0.5, MDA-MB231 = 439.3
# FOXD4L5: MCF7 = 8.29, MDA-MB231 = 17.98
# ZNF423: MCF7 = 22.0, MDA-MB231 = 0.3333333333333333
# FAM133A: MCF7 = 0.5, MDA-MB231 = 1002.6666666666666
# HRNR: MCF7 = 1.5, MDA-MB231 = 565.6666666666666
# EYA1: MCF7 = 0.5, MDA-MB231 = 114.92666666666666
# RIMS4: MCF7 = 559.26, MDA-MB231 = 1.35
# MCAM: MCF7 = 21.0, MDA-MB231 = 3759.76
# HOXA4: MCF7 = 110.215, MDA-MB231 = 0.6666666666666666
# ESRP1: MCF7 = 8080.0, MDA-MB231 = 24.666666666666668
# PPP4R3C: MCF7 = 0.5, MDA-MB231 = 174.33333333333334
# FLRT3: MCF7 = 1065.0, MDA-MB231 = 1.3333333333333333
# HLX: MCF7 = 0.5, MDA-MB231 = 81.66666666666667
# FOXD3: MCF7 = 32.37, MDA-MB231 = 11.68
# TFAP2C: MCF7 = 4442.0, MDA-MB231 = 754.6666666666666
# TMEM125: MCF7 = 623.5, MDA-MB231 = 0.3333333333333333
# SLC35F3: MCF7 = 3.0, MDA-MB231 = 1216.0
# ARNT: MCF7 = 3488.0, MDA-MB231 = 1428.3333333333333
# GNA15: MCF7 = 4.5, MDA-MB231 = 1575.6899999999998
# SIX1: MCF7 = 481.5, MDA-MB231 = 1654.0
# CKMT1B: MCF7 = 704.6700000000001, MDA-MB231 = 1.096666666666667
# TFDP1: MCF7 = 4659.205, MDA-MB231 = 10864.673333333334
# FAM50B: MCF7 = 338.5, MDA-MB231 = 1.0
# ZNF768: MCF7 = 3321.375, MDA-MB231 = 1550.84
# CACNG4: MCF7 = 13121.5, MDA-MB231 = 13.996666666666664
# AGR3: MCF7 = 1294.5, MDA-MB231 = 0.6666666666666666
# PLA2G4A: MCF7 = 0.5, MDA-MB231 = 226.33333333333331
# PID1: MCF7 = 1.0, MDA-MB231 = 363.3333333333333
# PALM3: MCF7 = 224.5, MDA-MB231 = 1.3333333333333333
# LRRC10B: MCF7 = 461.5, MDA-MB231 = 0.3333333333333333
# FOXA1: MCF7 = 13178.5, MDA-MB231 = 301.3333333333333
# OVOL2: MCF7 = 145.0, MDA-MB231 = 0.3366666666666666
# PRR15L: MCF7 = 2358.5, MDA-MB231 = 5.0
# LAPTM5: MCF7 = 10.0, MDA-MB231 = 7871.333333333333
# VSX2: MCF7 = 1.0, MDA-MB231 = 0.3333333333333333
# SOX7: MCF7 = 7.27, MDA-MB231 = 15.666666666666666
# KCNF1: MCF7 = 118.0, MDA-MB231 = 0.3333333333333333
# MACC1: MCF7 = 753.5899999999999, MDA-MB231 = 4.0
# PLS3: MCF7 = 15.0, MDA-MB231 = 10141.333333333334
# ZNF487: MCF7 = 167.0, MDA-MB231 = 33.333333333333336
# MME: MCF7 = 104.0, MDA-MB231 = 0.3333333333333333
# PDZD4: MCF7 = 708.5, MDA-MB231 = 0.6666666666666666
# ZNF300: MCF7 = 15.0, MDA-MB231 = 4.0
# SLAMF7: MCF7 = 2.015, MDA-MB231 = 629.0133333333333
# ZBTB7B: MCF7 = 2907.0, MDA-MB231 = 665.0
# PRDM8: MCF7 = 2.5, MDA-MB231 = 1754.0
# ZNF730: MCF7 = 93.835, MDA-MB231 = 1.7033333333333334
# SPTSSB: MCF7 = 71375.5, MDA-MB231 = 71.0
# NOG: MCF7 = 0.5, MDA-MB231 = 245.0
# SOD3: MCF7 = 1.0, MDA-MB231 = 303.3333333333333
# SP6: MCF7 = 402.98, MDA-MB231 = 168.33333333333334
# MAFA: MCF7 = 225.5, MDA-MB231 = 13.0
# C11orf52: MCF7 = 481.5, MDA-MB231 = 1.6666666666666667
# MYH15: MCF7 = 0.5, MDA-MB231 = 97.0
# TEAD4: MCF7 = 526.96, MDA-MB231 = 2038.83
# HOXA10: MCF7 = 404.215, MDA-MB231 = 1.6666666666666667
# NOVA1: MCF7 = 510.0, MDA-MB231 = 2.0
# ARID5B: MCF7 = 1756.5, MDA-MB231 = 605.6666666666666
# CEBPZ: MCF7 = 2840.3950000000004, MDA-MB231 = 7425.546666666666
# CARD11: MCF7 = 8.5, MDA-MB231 = 3599.67
# HS6ST2: MCF7 = 216.5, MDA-MB231 = 0.3333333333333333
# EREG: MCF7 = 7.5, MDA-MB231 = 4359.666666666667
# HSH2D: MCF7 = 1529.72, MDA-MB231 = 6.863333333333333
# NR5A2: MCF7 = 111.5, MDA-MB231 = 12.666666666666666
# DMRT2: MCF7 = 30.0, MDA-MB231 = 7.666666666666667
# BICDL2: MCF7 = 1483.825, MDA-MB231 = 5.333333333333333
# PNMA8A: MCF7 = 3.0700000000000003, MDA-MB231 = 1706.0200000000002
# TEAD1: MCF7 = 4047.0, MDA-MB231 = 11924.333333333334
# MECOM: MCF7 = 585.0, MDA-MB231 = 2526.6666666666665
# KIF26A: MCF7 = 949.5, MDA-MB231 = 1.6666666666666667
# FOSL1: MCF7 = 64.0, MDA-MB231 = 14956.01
# ADCY1: MCF7 = 19748.925, MDA-MB231 = 17.46
# EVX1: MCF7 = 1.5, MDA-MB231 = 0.3333333333333333
# HDX: MCF7 = 3.0, MDA-MB231 = 134.33333333333334
# NFIA: MCF7 = 11.0, MDA-MB231 = 482.3333333333333
# TMEM92: MCF7 = 1.0, MDA-MB231 = 822.0
# MMP1: MCF7 = 5.0, MDA-MB231 = 2372.293333333333
# CYBRD1: MCF7 = 7.5, MDA-MB231 = 4408.0
# HOXC5: MCF7 = 8.4, MDA-MB231 = 36.64666666666667
# GATA1: MCF7 = 2.0, MDA-MB231 = 0.3333333333333333
# NAP1L2: MCF7 = 225.5, MDA-MB231 = 0.3333333333333333
# SPESP1: MCF7 = 138.6, MDA-MB231 = 0.3333333333333333
# GBX1: MCF7 = 2.5, MDA-MB231 = 0.3333333333333333
# KLF2: MCF7 = 96.5, MDA-MB231 = 578.0
# RORC: MCF7 = 117.24, MDA-MB231 = 14.666666666666666
# MEIS1: MCF7 = 556.385, MDA-MB231 = 72.0
# RNF217: MCF7 = 1.5, MDA-MB231 = 934.4366666666666
# OSR1: MCF7 = 5.5, MDA-MB231 = 261.0
# PATZ1: MCF7 = 3322.0, MDA-MB231 = 1518.3333333333333
# GSTM1: MCF7 = 8.475, MDA-MB231 = 2412.6
# GPR37L1: MCF7 = 1552.785, MDA-MB231 = 6.343333333333334
# E2F2: MCF7 = 1496.5, MDA-MB231 = 659.3333333333334
# PLAG1: MCF7 = 10.0, MDA-MB231 = 435.6666666666667
# ILDR1: MCF7 = 501.0, MDA-MB231 = 0.3333333333333333
# TH: MCF7 = 191.5, MDA-MB231 = 0.3333333333333333
# MDFIC: MCF7 = 1.5, MDA-MB231 = 2134.633333333333
# IGDCC3: MCF7 = 544.0, MDA-MB231 = 2.333333333333333
# STAT6: MCF7 = 440.325, MDA-MB231 = 6576.53
# KLF15: MCF7 = 10.0, MDA-MB231 = 50.0
# HES7: MCF7 = 0.5, MDA-MB231 = 85.66666666666667
# POU3F2: MCF7 = 22.5, MDA-MB231 = 92.0
# RPS6KA6: MCF7 = 391.565, MDA-MB231 = 1.0
# MESP1: MCF7 = 199.0, MDA-MB231 = 80.66666666666667
#
# Differentially expressed genes (fold change > 2.0):
# COL4A5: MCF7 = 2259.0, MDA-MB231 = 3.0, Fold Change = 753.00
# ZFHX3: MCF7 = 5792.54, MDA-MB231 = 1849.466666666667, Fold Change = 3.13
# IRX5: MCF7 = 602.6800000000001, MDA-MB231 = 86.98333333333333, Fold Change = 6.93
# ZKSCAN7: MCF7 = 6.390000000000001, MDA-MB231 = 1.0, Fold Change = 6.39
# RARA: MCF7 = 2399.685, MDA-MB231 = 1116.49, Fold Change = 2.15
# PLCXD3: MCF7 = 252.0, MDA-MB231 = 0.3333333333333333, Fold Change = 756.00
# PCP4: MCF7 = 712.5, MDA-MB231 = 2.333333333333333, Fold Change = 305.36
# FOXA3: MCF7 = 6.0, MDA-MB231 = 2.6666666666666665, Fold Change = 2.25
# OTP: MCF7 = 7.0, MDA-MB231 = 1.0, Fold Change = 7.00
# THNSL2: MCF7 = 735.5, MDA-MB231 = 1.3333333333333333, Fold Change = 551.62
# GPC4: MCF7 = 912.0, MDA-MB231 = 1.0, Fold Change = 912.00
# CDH1: MCF7 = 42451.98, MDA-MB231 = 35.333333333333336, Fold Change = 1201.47
# OLFM1: MCF7 = 3131.5, MDA-MB231 = 5.333333333333333, Fold Change = 587.16
# CCDC63: MCF7 = 154.5, MDA-MB231 = 0.3333333333333333, Fold Change = 463.50
# ZNF552: MCF7 = 417.86, MDA-MB231 = 201.5233333333333, Fold Change = 2.07
# NTN1: MCF7 = 1039.0, MDA-MB231 = 5.666666666666667, Fold Change = 183.35
# SLC2A10: MCF7 = 2506.5, MDA-MB231 = 13.333333333333334, Fold Change = 187.99
# KCNJ3: MCF7 = 2125.5, MDA-MB231 = 2.6666666666666665, Fold Change = 797.06
# FGFR2: MCF7 = 472.5, MDA-MB231 = 1.6666666666666667, Fold Change = 283.50
# PBX1: MCF7 = 5848.0, MDA-MB231 = 97.66666666666669, Fold Change = 59.88
# HES4: MCF7 = 1161.5, MDA-MB231 = 214.0, Fold Change = 5.43
# S100A14: MCF7 = 11503.0, MDA-MB231 = 17.666666666666668, Fold Change = 651.11
# ZIC1: MCF7 = 953.5, MDA-MB231 = 3.333333333333333, Fold Change = 286.05
# TBX4: MCF7 = 35.5, MDA-MB231 = 1.6666666666666667, Fold Change = 21.30
# C1orf210: MCF7 = 456.3, MDA-MB231 = 1.3333333333333333, Fold Change = 342.23
# SIX5: MCF7 = 706.05, MDA-MB231 = 245.53666666666663, Fold Change = 2.88
# PREX1: MCF7 = 9755.5, MDA-MB231 = 37.0, Fold Change = 263.66
# GSC: MCF7 = 270.5, MDA-MB231 = 0.3333333333333333, Fold Change = 811.50
# SPINT1: MCF7 = 3621.37, MDA-MB231 = 9.0, Fold Change = 402.37
# GAL: MCF7 = 700.5, MDA-MB231 = 0.3333333333333333, Fold Change = 2101.50
# ...
# ETV2: MCF7 = 29.0, MDA-MB231 = 12.666666666666666, Fold Change = 2.29
# HOXA9: MCF7 = 5.0, MDA-MB231 = 0.3333333333333333, Fold Change = 15.00
# MSX2: MCF7 = 1593.99, MDA-MB231 = 79.33333333333333, Fold Change = 20.09
# ATOH7: MCF7 = 8.0, MDA-MB231 = 1.6666666666666667, Fold Change = 4.80
# HIVEP3: MCF7 = 928.0, MDA-MB231 = 418.0, Fold Change = 2.22
# KIF1A: MCF7 = 763.005, MDA-MB231 = 3.333333333333333, Fold Change = 228.90
# ENTPD8: MCF7 = 567.5, MDA-MB231 = 2.6666666666666665, Fold Change = 212.81
# GOLT1A: MCF7 = 249.5, MDA-MB231 = 1.0, Fold Change = 249.50
# IGFBP5: MCF7 = 1178.5, MDA-MB231 = 2.0, Fold Change = 589.25
# NR4A3: MCF7 = 226.5, MDA-MB231 = 24.33333333333333, Fold Change = 9.31
# DLX1: MCF7 = 271.0, MDA-MB231 = 74.33333333333333, Fold Change = 3.65
# SLC27A6: MCF7 = 534.0, MDA-MB231 = 0.3333333333333333, Fold Change = 1602.00
# TBX2: MCF7 = 10104.5, MDA-MB231 = 16.333333333333332, Fold Change = 618.64
# LHX2: MCF7 = 305.435, MDA-MB231 = 0.3333333333333333, Fold Change = 916.31
# NR2F2: MCF7 = 18510.0, MDA-MB231 = 6808.333333333333, Fold Change = 2.72
# ZNF276: MCF7 = 2172.64, MDA-MB231 = 1078.3466666666666, Fold Change = 2.01
# PKP1: MCF7 = 1287.0, MDA-MB231 = 4.333333333333333, Fold Change = 297.00
# PRDM6: MCF7 = 349.9, MDA-MB231 = 37.2, Fold Change = 9.41
# HES6: MCF7 = 1414.0, MDA-MB231 = 256.0, Fold Change = 5.52
# ENPP5: MCF7 = 344.515, MDA-MB231 = 0.6666666666666666, Fold Change = 516.77
# DOK7: MCF7 = 1191.5, MDA-MB231 = 3.6666666666666665, Fold Change = 324.95
# HOXB2: MCF7 = 27.78, MDA-MB231 = 11.923333333333332, Fold Change = 2.33
# SULT2B1: MCF7 = 1699.0, MDA-MB231 = 8.0, Fold Change = 212.38
# AK7: MCF7 = 1026.99, MDA-MB231 = 5.666666666666667, Fold Change = 181.23
# HENMT1: MCF7 = 2042.62, MDA-MB231 = 1.0366666666666666, Fold Change = 1970.37
# PRSS8: MCF7 = 3366.135, MDA-MB231 = 3.56, Fold Change = 945.54
# BATF: MCF7 = 386.0, MDA-MB231 = 45.333333333333336, Fold Change = 8.51
# ELOVL4: MCF7 = 174.5, MDA-MB231 = 0.3333333333333333, Fold Change = 523.50
# MLXIPL: MCF7 = 306.0, MDA-MB231 = 19.666666666666668, Fold Change = 15.56
# ZNF41: MCF7 = 742.5, MDA-MB231 = 329.6666666666667, Fold Change = 2.25
# BSPRY: MCF7 = 1852.0, MDA-MB231 = 2.333333333333333, Fold Change = 793.71
# GATA3: MCF7 = 48436.5, MDA-MB231 = 310.6666666666667, Fold Change = 155.91
# ESRRG: MCF7 = 38.5, MDA-MB231 = 2.6666666666666665, Fold Change = 14.44
# RBP7: MCF7 = 71.5, MDA-MB231 = 0.3333333333333333, Fold Change = 214.50
# PCDH8: MCF7 = 72.0, MDA-MB231 = 0.3333333333333333, Fold Change = 216.00
# RXRA: MCF7 = 13546.5, MDA-MB231 = 2533.6666666666665, Fold Change = 5.35
# CEACAM6: MCF7 = 687.895, MDA-MB231 = 1.0266666666666666, Fold Change = 670.03
# SULF1: MCF7 = 2108.0, MDA-MB231 = 4.666666666666667, Fold Change = 451.71
# SHISA9: MCF7 = 824.5, MDA-MB231 = 4.0, Fold Change = 206.12
# LYPD6B: MCF7 = 689.0, MDA-MB231 = 1.0, Fold Change = 689.00
# RREB1: MCF7 = 2786.5, MDA-MB231 = 1376.0, Fold Change = 2.03
# EMID1: MCF7 = 314.5, MDA-MB231 = 1.6666666666666667, Fold Change = 188.70
# MMEL1: MCF7 = 150.94, MDA-MB231 = 0.3333333333333333, Fold Change = 452.82
# KIAA0040: MCF7 = 373.5, MDA-MB231 = 2.0, Fold Change = 186.75
# TBX6: MCF7 = 175.5, MDA-MB231 = 16.666666666666668, Fold Change = 10.53
# MSI1: MCF7 = 523.5, MDA-MB231 = 1.0, Fold Change = 523.50
# ALOX15: MCF7 = 740.8399999999999, MDA-MB231 = 1.6666666666666667, Fold Change = 444.50
# HOXC6: MCF7 = 241.535, MDA-MB231 = 120.44333333333331, Fold Change = 2.01
# CACNA1D: MCF7 = 262.265, MDA-MB231 = 1.0, Fold Change = 262.26
# TMEM30B: MCF7 = 4239.81, MDA-MB231 = 4.203333333333333, Fold Change = 1008.68
# OVOL1: MCF7 = 772.29, MDA-MB231 = 2.356666666666667, Fold Change = 327.70
# FOXI1: MCF7 = 35.505, MDA-MB231 = 0.3333333333333333, Fold Change = 106.52
# SOX18: MCF7 = 113.5, MDA-MB231 = 33.666666666666664, Fold Change = 3.37
# ONECUT2: MCF7 = 463.0, MDA-MB231 = 226.33333333333331, Fold Change = 2.05
# ARID3A: MCF7 = 1360.36, MDA-MB231 = 165.06666666666666, Fold Change = 8.24
# ELF5: MCF7 = 137.5, MDA-MB231 = 0.6666666666666666, Fold Change = 206.25
# TFAP2A: MCF7 = 1525.665, MDA-MB231 = 138.96333333333334, Fold Change = 10.98
# SMTNL2: MCF7 = 132.0, MDA-MB231 = 0.3333333333333333, Fold Change = 396.00
# SYT10: MCF7 = 561.5, MDA-MB231 = 1.0, Fold Change = 561.50
# FAM83B: MCF7 = 2939.5, MDA-MB231 = 2.6666666666666665, Fold Change = 1102.31
# RAMP3: MCF7 = 2250.5, MDA-MB231 = 3.333333333333333, Fold Change = 675.15
# RNF223: MCF7 = 1204.0, MDA-MB231 = 1.6666666666666667, Fold Change = 722.40
# HEY2: MCF7 = 332.0, MDA-MB231 = 26.33333333333333, Fold Change = 12.61
# MYH14: MCF7 = 7061.855, MDA-MB231 = 6.666666666666667, Fold Change = 1059.28
# SHC2: MCF7 = 66.0, MDA-MB231 = 0.3333333333333333, Fold Change = 198.00
# ARNT2: MCF7 = 2226.21, MDA-MB231 = 569.7966666666666, Fold Change = 3.91
# ESR1: MCF7 = 13965.5, MDA-MB231 = 34.333333333333336, Fold Change = 406.76
# MAFB: MCF7 = 474.0, MDA-MB231 = 34.333333333333336, Fold Change = 13.81
# CAPN13: MCF7 = 943.5, MDA-MB231 = 2.0, Fold Change = 471.75
# KDF1: MCF7 = 609.0, MDA-MB231 = 1.3333333333333333, Fold Change = 456.75
# DRD1: MCF7 = 287.5, MDA-MB231 = 0.3333333333333333, Fold Change = 862.50
# PCDHA11: MCF7 = 773.73, MDA-MB231 = 1.1, Fold Change = 703.39
# COL4A6: MCF7 = 94.0, MDA-MB231 = 0.3333333333333333, Fold Change = 282.00
# RIPPLY3: MCF7 = 443.32, MDA-MB231 = 1.6666666666666667, Fold Change = 265.99
# BRINP2: MCF7 = 1036.5, MDA-MB231 = 2.0, Fold Change = 518.25
# ACOT4: MCF7 = 512.5, MDA-MB231 = 2.6666666666666665, Fold Change = 192.19
# CAPN9: MCF7 = 645.085, MDA-MB231 = 2.333333333333333, Fold Change = 276.47
# GCM2: MCF7 = 2.0, MDA-MB231 = 0.6666666666666666, Fold Change = 3.00
# FOXR1: MCF7 = 3.0, MDA-MB231 = 1.0, Fold Change = 3.00
# XBP1: MCF7 = 33344.7, MDA-MB231 = 3090.353333333333, Fold Change = 10.79
# BARX1: MCF7 = 2.0, MDA-MB231 = 0.3333333333333333, Fold Change = 6.00
# ARHGAP8: MCF7 = 960.935, MDA-MB231 = 1.0, Fold Change = 960.93
# ERBB4: MCF7 = 1829.5, MDA-MB231 = 6.0, Fold Change = 304.92
# EMC10: MCF7 = 5768.675, MDA-MB231 = 8.01, Fold Change = 720.18
# MNX1: MCF7 = 524.5, MDA-MB231 = 136.66666666666666, Fold Change = 3.84
# NECAB1: MCF7 = 3946.675, MDA-MB231 = 5.563333333333333, Fold Change = 709.41
# C14orf132: MCF7 = 1137.565, MDA-MB231 = 2.0, Fold Change = 568.78
# HBP1: MCF7 = 2285.495, MDA-MB231 = 887.4200000000001, Fold Change = 2.58
# ZNF18: MCF7 = 311.915, MDA-MB231 = 95.65333333333332, Fold Change = 3.26
# FOXJ1: MCF7 = 7.0, MDA-MB231 = 1.0, Fold Change = 7.00
# NBPF4: MCF7 = 238.63, MDA-MB231 = 0.4666666666666666, Fold Change = 511.35
# FOXD1: MCF7 = 174.34, MDA-MB231 = 1.7133333333333336, Fold Change = 101.75
# ESRRB: MCF7 = 6.5, MDA-MB231 = 1.0, Fold Change = 6.50
# ARX: MCF7 = 44.0, MDA-MB231 = 0.3333333333333333, Fold Change = 132.00
# DMRTA1: MCF7 = 143.5, MDA-MB231 = 0.3333333333333333, Fold Change = 430.50
# ADAMTS19: MCF7 = 4024.375, MDA-MB231 = 7.399999999999999, Fold Change = 543.83
# OOEP: MCF7 = 56.235, MDA-MB231 = 0.3333333333333333, Fold Change = 168.71
# KLF8: MCF7 = 102.5, MDA-MB231 = 21.666666666666668, Fold Change = 4.73
# BPIFB1: MCF7 = 124.005, MDA-MB231 = 0.6666666666666666, Fold Change = 186.01
# CLSTN2: MCF7 = 1451.5, MDA-MB231 = 1.0033333333333332, Fold Change = 1446.68
# THRB: MCF7 = 980.5, MDA-MB231 = 107.33333333333331, Fold Change = 9.14
# PDZRN3: MCF7 = 290.81, MDA-MB231 = 1.0, Fold Change = 290.81
# JUND: MCF7 = 5398.0, MDA-MB231 = 909.6666666666666, Fold Change = 5.93
# PGR: MCF7 = 2616.0, MDA-MB231 = 2.6666666666666665, Fold Change = 981.00
# EGR4: MCF7 = 1.0, MDA-MB231 = 0.3333333333333333, Fold Change = 3.00
# ONECUT1: MCF7 = 40.0, MDA-MB231 = 11.333333333333334, Fold Change = 3.53
# ZNF467: MCF7 = 1355.0, MDA-MB231 = 87.33333333333333, Fold Change = 15.52
# CCDC120: MCF7 = 1054.0, MDA-MB231 = 4.0, Fold Change = 263.50
# SIM1: MCF7 = 202.5, MDA-MB231 = 1.3333333333333333, Fold Change = 151.88
# PPL: MCF7 = 4755.0, MDA-MB231 = 16.0, Fold Change = 297.19
# HS3ST3A1: MCF7 = 736.24, MDA-MB231 = 0.3966666666666666, Fold Change = 1856.07
# CTNND2: MCF7 = 1769.0, MDA-MB231 = 4.0, Fold Change = 442.25
# IGFBP2: MCF7 = 3947.5, MDA-MB231 = 6.0, Fold Change = 657.92
# LHX6: MCF7 = 104.0, MDA-MB231 = 27.33333333333333, Fold Change = 3.80
# EGR3: MCF7 = 339.08500000000004, MDA-MB231 = 12.0, Fold Change = 28.26
# ABCA12: MCF7 = 1181.5, MDA-MB231 = 3.333333333333333, Fold Change = 354.45
# MYCL: MCF7 = 224.0, MDA-MB231 = 23.32333333333333, Fold Change = 9.60
# RARG: MCF7 = 3692.29, MDA-MB231 = 858.6666666666666, Fold Change = 4.30
# TMEM26: MCF7 = 485.095, MDA-MB231 = 0.3333333333333333, Fold Change = 1455.29
# NETO2: MCF7 = 1110.0, MDA-MB231 = 5.333333333333333, Fold Change = 208.12
# BMP5: MCF7 = 1808.0, MDA-MB231 = 8.666666666666666, Fold Change = 208.62
# EPPK1: MCF7 = 8488.57, MDA-MB231 = 24.10333333333333, Fold Change = 352.17
# TP73: MCF7 = 923.12, MDA-MB231 = 110.88, Fold Change = 8.33
# DLX3: MCF7 = 341.5, MDA-MB231 = 17.333333333333332, Fold Change = 19.70
# HPDL: MCF7 = 550.0, MDA-MB231 = 2.0, Fold Change = 275.00
# ZNF711: MCF7 = 107.39, MDA-MB231 = 0.3333333333333333, Fold Change = 322.17
# NPNT: MCF7 = 3554.035, MDA-MB231 = 5.6433333333333335, Fold Change = 629.78
# LHX4: MCF7 = 589.485, MDA-MB231 = 284.0133333333333, Fold Change = 2.08
# ARHGDIG: MCF7 = 191.28, MDA-MB231 = 1.0, Fold Change = 191.28
# EVPLL: MCF7 = 73.23, MDA-MB231 = 0.35, Fold Change = 209.23
# ZFP1: MCF7 = 1242.5, MDA-MB231 = 518.3333333333334, Fold Change = 2.40
# DSCAM: MCF7 = 5994.0, MDA-MB231 = 17.0, Fold Change = 352.59
# ERG: MCF7 = 17.0, MDA-MB231 = 0.3333333333333333, Fold Change = 51.00
# PCDHGB5: MCF7 = 1590.13, MDA-MB231 = 5.079999999999999, Fold Change = 313.02
# BCAS1: MCF7 = 1788.56, MDA-MB231 = 5.333333333333333, Fold Change = 335.36
# REG4: MCF7 = 235.5, MDA-MB231 = 0.6666666666666666, Fold Change = 353.25
# SORCS1: MCF7 = 282.0, MDA-MB231 = 1.0, Fold Change = 282.00
# KCTD15: MCF7 = 1739.5, MDA-MB231 = 2.6666666666666665, Fold Change = 652.31
# EBF2: MCF7 = 6.0, MDA-MB231 = 1.3333333333333333, Fold Change = 4.50
# SULF2: MCF7 = 64968.94500000001, MDA-MB231 = 51.86333333333334, Fold Change = 1252.70
# TEF: MCF7 = 1196.0, MDA-MB231 = 240.33333333333331, Fold Change = 4.98
# NR2E3: MCF7 = 33.5, MDA-MB231 = 6.333333333333333, Fold Change = 5.29
# HOXB7: MCF7 = 282.94, MDA-MB231 = 50.0, Fold Change = 5.66
# RET: MCF7 = 5778.0, MDA-MB231 = 3.0, Fold Change = 1926.00
# CPEB1: MCF7 = 9.5, MDA-MB231 = 2.04, Fold Change = 4.66
# RNF43: MCF7 = 3252.685, MDA-MB231 = 3.6666666666666665, Fold Change = 887.10
# GPR27: MCF7 = 505.0, MDA-MB231 = 0.3333333333333333, Fold Change = 1515.00
# MAF: MCF7 = 41.5, MDA-MB231 = 2.0, Fold Change = 20.75
# TP63: MCF7 = 24.0, MDA-MB231 = 8.0, Fold Change = 3.00
# PBX3: MCF7 = 1949.0, MDA-MB231 = 840.6666666666666, Fold Change = 2.32
# PROM2: MCF7 = 1955.415, MDA-MB231 = 7.0, Fold Change = 279.34
# NFATC1: MCF7 = 415.5, MDA-MB231 = 179.33333333333334, Fold Change = 2.32
# ALX3: MCF7 = 2.55, MDA-MB231 = 0.5833333333333334, Fold Change = 4.37
# PKNOX2: MCF7 = 5.5, MDA-MB231 = 1.0, Fold Change = 5.50
# PCDHAC2: MCF7 = 302.025, MDA-MB231 = 0.6666666666666666, Fold Change = 453.04
# FXYD3: MCF7 = 9192.0, MDA-MB231 = 6.666666666666667, Fold Change = 1378.80
# YBX2: MCF7 = 1905.44, MDA-MB231 = 3.0, Fold Change = 635.15
# SLC24A3: MCF7 = 2631.2, MDA-MB231 = 4.333333333333333, Fold Change = 607.20
# RUBCNL: MCF7 = 110.0, MDA-MB231 = 0.6666666666666666, Fold Change = 165.00
# BARX2: MCF7 = 407.0, MDA-MB231 = 3.333333333333333, Fold Change = 122.10
# ZNF248: MCF7 = 765.815, MDA-MB231 = 373.42, Fold Change = 2.05
# TDRD5: MCF7 = 281.5, MDA-MB231 = 0.6666666666666666, Fold Change = 422.25
# RASAL1: MCF7 = 1079.545, MDA-MB231 = 1.0, Fold Change = 1079.55
# ADGRG5: MCF7 = 162.0, MDA-MB231 = 0.3333333333333333, Fold Change = 486.00
# ZBTB42: MCF7 = 1644.0, MDA-MB231 = 148.33333333333334, Fold Change = 11.08
# ERBB3: MCF7 = 11822.0, MDA-MB231 = 67.33333333333333, Fold Change = 175.57
# RBBP8NL: MCF7 = 737.0, MDA-MB231 = 0.3333333333333333, Fold Change = 2211.00
# SMIM22: MCF7 = 701.665, MDA-MB231 = 1.02, Fold Change = 687.91
# CDKN2A: MCF7 = 65.66499999999999, MDA-MB231 = 0.3333333333333333, Fold Change = 196.99
# SFMBT2: MCF7 = 589.0, MDA-MB231 = 0.6666666666666666, Fold Change = 883.50
# ZNF423: MCF7 = 22.0, MDA-MB231 = 0.3333333333333333, Fold Change = 66.00
# RIMS4: MCF7 = 559.26, MDA-MB231 = 1.35, Fold Change = 414.27
# HOXA4: MCF7 = 110.215, MDA-MB231 = 0.6666666666666666, Fold Change = 165.32
# ESRP1: MCF7 = 8080.0, MDA-MB231 = 24.666666666666668, Fold Change = 327.57
# FLRT3: MCF7 = 1065.0, MDA-MB231 = 1.3333333333333333, Fold Change = 798.75
# FOXD3: MCF7 = 32.37, MDA-MB231 = 11.68, Fold Change = 2.77
# TFAP2C: MCF7 = 4442.0, MDA-MB231 = 754.6666666666666, Fold Change = 5.89
# TMEM125: MCF7 = 623.5, MDA-MB231 = 0.3333333333333333, Fold Change = 1870.50
# ARNT: MCF7 = 3488.0, MDA-MB231 = 1428.3333333333333, Fold Change = 2.44
# CKMT1B: MCF7 = 704.6700000000001, MDA-MB231 = 1.096666666666667, Fold Change = 642.56
# FAM50B: MCF7 = 338.5, MDA-MB231 = 1.0, Fold Change = 338.50
# ZNF768: MCF7 = 3321.375, MDA-MB231 = 1550.84, Fold Change = 2.14
# CACNG4: MCF7 = 13121.5, MDA-MB231 = 13.996666666666664, Fold Change = 937.47
# AGR3: MCF7 = 1294.5, MDA-MB231 = 0.6666666666666666, Fold Change = 1941.75
# PALM3: MCF7 = 224.5, MDA-MB231 = 1.3333333333333333, Fold Change = 168.38
# LRRC10B: MCF7 = 461.5, MDA-MB231 = 0.3333333333333333, Fold Change = 1384.50
# FOXA1: MCF7 = 13178.5, MDA-MB231 = 301.3333333333333, Fold Change = 43.73
# OVOL2: MCF7 = 145.0, MDA-MB231 = 0.3366666666666666, Fold Change = 430.69
# PRR15L: MCF7 = 2358.5, MDA-MB231 = 5.0, Fold Change = 471.70
# VSX2: MCF7 = 1.0, MDA-MB231 = 0.3333333333333333, Fold Change = 3.00
# KCNF1: MCF7 = 118.0, MDA-MB231 = 0.3333333333333333, Fold Change = 354.00
# MACC1: MCF7 = 753.5899999999999, MDA-MB231 = 4.0, Fold Change = 188.40
# ZNF487: MCF7 = 167.0, MDA-MB231 = 33.333333333333336, Fold Change = 5.01
# MME: MCF7 = 104.0, MDA-MB231 = 0.3333333333333333, Fold Change = 312.00
# PDZD4: MCF7 = 708.5, MDA-MB231 = 0.6666666666666666, Fold Change = 1062.75
# ZNF300: MCF7 = 15.0, MDA-MB231 = 4.0, Fold Change = 3.75
# ZBTB7B: MCF7 = 2907.0, MDA-MB231 = 665.0, Fold Change = 4.37
# ZNF730: MCF7 = 93.835, MDA-MB231 = 1.7033333333333334, Fold Change = 55.09
# SPTSSB: MCF7 = 71375.5, MDA-MB231 = 71.0, Fold Change = 1005.29
# SP6: MCF7 = 402.98, MDA-MB231 = 168.33333333333334, Fold Change = 2.39
# MAFA: MCF7 = 225.5, MDA-MB231 = 13.0, Fold Change = 17.35
# C11orf52: MCF7 = 481.5, MDA-MB231 = 1.6666666666666667, Fold Change = 288.90
# HOXA10: MCF7 = 404.215, MDA-MB231 = 1.6666666666666667, Fold Change = 242.53
# NOVA1: MCF7 = 510.0, MDA-MB231 = 2.0, Fold Change = 255.00
# ARID5B: MCF7 = 1756.5, MDA-MB231 = 605.6666666666666, Fold Change = 2.90
# HS6ST2: MCF7 = 216.5, MDA-MB231 = 0.3333333333333333, Fold Change = 649.50
# HSH2D: MCF7 = 1529.72, MDA-MB231 = 6.863333333333333, Fold Change = 222.88
# NR5A2: MCF7 = 111.5, MDA-MB231 = 12.666666666666666, Fold Change = 8.80
# DMRT2: MCF7 = 30.0, MDA-MB231 = 7.666666666666667, Fold Change = 3.91
# BICDL2: MCF7 = 1483.825, MDA-MB231 = 5.333333333333333, Fold Change = 278.22
# KIF26A: MCF7 = 949.5, MDA-MB231 = 1.6666666666666667, Fold Change = 569.70
# ADCY1: MCF7 = 19748.925, MDA-MB231 = 17.46, Fold Change = 1131.10
# EVX1: MCF7 = 1.5, MDA-MB231 = 0.3333333333333333, Fold Change = 4.50
# GATA1: MCF7 = 2.0, MDA-MB231 = 0.3333333333333333, Fold Change = 6.00
# NAP1L2: MCF7 = 225.5, MDA-MB231 = 0.3333333333333333, Fold Change = 676.50
# SPESP1: MCF7 = 138.6, MDA-MB231 = 0.3333333333333333, Fold Change = 415.80
# GBX1: MCF7 = 2.5, MDA-MB231 = 0.3333333333333333, Fold Change = 7.50
# RORC: MCF7 = 117.24, MDA-MB231 = 14.666666666666666, Fold Change = 7.99
# MEIS1: MCF7 = 556.385, MDA-MB231 = 72.0, Fold Change = 7.73
# PATZ1: MCF7 = 3322.0, MDA-MB231 = 1518.3333333333333, Fold Change = 2.19
# GPR37L1: MCF7 = 1552.785, MDA-MB231 = 6.343333333333334, Fold Change = 244.79
# E2F2: MCF7 = 1496.5, MDA-MB231 = 659.3333333333334, Fold Change = 2.27
# ILDR1: MCF7 = 501.0, MDA-MB231 = 0.3333333333333333, Fold Change = 1503.00
# TH: MCF7 = 191.5, MDA-MB231 = 0.3333333333333333, Fold Change = 574.50
# IGDCC3: MCF7 = 544.0, MDA-MB231 = 2.333333333333333, Fold Change = 233.14
# RPS6KA6: MCF7 = 391.565, MDA-MB231 = 1.0, Fold Change = 391.56
# MESP1: MCF7 = 199.0, MDA-MB231 = 80.66666666666667, Fold Change = 2.47

# %% [markdown]
# # **5. Analyze Signal Variation**

# %%
# ... previous code ...

# After setting node attributes with expression values
# Extract node expression values for G_mcf7
signal_mcf7_ppi = np.array([data['expression'] for node, data in G_mcf7_ppi.nodes(data=True)])

# Extract node expression values for G_mda
signal_mda_ppi = np.array([data['expression'] for node, data in G_mda_ppi.nodes(data=True)])

# Signal variation for MCF7
signal_variation_mcf7_ppi = signal_mcf7_ppi.T @ laplacian_mcf7_ppi @ signal_mcf7_ppi # Changed laplacian to laplacian_mcf7
print(f"\nSignal Variation (MCF7): {signal_variation_mcf7_ppi:.2e}")

# Signal variation for MDA
signal_variation_mda_ppi = signal_mda_ppi.T @ laplacian_mda_ppi @ signal_mda_ppi # Changed laplacian to laplacian_mda
print(f"\nSignal Variation (MDA): {signal_variation_mda_ppi:.2e}")
# Out:
# Signal Variation (MCF7): 8.06e+12
#
# Signal Variation (MDA): 1.93e+13

# %% [markdown]
# # 6.**Optional: Visualize Signal Distribution**

# %%
import matplotlib.pyplot as plt

# Plot RNA-seq signals for positive graph
plt.figure(figsize=(10, 6))
plt.hist(signal_mcf7_ppi, bins=30, alpha=0.7, label="MCF7 graph", color='blue')
plt.hist(signal_mda_ppi, bins=30, alpha=0.7, label="MDA graph", color='orange')
plt.xlabel("RNA-seq Expression Level")
plt.ylabel("Frequency")
plt.title("Distribution of RNA-seq Expression Levels")
plt.legend()
plt.show()

# %% [markdown]
# # Spectral Clustering
# We’ll now perform spectral clustering using the eigenvalues and eigenvectors of the Laplacian matrices for the positive and negative graphs. This helps group nodes (genes) into clusters based on their connectivity patterns and RNA-seq signal variations.
#
# Steps for Spectral Clustering:
#
# A) Compute Eigenvalues and Eigenvectors
#
# Use PyGSP to extract the Fourier basis (eigenvectors of the Laplacian) and corresponding eigenvalues.
#
# B) Cluster Nodes
#
# Use the eigenvectors corresponding to the smallest non-zero eigenvalues for clustering (spectral embedding).
#
# C) Visualize Clustering
#
# Optionally visualize clusters for insights.

# %% [markdown]
# # 1. Let's have a combined graph, i.e., we will not split the graph and see whether it works`

# %%
import networkx as nx

# Create a single graph to hold all edges
G_combined_MCF7_ppi = nx.DiGraph()

# Add edges to the combined graph with attributes for weight and sign
for u, v, data in G_mcf7_ppi.edges(data=True):
    weight = data.get("weight", 0)
    if weight > 0:
        G_combined_MCF7_ppi.add_edge(u, v, weight=weight, sign="positive")
    elif weight < 0:
        G_combined_MCF7_ppi.add_edge(u, v, weight=abs(weight), sign="negative")  # Use absolute value for negative weights
    else:  # Handle zero-weight edges
        G_combined_MCF7_ppi.add_edge(u, v, weight=weight, sign="neutral")

print(f"Combined Graph: {G_combined_MCF7_ppi.number_of_edges()} edges")
# Out:
# Combined Graph: 418819 edges

# %%
import networkx as nx

# Create a single graph to hold all edges
G_combined_MDA_ppi = nx.DiGraph()

# Add edges to the combined graph with attributes for weight and sign
for u, v, data in G_mda_ppi.edges(data=True):
    weight = data.get("weight", 0)
    if weight > 0:
        G_combined_MDA_ppi.add_edge(u, v, weight=weight, sign="positive")
    elif weight < 0:
        G_combined_MDA_ppi.add_edge(u, v, weight=abs(weight), sign="negative")  # Use absolute value for negative weights
    else:  # Handle zero-weight edges
        G_combined_MDA_ppi.add_edge(u, v, weight=weight, sign="neutral")

print(f"Combined MDA Graph: {G_combined_MDA_ppi.number_of_edges()} edges")
# Out:
# Combined MDA Graph: 463461 edges

# %% [markdown]
# #2. Handle Disconnected Components
# The graphs may contain disconnected components. Ensure that you handle these components separately during Fourier basis computation and clustering.

# %%
import networkx as nx
import pygsp as pg
from sklearn.cluster import KMeans
import numpy as np

def process_combined_graph(graph_nx, cell_line_name):
    print(f"Processing {cell_line_name} combined graph.")

    # Identify connected components
    if graph_nx.is_directed():
        connected_components = list(nx.weakly_connected_components(graph_nx))
    else:
        connected_components = list(nx.connected_components(graph_nx))

    all_clusters = []
    for i, component in enumerate(connected_components):
        print(f"Processing component {i+1} with {len(component)} nodes...")

        # Create a subgraph for the component
        subgraph_nx = graph_nx.subgraph(component)
        adjacency_matrix = nx.to_scipy_sparse_array(subgraph_nx, weight="weight")
        subgraph_pygsp = pg.graphs.Graph(adjacency_matrix)

        try:
            # Compute Laplacian and Fourier basis for the subgraph
            subgraph_pygsp.compute_laplacian(lap_type="combinatorial")
            subgraph_pygsp.compute_fourier_basis(recompute=True)

            # Clamp smallest eigenvalue to 0 if it's very close
            if abs(subgraph_pygsp.e[0]) < 1e-10:
                subgraph_pygsp.e[0] = 0

            # Perform clustering on the subgraph
            num_clusters = 3  # Number of clusters
            clusters_subgraph = KMeans(n_clusters=num_clusters).fit_predict(
                subgraph_pygsp.U[:, 1:num_clusters+1]
            )

            # Map cluster labels back to original node indices
            cluster_dict = dict(zip(subgraph_nx.nodes, clusters_subgraph))
            all_clusters.append(cluster_dict)

            print(f"Fourier basis and clustering computed for component {i+1}.")
        except Exception as e:
            print(f"Failed to compute Fourier basis for component {i+1}: {e}")

    # Combine cluster assignments for all components
    combined_clusters = {}
    for cluster_dict in all_clusters:
        combined_clusters.update(cluster_dict)

    return combined_clusters

# Process combined MCF7 graph
clusters_combined_mcf7_ppi = process_combined_graph(G_combined_MCF7_ppi, "MCF7 Combined")

# Process combined MDA graph
clusters_combined_mda_ppi = process_combined_graph(G_combined_MDA_ppi, "MDA Combined")

# Assign cluster labels to nodes in the combined NetworkX graphs
nx.set_node_attributes(G_combined_MCF7_ppi, clusters_combined_mcf7_ppi, "cluster")
nx.set_node_attributes(G_combined_MDA_ppi, clusters_combined_mda_ppi, "cluster")

print("Cluster assignments completed.")
# Out:
# Processing MCF7 Combined combined graph.
# Processing component 1 with 1309 nodes...
# Fourier basis and clustering computed for component 1.
# Processing MDA Combined combined graph.
# Processing component 1 with 1354 nodes...
# Fourier basis and clustering computed for component 1.
# Cluster assignments completed.

# %% [markdown]
# # If you want to visualized these graphs, it takes quite long to plot

# %%
import matplotlib.pyplot as plt

# Define node positions (e.g., using a layout algorithm)
#pos = nx.spring_layout(G_combined_MCF7_ppi)

# Separate edges by sign
#positive_edges = [(u, v) for u, v, data in G_combined_MCF7_ppi.edges(data=True) if data["sign"] == "positive"]
#negative_edges = [(u, v) for u, v, data in G_combined_MCF7_ppi.edges(data=True) if data["sign"] == "negative"]
#neutral_edges = [(u, v) for u, v, data in G_combined_MCF7_ppi.edges(data=True) if data["sign"] == "neutral"]

# Draw nodes
#nx.draw_networkx_nodes(G_combined_MCF7_ppi, pos, node_size=300, node_color="lightblue")

# Draw edges with different colors
#nx.draw_networkx_edges(G_combined_MCF7_ppi, pos, edgelist=positive_edges, edge_color="green", width=2, label="Positive")
#nx.draw_networkx_edges(G_combined_MCF7_ppi, pos, edgelist=negative_edges, edge_color="red", width=2, label="Negative")
#nx.draw_networkx_edges(G_combined_MCF7_ppi, pos, edgelist=neutral_edges, edge_color="gray", width=2, label="Neutral")

# Draw labels
#nx.draw_networkx_labels(G_combined_MCF7_ppi, pos, font_size=10, font_color="black")

# Add legend
#plt.legend(["Positive Edges", "Negative Edges", "Neutral Edges"])

# Show the plot
#plt.title("Combined Graph with Positive, Negative, and Neutral Edges")
#plt.axis("off")
#plt.show()

# %%
import networkx as nx
import pygsp as pg
from networkx import to_scipy_sparse_array

# Function to process a single graph
def process_graph(nx_graph, graph_name):
    print(f"Processing {graph_name} graph...")

    # Remove self-loops
    nx_graph.remove_edges_from(nx.selfloop_edges(nx_graph))

    # Check connectivity
    #if nx.is_connected(nx_graph):  # For undirected graphs
     #   print(f"{graph_name} graph is connected.")
    #else:
      #  print(f"{graph_name} graph is disconnected. Processing components separately...")
     #   connected_components = list(nx.connected_components(nx_graph))
      #  for i, component in enumerate(connected_components):
       #     subgraph = nx_graph.subgraph(component)
        #    print(f"Processing component {i+1} with {subgraph.number_of_nodes()} nodes.")

    # Extract adjacency matrix with edge weights
    adjacency_matrix = to_scipy_sparse_array(nx_graph, weight="weight")  # Use "weight" if default

    # Create PyGSP graph
    gsp_graph = pg.graphs.Graph(adjacency_matrix)

    # Display basic graph info
    print(f"PyGSP {graph_name} Graph with {gsp_graph.N} nodes and {gsp_graph.Ne} edges.")

    # Compute Laplacian
    gsp_graph.compute_laplacian(lap_type="combinatorial")

    # Compute Fourier basis
    gsp_graph.compute_fourier_basis(recompute=True)

    # Clamp smallest eigenvalue to 0 if it's very close
    if abs(gsp_graph.e[0]) < 1e-10:
        gsp_graph.e[0] = 0

    # Display first few eigenvalues
    print(f"Eigenvalues ({graph_name}):", gsp_graph.e[:10])

    return gsp_graph

# Process both combined graphs
gsp_graph_mcf7_ppi = process_graph(G_combined_MCF7_ppi, "MCF7 Positive ")

gsp_graph_mda_ppi = process_graph(G_combined_MDA_ppi, "MDA Positive")

# Store results in a dictionary
results = {
    "MCF7 Combined": {"graph": gsp_graph_mcf7_ppi},
    "MDA Combined": {"graph": gsp_graph_mda_ppi},
}

# Optionally, extract eigenvalues and eigenvectors for all graphs
for graph_name, data in results.items():
    gsp_graph = data["graph"]
    results[graph_name]["eigenvalues"] = gsp_graph.e
    results[graph_name]["eigenvectors"] = gsp_graph.U

# Print summary of results
for graph_name, data in results.items():
    print(f"\nSummary for {graph_name}:")
    print(f"Eigenvalues: {data['eigenvalues'][:5]}")  # First 5 eigenvalues
# Out:
# Processing MCF7 Positive  graph...
# PyGSP MCF7 Positive  Graph with 1309 nodes and 418819 edges.
# Eigenvalues (MCF7 Positive ): [ 0.         18.45801395 18.4751567  19.24903496 19.32888787 19.4507603
#  19.66513952 19.82701706 19.84444604 19.89629764]
# Processing MDA Positive graph...
# PyGSP MDA Positive Graph with 1354 nodes and 463461 edges.
# Eigenvalues (MDA Positive): [ 0.         29.79504579 29.97321704 30.05918517 30.57264172 30.82117572
#  30.92717268 31.2139313  31.41074221 32.01866253]
#
# Summary for MCF7 Combined:
# Eigenvalues: [ 0.         18.45801395 18.4751567  19.24903496 19.32888787]
#
# Summary for MDA Combined:
# Eigenvalues: [ 0.         29.79504579 29.97321704 30.05918517 30.57264172]

# %%
# Assign Clusters to Nodes
# Assign the cluster labels to nodes in the NetworkX graph for further exploration.

# Assign cluster labels as node attributes for positive and negative graphs
nx.set_node_attributes(G_combined_MCF7_ppi, dict(zip(G_combined_MCF7_ppi.nodes, clusters_combined_mcf7_ppi)), "cluster")
nx.set_node_attributes(G_combined_MDA_ppi, dict(zip(G_combined_MDA_ppi.nodes, clusters_combined_mda_ppi)), "cluster")

# Verify node clusters
print("\nG_combined_mcf7 Clusters:")
for node, data in list(G_combined_MCF7_ppi.nodes(data=True))[:5]:  # First 5 for brevity
    print(node, data)

print("\nG_combined_mda Clusters:")
for node, data in list(G_combined_MDA_ppi.nodes(data=True))[:5]:  # First 5 for brevity
    print(node, data)
# Out:
# G_combined_mcf7 Clusters:
# AHR {'cluster': 'AHR'}
# ABCA12 {'cluster': 'ABCA12'}
# ACKR3 {'cluster': 'ACKR3'}
# ACOT4 {'cluster': 'ACOT4'}
# ACSL5 {'cluster': 'ACSL5'}
#
# G_combined_mda Clusters:
# AHR {'cluster': 'AHR'}
# ABCA12 {'cluster': 'ABCA12'}
# ACKR3 {'cluster': 'ACKR3'}
# ACOT4 {'cluster': 'ACOT4'}
# ACSL5 {'cluster': 'ACSL5'}

# %% [markdown]
# # Lets try to identify the positive graph with stronger interaction hub depicted with thicker edges

# %% [markdown]
# # 1. Identify the Hub Node
# # The hub node is likely the node with the highest degree or the strongest total edge weight. You can calculate these metrics:
#
# # Degree Centrality (Number of Connections)

# %%
# Get degree centrality for G_positive
degree_centrality = nx.degree_centrality(G_combined_MCF7_ppi)

# Sort nodes by degree centrality
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)

# Display the top nodes
print("Top Nodes by Degree Centrality (Combined MCF7_ppi Graph):")
for node, centrality in sorted_degree[:20]:  # Top 10 nodes
    print(f"Node: {node}, Degree Centrality: {centrality}")
# Out:
# Top Nodes by Degree Centrality (Combined MCF7_ppi Graph):
# Node: SOX2, Degree Centrality: 1.4655963302752293
# Node: ASCL1, Degree Centrality: 1.0244648318042813
# Node: ASCL2, Degree Centrality: 1.0244648318042813
# Node: BATF3, Degree Centrality: 1.0244648318042813
# Node: CREB5, Degree Centrality: 1.0244648318042813
# Node: DMRTA1, Degree Centrality: 1.0244648318042813
# Node: ELF5, Degree Centrality: 1.0244648318042813
# Node: ESR1, Degree Centrality: 1.0244648318042813
# Node: ETS1, Degree Centrality: 1.0244648318042813
# Node: ETV1, Degree Centrality: 1.0244648318042813
# Node: FOSL1, Degree Centrality: 1.0244648318042813
# Node: FOXA2, Degree Centrality: 1.0244648318042813
# Node: FOXI3, Degree Centrality: 1.0244648318042813
# Node: GRHL2, Degree Centrality: 1.0244648318042813
# Node: GSC, Degree Centrality: 1.0244648318042813
# Node: HMGA2, Degree Centrality: 1.0244648318042813
# Node: HOXA10, Degree Centrality: 1.0244648318042813
# Node: HOXA4, Degree Centrality: 1.0244648318042813
# Node: HOXC13, Degree Centrality: 1.0244648318042813
# Node: HOXD3, Degree Centrality: 1.0244648318042813

# %%
# Get degree centrality for G_positive
degree_centrality = nx.degree_centrality(G_combined_MDA_ppi)

# Sort nodes by degree centrality
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)

# Display the top nodes
print("Top Nodes by Degree Centrality (Combined MDA_ppi Graph):")
for node, centrality in sorted_degree[:20]:  # Top 10 nodes
    print(f"Node: {node}, Degree Centrality: {centrality}")
# Out:
# Top Nodes by Degree Centrality (Combined MDA_ppi Graph):
# Node: SOX2, Degree Centrality: 1.450849963045085
# Node: ASCL1, Degree Centrality: 1.0288248337028825
# Node: ASCL2, Degree Centrality: 1.0288248337028825
# Node: BATF3, Degree Centrality: 1.0288248337028825
# Node: CREB5, Degree Centrality: 1.0288248337028825
# Node: DMRTA1, Degree Centrality: 1.0288248337028825
# Node: ELF5, Degree Centrality: 1.0288248337028825
# Node: ESR1, Degree Centrality: 1.0288248337028825
# Node: ETS1, Degree Centrality: 1.0288248337028825
# Node: ETV1, Degree Centrality: 1.0288248337028825
# Node: FOSL1, Degree Centrality: 1.0288248337028825
# Node: FOXA2, Degree Centrality: 1.0288248337028825
# Node: FOXI3, Degree Centrality: 1.0288248337028825
# Node: GRHL2, Degree Centrality: 1.0288248337028825
# Node: GSC, Degree Centrality: 1.0288248337028825
# Node: HMGA2, Degree Centrality: 1.0288248337028825
# Node: HOXA10, Degree Centrality: 1.0288248337028825
# Node: HOXA4, Degree Centrality: 1.0288248337028825
# Node: HOXC13, Degree Centrality: 1.0288248337028825
# Node: HOXD3, Degree Centrality: 1.0288248337028825

# %%
# Compute strength (sum of edge weights) for each node
strength = {node: sum(data["weight"] for _, _, data in G_combined_MCF7_ppi.edges(node, data=True)) for node in G_combined_MCF7_ppi.nodes()}

# Sort nodes by strength
sorted_strength = sorted(strength.items(), key=lambda x: x[1], reverse=True)

# Display the top nodes
print("\nTop Nodes by Strength (Edge Weights, Positive Graph):")
for node, weight in sorted_strength[:10]:  # Top 10 nodes
    print(f"Node: {node}, Strength (Sum of Weights): {weight}")
# Out:
# Top Nodes by Strength (Edge Weights, Positive Graph):
# Node: SOX2, Strength (Sum of Weights): 272.45839071775174
# Node: LEF1, Strength (Sum of Weights): 211.2039246356656
# Node: ZBTB7B, Strength (Sum of Weights): 190.08023339737917
# Node: ZNF235, Strength (Sum of Weights): 186.2514563234892
# Node: CREB1, Strength (Sum of Weights): 178.65040391597313
# Node: PRDM9, Strength (Sum of Weights): 177.58734633521524
# Node: CTCF, Strength (Sum of Weights): 173.53959237369008
# Node: NFKB1, Strength (Sum of Weights): 158.64536756640277
# Node: ZNF529, Strength (Sum of Weights): 155.26819030985604
# Node: RXRA, Strength (Sum of Weights): 152.8365446327219

# %%
# Compute strength (sum of edge weights) for each node
strength = {node: sum(data["weight"] for _, _, data in G_combined_MDA_ppi.edges(node, data=True)) for node in G_combined_MDA_ppi.nodes()}

# Sort nodes by strength
sorted_strength = sorted(strength.items(), key=lambda x: x[1], reverse=True)

# Display the top nodes
print("\nTop Nodes by Strength (Edge Weights, Positive Graph):")
for node, weight in sorted_strength[:10]:  # Top 10 nodes
    print(f"Node: {node}, Strength (Sum of Weights): {weight}")
# Out:
# Top Nodes by Strength (Edge Weights, Positive Graph):
# Node: SOX2, Strength (Sum of Weights): 315.6013235966641
# Node: LEF1, Strength (Sum of Weights): 256.4111787307812
# Node: CREB1, Strength (Sum of Weights): 241.93073299824053
# Node: RXRA, Strength (Sum of Weights): 197.13071750149885
# Node: STAT5A, Strength (Sum of Weights): 180.84635823696476
# Node: CTCF, Strength (Sum of Weights): 177.5991197623053
# Node: NFKB1, Strength (Sum of Weights): 172.61728057916662
# Node: REL, Strength (Sum of Weights): 165.84302491201805
# Node: NFKB2, Strength (Sum of Weights): 142.34266683147666
# Node: MZF1, Strength (Sum of Weights): 129.00603889012118

# %% [markdown]
# # **2. Identify Genes and TFs Connected to the Hub**
# # Once you identify the hub node, find all nodes connected to it and analyze their edge weights:

# %%
# Get the top hub node (by strength or degree centrality)
top_hub_node_MDA = sorted_strength[0][0]  # Replace with your preferred metric

# Get neighbors (connected nodes) of the hub
neighbors = G_combined_MDA_ppi[top_hub_node_MDA]

print(f"\nNeighbors of Hub Node ({top_hub_node_MDA}):")
for neighbor, edge_data in neighbors.items():
    print(f"Connected Node: {neighbor}, Edge Weight: {edge_data['weight']}")
# Out:
# Neighbors of Hub Node (SOX2):
# Connected Node: ABCA12, Edge Weight: 0.10528367082271572
# Connected Node: ACKR3, Edge Weight: 0.19546217319545822
# Connected Node: ACOT4, Edge Weight: 0.1822168368816205
# Connected Node: ACSL5, Edge Weight: 0.0955462436388832
# Connected Node: ADAMTS1, Edge Weight: 0.1864099089507104
# Connected Node: ADAMTS12, Edge Weight: 0.14011159681698448
# Connected Node: ADAMTS16, Edge Weight: 0.24330307241306992
# Connected Node: ADAMTS19, Edge Weight: 0.19987210281974477
# Connected Node: ADCY1, Edge Weight: 0.20137765541934227
# Connected Node: ADCY5, Edge Weight: 0.18176071066870714
# Connected Node: ADD2, Edge Weight: 0.20055604126241422
# Connected Node: ADGRE1, Edge Weight: 0.1861378419512304
# Connected Node: ADGRF5, Edge Weight: 0.20876750875094907
# Connected Node: ADGRG5, Edge Weight: 0.17897475710470456
# Connected Node: ADRA2C, Edge Weight: 0.24250121468402164
# Connected Node: ADRB2, Edge Weight: 0.21386221404907013
# Connected Node: AGPAT4, Edge Weight: 0.17069980302761056
# Connected Node: AGPS, Edge Weight: 0.20179237982378107
# Connected Node: AGR3, Edge Weight: 0.08302768822092899
# Connected Node: AK7, Edge Weight: 0.1668309830628979
# Connected Node: AKR1B1, Edge Weight: 0.18577050506434267
# Connected Node: AKT3, Edge Weight: 0.20539495140453512
# Connected Node: ALDH2, Edge Weight: 0.24152090205541832
# Connected Node: ALDH3B2, Edge Weight: 0.17054834051051992
# Connected Node: ALOX15, Edge Weight: 0.20265105527401006
# Connected Node: ANK2, Edge Weight: 0.18623604704425556
# Connected Node: ANKRD1, Edge Weight: 0.06288827794409946
# Connected Node: ANKRD33B, Edge Weight: 0.2537796890434578
# Connected Node: ANKRD34B, Edge Weight: 0.10483122788712518
# Connected Node: ANO3, Edge Weight: 0.11346661094576171
# Connected Node: ANTXR2, Edge Weight: 0.1435754939798396
# Connected Node: ANXA8L1, Edge Weight: 0.2613222954990827
# Connected Node: APOBEC3C, Edge Weight: 0.21684791774613466
# Connected Node: APOL1, Edge Weight: 0.18922949530985378
# Connected Node: APOL3, Edge Weight: 0.135350952697043
# Connected Node: APOL6, Edge Weight: 0.22002879287163213
# Connected Node: ARHGAP23, Edge Weight: 0.23648120680103324
# Connected Node: ARHGAP40, Edge Weight: 0.19093631792844268
# Connected Node: ARHGAP8, Edge Weight: 0.2222862689123316
# Connected Node: ARHGDIB, Edge Weight: 0.052887802412114215
# Connected Node: ARHGDIG, Edge Weight: 0.1585939826108319
# Connected Node: ASCL1, Edge Weight: 0.778
# Connected Node: ASCL2, Edge Weight: 0.306
# Connected Node: ATP10D, Edge Weight: 0.16713943875053605
# Connected Node: AXL, Edge Weight: 0.22453604207915212
# Connected Node: BATF3, Edge Weight: 0.2110997675055991
# Connected Node: BCAS1, Edge Weight: 0.14809943323669905
# Connected Node: BCAT1, Edge Weight: 0.0929755620861813
# Connected Node: BCHE, Edge Weight: 0.018983155878085523
# Connected Node: BEX4, Edge Weight: 0.2054373443070947
# Connected Node: BICC1, Edge Weight: 0.17888956451084426
# Connected Node: BICDL2, Edge Weight: 0.22959229235004364
# Connected Node: BIRC3, Edge Weight: 0.15365643615645885
# Connected Node: BMP5, Edge Weight: 0.09107167325680765
# Connected Node: BMP7, Edge Weight: 0.22834521698075227
# Connected Node: BPIFB1, Edge Weight: 0.1993784837050685
# Connected Node: BRINP2, Edge Weight: 0.1453034346634675
# Connected Node: BSPRY, Edge Weight: 0.17768735443111772
# Connected Node: BTNL9, Edge Weight: 0.16593194329983085
# Connected Node: C11orf52, Edge Weight: 0.1870875379622402
# Connected Node: C14orf132, Edge Weight: 0.19787080374456123
# Connected Node: C19orf81, Edge Weight: 0.2193633282753229
# Connected Node: C1orf210, Edge Weight: 0.20620210509006087
# Connected Node: C4BPB, Edge Weight: 0.09942211513407506
# Connected Node: CA8, Edge Weight: 0.18199458516851086
# Connected Node: CACNA1D, Edge Weight: 0.21480327599834237
# Connected Node: CACNA2D4, Edge Weight: 0.19983788271040526
# Connected Node: CACNG4, Edge Weight: 0.3037546715052313
# Connected Node: CALD1, Edge Weight: 0.10040907263317178
# Connected Node: CALML5, Edge Weight: 0.2012134026666017
# Connected Node: CAMK4, Edge Weight: 0.1047637486180335
# Connected Node: CAPN13, Edge Weight: 0.15416169916397104
# Connected Node: CAPN9, Edge Weight: 0.21309936634112625
# Connected Node: CARD11, Edge Weight: 0.2215458461999631
# Connected Node: CASP1, Edge Weight: 0.21249971573595627
# Connected Node: CASP4, Edge Weight: 0.033113646389101414
# Connected Node: CAVIN2, Edge Weight: 0.1196378630176761
# Connected Node: CAVIN3, Edge Weight: 0.1601670620344603
# Connected Node: CBFA2T3, Edge Weight: 0.23048141891678675
# Connected Node: CBLN4, Edge Weight: 0.19831682387419214
# Connected Node: CBS, Edge Weight: 0.1269341021522149
# Connected Node: CCBE1, Edge Weight: 0.24751529115548165
# Connected Node: CCDC120, Edge Weight: 0.21951758805135413
# Connected Node: CCDC170, Edge Weight: 0.2148148993602238
# Connected Node: CCDC63, Edge Weight: 0.247505579901788
# Connected Node: CCDC83, Edge Weight: 0.20001082854769991
# Connected Node: CD274, Edge Weight: 0.14349609021795284
# Connected Node: CD40, Edge Weight: 0.24176542491102215
# Connected Node: CD96, Edge Weight: 0.0034579453601815135
# Connected Node: CDC42EP3, Edge Weight: 0.25035831991203794
# Connected Node: CDCP1, Edge Weight: 0.16350180237045764
# Connected Node: CDH1, Edge Weight: 0.16636991232697085
# Connected Node: CDK15, Edge Weight: 0.17328700433247468
# Connected Node: CDKN2A, Edge Weight: 0.1452380090044283
# Connected Node: CEACAM5, Edge Weight: 0.20728299294416996
# Connected Node: CEACAM6, Edge Weight: 0.15181612471478845
# Connected Node: CELF2, Edge Weight: 0.0883192899438483
# Connected Node: CFH, Edge Weight: 0.06727061060259754
# Connected Node: CHDH, Edge Weight: 0.2233533749676152
# Connected Node: CHRM3, Edge Weight: 0.19479457898856312
# Connected Node: CHST2, Edge Weight: 0.21888170411565067
# Connected Node: CKMT1B, Edge Weight: 0.16762922486342624
# Connected Node: CLDN1, Edge Weight: 0.14541601567104978
# Connected Node: CLSTN2, Edge Weight: 0.1889614332659867
# Connected Node: CMTM7, Edge Weight: 0.22794977940042005
# Connected Node: CNN3, Edge Weight: 0.17912071558873954
# Connected Node: COL13A1, Edge Weight: 0.23251015055116686
# Connected Node: COL4A1, Edge Weight: 0.22361935600193927
# Connected Node: COL4A2, Edge Weight: 0.22093390634790233
# Connected Node: COL4A5, Edge Weight: 0.01921181098824709
# Connected Node: COL4A6, Edge Weight: 0.186183669718484
# Connected Node: COL8A1, Edge Weight: 0.20824509125297064
# Connected Node: COX7B2, Edge Weight: 0.09526946791659863
# Connected Node: CPA4, Edge Weight: 0.2586541150506626
# Connected Node: CPED1, Edge Weight: 0.14985114408148836
# Connected Node: CPNE8, Edge Weight: 0.14888128743986084
# Connected Node: CPVL, Edge Weight: 0.035855726826442336
# Connected Node: CREB5, Edge Weight: 0.13294907065763384
# Connected Node: CST1, Edge Weight: 0.2368084617822167
# Connected Node: CST4, Edge Weight: 0.24955943464621577
# Connected Node: CT83, Edge Weight: 0.09084479825818903
# Connected Node: CTNND2, Edge Weight: 0.10834471943462698
# Connected Node: CXCL1, Edge Weight: 0.23492912817917322
# Connected Node: CXCL12, Edge Weight: 0.20912949101327405
# Connected Node: CXCL2, Edge Weight: 0.23458503234822592
# Connected Node: CXCL8, Edge Weight: 0.02672646862760597
# Connected Node: CYBRD1, Edge Weight: 0.12797852118106146
# Connected Node: CYP27A1, Edge Weight: 0.1976821120730321
# Connected Node: DAW1, Edge Weight: 0.12908110116265104
# Connected Node: DCDC2, Edge Weight: 0.17543144844756942
# Connected Node: DEGS2, Edge Weight: 0.23970591021017817
# Connected Node: DGKG, Edge Weight: 0.23467886628792034
# Connected Node: DIRAS2, Edge Weight: 0.11059933592489624
# Connected Node: DMRTA1, Edge Weight: 0.251
# Connected Node: DNAJC12, Edge Weight: 0.1003945143451418
# Connected Node: DOCK8, Edge Weight: 0.07627439166793548
# Connected Node: DOK7, Edge Weight: 0.24996958741042064
# Connected Node: DRD1, Edge Weight: 0.26272904320029733
# Connected Node: DSCAM, Edge Weight: 0.002534222529295471
# Connected Node: EDIL3, Edge Weight: 0.1857741710261307
# Connected Node: EHD3, Edge Weight: 0.1366668932059666
# Connected Node: ELF5, Edge Weight: 0.402
# Connected Node: ELOVL2, Edge Weight: 0.10402532551984078
# Connected Node: ELOVL4, Edge Weight: 0.09835378104416526
# Connected Node: EMC10, Edge Weight: 0.22234840849548865
# Connected Node: EMID1, Edge Weight: 0.18332728784938768
# Connected Node: EMP1, Edge Weight: 0.2130628861053394
# Connected Node: ENPP5, Edge Weight: 0.1431961163562312
# Connected Node: ENTPD2, Edge Weight: 0.22803634040877552
# Connected Node: ENTPD8, Edge Weight: 0.2280990311246479
# Connected Node: EPN3, Edge Weight: 0.19718902741597422
# Connected Node: EPPK1, Edge Weight: 0.2171618488786966
# Connected Node: ERBB3, Edge Weight: 0.21352509173362177
# Connected Node: ERBB4, Edge Weight: 0.170855595023656
# Connected Node: EREG, Edge Weight: 0.1883093247341917
# Connected Node: ESR1, Edge Weight: 0.495
# Connected Node: ESRP1, Edge Weight: 0.21142011143347927
# Connected Node: ETS1, Edge Weight: 0.317
# Connected Node: ETV1, Edge Weight: 0.302
# Connected Node: EVA1A, Edge Weight: 0.22214034913681358
# Connected Node: EVC, Edge Weight: 0.21621706508068972
# Connected Node: EVI2A, Edge Weight: 0.13163874472257797
# Connected Node: EVI2B, Edge Weight: 0.06932981282694062
# Connected Node: EVPLL, Edge Weight: 0.2304190701567449
# Connected Node: EYA1, Edge Weight: 0.14547735196257106
# Connected Node: EYA2, Edge Weight: 0.2095999947012357
# Connected Node: F2RL3, Edge Weight: 0.1761462036322199
# Connected Node: F3, Edge Weight: 0.17895492996836826
# Connected Node: FAM110C, Edge Weight: 0.23295916981412834
# Connected Node: FAM133A, Edge Weight: 0.18038064010987398
# Connected Node: FAM171A1, Edge Weight: 0.2006777928509752
# Connected Node: FAM178B, Edge Weight: 0.20334242145799186
# Connected Node: FAM50B, Edge Weight: 0.05182680402558748
# Connected Node: FAM83B, Edge Weight: 0.10033562711586619
# Connected Node: FGF5, Edge Weight: 0.22767847303345912
# Connected Node: FGFR2, Edge Weight: 0.17447175243142898
# Connected Node: FLG, Edge Weight: 0.07762977175315455
# Connected Node: FLNC, Edge Weight: 0.23824773527747578
# Connected Node: FLRT3, Edge Weight: 0.0962641047285212
# Connected Node: FOSL1, Edge Weight: 0.245
# Connected Node: FOXA2, Edge Weight: 0.773
# Connected Node: FOXI3, Edge Weight: 0.153
# Connected Node: FSD1, Edge Weight: 0.20376672048102806
# Connected Node: FST, Edge Weight: 0.1404032521277877
# Connected Node: FSTL1, Edge Weight: 0.23789209133633815
# Connected Node: FUT9, Edge Weight: 0.23196890272869597
# Connected Node: FXYD3, Edge Weight: 0.17436657640798447
# Connected Node: FXYD5, Edge Weight: 0.24443608339562162
# Connected Node: G0S2, Edge Weight: 0.17858763849169534
# Connected Node: GABRA3, Edge Weight: 0.18537076942274466
# Connected Node: GABRE, Edge Weight: 0.07968484126330377
# Connected Node: GAL, Edge Weight: 0.22149429382469865
# Connected Node: GBP1, Edge Weight: 0.020693930412335027
# Connected Node: GBP3, Edge Weight: 0.08428530850805149
# Connected Node: GCNT2, Edge Weight: 0.16687407164640466
# Connected Node: GFRA1, Edge Weight: 0.1372964819356144
# Connected Node: GJA1, Edge Weight: 0.153500810044905
# Connected Node: GLRA3, Edge Weight: 0.1414173458321698
# Connected Node: GLRB, Edge Weight: 0.04108997489847599
# Connected Node: GMFG, Edge Weight: 0.2270900775014969
# Connected Node: GNA15, Edge Weight: 0.250878439894867
# Connected Node: GNG11, Edge Weight: 0.131596532429338
# Connected Node: GOLT1A, Edge Weight: 0.2214138424319767
# Connected Node: GP2, Edge Weight: 0.026910770391833982
# Connected Node: GPAT2, Edge Weight: 0.21425983621712796
# Connected Node: GPC4, Edge Weight: 0.23715818685583145
# Connected Node: GPR27, Edge Weight: 0.1932801562032448
# Connected Node: GPR37L1, Edge Weight: 0.22011159671098757
# Connected Node: GPX1, Edge Weight: 0.17025455519899368
# Connected Node: GRHL2, Edge Weight: 0.157
# Connected Node: GRIK3, Edge Weight: 0.23013204453603175
# Connected Node: GSC, Edge Weight: 0.306
# Connected Node: GSTM1, Edge Weight: 0.21941385796656943
# Connected Node: GSTP1, Edge Weight: 0.21138009639896527
# Connected Node: HAS2, Edge Weight: 0.194508738284072
# Connected Node: HENMT1, Edge Weight: 0.1977774402928748
# Connected Node: HMGA2, Edge Weight: 0.689
# Connected Node: HMGCLL1, Edge Weight: 0.20185208958522904
# Connected Node: HOXA10, Edge Weight: 0.2
# Connected Node: HOXA4, Edge Weight: 0.20003216207044627
# Connected Node: HOXC13, Edge Weight: 0.237
# Connected Node: HOXD3, Edge Weight: 0.19093940672720489
# Connected Node: HPDL, Edge Weight: 0.22229283800404287
# Connected Node: HRH1, Edge Weight: 0.23002857460004855
# Connected Node: HRNR, Edge Weight: 0.04214258505665913
# Connected Node: HS3ST3A1, Edge Weight: 0.18565063348210054
# Connected Node: HS6ST2, Edge Weight: 0.13540629681685812
# Connected Node: HSH2D, Edge Weight: 0.1725019430063771
# Connected Node: HTR1F, Edge Weight: 0.30470720319746725
# Connected Node: HUNK, Edge Weight: 0.20668846559686416
# Connected Node: ICAM2, Edge Weight: 0.24300599690584967
# Connected Node: IFI16, Edge Weight: 0.11159137979504952
# Connected Node: IFI44, Edge Weight: 0.18343284950195504
# Connected Node: IFI44L, Edge Weight: 0.15362041380010205
# Connected Node: IFIT3, Edge Weight: 0.10703604320005589
# Connected Node: IGDCC3, Edge Weight: 0.254402556272625
# Connected Node: IGF2BP3, Edge Weight: 0.21885046172839406
# Connected Node: IGFBP1, Edge Weight: 0.1886855862624388
# Connected Node: IGFBP2, Edge Weight: 0.2052840532851805
# Connected Node: IGFBP5, Edge Weight: 0.24504248197336653
# Connected Node: IL1RAPL1, Edge Weight: 0.052590818409379514
# Connected Node: IL31RA, Edge Weight: 0.15999743657835974
# Connected Node: IL7R, Edge Weight: 0.1684934784846004
# Connected Node: ILDR1, Edge Weight: 0.10286600753961594
# Connected Node: ILDR2, Edge Weight: 0.2067267227051296
# Connected Node: IQANK1, Edge Weight: 0.14838711362216517
# Connected Node: IRF6, Edge Weight: 0.281
# Connected Node: IRX2, Edge Weight: 0.25
# Connected Node: IRX4, Edge Weight: 0.261
# Connected Node: ITGBL1, Edge Weight: 0.007908444156385253
# Connected Node: KCNF1, Edge Weight: 0.22143732726448873
# Connected Node: KCNJ3, Edge Weight: 0.23853032128192597
# Connected Node: KCNQ3, Edge Weight: 0.22845663054414245
# Connected Node: KCNQ5, Edge Weight: 0.2165167386257535
# Connected Node: KCTD14, Edge Weight: 0.20919679707184613
# Connected Node: KCTD15, Edge Weight: 0.1983009110468299
# Connected Node: KCTD4, Edge Weight: 0.14103470417226338
# Connected Node: KDF1, Edge Weight: 0.20939549975938976
# Connected Node: KIAA0040, Edge Weight: 0.250049110125119
# Connected Node: KIF1A, Edge Weight: 0.2260493949923894
# Connected Node: KIF26A, Edge Weight: 0.25078756645555766
# Connected Node: KIRREL1, Edge Weight: 0.17718907422936825
# Connected Node: KLHL9, Edge Weight: 0.06820041763916473
# Connected Node: KLK11, Edge Weight: 0.24450505432019398
# Connected Node: KLRC2, Edge Weight: 0.06640606076648103
# Connected Node: KLRG2, Edge Weight: 0.19877404080006678
# Connected Node: LAD1, Edge Weight: 0.17164601967326665
# Connected Node: LAMA1, Edge Weight: 0.23542253569459815
# Connected Node: LAMA4, Edge Weight: 0.11766910595994318
# Connected Node: LAPTM5, Edge Weight: 0.23871223782599027
# Connected Node: LARGE2, Edge Weight: 0.20783515611457626
# Connected Node: LAYN, Edge Weight: 0.12253677966035315
# Connected Node: LDHB, Edge Weight: 0.14670515597517797
# Connected Node: LDOC1, Edge Weight: 0.18927309488684174
# Connected Node: LHFPL6, Edge Weight: 0.18944788555324654
# Connected Node: LHX1, Edge Weight: 0.475
# Connected Node: LHX2, Edge Weight: 0.606
# Connected Node: LIMCH1, Edge Weight: 0.2384064840251039
# Connected Node: LIMS2, Edge Weight: 0.23149927791573555
# Connected Node: LPAR1, Edge Weight: 0.07287045003264758
# Connected Node: LRP3, Edge Weight: 0.20663598162419317
# Connected Node: LRRC10B, Edge Weight: 0.24467856953910005
# Connected Node: LY96, Edge Weight: 0.21100030834632832
# Connected Node: LYPD3, Edge Weight: 0.19730688958496967
# Connected Node: LYPD6B, Edge Weight: 0.210630412803262
# Connected Node: LYPD8, Edge Weight: 0.20503569915541586
# Connected Node: MACC1, Edge Weight: 0.07594704872696956
# Connected Node: MAGEA3, Edge Weight: 0.24789292605719404
# Connected Node: MAGEC1, Edge Weight: 0.17482760105600792
# Connected Node: MAGEC2, Edge Weight: 0.22893471304398139
# Connected Node: MAGEH1, Edge Weight: 0.23520116734214924
# Connected Node: MAL2, Edge Weight: 0.22127667608055657
# Connected Node: MALRD1, Edge Weight: 0.2195740002883071
# Connected Node: MARVELD3, Edge Weight: 0.20190286336579422
# Connected Node: MCAM, Edge Weight: 0.20745735788365371
# Connected Node: MDFIC, Edge Weight: 0.0032814583721509916
# Connected Node: ME3, Edge Weight: 0.2038530672871649
# Connected Node: MGMT, Edge Weight: 0.2530938612288177
# Connected Node: MME, Edge Weight: 0.18908677429445953
# Connected Node: MMEL1, Edge Weight: 0.19000937975935217
# Connected Node: MMP1, Edge Weight: 0.23607340998404758
# Connected Node: MMP14, Edge Weight: 0.1900892045809892
# Connected Node: MPP1, Edge Weight: 0.21809955264790104
# Connected Node: MPP4, Edge Weight: 0.07351374786573128
# Connected Node: MSI1, Edge Weight: 0.21402052279120487
# Connected Node: MSN, Edge Weight: 0.21745413136644043
# Connected Node: MSRB3, Edge Weight: 0.1950782057124152
# Connected Node: MT1E, Edge Weight: 0.20566099952100303
# Connected Node: MUC15, Edge Weight: 0.05589864642170794
# Connected Node: MYH14, Edge Weight: 0.21619407874085428
# Connected Node: MYH15, Edge Weight: 0.06167627214727045
# Connected Node: MYL9, Edge Weight: 0.20517346649083512
# Connected Node: N4BP3, Edge Weight: 0.19746975713294512
# Connected Node: NAP1L2, Edge Weight: 0.18174591905868398
# Connected Node: NAV3, Edge Weight: 0.033686088958333804
# Connected Node: NBPF4, Edge Weight: 0.1390491444573495
# Connected Node: NBPF6, Edge Weight: 0.22065175228756173
# Connected Node: NECAB1, Edge Weight: 0.19180357669766668
# Connected Node: NECTIN4, Edge Weight: 0.24377169854437952
# Connected Node: NETO2, Edge Weight: 0.20243339376315783
# Connected Node: NINJ2, Edge Weight: 0.22484435471621245
# Connected Node: NLRP1, Edge Weight: 0.19703739426435019
# Connected Node: NLRP3, Edge Weight: 0.13248833235657287
# Connected Node: NMNAT3, Edge Weight: 0.23876268445018234
# Connected Node: NNMT, Edge Weight: 0.22121823550984498
# Connected Node: NOG, Edge Weight: 0.22916017735443384
# Connected Node: NOVA1, Edge Weight: 0.12120923599902722
# Connected Node: NPNT, Edge Weight: 0.18356205019825034
# Connected Node: NRG1, Edge Weight: 0.1003326063632195
# Connected Node: NRK, Edge Weight: 0.09830816108019491
# Connected Node: NRROS, Edge Weight: 0.2020041137973846
# Connected Node: NTN1, Edge Weight: 0.22283527837678874
# Connected Node: NUP210L, Edge Weight: 0.18604234522326268
# Connected Node: OLFM1, Edge Weight: 0.2594037329859793
# Connected Node: OOEP, Edge Weight: 0.15857786631493342
# Connected Node: OVOL1, Edge Weight: 0.211
# Connected Node: OVOL2, Edge Weight: 0.210068215043552
# Connected Node: P3H2, Edge Weight: 0.16767969163388652
# Connected Node: PALM3, Edge Weight: 0.22836229894052418
# Connected Node: PCDH10, Edge Weight: 0.2409077871843498
# Connected Node: PCDH8, Edge Weight: 0.05143847269777113
# Connected Node: PCDHA11, Edge Weight: 0.045869608083842106
# Connected Node: PCDHA12, Edge Weight: 0.06850284743018453
# Connected Node: PCDHAC2, Edge Weight: 0.09638137331492258
# Connected Node: PCDHGB5, Edge Weight: 0.20815055785619818
# Connected Node: PCP4, Edge Weight: 0.17741750273984913
# Connected Node: PCSK1N, Edge Weight: 0.16666645772055055
# Connected Node: PCSK2, Edge Weight: 0.04344111048509569
# Connected Node: PDCD1LG2, Edge Weight: 0.1911355449576485
# Connected Node: PDE10A, Edge Weight: 0.23242252020366994
# Connected Node: PDE4B, Edge Weight: 0.17051288540119425
# Connected Node: PDGFRB, Edge Weight: 0.22528148811200432
# Connected Node: PDIA2, Edge Weight: 0.22310265561901566
# Connected Node: PDLIM4, Edge Weight: 0.2182666320189912
# Connected Node: PDZD4, Edge Weight: 0.2710197040030079
# Connected Node: PDZRN3, Edge Weight: 0.11557300846237695
# Connected Node: PEG10, Edge Weight: 0.18814737680439853
# Connected Node: PGR, Edge Weight: 0.352
# Connected Node: PHYHD1, Edge Weight: 0.24463137978844907
# Connected Node: PID1, Edge Weight: 0.08552706411215039
# Connected Node: PKP1, Edge Weight: 0.20807466768448413
# Connected Node: PLA2G4A, Edge Weight: 0.12271194369734495
# Connected Node: PLA2G4F, Edge Weight: 0.20559515592237665
# Connected Node: PLCL2, Edge Weight: 0.149990845542061
# Connected Node: PLCXD3, Edge Weight: 0.18075291083112954
# Connected Node: PLPPR5, Edge Weight: 0.175816296373417
# Connected Node: PLS3, Edge Weight: 0.11938241438295827
# Connected Node: PNMA2, Edge Weight: 0.2432491945882841
# Connected Node: PNMA8A, Edge Weight: 0.23387273235477102
# Connected Node: POPDC3, Edge Weight: 0.19721824483547512
# Connected Node: PPARGC1A, Edge Weight: 0.21891431355517854
# Connected Node: PPL, Edge Weight: 0.18365012670736613
# Connected Node: PPP4R3C, Edge Weight: 0.06509124997718752
# Connected Node: PRDM8, Edge Weight: 0.187
# Connected Node: PRDM9, Edge Weight: 0.212
# Connected Node: PREX1, Edge Weight: 0.23872758482365064
# Connected Node: PRKAA2, Edge Weight: 0.2237794382259941
# Connected Node: PROM2, Edge Weight: 0.26769825607403863
# Connected Node: PRR15L, Edge Weight: 0.2021706289885341
# Connected Node: PRSS2, Edge Weight: 0.22768272156360736
# Connected Node: PRSS8, Edge Weight: 0.20563847050315553
# Connected Node: PSAT1, Edge Weight: 0.1993154025309185
# Connected Node: PSMB8, Edge Weight: 0.22507507127158244
# Connected Node: PTPRM, Edge Weight: 0.2573109222489921
# Connected Node: PTX3, Edge Weight: 0.25155977649024996
# Connected Node: QPRT, Edge Weight: 0.23454052523509494
# Connected Node: RAB17, Edge Weight: 0.24864153036582648
# Connected Node: RAB25, Edge Weight: 0.23727921123996998
# Connected Node: RAB34, Edge Weight: 0.18909797744467172
# Connected Node: RAB38, Edge Weight: 0.047192416045805596
# Connected Node: RAC2, Edge Weight: 0.18346395091361523
# Connected Node: RAMP3, Edge Weight: 0.2245288954945217
# Connected Node: RASAL1, Edge Weight: 0.18785845754792418
# Connected Node: RBBP8NL, Edge Weight: 0.22597579825200131
# Connected Node: RBMS3, Edge Weight: 0.09287553992897923
# Connected Node: RBP7, Edge Weight: 0.21790322206401058
# Connected Node: RCSD1, Edge Weight: 0.21616287950708069
# Connected Node: REG4, Edge Weight: 0.13848397527542167
# Connected Node: RET, Edge Weight: 0.2634557784619237
# Connected Node: RFPL4AL1, Edge Weight: 0.08198387162944853
# Connected Node: RIMS4, Edge Weight: 0.16299892874061672
# Connected Node: RIPPLY3, Edge Weight: 0.20032505383239907
# Connected Node: RNF217, Edge Weight: 0.1314566261119018
# Connected Node: RNF223, Edge Weight: 0.23461924221265773
# Connected Node: RNF43, Edge Weight: 0.22226626342380185
# Connected Node: ROBO4, Edge Weight: 0.23026315100088834
# Connected Node: ROR1, Edge Weight: 0.11950314066892753
# Connected Node: RPS6KA6, Edge Weight: 0.23746453485917152
# Connected Node: RUBCNL, Edge Weight: 0.2302563166077194
# Connected Node: RYR2, Edge Weight: 0.15627291652074893
# Connected Node: S100A14, Edge Weight: 0.22999656629326126
# Connected Node: SAMD9L, Edge Weight: 0.14030101979043574
# Connected Node: SCUBE2, Edge Weight: 0.22794397124729016
# Connected Node: SDHAF3, Edge Weight: 0.17545025619198618
# Connected Node: SERPINE1, Edge Weight: 0.22030005343929604
# Connected Node: SFMBT2, Edge Weight: 0.1770912591652275
# Connected Node: SGCG, Edge Weight: 0.15358537072568967
# Connected Node: SH3RF3, Edge Weight: 0.23357019426471393
# Connected Node: SHC2, Edge Weight: 0.20067604873546996
# Connected Node: SHISA3, Edge Weight: 0.19638558397364014
# Connected Node: SHISA9, Edge Weight: 0.22437030740574793
# Connected Node: SLAMF7, Edge Weight: 0.04722554393428091
# Connected Node: SLC17A9, Edge Weight: 0.20244241847879585
# Connected Node: SLC18B1, Edge Weight: 0.1776121454883598
# Connected Node: SLC24A3, Edge Weight: 0.2242496227602634
# Connected Node: SLC27A6, Edge Weight: 0.07696287005753089
# Connected Node: SLC2A10, Edge Weight: 0.12028231437202441
# Connected Node: SLC2A3, Edge Weight: 0.1366469507942797
# Connected Node: SLC35F3, Edge Weight: 0.2296983923694973
# Connected Node: SLC43A3, Edge Weight: 0.24565943759993902
# Connected Node: SLC4A4, Edge Weight: 0.07663707238987749
# Connected Node: SLC6A14, Edge Weight: 0.14152831552040657
# Connected Node: SLC9A2, Edge Weight: 0.22991049445548117
# Connected Node: SLCO1B3, Edge Weight: 0.18579672339989795
# Connected Node: SLFN12, Edge Weight: 0.08779319762304372
# Connected Node: SLITRK6, Edge Weight: 0.14248766270146795
# Connected Node: SMIM22, Edge Weight: 0.2125215427751862
# Connected Node: SMOC2, Edge Weight: 0.24079645493024904
# Connected Node: SMTNL2, Edge Weight: 0.24797748317884571
# Connected Node: SNPH, Edge Weight: 0.21799973390048621
# Connected Node: SOD3, Edge Weight: 0.19915966595755608
# Connected Node: SORBS2, Edge Weight: 0.11188662406529148
# Connected Node: SORCS1, Edge Weight: 0.20651156708895613
# Connected Node: SOX3, Edge Weight: 0.369
# Connected Node: SPAG16, Edge Weight: 0.30091058972068896
# Connected Node: SPANXB1, Edge Weight: 0.144284174294531
# Connected Node: SPANXC, Edge Weight: 0.1706107789331922
# Connected Node: SPARC, Edge Weight: 0.10052622239562614
# Connected Node: SPESP1, Edge Weight: 0.2048760518084789
# Connected Node: SPINT1, Edge Weight: 0.21697339189259768
# Connected Node: SPSB4, Edge Weight: 0.25316456874570004
# Connected Node: SPTSSB, Edge Weight: 0.11851699292087559
# Connected Node: SPX, Edge Weight: 0.13887624850551816
# Connected Node: SRGN, Edge Weight: 0.20310702125164726
# Connected Node: ST6GALNAC3, Edge Weight: 0.16983674398012005
# Connected Node: STAC, Edge Weight: 0.13709457574206185
# Connected Node: STK31, Edge Weight: 0.12303767479173167
# Connected Node: STK33, Edge Weight: 0.214774908150558
# Connected Node: SULF1, Edge Weight: 0.19484572443624237
# Connected Node: SULF2, Edge Weight: 0.11517106847568648
# Connected Node: SULT2B1, Edge Weight: 0.23716745126216032
# Connected Node: SYK, Edge Weight: 0.18365087970814442
# Connected Node: SYT10, Edge Weight: 0.22110701434817437
# Connected Node: SYTL5, Edge Weight: 0.10013341517355712
# Connected Node: TBX2, Edge Weight: 0.61
# Connected Node: TBX3, Edge Weight: 0.721
# Connected Node: TCEAL9, Edge Weight: 0.09274335609512196
# Connected Node: TDRD5, Edge Weight: 0.15349681968185125
# Connected Node: TFCP2, Edge Weight: 0.04496884275848467
# Connected Node: TH, Edge Weight: 0.25615714764271347
# Connected Node: THNSL2, Edge Weight: 0.2528643130614251
# Connected Node: TLE4, Edge Weight: 0.1994953191830494
# Connected Node: TLR4, Edge Weight: 0.16423026342280578
# Connected Node: TM4SF1, Edge Weight: 0.20932142102660367
# Connected Node: TM4SF18, Edge Weight: 0.06673682613495724
# Connected Node: TMEM125, Edge Weight: 0.18181132749946527
# Connected Node: TMEM156, Edge Weight: 0.09874333644281974
# Connected Node: TMEM178B, Edge Weight: 0.2251634272280677
# Connected Node: TMEM26, Edge Weight: 0.1071086345315414
# Connected Node: TMEM30B, Edge Weight: 0.06103644997012214
# Connected Node: TMEM71, Edge Weight: 0.12673069234309875
# Connected Node: TMEM92, Edge Weight: 0.16940800983022264
# Connected Node: TMLHE, Edge Weight: 0.07963735962561802
# Connected Node: TMPRSS13, Edge Weight: 0.1763520609998629
# Connected Node: TMPRSS15, Edge Weight: 0.14254253785050963
# Connected Node: TMPRSS4, Edge Weight: 0.16507481341931307
# Connected Node: TNC, Edge Weight: 0.23027270066054983
# Connected Node: TNFRSF10D, Edge Weight: 0.2016219739441747
# Connected Node: TNFRSF14, Edge Weight: 0.21585115170040992
# Connected Node: TNFRSF18, Edge Weight: 0.22985966082961695
# Connected Node: TNFSF12, Edge Weight: 0.22949437267574502
# Connected Node: TOX, Edge Weight: 0.21323800537242987
# Connected Node: TRABD2A, Edge Weight: 0.04744254796676084
# Connected Node: TRIML2, Edge Weight: 0.18297414249344857
# Connected Node: TRPV4, Edge Weight: 0.2606616512305632
# Connected Node: TSPAN8, Edge Weight: 0.05406916534447548
# Connected Node: TSPYL5, Edge Weight: 0.21499555280633553
# Connected Node: TSTD1, Edge Weight: 0.18947078415784424
# Connected Node: UCN2, Edge Weight: 0.24494115910468495
# Connected Node: UGT1A6, Edge Weight: 0.02898230942472535
# Connected Node: UGT8, Edge Weight: 0.15809495165700027
# Connected Node: ULK2, Edge Weight: 0.18631259728163008
# Connected Node: UNC5A, Edge Weight: 0.26867991192097473
# Connected Node: VAV3, Edge Weight: 0.17165489780702248
# Connected Node: VGLL3, Edge Weight: 0.20670505413914542
# Connected Node: VIM, Edge Weight: 0.11204547780907681
# Connected Node: VSTM2L, Edge Weight: 0.17651084514989357
# Connected Node: WNK2, Edge Weight: 0.19390483483305698
# Connected Node: XAGE1A, Edge Weight: 0.218544710270423
# Connected Node: XAGE1B, Edge Weight: 0.20998586451547896
# Connected Node: XYLT1, Edge Weight: 0.2562458194490047
# Connected Node: YBX2, Edge Weight: 0.206
# Connected Node: ZC4H2, Edge Weight: 0.21321814543204776
# Connected Node: ZEB2, Edge Weight: 0.616
# Connected Node: ZFP28, Edge Weight: 0.15332408196523006
# Connected Node: ZFP82, Edge Weight: 0.1822760718245181
# Connected Node: ZFPM2, Edge Weight: 0.28
# Connected Node: ZIC1, Edge Weight: 0.659
# Connected Node: ZIC4, Edge Weight: 0.294
# Connected Node: ZNF215, Edge Weight: 0.08122367040714562
# Connected Node: ZNF229, Edge Weight: 0.13179591827981574
# Connected Node: ZNF287, Edge Weight: 0.24062941315618724
# Connected Node: ZNF469, Edge Weight: 0.22020611533280798
# Connected Node: ZNF470, Edge Weight: 0.16547931229404877
# Connected Node: ZNF501, Edge Weight: 0.257
# Connected Node: ZNF502, Edge Weight: 0.10391408786235667
# Connected Node: ZNF518B, Edge Weight: 0.16229512314370953
# Connected Node: ZNF521, Edge Weight: 0.262
# Connected Node: ZNF577, Edge Weight: 0.1330956893145948
# Connected Node: ZNF630, Edge Weight: 0.2017928801194846
# Connected Node: ZNF655, Edge Weight: 0.2170833923866119
# Connected Node: ZNF71, Edge Weight: 0.25557065710193827
# Connected Node: ZNF711, Edge Weight: 0.167
# Connected Node: ZNF732, Edge Weight: 0.18038405185831263
# Connected Node: AHR, Edge Weight: 0.154
# Connected Node: AIRE, Edge Weight: 0.165
# Connected Node: AR, Edge Weight: 0.471
# Connected Node: ARGFX, Edge Weight: 0.211
# Connected Node: ARID3A, Edge Weight: 0.518
# Connected Node: ARID3B, Edge Weight: 0.275
# Connected Node: ARID5B, Edge Weight: 0.156
# Connected Node: ARNT, Edge Weight: 0.165
# Connected Node: ARNT2, Edge Weight: 0.161
# Connected Node: ASCL3, Edge Weight: 0.19
# Connected Node: ASCL4, Edge Weight: 0.263
# Connected Node: ATF3, Edge Weight: 0.22
# Connected Node: ATOH1, Edge Weight: 0.821
# Connected Node: ATOH7, Edge Weight: 0.44
# Connected Node: BARHL1, Edge Weight: 0.31
# Connected Node: BARHL2, Edge Weight: 0.266
# Connected Node: BARX1, Edge Weight: 0.288
# Connected Node: BARX2, Edge Weight: 0.246
# Connected Node: BCL11A, Edge Weight: 0.258
# Connected Node: BCL11B, Edge Weight: 0.477
# Connected Node: BCL6, Edge Weight: 0.256
# Connected Node: BCL6B, Edge Weight: 0.231
# Connected Node: BHLHA15, Edge Weight: 0.234
# Connected Node: BHLHE22, Edge Weight: 0.255
# Connected Node: BHLHE40, Edge Weight: 0.211
# Connected Node: BPTF, Edge Weight: 0.237
# Connected Node: CDX1, Edge Weight: 0.666
# Connected Node: CDX2, Edge Weight: 0.764
# Connected Node: CDX4, Edge Weight: 0.425
# Connected Node: CEBPA, Edge Weight: 0.377
# Connected Node: CEBPB, Edge Weight: 0.278
# Connected Node: CLOCK, Edge Weight: 0.173
# Connected Node: CREB1, Edge Weight: 0.357
# Connected Node: CRX, Edge Weight: 0.401
# Connected Node: CTCF, Edge Weight: 0.61
# Connected Node: CTCFL, Edge Weight: 0.398
# Connected Node: CUX1, Edge Weight: 0.433
# Connected Node: CUX2, Edge Weight: 0.239
# Connected Node: CXXC1, Edge Weight: 0.29
# Connected Node: DBX1, Edge Weight: 0.283
# Connected Node: DBX2, Edge Weight: 0.25
# Connected Node: DDIT3, Edge Weight: 0.16
# Connected Node: DLX1, Edge Weight: 0.5
# Connected Node: DLX2, Edge Weight: 0.541
# Connected Node: DLX3, Edge Weight: 0.394
# Connected Node: DLX5, Edge Weight: 0.523
# Connected Node: DLX6, Edge Weight: 0.276
# Connected Node: DMRT1, Edge Weight: 0.628
# Connected Node: DMRT2, Edge Weight: 0.217
# Connected Node: DMRT3, Edge Weight: 0.247
# Connected Node: DMRTA2, Edge Weight: 0.599
# Connected Node: DNMT1, Edge Weight: 0.769
# Connected Node: DPF1, Edge Weight: 0.251
# Connected Node: DPRX, Edge Weight: 0.185
# Connected Node: DRGX, Edge Weight: 0.15
# Connected Node: E2F1, Edge Weight: 0.264
# Connected Node: E2F2, Edge Weight: 0.286
# Connected Node: E2F3, Edge Weight: 0.337
# Connected Node: E2F4, Edge Weight: 0.345
# Connected Node: E2F5, Edge Weight: 0.193
# Connected Node: E2F6, Edge Weight: 0.19
# Connected Node: E2F7, Edge Weight: 0.209
# Connected Node: E2F8, Edge Weight: 0.208
# Connected Node: E4F1, Edge Weight: 0.296
# Connected Node: EBF1, Edge Weight: 0.292
# Connected Node: EBF2, Edge Weight: 0.168
# Connected Node: EGR1, Edge Weight: 0.386
# Connected Node: EGR2, Edge Weight: 0.5
# Connected Node: EGR3, Edge Weight: 0.213
# Connected Node: EGR4, Edge Weight: 0.173
# Connected Node: ELF3, Edge Weight: 0.282
# Connected Node: ELK4, Edge Weight: 0.175
# Connected Node: EMX1, Edge Weight: 0.36
# Connected Node: EMX2, Edge Weight: 0.648
# Connected Node: EN1, Edge Weight: 0.451
# Connected Node: EN2, Edge Weight: 0.34
# Connected Node: EOMES, Edge Weight: 0.845
# Connected Node: EPAS1, Edge Weight: 0.935
# Connected Node: ERG, Edge Weight: 0.392
# Connected Node: ESR2, Edge Weight: 0.265
# Connected Node: ESRRA, Edge Weight: 0.258
# Connected Node: ESRRB, Edge Weight: 0.818
# Connected Node: ESRRG, Edge Weight: 0.389
# Connected Node: ESX1, Edge Weight: 0.549
# Connected Node: ETS2, Edge Weight: 0.272
# Connected Node: ETV2, Edge Weight: 0.279
# Connected Node: ETV4, Edge Weight: 0.337
# Connected Node: ETV5, Edge Weight: 0.332
# Connected Node: ETV6, Edge Weight: 0.194
# Connected Node: EVX1, Edge Weight: 0.236
# Connected Node: FEV, Edge Weight: 0.302
# Connected Node: FEZF1, Edge Weight: 0.434
# Connected Node: FEZF2, Edge Weight: 0.495
# Connected Node: FIGLA, Edge Weight: 0.221
# Connected Node: FLI1, Edge Weight: 0.345
# Connected Node: FOS, Edge Weight: 0.358
# Connected Node: FOSB, Edge Weight: 0.172
# Connected Node: FOSL2, Edge Weight: 0.281
# Connected Node: FOXA1, Edge Weight: 0.639
# Connected Node: FOXA3, Edge Weight: 0.412
# Connected Node: FOXB1, Edge Weight: 0.323
# Connected Node: FOXC1, Edge Weight: 0.406
# Connected Node: FOXC2, Edge Weight: 0.396
# Connected Node: FOXD1, Edge Weight: 0.234
# Connected Node: FOXD3, Edge Weight: 0.973
# Connected Node: FOXD4, Edge Weight: 0.167
# Connected Node: FOXD4L1, Edge Weight: 0.248
# Connected Node: FOXE1, Edge Weight: 0.392
# Connected Node: FOXE3, Edge Weight: 0.519
# Connected Node: FOXF1, Edge Weight: 0.389
# Connected Node: FOXF2, Edge Weight: 0.253
# Connected Node: FOXG1, Edge Weight: 0.661
# Connected Node: FOXH1, Edge Weight: 0.357
# Connected Node: FOXI1, Edge Weight: 0.347
# Connected Node: FOXI2, Edge Weight: 0.202
# Connected Node: FOXJ1, Edge Weight: 0.511
# Connected Node: FOXK2, Edge Weight: 0.166
# Connected Node: FOXL1, Edge Weight: 0.249
# Connected Node: FOXL2, Edge Weight: 0.289
# Connected Node: FOXM1, Edge Weight: 0.693
# Connected Node: FOXN1, Edge Weight: 0.254
# Connected Node: FOXN4, Edge Weight: 0.285
# Connected Node: FOXO1, Edge Weight: 0.598
# Connected Node: FOXO3, Edge Weight: 0.342
# Connected Node: FOXO4, Edge Weight: 0.225
# Connected Node: FOXO6, Edge Weight: 0.46
# Connected Node: FOXP1, Edge Weight: 0.411
# Connected Node: FOXP2, Edge Weight: 0.387
# Connected Node: FOXP3, Edge Weight: 0.265
# Connected Node: FOXP4, Edge Weight: 0.233
# Connected Node: FOXQ1, Edge Weight: 0.177
# Connected Node: GABPA, Edge Weight: 0.193
# Connected Node: GATA1, Edge Weight: 0.504
# Connected Node: GATA2, Edge Weight: 0.596
# Connected Node: GATA3, Edge Weight: 0.626
# Connected Node: GATA4, Edge Weight: 0.765
# Connected Node: GATA5, Edge Weight: 0.372
# Connected Node: GATA6, Edge Weight: 0.756
# Connected Node: GBX2, Edge Weight: 0.562
# Connected Node: GCM1, Edge Weight: 0.263
# Connected Node: GCM2, Edge Weight: 0.156
# Connected Node: GFI1, Edge Weight: 0.362
# Connected Node: GFI1B, Edge Weight: 0.237
# Connected Node: GLI1, Edge Weight: 0.665
# Connected Node: GLI2, Edge Weight: 0.65
# Connected Node: GLI3, Edge Weight: 0.625
# Connected Node: GLIS1, Edge Weight: 0.542
# Connected Node: GLIS2, Edge Weight: 0.2
# Connected Node: GLIS3, Edge Weight: 0.258
# Connected Node: GSC2, Edge Weight: 0.235
# Connected Node: GSX1, Edge Weight: 0.234
# Connected Node: GSX2, Edge Weight: 0.427
# Connected Node: GTF3A, Edge Weight: 0.15
# Connected Node: HAND1, Edge Weight: 0.309
# Connected Node: HAND2, Edge Weight: 0.333
# Connected Node: HELT, Edge Weight: 0.382
# Connected Node: HES1, Edge Weight: 0.284
# Connected Node: HES3, Edge Weight: 0.461
# Connected Node: HES4, Edge Weight: 0.221
# Connected Node: HES5, Edge Weight: 0.82
# Connected Node: HES6, Edge Weight: 0.318
# Connected Node: HES7, Edge Weight: 0.218
# Connected Node: HESX1, Edge Weight: 0.567
# Connected Node: HEY1, Edge Weight: 0.452
# Connected Node: HEY2, Edge Weight: 0.42
# Connected Node: HEYL, Edge Weight: 0.151
# Connected Node: HHEX, Edge Weight: 0.394
# Connected Node: HIC1, Edge Weight: 0.197
# Connected Node: HIF1A, Edge Weight: 0.427
# Connected Node: HIF3A, Edge Weight: 0.22
# Connected Node: HIVEP1, Edge Weight: 0.158
# Connected Node: HMX1, Edge Weight: 0.444
# Connected Node: HMX2, Edge Weight: 0.423
# Connected Node: HMX3, Edge Weight: 0.35
# Connected Node: HNF1A, Edge Weight: 0.282
# Connected Node: HNF1B, Edge Weight: 0.212
# Connected Node: HNF4A, Edge Weight: 0.568
# Connected Node: HOXA1, Edge Weight: 0.171
# Connected Node: HOXA11, Edge Weight: 0.191
# Connected Node: HOXA13, Edge Weight: 0.241
# Connected Node: HOXA2, Edge Weight: 0.339
# Connected Node: HOXA3, Edge Weight: 0.226
# Connected Node: HOXA5, Edge Weight: 0.63
# Connected Node: HOXA6, Edge Weight: 0.231
# Connected Node: HOXA7, Edge Weight: 0.313
# Connected Node: HOXA9, Edge Weight: 0.367
# Connected Node: HOXB1, Edge Weight: 0.491
# Connected Node: HOXB13, Edge Weight: 0.168
# Connected Node: HOXB2, Edge Weight: 0.251
# Connected Node: HOXB3, Edge Weight: 0.243
# Connected Node: HOXB4, Edge Weight: 0.446
# Connected Node: HOXB5, Edge Weight: 0.245
# Connected Node: HOXB6, Edge Weight: 0.189
# Connected Node: HOXB7, Edge Weight: 0.268
# Connected Node: HOXB8, Edge Weight: 0.196
# Connected Node: HOXB9, Edge Weight: 0.354
# Connected Node: HOXC12, Edge Weight: 0.208
# Connected Node: HOXC4, Edge Weight: 0.198
# Connected Node: HOXC5, Edge Weight: 0.224
# Connected Node: HOXC6, Edge Weight: 0.257
# Connected Node: HOXC8, Edge Weight: 0.221
# Connected Node: HOXC9, Edge Weight: 0.183
# Connected Node: HOXD1, Edge Weight: 0.199
# Connected Node: HOXD10, Edge Weight: 0.243
# Connected Node: HOXD11, Edge Weight: 0.156
# Connected Node: HOXD13, Edge Weight: 0.171
# Connected Node: HOXD4, Edge Weight: 0.226
# Connected Node: HOXD8, Edge Weight: 0.157
# Connected Node: HOXD9, Edge Weight: 0.165
# Connected Node: IKZF1, Edge Weight: 0.235
# Connected Node: INSM1, Edge Weight: 0.326
# Connected Node: IRX1, Edge Weight: 0.345
# Connected Node: IRX3, Edge Weight: 0.429
# Connected Node: IRX5, Edge Weight: 0.216
# Connected Node: IRX6, Edge Weight: 0.426
# Connected Node: ISL1, Edge Weight: 0.732
# Connected Node: ISL2, Edge Weight: 0.461
# Connected Node: JUN, Edge Weight: 0.466
# Connected Node: JUND, Edge Weight: 0.243
# Connected Node: KDM2B, Edge Weight: 0.315
# Connected Node: KLF1, Edge Weight: 0.54
# Connected Node: KLF10, Edge Weight: 0.213
# Connected Node: KLF11, Edge Weight: 0.222
# Connected Node: KLF12, Edge Weight: 0.226
# Connected Node: KLF13, Edge Weight: 0.236
# Connected Node: KLF14, Edge Weight: 0.183
# Connected Node: KLF15, Edge Weight: 0.204
# Connected Node: KLF16, Edge Weight: 0.204
# Connected Node: KLF17, Edge Weight: 0.326
# Connected Node: KLF2, Edge Weight: 0.755
# Connected Node: KLF3, Edge Weight: 0.281
# Connected Node: KLF4, Edge Weight: 0.996
# Connected Node: KLF5, Edge Weight: 0.746
# Connected Node: KLF6, Edge Weight: 0.307
# Connected Node: KLF7, Edge Weight: 0.36
# Connected Node: KLF8, Edge Weight: 0.307
# Connected Node: KLF9, Edge Weight: 0.333
# Connected Node: KMT2A, Edge Weight: 0.31
# Connected Node: LBX1, Edge Weight: 0.342
# Connected Node: LEF1, Edge Weight: 0.596
# Connected Node: LHX3, Edge Weight: 0.49
# Connected Node: LHX4, Edge Weight: 0.42
# Connected Node: LHX5, Edge Weight: 0.365
# Connected Node: LHX6, Edge Weight: 0.233
# Connected Node: LHX8, Edge Weight: 0.235
# Connected Node: LHX9, Edge Weight: 0.219
# Connected Node: LIN28A, Edge Weight: 0.994
# Connected Node: LIN28B, Edge Weight: 0.816
# Connected Node: LMX1A, Edge Weight: 0.609
# Connected Node: LMX1B, Edge Weight: 0.333
# Connected Node: MAF, Edge Weight: 0.574
# Connected Node: MAFB, Edge Weight: 0.242
# Connected Node: MAX, Edge Weight: 0.305
# Connected Node: MAZ, Edge Weight: 0.239
# Connected Node: MBD2, Edge Weight: 0.275
# Connected Node: MBNL2, Edge Weight: 0.309
# Connected Node: MECOM, Edge Weight: 0.317
# Connected Node: MECP2, Edge Weight: 0.645
# Connected Node: MEF2A, Edge Weight: 0.241
# Connected Node: MEF2C, Edge Weight: 0.528
# Connected Node: MEF2D, Edge Weight: 0.158
# Connected Node: MEIS1, Edge Weight: 0.447
# Connected Node: MEIS2, Edge Weight: 0.403
# Connected Node: MEOX1, Edge Weight: 0.325
# Connected Node: MEOX2, Edge Weight: 0.246
# Connected Node: MESP1, Edge Weight: 0.408
# Connected Node: MESP2, Edge Weight: 0.25
# Connected Node: MITF, Edge Weight: 0.479
# Connected Node: MIXL1, Edge Weight: 0.552
# Connected Node: MLX, Edge Weight: 0.237
# Connected Node: MNT, Edge Weight: 0.23
# Connected Node: MNX1, Edge Weight: 0.338
# Connected Node: MSX1, Edge Weight: 0.728
# Connected Node: MSX2, Edge Weight: 0.598
# Connected Node: MYB, Edge Weight: 0.29
# Connected Node: MYBL1, Edge Weight: 0.17
# Connected Node: MYBL2, Edge Weight: 0.317
# Connected Node: MYC, Edge Weight: 0.943
# Connected Node: MYCL, Edge Weight: 0.689
# Connected Node: MYCN, Edge Weight: 0.745
# Connected Node: MYF5, Edge Weight: 0.336
# Connected Node: MYF6, Edge Weight: 0.17
# Connected Node: MYOD1, Edge Weight: 0.592
# Connected Node: MYOG, Edge Weight: 0.335
# Connected Node: MYRF, Edge Weight: 0.161
# Connected Node: MYT1L, Edge Weight: 0.525
# Connected Node: MZF1, Edge Weight: 0.309
# Connected Node: NANOG, Edge Weight: 0.997
# Connected Node: NEUROD1, Edge Weight: 0.893
# Connected Node: NEUROD2, Edge Weight: 0.368
# Connected Node: NEUROD4, Edge Weight: 0.332
# Connected Node: NEUROD6, Edge Weight: 0.271
# Connected Node: NEUROG1, Edge Weight: 0.779
# Connected Node: NEUROG2, Edge Weight: 0.657
# Connected Node: NEUROG3, Edge Weight: 0.481
# Connected Node: NFATC1, Edge Weight: 0.237
# Connected Node: NFATC2, Edge Weight: 0.57
# Connected Node: NFATC4, Edge Weight: 0.185
# Connected Node: NFE2, Edge Weight: 0.181
# Connected Node: NFE2L2, Edge Weight: 0.297
# Connected Node: NFIA, Edge Weight: 0.279
# Connected Node: NFIB, Edge Weight: 0.407
# Connected Node: NFIC, Edge Weight: 0.208
# Connected Node: NFIX, Edge Weight: 0.242
# Connected Node: NFKB1, Edge Weight: 0.172
# Connected Node: NFKB2, Edge Weight: 0.157
# Connected Node: NFYA, Edge Weight: 0.278
# Connected Node: NFYB, Edge Weight: 0.203
# Connected Node: NHLH1, Edge Weight: 0.278
# Connected Node: NHLH2, Edge Weight: 0.26
# Connected Node: NKX1-2, Edge Weight: 0.298
# Connected Node: NKX2-1, Edge Weight: 0.75
# Connected Node: NKX2-2, Edge Weight: 0.722
# Connected Node: NKX2-4, Edge Weight: 0.184
# Connected Node: NKX2-5, Edge Weight: 0.617
# Connected Node: NKX3-1, Edge Weight: 0.248
# Connected Node: NKX3-2, Edge Weight: 0.18
# Connected Node: NKX6-1, Edge Weight: 0.537
# Connected Node: NKX6-2, Edge Weight: 0.507
# Connected Node: NKX6-3, Edge Weight: 0.234
# Connected Node: NOBOX, Edge Weight: 0.317
# Connected Node: NPAS1, Edge Weight: 0.192
# Connected Node: NPAS3, Edge Weight: 0.321
# Connected Node: NR0B1, Edge Weight: 0.767
# Connected Node: NR1H3, Edge Weight: 0.152
# Connected Node: NR1I2, Edge Weight: 0.186
# Connected Node: NR1I3, Edge Weight: 0.154
# Connected Node: NR2E1, Edge Weight: 0.555
# Connected Node: NR2E3, Edge Weight: 0.28
# Connected Node: NR2F1, Edge Weight: 0.532
# Connected Node: NR2F2, Edge Weight: 0.517
# Connected Node: NR2F6, Edge Weight: 0.165
# Connected Node: NR3C1, Edge Weight: 0.331
# Connected Node: NR3C2, Edge Weight: 0.156
# Connected Node: NR4A2, Edge Weight: 0.42
# Connected Node: NR5A1, Edge Weight: 0.575
# Connected Node: NR5A2, Edge Weight: 0.583
# Connected Node: NR6A1, Edge Weight: 0.505
# Connected Node: NRL, Edge Weight: 0.347
# Connected Node: OLIG1, Edge Weight: 0.551
# Connected Node: OLIG2, Edge Weight: 0.772
# Connected Node: OLIG3, Edge Weight: 0.345
# Connected Node: ONECUT1, Edge Weight: 0.377
# Connected Node: ONECUT2, Edge Weight: 0.167
# Connected Node: OSR2, Edge Weight: 0.268
# Connected Node: OTP, Edge Weight: 0.211
# Connected Node: OTX1, Edge Weight: 0.503
# Connected Node: OTX2, Edge Weight: 0.851
# Connected Node: PATZ1, Edge Weight: 0.316
# Connected Node: PAX1, Edge Weight: 0.244
# Connected Node: PAX2, Edge Weight: 0.833
# Connected Node: PAX3, Edge Weight: 0.807
# Connected Node: PAX4, Edge Weight: 0.316
# Connected Node: PAX5, Edge Weight: 0.585
# Connected Node: PAX6, Edge Weight: 0.969
# Connected Node: PAX7, Edge Weight: 0.653
# Connected Node: PAX8, Edge Weight: 0.371
# Connected Node: PAX9, Edge Weight: 0.36
# Connected Node: PBX1, Edge Weight: 0.932
# Connected Node: PBX2, Edge Weight: 0.176
# Connected Node: PBX3, Edge Weight: 0.225
# Connected Node: PDX1, Edge Weight: 0.298
# Connected Node: PHOX2A, Edge Weight: 0.405
# Connected Node: PHOX2B, Edge Weight: 0.32
# Connected Node: PITX1, Edge Weight: 0.35
# Connected Node: PITX2, Edge Weight: 0.528
# Connected Node: PITX3, Edge Weight: 0.52
# Connected Node: PKNOX1, Edge Weight: 0.235
# Connected Node: PKNOX2, Edge Weight: 0.162
# Connected Node: PLAG1, Edge Weight: 0.162
# Connected Node: PLAGL1, Edge Weight: 0.28
# Connected Node: POU1F1, Edge Weight: 0.555
# Connected Node: POU2F1, Edge Weight: 0.983
# Connected Node: POU2F2, Edge Weight: 0.395
# Connected Node: POU2F3, Edge Weight: 0.488
# Connected Node: POU3F1, Edge Weight: 0.731
# Connected Node: POU3F2, Edge Weight: 0.836
# Connected Node: POU3F3, Edge Weight: 0.687
# Connected Node: POU3F4, Edge Weight: 0.704
# Connected Node: POU4F1, Edge Weight: 0.61
# Connected Node: POU4F2, Edge Weight: 0.552
# Connected Node: POU4F3, Edge Weight: 0.64
# Connected Node: POU5F1, Edge Weight: 0.999
# Connected Node: POU5F1B, Edge Weight: 0.732
# Connected Node: POU6F1, Edge Weight: 0.38
# Connected Node: POU6F2, Edge Weight: 0.391
# Connected Node: PPARA, Edge Weight: 0.165
# Connected Node: PPARD, Edge Weight: 0.155
# Connected Node: PPARG, Edge Weight: 0.375
# Connected Node: PRDM1, Edge Weight: 0.597
# Connected Node: PRDM14, Edge Weight: 0.972
# Connected Node: PRDM16, Edge Weight: 0.233
# Connected Node: PRDM6, Edge Weight: 0.162
# Connected Node: PROP1, Edge Weight: 0.474
# Connected Node: PROX1, Edge Weight: 0.603
# Connected Node: PRRX1, Edge Weight: 0.386
# Connected Node: PRRX2, Edge Weight: 0.17
# Connected Node: PTF1A, Edge Weight: 0.386
# Connected Node: RARA, Edge Weight: 0.257
# Connected Node: RARB, Edge Weight: 0.281
# Connected Node: RARG, Edge Weight: 0.32
# Connected Node: RAX, Edge Weight: 0.563
# Connected Node: RBPJ, Edge Weight: 0.445
# Connected Node: REL, Edge Weight: 0.193
# Connected Node: RELA, Edge Weight: 0.286
# Connected Node: RELB, Edge Weight: 0.186
# Connected Node: REST, Edge Weight: 0.46
# Connected Node: RFX3, Edge Weight: 0.284
# Connected Node: RFX4, Edge Weight: 0.293
# Connected Node: RFX6, Edge Weight: 0.161
# Connected Node: RORB, Edge Weight: 0.165
# Connected Node: RREB1, Edge Weight: 0.239
# Connected Node: RUNX1, Edge Weight: 0.2
# Connected Node: RUNX2, Edge Weight: 0.515
# Connected Node: RUNX3, Edge Weight: 0.297
# Connected Node: RXRA, Edge Weight: 0.216
# Connected Node: RXRG, Edge Weight: 0.21
# Connected Node: SCRT1, Edge Weight: 0.172
# Connected Node: SHOX, Edge Weight: 0.217
# Connected Node: SIM1, Edge Weight: 0.279
# Connected Node: SIM2, Edge Weight: 0.361
# Connected Node: SIX1, Edge Weight: 0.676
# Connected Node: SIX2, Edge Weight: 0.438
# Connected Node: SIX3, Edge Weight: 0.839
# Connected Node: SIX4, Edge Weight: 0.37
# Connected Node: SIX5, Edge Weight: 0.279
# Connected Node: SIX6, Edge Weight: 0.686
# Connected Node: SMAD1, Edge Weight: 0.327
# Connected Node: SMAD3, Edge Weight: 0.505
# Connected Node: SMAD4, Edge Weight: 0.944
# Connected Node: SMAD5, Edge Weight: 0.388
# Connected Node: SMAD9, Edge Weight: 0.295
# Connected Node: SNAI1, Edge Weight: 0.797
# Connected Node: SNAI2, Edge Weight: 0.878
# Connected Node: SOX1, Edge Weight: 0.199
# Connected Node: SOX10, Edge Weight: 0.323
# Connected Node: SOX11, Edge Weight: 0.247
# Connected Node: SOX13, Edge Weight: 0.205
# Connected Node: SOX14, Edge Weight: 0.475
# Connected Node: SOX17, Edge Weight: 0.246
# Connected Node: SOX21, Edge Weight: 0.695
# Connected Node: SOX4, Edge Weight: 0.263
# Connected Node: SOX5, Edge Weight: 0.342
# Connected Node: SOX6, Edge Weight: 0.335
# Connected Node: SOX7, Edge Weight: 0.195
# Connected Node: SOX8, Edge Weight: 0.388
# Connected Node: SOX9, Edge Weight: 0.312
# Connected Node: SP1, Edge Weight: 0.268
# Connected Node: SP2, Edge Weight: 0.277
# Connected Node: SP3, Edge Weight: 0.344
# Connected Node: SP5, Edge Weight: 0.17
# Connected Node: SP6, Edge Weight: 0.224
# Connected Node: SP7, Edge Weight: 0.37
# Connected Node: SP8, Edge Weight: 0.457
# Connected Node: SP9, Edge Weight: 0.208
# Connected Node: SPDEF, Edge Weight: 0.181
# Connected Node: SPI1, Edge Weight: 0.4
# Connected Node: SRF, Edge Weight: 0.366
# Connected Node: STAT1, Edge Weight: 0.336
# Connected Node: STAT2, Edge Weight: 0.272
# Connected Node: STAT3, Edge Weight: 0.983
# Connected Node: STAT4, Edge Weight: 0.16
# Connected Node: STAT5A, Edge Weight: 0.372
# Connected Node: STAT5B, Edge Weight: 0.358
# Connected Node: STAT6, Edge Weight: 0.937
# Connected Node: T, Edge Weight: 0.606
# Connected Node: TAL1, Edge Weight: 0.444
# Connected Node: TBP, Edge Weight: 0.395
# Connected Node: TBR1, Edge Weight: 0.558
# Connected Node: TBX1, Edge Weight: 0.362
# Connected Node: TBX18, Edge Weight: 0.322
# Connected Node: TBX19, Edge Weight: 0.257
# Connected Node: TBX20, Edge Weight: 0.227
# Connected Node: TBX4, Edge Weight: 0.196
# Connected Node: TBX5, Edge Weight: 0.547
# Connected Node: TBX6, Edge Weight: 0.478
# Connected Node: TCF12, Edge Weight: 0.33
# Connected Node: TCF15, Edge Weight: 0.236
# Connected Node: TCF3, Edge Weight: 0.46
# Connected Node: TCF4, Edge Weight: 0.701
# Connected Node: TCF7, Edge Weight: 0.355
# Connected Node: TCF7L1, Edge Weight: 0.453
# Connected Node: TCF7L2, Edge Weight: 0.385
# Connected Node: TEAD1, Edge Weight: 0.44
# Connected Node: TEAD2, Edge Weight: 0.39
# Connected Node: TEAD3, Edge Weight: 0.217
# Connected Node: TEAD4, Edge Weight: 0.596
# Connected Node: TEF, Edge Weight: 0.202
# Connected Node: TET1, Edge Weight: 0.659
# Connected Node: TFAP2A, Edge Weight: 0.44
# Connected Node: TFAP2B, Edge Weight: 0.222
# Connected Node: TFAP2C, Edge Weight: 0.468
# Connected Node: TFCP2L1, Edge Weight: 0.558
# Connected Node: TFDP1, Edge Weight: 0.186
# Connected Node: TFE3, Edge Weight: 0.24
# Connected Node: TFEB, Edge Weight: 0.191
# Connected Node: TFEC, Edge Weight: 0.17
# Connected Node: TGIF1, Edge Weight: 0.21
# Connected Node: TGIF2, Edge Weight: 0.174
# Connected Node: THRA, Edge Weight: 0.169
# Connected Node: THRB, Edge Weight: 0.172
# Connected Node: TLX1, Edge Weight: 0.394
# Connected Node: TLX2, Edge Weight: 0.276
# Connected Node: TLX3, Edge Weight: 0.305
# Connected Node: TP53, Edge Weight: 0.833
# Connected Node: TP63, Edge Weight: 0.485
# Connected Node: TP73, Edge Weight: 0.55
# Connected Node: TWIST1, Edge Weight: 0.784
# Connected Node: TWIST2, Edge Weight: 0.409
# Connected Node: UNCX, Edge Weight: 0.19
# Connected Node: USF1, Edge Weight: 0.35
# Connected Node: USF2, Edge Weight: 0.262
# Connected Node: VAX1, Edge Weight: 0.556
# Connected Node: VAX2, Edge Weight: 0.217
# Connected Node: VDR, Edge Weight: 0.225
# Connected Node: VENTX, Edge Weight: 0.321
# Connected Node: VSX1, Edge Weight: 0.35
# Connected Node: VSX2, Edge Weight: 0.662
# Connected Node: WT1, Edge Weight: 0.437
# Connected Node: XBP1, Edge Weight: 0.205
# Connected Node: YBX1, Edge Weight: 0.393
# Connected Node: YY1, Edge Weight: 0.734
# Connected Node: YY2, Edge Weight: 0.297
# Connected Node: ZBTB18, Edge Weight: 0.172
# Connected Node: ZBTB20, Edge Weight: 0.179
# Connected Node: ZBTB33, Edge Weight: 0.274
# Connected Node: ZBTB7A, Edge Weight: 0.209
# Connected Node: ZEB1, Edge Weight: 0.703
# Connected Node: ZFHX3, Edge Weight: 0.167
# Connected Node: ZFHX4, Edge Weight: 0.179
# Connected Node: ZFP1, Edge Weight: 0.166
# Connected Node: ZFP42, Edge Weight: 0.715
# Connected Node: ZFP57, Edge Weight: 0.323
# Connected Node: ZFP64, Edge Weight: 0.154
# Connected Node: ZFX, Edge Weight: 0.622
# Connected Node: ZIC2, Edge Weight: 0.674
# Connected Node: ZIC3, Edge Weight: 0.967
# Connected Node: ZIC5, Edge Weight: 0.524
# Connected Node: ZKSCAN2, Edge Weight: 0.16
# Connected Node: ZKSCAN7, Edge Weight: 0.258
# Connected Node: ZNF114, Edge Weight: 0.15
# Connected Node: ZNF143, Edge Weight: 0.265
# Connected Node: ZNF148, Edge Weight: 0.206
# Connected Node: ZNF219, Edge Weight: 0.206
# Connected Node: ZNF235, Edge Weight: 0.15
# Connected Node: ZNF263, Edge Weight: 0.239
# Connected Node: ZNF274, Edge Weight: 0.275
# Connected Node: ZNF281, Edge Weight: 0.6
# Connected Node: ZNF296, Edge Weight: 0.49
# Connected Node: ZNF32, Edge Weight: 0.401
# Connected Node: ZNF334, Edge Weight: 0.155
# Connected Node: ZNF354C, Edge Weight: 0.159
# Connected Node: ZNF384, Edge Weight: 0.209
# Connected Node: ZNF423, Edge Weight: 0.272
# Connected Node: ZNF436, Edge Weight: 0.257
# Connected Node: ZNF44, Edge Weight: 0.245
# Connected Node: ZNF534, Edge Weight: 0.15
# Connected Node: ZNF589, Edge Weight: 0.213
# Connected Node: ZNF597, Edge Weight: 0.182
# Connected Node: ZNF691, Edge Weight: 0.155
# Connected Node: ZNF730, Edge Weight: 0.15
# Connected Node: ZNF740, Edge Weight: 0.236
# Connected Node: ZNF75D, Edge Weight: 0.158
# Connected Node: ZNF76, Edge Weight: 0.152
# Connected Node: ZNF766, Edge Weight: 0.15
# Connected Node: ZNF787, Edge Weight: 0.195
# Connected Node: ZNF860, Edge Weight: 0.154
# Connected Node: ZSCAN1, Edge Weight: 0.23
# Connected Node: ZSCAN10, Edge Weight: 0.948
# Connected Node: ZSCAN29, Edge Weight: 0.167
# Connected Node: ZSCAN4, Edge Weight: 0.489

# %%
top_hub_node_MCF7 = sorted_degree[0][0]  # Use degree centrality to select the hub
# Get neighbors (connected nodes) of the hub
neighbors = G_combined_MCF7_ppi[top_hub_node_MCF7]

print(f"\nNeighbors of Hub Node ({top_hub_node_MCF7}):")
for neighbor, edge_data in neighbors.items():
    print(f"Connected Node: {neighbor}, Edge Weight: {edge_data['weight']}")
# Out:
# Neighbors of Hub Node (SOX2):
# Connected Node: ABCA12, Edge Weight: 0.16354405933867655
# Connected Node: ACKR3, Edge Weight: 0.06339998190400542
# Connected Node: ACOT4, Edge Weight: 0.042522459683917324
# Connected Node: ACSL5, Edge Weight: 0.24412552440608692
# Connected Node: ADAMTS1, Edge Weight: 0.08349947802886803
# Connected Node: ADAMTS12, Edge Weight: 0.1390974280643158
# Connected Node: ADAMTS16, Edge Weight: 0.036939461824562425
# Connected Node: ADAMTS19, Edge Weight: 0.10697740850840098
# Connected Node: ADCY1, Edge Weight: 0.08649231313211514
# Connected Node: ADCY5, Edge Weight: 0.05921590767454399
# Connected Node: ADD2, Edge Weight: 0.03854905836304057
# Connected Node: ADGRE1, Edge Weight: 0.0500137303604995
# Connected Node: ADGRF5, Edge Weight: 0.0687023536213256
# Connected Node: ADGRG5, Edge Weight: 0.075959047777576
# Connected Node: ADRA2C, Edge Weight: 0.05275203864983191
# Connected Node: ADRB2, Edge Weight: 0.09397024210434357
# Connected Node: AGPAT4, Edge Weight: 0.08904152722615688
# Connected Node: AGPS, Edge Weight: 0.10950071044215659
# Connected Node: AGR3, Edge Weight: 0.2534291040765615
# Connected Node: AK7, Edge Weight: 0.09954275255527545
# Connected Node: AKR1B1, Edge Weight: 0.10451327591976001
# Connected Node: AKT3, Edge Weight: 0.11703738098598016
# Connected Node: ALDH2, Edge Weight: 0.04271914828038992
# Connected Node: ALDH3B2, Edge Weight: 0.1178796938991733
# Connected Node: ALOX15, Edge Weight: 0.055576870075433105
# Connected Node: ANK2, Edge Weight: 0.08682359657052263
# Connected Node: ANKRD1, Edge Weight: 0.2756393441103966
# Connected Node: ANKRD33B, Edge Weight: 0.03982084197489577
# Connected Node: ANKRD34B, Edge Weight: 0.1686434875238354
# Connected Node: ANO3, Edge Weight: 0.19463112376681124
# Connected Node: ANTXR2, Edge Weight: 0.1773145744038893
# Connected Node: ANXA8L1, Edge Weight: 0.03081929563886532
# Connected Node: APOBEC3C, Edge Weight: 0.02102165336331918
# Connected Node: APOL1, Edge Weight: 0.08727671197535392
# Connected Node: APOL3, Edge Weight: 0.20537771004601413
# Connected Node: APOL6, Edge Weight: 0.06004974930769036
# Connected Node: ARHGAP23, Edge Weight: 0.052030716124581655
# Connected Node: ARHGAP40, Edge Weight: 0.05166861377250531
# Connected Node: ARHGAP8, Edge Weight: 0.051713893120337584
# Connected Node: ARHGDIB, Edge Weight: 0.29209652457318414
# Connected Node: ARHGDIG, Edge Weight: 0.05697171402045065
# Connected Node: ASCL1, Edge Weight: 0.778
# Connected Node: ASCL2, Edge Weight: 0.306
# Connected Node: ATP10D, Edge Weight: 0.14207334854458287
# Connected Node: AXL, Edge Weight: 0.09830221054128896
# Connected Node: BATF3, Edge Weight: 0.003150327333558134
# Connected Node: BCAS1, Edge Weight: 0.08404626598057274
# Connected Node: BCAT1, Edge Weight: 0.19702883039918095
# Connected Node: BCHE, Edge Weight: 0.3657886385899096
# Connected Node: BEX4, Edge Weight: 0.09463452419000284
# Connected Node: BICC1, Edge Weight: 0.1279124809662644
# Connected Node: BICDL2, Edge Weight: 0.07179557511212731
# Connected Node: BIRC3, Edge Weight: 0.19358644452604934
# Connected Node: BMP5, Edge Weight: 0.25142585822898744
# Connected Node: BMP7, Edge Weight: 0.02073335431464729
# Connected Node: BPIFB1, Edge Weight: 0.09558969703305165
# Connected Node: BRINP2, Edge Weight: 0.13569693475953182
# Connected Node: BSPRY, Edge Weight: 0.01413829357827634
# Connected Node: BTNL9, Edge Weight: 0.14959035222658779
# Connected Node: C11orf52, Edge Weight: 0.046763892814409846
# Connected Node: C14orf132, Edge Weight: 0.03109083848315186
# Connected Node: C19orf81, Edge Weight: 0.061532484333000514
# Connected Node: C1orf210, Edge Weight: 0.061997305929913926
# Connected Node: C4BPB, Edge Weight: 0.1185653497176753
# Connected Node: CA8, Edge Weight: 0.09784478621565218
# Connected Node: CACNA1D, Edge Weight: 0.040802025570254585
# Connected Node: CACNA2D4, Edge Weight: 0.08893100091156692
# Connected Node: CACNG4, Edge Weight: 0.047122923708223574
# Connected Node: CALD1, Edge Weight: 0.22895036141802816
# Connected Node: CALML5, Edge Weight: 0.08167091651076341
# Connected Node: CAMK4, Edge Weight: 0.16540371096619233
# Connected Node: CAPN13, Edge Weight: 0.029416160380789425
# Connected Node: CAPN9, Edge Weight: 0.08379830909871844
# Connected Node: CARD11, Edge Weight: 0.035230531846181634
# Connected Node: CASP1, Edge Weight: 0.10196276881379829
# Connected Node: CASP4, Edge Weight: 0.3065101279582021
# Connected Node: CAVIN2, Edge Weight: 0.23491342947079996
# Connected Node: CAVIN3, Edge Weight: 0.09052189068287397
# Connected Node: CBFA2T3, Edge Weight: 0.039009068712517525
# Connected Node: CBLN4, Edge Weight: 0.06966174166590866
# Connected Node: CBS, Edge Weight: 0.21386964704387457
# Connected Node: CCBE1, Edge Weight: 0.02593102525529667
# Connected Node: CCDC120, Edge Weight: 0.061762890914253576
# Connected Node: CCDC170, Edge Weight: 0.028360069587040737
# Connected Node: CCDC63, Edge Weight: 0.05328449421247794
# Connected Node: CCDC83, Edge Weight: 0.0426590590137641
# Connected Node: CD274, Edge Weight: 0.12326312027931108
# Connected Node: CD40, Edge Weight: 0.011010872295765584
# Connected Node: CD96, Edge Weight: 0.39179550287628007
# Connected Node: CDC42EP3, Edge Weight: 0.015809025563320533
# Connected Node: CDCP1, Edge Weight: 0.0683371104013355
# Connected Node: CDH1, Edge Weight: 0.12106883384257094
# Connected Node: CDK15, Edge Weight: 0.14272117707792242
# Connected Node: CDKN2A, Edge Weight: 0.1990378475888388
# Connected Node: CEACAM5, Edge Weight: 0.05583722562162663
# Connected Node: CEACAM6, Edge Weight: 0.08274782619328125
# Connected Node: CELF2, Edge Weight: 0.21008181356151878
# Connected Node: CFH, Edge Weight: 0.26354358229621666
# Connected Node: CHDH, Edge Weight: 0.0514833809627826
# Connected Node: CHRM3, Edge Weight: 0.13990804664680034
# Connected Node: CHST2, Edge Weight: 0.057777703434014116
# Connected Node: CKMT1B, Edge Weight: 0.12743426265703706
# Connected Node: CLDN1, Edge Weight: 0.1311080852654205
# Connected Node: CLSTN2, Edge Weight: 0.08073568881783677
# Connected Node: CMTM7, Edge Weight: 0.04257971993878318
# Connected Node: CNN3, Edge Weight: 0.0913601999261291
# Connected Node: COL13A1, Edge Weight: 0.04531344139799853
# Connected Node: COL4A1, Edge Weight: 0.05418265541931677
# Connected Node: COL4A2, Edge Weight: 0.04424621831411746
# Connected Node: COL4A5, Edge Weight: 0.3616665100915968
# Connected Node: COL4A6, Edge Weight: 0.1449622187109132
# Connected Node: COL8A1, Edge Weight: 0.05274900790612258
# Connected Node: COX7B2, Edge Weight: 0.18199160019673388
# Connected Node: CPA4, Edge Weight: 0.11873707070984363
# Connected Node: CPED1, Edge Weight: 0.15895277915324302
# Connected Node: CPNE8, Edge Weight: 0.10803906885814252
# Connected Node: CPVL, Edge Weight: 0.12710527184863385
# Connected Node: CREB5, Edge Weight: 0.1711514698488963
# Connected Node: CST1, Edge Weight: 0.04215214972184067
# Connected Node: CST4, Edge Weight: 0.011113551529890575
# Connected Node: CT83, Edge Weight: 0.2629793891436487
# Connected Node: CTNND2, Edge Weight: 0.22700886059834557
# Connected Node: CXCL1, Edge Weight: 0.03746023680414767
# Connected Node: CXCL12, Edge Weight: 0.07156817334071253
# Connected Node: CXCL2, Edge Weight: 0.07937914216202113
# Connected Node: CXCL8, Edge Weight: 0.26340795876210876
# Connected Node: CYBRD1, Edge Weight: 0.14573471071295474
# Connected Node: CYP27A1, Edge Weight: 0.12333090448824313
# Connected Node: DAW1, Edge Weight: 0.11717016722464901
# Connected Node: DCDC2, Edge Weight: 0.11941223094452669
# Connected Node: DEGS2, Edge Weight: 0.033159037632938704
# Connected Node: DGKG, Edge Weight: 0.017887927984461927
# Connected Node: DIRAS2, Edge Weight: 0.20556761208951113
# Connected Node: DMRTA1, Edge Weight: 0.251
# Connected Node: DNAJC12, Edge Weight: 0.14247493372652031
# Connected Node: DOCK8, Edge Weight: 0.22867377197236483
# Connected Node: DOK7, Edge Weight: 0.029297035336606436
# Connected Node: DRD1, Edge Weight: 0.014541902847418742
# Connected Node: DSCAM, Edge Weight: 0.357521141596272
# Connected Node: EDIL3, Edge Weight: 0.15927822498013366
# Connected Node: EHD3, Edge Weight: 0.08785035074188197
# Connected Node: ELF5, Edge Weight: 0.402
# Connected Node: ELOVL2, Edge Weight: 0.2240985503214563
# Connected Node: ELOVL4, Edge Weight: 0.14655378471197
# Connected Node: EMC10, Edge Weight: 0.04823525472733592
# Connected Node: EMID1, Edge Weight: 0.026619558000956722
# Connected Node: EMP1, Edge Weight: 0.0832792361174044
# Connected Node: ENPP5, Edge Weight: 0.09816988916319902
# Connected Node: ENTPD2, Edge Weight: 0.005165249324574184
# Connected Node: ENTPD8, Edge Weight: 0.04334398673477402
# Connected Node: EPN3, Edge Weight: 0.08309418733529728
# Connected Node: EPPK1, Edge Weight: 0.057961096400713785
# Connected Node: ERBB3, Edge Weight: 0.06087384191682732
# Connected Node: ERBB4, Edge Weight: 0.08952910008301607
# Connected Node: EREG, Edge Weight: 0.06388139668466519
# Connected Node: ESR1, Edge Weight: 0.495
# Connected Node: ESRP1, Edge Weight: 0.07838784403208154
# Connected Node: ETS1, Edge Weight: 0.317
# Connected Node: ETV1, Edge Weight: 0.302
# Connected Node: EVA1A, Edge Weight: 0.07526580004841055
# Connected Node: EVC, Edge Weight: 0.12897919165315974
# Connected Node: EVI2A, Edge Weight: 0.2338042222108263
# Connected Node: EVI2B, Edge Weight: 0.25354442030676005
# Connected Node: EVPLL, Edge Weight: 0.032609492732068146
# Connected Node: EYA1, Edge Weight: 0.09600884312736246
# Connected Node: EYA2, Edge Weight: 0.05569981665689783
# Connected Node: F2RL3, Edge Weight: 0.010358726828650022
# Connected Node: F3, Edge Weight: 0.09610192699160391
# Connected Node: FAM110C, Edge Weight: 0.07288523099451405
# Connected Node: FAM133A, Edge Weight: 0.09636787553714354
# Connected Node: FAM171A1, Edge Weight: 0.08696991038197832
# Connected Node: FAM178B, Edge Weight: 0.07962505638606965
# Connected Node: FAM50B, Edge Weight: 0.26815461743200397
# Connected Node: FAM83B, Edge Weight: 0.2338438488951664
# Connected Node: FGF5, Edge Weight: 0.1251046388791801
# Connected Node: FGFR2, Edge Weight: 0.0739917041531164
# Connected Node: FLG, Edge Weight: 0.18421487945611048
# Connected Node: FLNC, Edge Weight: 0.04855994192081958
# Connected Node: FLRT3, Edge Weight: 0.15242640760420834
# Connected Node: FOSL1, Edge Weight: 0.245
# Connected Node: FOXA2, Edge Weight: 0.773
# Connected Node: FOXI3, Edge Weight: 0.153
# Connected Node: FSD1, Edge Weight: 0.03860486691668319
# Connected Node: FST, Edge Weight: 0.12686588938675247
# Connected Node: FSTL1, Edge Weight: 0.058344126033229804
# Connected Node: FUT9, Edge Weight: 0.012983305455964933
# Connected Node: FXYD3, Edge Weight: 0.06311387461936291
# Connected Node: FXYD5, Edge Weight: 0.04188262430533074
# Connected Node: G0S2, Edge Weight: 0.044429138136559354
# Connected Node: GABRA3, Edge Weight: 0.0994633386023327
# Connected Node: GABRE, Edge Weight: 0.3376896794466926
# Connected Node: GAL, Edge Weight: 0.06496499308287618
# Connected Node: GBP1, Edge Weight: 0.23133412818861587
# Connected Node: GBP3, Edge Weight: 0.19833338657356747
# Connected Node: GCNT2, Edge Weight: 0.18531214403308627
# Connected Node: GFRA1, Edge Weight: 0.13990768498028872
# Connected Node: GJA1, Edge Weight: 0.11087092511431162
# Connected Node: GLRA3, Edge Weight: 0.11501176292445514
# Connected Node: GLRB, Edge Weight: 0.1904612284347078
# Connected Node: GMFG, Edge Weight: 0.05592553965682745
# Connected Node: GNA15, Edge Weight: 0.005306777281048225
# Connected Node: GNG11, Edge Weight: 0.10498344076038801
# Connected Node: GOLT1A, Edge Weight: 0.09651089964517112
# Connected Node: GP2, Edge Weight: 0.22402968674372592
# Connected Node: GPAT2, Edge Weight: 0.04860996077834434
# Connected Node: GPC4, Edge Weight: 0.043192625401532236
# Connected Node: GPR27, Edge Weight: 0.021400213111775424
# Connected Node: GPR37L1, Edge Weight: 0.05980370660540357
# Connected Node: GPX1, Edge Weight: 0.1564675852293298
# Connected Node: GRHL2, Edge Weight: 0.157
# Connected Node: GRIK3, Edge Weight: 0.0465517078907558
# Connected Node: GSC, Edge Weight: 0.306
# Connected Node: GSTM1, Edge Weight: 0.012643574072580765
# Connected Node: GSTP1, Edge Weight: 0.10051688035101747
# Connected Node: HAS2, Edge Weight: 0.09680528920120901
# Connected Node: HENMT1, Edge Weight: 0.08758302304498788
# Connected Node: HMGA2, Edge Weight: 0.689
# Connected Node: HMGCLL1, Edge Weight: 0.0571047208323785
# Connected Node: HOXA10, Edge Weight: 0.2
# Connected Node: HOXA4, Edge Weight: 0.0817810996211592
# Connected Node: HOXC13, Edge Weight: 0.237
# Connected Node: HOXD3, Edge Weight: 0.08838502930831438
# Connected Node: HPDL, Edge Weight: 0.06578286091324759
# Connected Node: HRH1, Edge Weight: 0.04391412464526945
# Connected Node: HRNR, Edge Weight: 0.3248980656337561
# Connected Node: HS3ST3A1, Edge Weight: 0.09592018908232758
# Connected Node: HS6ST2, Edge Weight: 0.10388680130340333
# Connected Node: HSH2D, Edge Weight: 0.05364681735437982
# Connected Node: HTR1F, Edge Weight: 0.03333830900909218
# Connected Node: HUNK, Edge Weight: 0.08966760953180342
# Connected Node: ICAM2, Edge Weight: 0.06321083557026375
# Connected Node: IFI16, Edge Weight: 0.21529799511398395
# Connected Node: IFI44, Edge Weight: 0.13349316551348855
# Connected Node: IFI44L, Edge Weight: 0.16310153052985044
# Connected Node: IFIT3, Edge Weight: 0.18186879589963922
# Connected Node: IGDCC3, Edge Weight: 0.015474478084647414
# Connected Node: IGF2BP3, Edge Weight: 0.07425213246574591
# Connected Node: IGFBP1, Edge Weight: 0.1260151736827544
# Connected Node: IGFBP2, Edge Weight: 0.05980595565134461
# Connected Node: IGFBP5, Edge Weight: 0.028769061515050875
# Connected Node: IL1RAPL1, Edge Weight: 0.20873220911604706
# Connected Node: IL31RA, Edge Weight: 0.08331861472450575
# Connected Node: IL7R, Edge Weight: 0.16013476021232287
# Connected Node: ILDR1, Edge Weight: 0.2374039146082607
# Connected Node: ILDR2, Edge Weight: 0.05761098031569878
# Connected Node: IQANK1, Edge Weight: 0.09160736671825265
# Connected Node: IRF6, Edge Weight: 0.281
# Connected Node: IRX2, Edge Weight: 0.25
# Connected Node: IRX4, Edge Weight: 0.261
# Connected Node: ITGBL1, Edge Weight: 0.2911234329953105
# Connected Node: KCNF1, Edge Weight: 0.012218970928715711
# Connected Node: KCNJ3, Edge Weight: 0.052541127030521384
# Connected Node: KCNQ3, Edge Weight: 0.11527019958075391
# Connected Node: KCNQ5, Edge Weight: 0.05120557387043623
# Connected Node: KCTD14, Edge Weight: 0.06560523371203719
# Connected Node: KCTD15, Edge Weight: 0.06836766651122539
# Connected Node: KCTD4, Edge Weight: 0.15562784994801437
# Connected Node: KDF1, Edge Weight: 0.03580191880554229
# Connected Node: KIAA0040, Edge Weight: 0.05466851176793064
# Connected Node: KIF1A, Edge Weight: 0.04260866067711078
# Connected Node: KIF26A, Edge Weight: 0.01558516113943953
# Connected Node: KIRREL1, Edge Weight: 0.08800344607113586
# Connected Node: KLHL9, Edge Weight: 0.2282146399635785
# Connected Node: KLK11, Edge Weight: 0.02100427983534625
# Connected Node: KLRC2, Edge Weight: 0.24512565245065043
# Connected Node: KLRG2, Edge Weight: 0.042344165890178864
# Connected Node: LAD1, Edge Weight: 0.04358645938794403
# Connected Node: LAMA1, Edge Weight: 0.04813142324969322
# Connected Node: LAMA4, Edge Weight: 0.1513676505486301
# Connected Node: LAPTM5, Edge Weight: 0.0640109658780581
# Connected Node: LARGE2, Edge Weight: 0.08603020695768948
# Connected Node: LAYN, Edge Weight: 0.14634331369775988
# Connected Node: LDHB, Edge Weight: 0.052451221229536715
# Connected Node: LDOC1, Edge Weight: 0.0639968297526381
# Connected Node: LHFPL6, Edge Weight: 0.055844140869407255
# Connected Node: LHX1, Edge Weight: 0.475
# Connected Node: LHX2, Edge Weight: 0.606
# Connected Node: LIMCH1, Edge Weight: 0.05963107505823695
# Connected Node: LIMS2, Edge Weight: 0.03882183460924282
# Connected Node: LPAR1, Edge Weight: 0.11731914426599999
# Connected Node: LRP3, Edge Weight: 0.07025019787692544
# Connected Node: LRRC10B, Edge Weight: 0.0220725594402309
# Connected Node: LY96, Edge Weight: 0.05909160484366138
# Connected Node: LYPD3, Edge Weight: 0.030317477831782513
# Connected Node: LYPD6B, Edge Weight: 0.06305860732022839
# Connected Node: LYPD8, Edge Weight: 0.08273747056573977
# Connected Node: MACC1, Edge Weight: 0.20849658766103407
# Connected Node: MAGEA3, Edge Weight: 0.02940892331478362
# Connected Node: MAGEC1, Edge Weight: 0.08368997806736789
# Connected Node: MAGEC2, Edge Weight: 0.05143887492075616
# Connected Node: MAGEH1, Edge Weight: 0.011854525215868494
# Connected Node: MAL2, Edge Weight: 0.04264841730151492
# Connected Node: MALRD1, Edge Weight: 0.08181432367127117
# Connected Node: MARVELD3, Edge Weight: 0.042758037013449934
# Connected Node: MCAM, Edge Weight: 0.03887785328679727
# Connected Node: MDFIC, Edge Weight: 0.21083443707807548
# Connected Node: ME3, Edge Weight: 0.011388871785979138
# Connected Node: MGMT, Edge Weight: 0.016841896933900813
# Connected Node: MME, Edge Weight: 0.13099271825031344
# Connected Node: MMEL1, Edge Weight: 0.04811993579005236
# Connected Node: MMP1, Edge Weight: 0.02974281865676054
# Connected Node: MMP14, Edge Weight: 0.08683190661660656
# Connected Node: MPP1, Edge Weight: 0.060858151166824914
# Connected Node: MPP4, Edge Weight: 0.2605877163322925
# Connected Node: MSI1, Edge Weight: 0.06110298564308314
# Connected Node: MSN, Edge Weight: 0.04387785214711459
# Connected Node: MSRB3, Edge Weight: 0.10219601599313366
# Connected Node: MT1E, Edge Weight: 0.04970517284372589
# Connected Node: MUC15, Edge Weight: 0.19701294825829252
# Connected Node: MYH14, Edge Weight: 0.04448137507097649
# Connected Node: MYH15, Edge Weight: 0.3192003782884445
# Connected Node: MYL9, Edge Weight: 0.01593102417787673
# Connected Node: N4BP3, Edge Weight: 0.09468887129691739
# Connected Node: NAP1L2, Edge Weight: 0.10873676438155688
# Connected Node: NAV3, Edge Weight: 0.27798938856486877
# Connected Node: NBPF4, Edge Weight: 0.14912574882069873
# Connected Node: NBPF6, Edge Weight: 0.07551715437566275
# Connected Node: NECAB1, Edge Weight: 0.07663153487443419
# Connected Node: NECTIN4, Edge Weight: 0.011168429550250103
# Connected Node: NETO2, Edge Weight: 0.06530974313052385
# Connected Node: NINJ2, Edge Weight: 0.01091730137285063
# Connected Node: NLRP1, Edge Weight: 0.03291081459051992
# Connected Node: NLRP3, Edge Weight: 0.08146168230939566
# Connected Node: NMNAT3, Edge Weight: 0.09971904911608886
# Connected Node: NNMT, Edge Weight: 0.05826597775065201
# Connected Node: NOG, Edge Weight: 0.053106290023241964
# Connected Node: NOVA1, Edge Weight: 0.29088994445230654
# Connected Node: NPNT, Edge Weight: 0.10793039992848397
# Connected Node: NRG1, Edge Weight: 0.20078469418617573
# Connected Node: NRK, Edge Weight: 0.14978381435712973
# Connected Node: NRROS, Edge Weight: 0.06413289372942121
# Connected Node: NTN1, Edge Weight: 0.017884441854969957
# Connected Node: NUP210L, Edge Weight: 0.12073293141388075
# Connected Node: OLFM1, Edge Weight: 0.00818381429302606
# Connected Node: OOEP, Edge Weight: 0.12670445277165698
# Connected Node: OVOL1, Edge Weight: 0.211
# Connected Node: OVOL2, Edge Weight: 0.10501640612148933
# Connected Node: P3H2, Edge Weight: 0.13059073788815634
# Connected Node: PALM3, Edge Weight: 0.03392388325777285
# Connected Node: PCDH10, Edge Weight: 0.039174883712210784
# Connected Node: PCDH8, Edge Weight: 0.10274727247535553
# Connected Node: PCDHA11, Edge Weight: 0.2469541403901938
# Connected Node: PCDHA12, Edge Weight: 0.3039529843800386
# Connected Node: PCDHAC2, Edge Weight: 0.23183785714333172
# Connected Node: PCDHGB5, Edge Weight: 0.05275088732672306
# Connected Node: PCP4, Edge Weight: 0.10557951703574897
# Connected Node: PCSK1N, Edge Weight: 0.03853059149771276
# Connected Node: PCSK2, Edge Weight: 0.3439301232990819
# Connected Node: PDCD1LG2, Edge Weight: 0.10899300921968447
# Connected Node: PDE10A, Edge Weight: 0.037438733726799844
# Connected Node: PDE4B, Edge Weight: 0.09483655510978117
# Connected Node: PDGFRB, Edge Weight: 0.03900569698442369
# Connected Node: PDIA2, Edge Weight: 0.02863878528528474
# Connected Node: PDLIM4, Edge Weight: 0.00464276509173045
# Connected Node: PDZD4, Edge Weight: 0.00607351921869137
# Connected Node: PDZRN3, Edge Weight: 0.16480261115381545
# Connected Node: PEG10, Edge Weight: 0.09974457389255909
# Connected Node: PGR, Edge Weight: 0.352
# Connected Node: PHYHD1, Edge Weight: 0.004336895818313868
# Connected Node: PID1, Edge Weight: 0.19661914123444424
# Connected Node: PKP1, Edge Weight: 0.04394075753977722
# Connected Node: PLA2G4A, Edge Weight: 0.2007317263388988
# Connected Node: PLA2G4F, Edge Weight: 0.058354798389677276
# Connected Node: PLCL2, Edge Weight: 0.18993037302980809
# Connected Node: PLCXD3, Edge Weight: 0.13793679328824004
# Connected Node: PLPPR5, Edge Weight: 0.042188894606269844
# Connected Node: PLS3, Edge Weight: 0.14542470874994473
# Connected Node: PNMA2, Edge Weight: 0.02053208478950186
# Connected Node: PNMA8A, Edge Weight: 0.0164301055554954
# Connected Node: POPDC3, Edge Weight: 0.11616175891193281
# Connected Node: PPARGC1A, Edge Weight: 0.009759615261677457
# Connected Node: PPL, Edge Weight: 0.07894339909404513
# Connected Node: PPP4R3C, Edge Weight: 0.10464276725739796
# Connected Node: PRDM8, Edge Weight: 0.187
# Connected Node: PRDM9, Edge Weight: 0.212
# Connected Node: PREX1, Edge Weight: 0.05103341806632877
# Connected Node: PRKAA2, Edge Weight: 0.06437971266116493
# Connected Node: PROM2, Edge Weight: 0.03178748192518155
# Connected Node: PRR15L, Edge Weight: 0.047467164769812165
# Connected Node: PRSS2, Edge Weight: 0.0724059074909007
# Connected Node: PRSS8, Edge Weight: 0.09740041453186854
# Connected Node: PSAT1, Edge Weight: 0.04604899712472488
# Connected Node: PSMB8, Edge Weight: 0.05150925452004129
# Connected Node: PTPRM, Edge Weight: 0.013091612448403511
# Connected Node: PTX3, Edge Weight: 0.0667476809939227
# Connected Node: QPRT, Edge Weight: 0.02372447550845047
# Connected Node: RAB17, Edge Weight: 0.02449016975018581
# Connected Node: RAB25, Edge Weight: 0.02818547015174655
# Connected Node: RAB34, Edge Weight: 0.06092774127193801
# Connected Node: RAB38, Edge Weight: 0.25611787342033865
# Connected Node: RAC2, Edge Weight: 0.04580273996719075
# Connected Node: RAMP3, Edge Weight: 0.049037202734200536
# Connected Node: RASAL1, Edge Weight: 0.05211960628154122
# Connected Node: RBBP8NL, Edge Weight: 0.0058403094512661236
# Connected Node: RBMS3, Edge Weight: 0.21064258891141163
# Connected Node: RBP7, Edge Weight: 0.007127850515689871
# Connected Node: RCSD1, Edge Weight: 0.07034775758081269
# Connected Node: REG4, Edge Weight: 0.15877121411839323
# Connected Node: RET, Edge Weight: 0.04444465195150782
# Connected Node: RFPL4AL1, Edge Weight: 0.17564327696300008
# Connected Node: RIMS4, Edge Weight: 0.07425346408069333
# Connected Node: RIPPLY3, Edge Weight: 0.1007359794937599
# Connected Node: RNF217, Edge Weight: 0.11832084382735375
# Connected Node: RNF223, Edge Weight: 0.03022259039945263
# Connected Node: RNF43, Edge Weight: 0.06472405626712074
# Connected Node: ROBO4, Edge Weight: 0.013205917690762625
# Connected Node: ROR1, Edge Weight: 0.13546391741168495
# Connected Node: RPS6KA6, Edge Weight: 0.02232232665788514
# Connected Node: RUBCNL, Edge Weight: 0.044730335577399805
# Connected Node: RYR2, Edge Weight: 0.07617362289456575
# Connected Node: S100A14, Edge Weight: 0.06151877738878353
# Connected Node: SAMD9L, Edge Weight: 0.18778212966362617
# Connected Node: SCUBE2, Edge Weight: 0.04257614685773192
# Connected Node: SDHAF3, Edge Weight: 0.12096927955870118
# Connected Node: SERPINE1, Edge Weight: 0.05950355897199677
# Connected Node: SFMBT2, Edge Weight: 0.12030080923407116
# Connected Node: SGCG, Edge Weight: 0.13856329789909494
# Connected Node: SH3RF3, Edge Weight: 0.08130140356855398
# Connected Node: SHC2, Edge Weight: 0.03580908602876365
# Connected Node: SHISA3, Edge Weight: 0.050511664908770015
# Connected Node: SHISA9, Edge Weight: 0.018045559683774748
# Connected Node: SLAMF7, Edge Weight: 0.24479151850623082
# Connected Node: SLC17A9, Edge Weight: 0.007424558689744787
# Connected Node: SLC18B1, Edge Weight: 0.09092775154261723
# Connected Node: SLC24A3, Edge Weight: 0.04023984118279267
# Connected Node: SLC27A6, Edge Weight: 0.17271777106189412
# Connected Node: SLC2A10, Edge Weight: 0.14094333159992756
# Connected Node: SLC2A3, Edge Weight: 0.09803876843130022
# Connected Node: SLC35F3, Edge Weight: 0.057774992559429084
# Connected Node: SLC43A3, Edge Weight: 0.009796798368972404
# Connected Node: SLC4A4, Edge Weight: 0.24984779435412174
# Connected Node: SLC6A14, Edge Weight: 0.16652179020888536
# Connected Node: SLC9A2, Edge Weight: 0.05934552922295433
# Connected Node: SLCO1B3, Edge Weight: 0.12795702263352515
# Connected Node: SLFN12, Edge Weight: 0.25525333653315063
# Connected Node: SLITRK6, Edge Weight: 0.1795835323060868
# Connected Node: SMIM22, Edge Weight: 0.03679465466814835
# Connected Node: SMOC2, Edge Weight: 0.042010473904402046
# Connected Node: SMTNL2, Edge Weight: 0.04939330965172428
# Connected Node: SNPH, Edge Weight: 0.05404528419134813
# Connected Node: SOD3, Edge Weight: 0.06361591608578099
# Connected Node: SORBS2, Edge Weight: 0.15757272926350252
# Connected Node: SORCS1, Edge Weight: 0.06255989118247318
# Connected Node: SOX3, Edge Weight: 0.369
# Connected Node: SPAG16, Edge Weight: 0.1305240644502048
# Connected Node: SPANXB1, Edge Weight: 0.07392018568331205
# Connected Node: SPANXC, Edge Weight: 0.10108432254660205
# Connected Node: SPARC, Edge Weight: 0.22130983654876712
# Connected Node: SPESP1, Edge Weight: 0.10206666970109213
# Connected Node: SPINT1, Edge Weight: 0.06502230921196972
# Connected Node: SPSB4, Edge Weight: 0.007451628940851052
# Connected Node: SPTSSB, Edge Weight: 0.20797879691744336
# Connected Node: SPX, Edge Weight: 0.1492391763720673
# Connected Node: SRGN, Edge Weight: 0.07845655612135394
# Connected Node: ST6GALNAC3, Edge Weight: 0.12508219915053753
# Connected Node: STAC, Edge Weight: 0.06744148129321048
# Connected Node: STK31, Edge Weight: 0.20239324665623992
# Connected Node: STK33, Edge Weight: 0.06635517975943395
# Connected Node: SULF1, Edge Weight: 0.16223553641898625
# Connected Node: SULF2, Edge Weight: 0.13184328582263838
# Connected Node: SULT2B1, Edge Weight: 0.04771006893227803
# Connected Node: SYK, Edge Weight: 0.10971539963569388
# Connected Node: SYT10, Edge Weight: 0.08662689557560221
# Connected Node: SYTL5, Edge Weight: 0.15135654478792726
# Connected Node: TBX2, Edge Weight: 0.61
# Connected Node: TBX3, Edge Weight: 0.721
# Connected Node: TCEAL9, Edge Weight: 0.11359107325100903
# Connected Node: TDRD5, Edge Weight: 0.11591856124734745
# Connected Node: TFCP2, Edge Weight: 0.12111791794376026
# Connected Node: TH, Edge Weight: 0.005949001499427675
# Connected Node: THNSL2, Edge Weight: 0.028133397158376816
# Connected Node: TLE4, Edge Weight: 0.0703038014018238
# Connected Node: TLR4, Edge Weight: 0.12159261720534631
# Connected Node: TM4SF1, Edge Weight: 0.07701140230720949
# Connected Node: TM4SF18, Edge Weight: 0.2864688634984669
# Connected Node: TMEM125, Edge Weight: 0.06139448527795621
# Connected Node: TMEM156, Edge Weight: 0.17275613548679591
# Connected Node: TMEM178B, Edge Weight: 0.04809792085713571
# Connected Node: TMEM26, Edge Weight: 0.17260683641065322
# Connected Node: TMEM30B, Edge Weight: 0.24710873300797687
# Connected Node: TMEM71, Edge Weight: 0.18300531526166353
# Connected Node: TMEM92, Edge Weight: 0.07578310530343702
# Connected Node: AHR, Edge Weight: 0.154
# Connected Node: AIRE, Edge Weight: 0.165
# Connected Node: AR, Edge Weight: 0.471
# Connected Node: ARGFX, Edge Weight: 0.211
# Connected Node: ARID3A, Edge Weight: 0.518
# Connected Node: ARID3B, Edge Weight: 0.275
# Connected Node: ARID5B, Edge Weight: 0.156
# Connected Node: ARNT, Edge Weight: 0.165
# Connected Node: ARNT2, Edge Weight: 0.161
# Connected Node: ASCL3, Edge Weight: 0.19
# Connected Node: ASCL4, Edge Weight: 0.263
# Connected Node: ATF3, Edge Weight: 0.22
# Connected Node: ATOH1, Edge Weight: 0.821
# Connected Node: ATOH7, Edge Weight: 0.44
# Connected Node: BARHL1, Edge Weight: 0.31
# Connected Node: BARHL2, Edge Weight: 0.266
# Connected Node: BARX1, Edge Weight: 0.288
# Connected Node: BARX2, Edge Weight: 0.246
# Connected Node: BCL11A, Edge Weight: 0.258
# Connected Node: BCL11B, Edge Weight: 0.477
# Connected Node: BCL6, Edge Weight: 0.256
# Connected Node: BCL6B, Edge Weight: 0.231
# Connected Node: BHLHA15, Edge Weight: 0.234
# Connected Node: BHLHE22, Edge Weight: 0.255
# Connected Node: BHLHE40, Edge Weight: 0.211
# Connected Node: BPTF, Edge Weight: 0.237
# Connected Node: CDX1, Edge Weight: 0.666
# Connected Node: CDX2, Edge Weight: 0.764
# Connected Node: CDX4, Edge Weight: 0.425
# Connected Node: CEBPA, Edge Weight: 0.377
# Connected Node: CEBPB, Edge Weight: 0.278
# Connected Node: CLOCK, Edge Weight: 0.173
# Connected Node: CREB1, Edge Weight: 0.357
# Connected Node: CRX, Edge Weight: 0.401
# Connected Node: CTCF, Edge Weight: 0.61
# Connected Node: CTCFL, Edge Weight: 0.398
# Connected Node: CUX1, Edge Weight: 0.433
# Connected Node: CUX2, Edge Weight: 0.239
# Connected Node: CXXC1, Edge Weight: 0.29
# Connected Node: DBX1, Edge Weight: 0.283
# Connected Node: DBX2, Edge Weight: 0.25
# Connected Node: DDIT3, Edge Weight: 0.16
# Connected Node: DLX1, Edge Weight: 0.5
# Connected Node: DLX2, Edge Weight: 0.541
# Connected Node: DLX3, Edge Weight: 0.394
# Connected Node: DLX5, Edge Weight: 0.523
# Connected Node: DLX6, Edge Weight: 0.276
# Connected Node: DMRT1, Edge Weight: 0.628
# Connected Node: DMRT2, Edge Weight: 0.217
# Connected Node: DMRT3, Edge Weight: 0.247
# Connected Node: DMRTA2, Edge Weight: 0.599
# Connected Node: DNMT1, Edge Weight: 0.769
# Connected Node: DPF1, Edge Weight: 0.251
# Connected Node: DPRX, Edge Weight: 0.185
# Connected Node: DRGX, Edge Weight: 0.15
# Connected Node: E2F1, Edge Weight: 0.264
# Connected Node: E2F2, Edge Weight: 0.286
# Connected Node: E2F3, Edge Weight: 0.337
# Connected Node: E2F4, Edge Weight: 0.345
# Connected Node: E2F5, Edge Weight: 0.193
# Connected Node: E2F6, Edge Weight: 0.19
# Connected Node: E2F7, Edge Weight: 0.209
# Connected Node: E2F8, Edge Weight: 0.208
# Connected Node: E4F1, Edge Weight: 0.296
# Connected Node: EBF1, Edge Weight: 0.292
# Connected Node: EBF2, Edge Weight: 0.168
# Connected Node: EGR1, Edge Weight: 0.386
# Connected Node: EGR2, Edge Weight: 0.5
# Connected Node: EGR3, Edge Weight: 0.213
# Connected Node: EGR4, Edge Weight: 0.173
# Connected Node: ELF3, Edge Weight: 0.282
# Connected Node: ELK4, Edge Weight: 0.175
# Connected Node: EMX1, Edge Weight: 0.36
# Connected Node: EMX2, Edge Weight: 0.648
# Connected Node: EN1, Edge Weight: 0.451
# Connected Node: EN2, Edge Weight: 0.34
# Connected Node: EOMES, Edge Weight: 0.845
# Connected Node: EPAS1, Edge Weight: 0.935
# Connected Node: ERG, Edge Weight: 0.392
# Connected Node: ESR2, Edge Weight: 0.265
# Connected Node: ESRRA, Edge Weight: 0.258
# Connected Node: ESRRB, Edge Weight: 0.818
# Connected Node: ESRRG, Edge Weight: 0.389
# Connected Node: ESX1, Edge Weight: 0.549
# Connected Node: ETS2, Edge Weight: 0.272
# Connected Node: ETV2, Edge Weight: 0.279
# Connected Node: ETV4, Edge Weight: 0.337
# Connected Node: ETV5, Edge Weight: 0.332
# Connected Node: ETV6, Edge Weight: 0.194
# Connected Node: EVX1, Edge Weight: 0.236
# Connected Node: FEV, Edge Weight: 0.302
# Connected Node: FEZF1, Edge Weight: 0.434
# Connected Node: FEZF2, Edge Weight: 0.495
# Connected Node: FIGLA, Edge Weight: 0.221
# Connected Node: FLI1, Edge Weight: 0.345
# Connected Node: FOS, Edge Weight: 0.358
# Connected Node: FOSB, Edge Weight: 0.172
# Connected Node: FOSL2, Edge Weight: 0.281
# Connected Node: FOXA1, Edge Weight: 0.639
# Connected Node: FOXA3, Edge Weight: 0.412
# Connected Node: FOXB1, Edge Weight: 0.323
# Connected Node: FOXC1, Edge Weight: 0.406
# Connected Node: FOXC2, Edge Weight: 0.396
# Connected Node: FOXD1, Edge Weight: 0.234
# Connected Node: FOXD3, Edge Weight: 0.973
# Connected Node: FOXD4, Edge Weight: 0.167
# Connected Node: FOXD4L1, Edge Weight: 0.248
# Connected Node: FOXE1, Edge Weight: 0.392
# Connected Node: FOXE3, Edge Weight: 0.519
# Connected Node: FOXF1, Edge Weight: 0.389
# Connected Node: FOXF2, Edge Weight: 0.253
# Connected Node: FOXG1, Edge Weight: 0.661
# Connected Node: FOXH1, Edge Weight: 0.357
# Connected Node: FOXI1, Edge Weight: 0.347
# Connected Node: FOXI2, Edge Weight: 0.202
# Connected Node: FOXJ1, Edge Weight: 0.511
# Connected Node: FOXK2, Edge Weight: 0.166
# Connected Node: FOXL1, Edge Weight: 0.249
# Connected Node: FOXL2, Edge Weight: 0.289
# Connected Node: FOXM1, Edge Weight: 0.693
# Connected Node: FOXN1, Edge Weight: 0.254
# Connected Node: FOXN4, Edge Weight: 0.285
# Connected Node: FOXO1, Edge Weight: 0.598
# Connected Node: FOXO3, Edge Weight: 0.342
# Connected Node: FOXO4, Edge Weight: 0.225
# Connected Node: FOXO6, Edge Weight: 0.46
# Connected Node: FOXP1, Edge Weight: 0.411
# Connected Node: FOXP2, Edge Weight: 0.387
# Connected Node: FOXP3, Edge Weight: 0.265
# Connected Node: FOXP4, Edge Weight: 0.233
# Connected Node: FOXQ1, Edge Weight: 0.177
# Connected Node: GABPA, Edge Weight: 0.193
# Connected Node: GATA1, Edge Weight: 0.504
# Connected Node: GATA2, Edge Weight: 0.596
# Connected Node: GATA3, Edge Weight: 0.626
# Connected Node: GATA4, Edge Weight: 0.765
# Connected Node: GATA5, Edge Weight: 0.372
# Connected Node: GATA6, Edge Weight: 0.756
# Connected Node: GBX2, Edge Weight: 0.562
# Connected Node: GCM1, Edge Weight: 0.263
# Connected Node: GCM2, Edge Weight: 0.156
# Connected Node: GFI1, Edge Weight: 0.362
# Connected Node: GFI1B, Edge Weight: 0.237
# Connected Node: GLI1, Edge Weight: 0.665
# Connected Node: GLI2, Edge Weight: 0.65
# Connected Node: GLI3, Edge Weight: 0.625
# Connected Node: GLIS1, Edge Weight: 0.542
# Connected Node: GLIS2, Edge Weight: 0.2
# Connected Node: GLIS3, Edge Weight: 0.258
# Connected Node: GSC2, Edge Weight: 0.235
# Connected Node: GSX1, Edge Weight: 0.234
# Connected Node: GSX2, Edge Weight: 0.427
# Connected Node: GTF3A, Edge Weight: 0.15
# Connected Node: HAND1, Edge Weight: 0.309
# Connected Node: HAND2, Edge Weight: 0.333
# Connected Node: HELT, Edge Weight: 0.382
# Connected Node: HES1, Edge Weight: 0.284
# Connected Node: HES3, Edge Weight: 0.461
# Connected Node: HES4, Edge Weight: 0.221
# Connected Node: HES5, Edge Weight: 0.82
# Connected Node: HES6, Edge Weight: 0.318
# Connected Node: HES7, Edge Weight: 0.218
# Connected Node: HESX1, Edge Weight: 0.567
# Connected Node: HEY1, Edge Weight: 0.452
# Connected Node: HEY2, Edge Weight: 0.42
# Connected Node: HEYL, Edge Weight: 0.151
# Connected Node: HHEX, Edge Weight: 0.394
# Connected Node: HIC1, Edge Weight: 0.197
# Connected Node: HIF1A, Edge Weight: 0.427
# Connected Node: HIF3A, Edge Weight: 0.22
# Connected Node: HIVEP1, Edge Weight: 0.158
# Connected Node: HMX1, Edge Weight: 0.444
# Connected Node: HMX2, Edge Weight: 0.423
# Connected Node: HMX3, Edge Weight: 0.35
# Connected Node: HNF1A, Edge Weight: 0.282
# Connected Node: HNF1B, Edge Weight: 0.212
# Connected Node: HNF4A, Edge Weight: 0.568
# Connected Node: HOXA1, Edge Weight: 0.171
# Connected Node: HOXA11, Edge Weight: 0.191
# Connected Node: HOXA13, Edge Weight: 0.241
# Connected Node: HOXA2, Edge Weight: 0.339
# Connected Node: HOXA3, Edge Weight: 0.226
# Connected Node: HOXA5, Edge Weight: 0.63
# Connected Node: HOXA6, Edge Weight: 0.231
# Connected Node: HOXA7, Edge Weight: 0.313
# Connected Node: HOXA9, Edge Weight: 0.367
# Connected Node: HOXB1, Edge Weight: 0.491
# Connected Node: HOXB13, Edge Weight: 0.168
# Connected Node: HOXB2, Edge Weight: 0.251
# Connected Node: HOXB3, Edge Weight: 0.243
# Connected Node: HOXB4, Edge Weight: 0.446
# Connected Node: HOXB5, Edge Weight: 0.245
# Connected Node: HOXB6, Edge Weight: 0.189
# Connected Node: HOXB7, Edge Weight: 0.268
# Connected Node: HOXB8, Edge Weight: 0.196
# Connected Node: HOXB9, Edge Weight: 0.354
# Connected Node: HOXC12, Edge Weight: 0.208
# Connected Node: HOXC4, Edge Weight: 0.198
# Connected Node: HOXC5, Edge Weight: 0.224
# Connected Node: HOXC6, Edge Weight: 0.257
# Connected Node: HOXC8, Edge Weight: 0.221
# Connected Node: HOXC9, Edge Weight: 0.183
# Connected Node: HOXD1, Edge Weight: 0.199
# Connected Node: HOXD10, Edge Weight: 0.243
# Connected Node: HOXD11, Edge Weight: 0.156
# Connected Node: HOXD13, Edge Weight: 0.171
# Connected Node: HOXD4, Edge Weight: 0.226
# Connected Node: HOXD8, Edge Weight: 0.157
# Connected Node: HOXD9, Edge Weight: 0.165
# Connected Node: IKZF1, Edge Weight: 0.235
# Connected Node: INSM1, Edge Weight: 0.326
# Connected Node: IRX1, Edge Weight: 0.345
# Connected Node: IRX3, Edge Weight: 0.429
# Connected Node: IRX5, Edge Weight: 0.216
# Connected Node: IRX6, Edge Weight: 0.426
# Connected Node: ISL1, Edge Weight: 0.732
# Connected Node: ISL2, Edge Weight: 0.461
# Connected Node: JUN, Edge Weight: 0.466
# Connected Node: JUND, Edge Weight: 0.243
# Connected Node: KDM2B, Edge Weight: 0.315
# Connected Node: KLF1, Edge Weight: 0.54
# Connected Node: KLF10, Edge Weight: 0.213
# Connected Node: KLF11, Edge Weight: 0.222
# Connected Node: KLF12, Edge Weight: 0.226
# Connected Node: KLF13, Edge Weight: 0.236
# Connected Node: KLF14, Edge Weight: 0.183
# Connected Node: KLF15, Edge Weight: 0.204
# Connected Node: KLF16, Edge Weight: 0.204
# Connected Node: KLF17, Edge Weight: 0.326
# Connected Node: KLF2, Edge Weight: 0.755
# Connected Node: KLF3, Edge Weight: 0.281
# Connected Node: KLF4, Edge Weight: 0.996
# Connected Node: KLF5, Edge Weight: 0.746
# Connected Node: KLF6, Edge Weight: 0.307
# Connected Node: KLF7, Edge Weight: 0.36
# Connected Node: KLF8, Edge Weight: 0.307
# Connected Node: KLF9, Edge Weight: 0.333
# Connected Node: KMT2A, Edge Weight: 0.31
# Connected Node: LBX1, Edge Weight: 0.342
# Connected Node: LEF1, Edge Weight: 0.596
# Connected Node: LHX3, Edge Weight: 0.49
# Connected Node: LHX4, Edge Weight: 0.42
# Connected Node: LHX5, Edge Weight: 0.365
# Connected Node: LHX6, Edge Weight: 0.233
# Connected Node: LHX8, Edge Weight: 0.235
# Connected Node: LHX9, Edge Weight: 0.219
# Connected Node: LIN28A, Edge Weight: 0.994
# Connected Node: LIN28B, Edge Weight: 0.816
# Connected Node: LMX1A, Edge Weight: 0.609
# Connected Node: LMX1B, Edge Weight: 0.333
# Connected Node: MAF, Edge Weight: 0.574
# Connected Node: MAFB, Edge Weight: 0.242
# Connected Node: MAX, Edge Weight: 0.305
# Connected Node: MAZ, Edge Weight: 0.239
# Connected Node: MBD2, Edge Weight: 0.275
# Connected Node: MBNL2, Edge Weight: 0.309
# Connected Node: MECOM, Edge Weight: 0.317
# Connected Node: MECP2, Edge Weight: 0.645
# Connected Node: MEF2A, Edge Weight: 0.241
# Connected Node: MEF2C, Edge Weight: 0.528
# Connected Node: MEF2D, Edge Weight: 0.158
# Connected Node: MEIS1, Edge Weight: 0.447
# Connected Node: MEIS2, Edge Weight: 0.403
# Connected Node: MEOX1, Edge Weight: 0.325
# Connected Node: MEOX2, Edge Weight: 0.246
# Connected Node: MESP1, Edge Weight: 0.408
# Connected Node: MESP2, Edge Weight: 0.25
# Connected Node: MITF, Edge Weight: 0.479
# Connected Node: MIXL1, Edge Weight: 0.552
# Connected Node: MLX, Edge Weight: 0.237
# Connected Node: MNT, Edge Weight: 0.23
# Connected Node: MNX1, Edge Weight: 0.338
# Connected Node: MSX1, Edge Weight: 0.728
# Connected Node: MSX2, Edge Weight: 0.598
# Connected Node: MYB, Edge Weight: 0.29
# Connected Node: MYBL1, Edge Weight: 0.17
# Connected Node: MYBL2, Edge Weight: 0.317
# Connected Node: MYC, Edge Weight: 0.943
# Connected Node: MYCL, Edge Weight: 0.689
# Connected Node: MYCN, Edge Weight: 0.745
# Connected Node: MYF5, Edge Weight: 0.336
# Connected Node: MYF6, Edge Weight: 0.17
# Connected Node: MYOD1, Edge Weight: 0.592
# Connected Node: MYOG, Edge Weight: 0.335
# Connected Node: MYRF, Edge Weight: 0.161
# Connected Node: MYT1L, Edge Weight: 0.525
# Connected Node: MZF1, Edge Weight: 0.309
# Connected Node: NANOG, Edge Weight: 0.997
# Connected Node: NEUROD1, Edge Weight: 0.893
# Connected Node: NEUROD2, Edge Weight: 0.368
# Connected Node: NEUROD4, Edge Weight: 0.332
# Connected Node: NEUROD6, Edge Weight: 0.271
# Connected Node: NEUROG1, Edge Weight: 0.779
# Connected Node: NEUROG2, Edge Weight: 0.657
# Connected Node: NEUROG3, Edge Weight: 0.481
# Connected Node: NFATC1, Edge Weight: 0.237
# Connected Node: NFATC2, Edge Weight: 0.57
# Connected Node: NFATC4, Edge Weight: 0.185
# Connected Node: NFE2, Edge Weight: 0.181
# Connected Node: NFE2L2, Edge Weight: 0.297
# Connected Node: NFIA, Edge Weight: 0.279
# Connected Node: NFIB, Edge Weight: 0.407
# Connected Node: NFIC, Edge Weight: 0.208
# Connected Node: NFIX, Edge Weight: 0.242
# Connected Node: NFKB1, Edge Weight: 0.172
# Connected Node: NFKB2, Edge Weight: 0.157
# Connected Node: NFYA, Edge Weight: 0.278
# Connected Node: NFYB, Edge Weight: 0.203
# Connected Node: NHLH1, Edge Weight: 0.278
# Connected Node: NHLH2, Edge Weight: 0.26
# Connected Node: NKX1-2, Edge Weight: 0.298
# Connected Node: NKX2-1, Edge Weight: 0.75
# Connected Node: NKX2-2, Edge Weight: 0.722
# Connected Node: NKX2-4, Edge Weight: 0.184
# Connected Node: NKX2-5, Edge Weight: 0.617
# Connected Node: NKX3-1, Edge Weight: 0.248
# Connected Node: NKX3-2, Edge Weight: 0.18
# Connected Node: NKX6-1, Edge Weight: 0.537
# Connected Node: NKX6-2, Edge Weight: 0.507
# Connected Node: NKX6-3, Edge Weight: 0.234
# Connected Node: NOBOX, Edge Weight: 0.317
# Connected Node: NPAS1, Edge Weight: 0.192
# Connected Node: NPAS3, Edge Weight: 0.321
# Connected Node: NR0B1, Edge Weight: 0.767
# Connected Node: NR1H3, Edge Weight: 0.152
# Connected Node: NR1I2, Edge Weight: 0.186
# Connected Node: NR1I3, Edge Weight: 0.154
# Connected Node: NR2E1, Edge Weight: 0.555
# Connected Node: NR2E3, Edge Weight: 0.28
# Connected Node: NR2F1, Edge Weight: 0.532
# Connected Node: NR2F2, Edge Weight: 0.517
# Connected Node: NR2F6, Edge Weight: 0.165
# Connected Node: NR3C1, Edge Weight: 0.331
# Connected Node: NR3C2, Edge Weight: 0.156
# Connected Node: NR4A2, Edge Weight: 0.42
# Connected Node: NR5A1, Edge Weight: 0.575
# Connected Node: NR5A2, Edge Weight: 0.583
# Connected Node: NR6A1, Edge Weight: 0.505
# Connected Node: NRL, Edge Weight: 0.347
# Connected Node: OLIG1, Edge Weight: 0.551
# Connected Node: OLIG2, Edge Weight: 0.772
# Connected Node: OLIG3, Edge Weight: 0.345
# Connected Node: ONECUT1, Edge Weight: 0.377
# Connected Node: ONECUT2, Edge Weight: 0.167
# Connected Node: OSR2, Edge Weight: 0.268
# Connected Node: OTP, Edge Weight: 0.211
# Connected Node: OTX1, Edge Weight: 0.503
# Connected Node: OTX2, Edge Weight: 0.851
# Connected Node: PATZ1, Edge Weight: 0.316
# Connected Node: PAX1, Edge Weight: 0.244
# Connected Node: PAX2, Edge Weight: 0.833
# Connected Node: PAX3, Edge Weight: 0.807
# Connected Node: PAX4, Edge Weight: 0.316
# Connected Node: PAX5, Edge Weight: 0.585
# Connected Node: PAX6, Edge Weight: 0.969
# Connected Node: PAX7, Edge Weight: 0.653
# Connected Node: PAX8, Edge Weight: 0.371
# Connected Node: PAX9, Edge Weight: 0.36
# Connected Node: PBX1, Edge Weight: 0.932
# Connected Node: PBX2, Edge Weight: 0.176
# Connected Node: PBX3, Edge Weight: 0.225
# Connected Node: PDX1, Edge Weight: 0.298
# Connected Node: PHOX2A, Edge Weight: 0.405
# Connected Node: PHOX2B, Edge Weight: 0.32
# Connected Node: PITX1, Edge Weight: 0.35
# Connected Node: PITX2, Edge Weight: 0.528
# Connected Node: PITX3, Edge Weight: 0.52
# Connected Node: PKNOX1, Edge Weight: 0.235
# Connected Node: PKNOX2, Edge Weight: 0.162
# Connected Node: PLAG1, Edge Weight: 0.162
# Connected Node: PLAGL1, Edge Weight: 0.28
# Connected Node: POU1F1, Edge Weight: 0.555
# Connected Node: POU2F1, Edge Weight: 0.983
# Connected Node: POU2F2, Edge Weight: 0.395
# Connected Node: POU2F3, Edge Weight: 0.488
# Connected Node: POU3F1, Edge Weight: 0.731
# Connected Node: POU3F2, Edge Weight: 0.836
# Connected Node: POU3F3, Edge Weight: 0.687
# Connected Node: POU3F4, Edge Weight: 0.704
# Connected Node: POU4F1, Edge Weight: 0.61
# Connected Node: POU4F2, Edge Weight: 0.552
# Connected Node: POU4F3, Edge Weight: 0.64
# Connected Node: POU5F1, Edge Weight: 0.999
# Connected Node: POU5F1B, Edge Weight: 0.732
# Connected Node: POU6F1, Edge Weight: 0.38
# Connected Node: POU6F2, Edge Weight: 0.391
# Connected Node: PPARA, Edge Weight: 0.165
# Connected Node: PPARD, Edge Weight: 0.155
# Connected Node: PPARG, Edge Weight: 0.375
# Connected Node: PRDM1, Edge Weight: 0.597
# Connected Node: PRDM14, Edge Weight: 0.972
# Connected Node: PRDM16, Edge Weight: 0.233
# Connected Node: PRDM6, Edge Weight: 0.162
# Connected Node: PROP1, Edge Weight: 0.474
# Connected Node: PROX1, Edge Weight: 0.603
# Connected Node: PRRX1, Edge Weight: 0.386
# Connected Node: PRRX2, Edge Weight: 0.17
# Connected Node: PTF1A, Edge Weight: 0.386
# Connected Node: RARA, Edge Weight: 0.257
# Connected Node: RARB, Edge Weight: 0.281
# Connected Node: RARG, Edge Weight: 0.32
# Connected Node: RAX, Edge Weight: 0.563
# Connected Node: RBPJ, Edge Weight: 0.445
# Connected Node: REL, Edge Weight: 0.193
# Connected Node: RELA, Edge Weight: 0.286
# Connected Node: RELB, Edge Weight: 0.186
# Connected Node: REST, Edge Weight: 0.46
# Connected Node: RFX3, Edge Weight: 0.284
# Connected Node: RFX4, Edge Weight: 0.293
# Connected Node: RFX6, Edge Weight: 0.161
# Connected Node: RORB, Edge Weight: 0.165
# Connected Node: RREB1, Edge Weight: 0.239
# Connected Node: RUNX1, Edge Weight: 0.2
# Connected Node: RUNX2, Edge Weight: 0.515
# Connected Node: RUNX3, Edge Weight: 0.297
# Connected Node: RXRA, Edge Weight: 0.216
# Connected Node: RXRG, Edge Weight: 0.21
# Connected Node: SCRT1, Edge Weight: 0.172
# Connected Node: SHOX, Edge Weight: 0.217
# Connected Node: SIM1, Edge Weight: 0.279
# Connected Node: SIM2, Edge Weight: 0.361
# Connected Node: SIX1, Edge Weight: 0.676
# Connected Node: SIX2, Edge Weight: 0.438
# Connected Node: SIX3, Edge Weight: 0.839
# Connected Node: SIX4, Edge Weight: 0.37
# Connected Node: SIX5, Edge Weight: 0.279
# Connected Node: SIX6, Edge Weight: 0.686
# Connected Node: SMAD1, Edge Weight: 0.327
# Connected Node: SMAD3, Edge Weight: 0.505
# Connected Node: SMAD4, Edge Weight: 0.944
# Connected Node: SMAD5, Edge Weight: 0.388
# Connected Node: SMAD9, Edge Weight: 0.295
# Connected Node: SNAI1, Edge Weight: 0.797
# Connected Node: SNAI2, Edge Weight: 0.878
# Connected Node: SOX1, Edge Weight: 0.199
# Connected Node: SOX10, Edge Weight: 0.323
# Connected Node: SOX11, Edge Weight: 0.247
# Connected Node: SOX13, Edge Weight: 0.205
# Connected Node: SOX14, Edge Weight: 0.475
# Connected Node: SOX17, Edge Weight: 0.246
# Connected Node: SOX21, Edge Weight: 0.695
# Connected Node: SOX4, Edge Weight: 0.263
# Connected Node: SOX5, Edge Weight: 0.342
# Connected Node: SOX6, Edge Weight: 0.335
# Connected Node: SOX7, Edge Weight: 0.195
# Connected Node: SOX8, Edge Weight: 0.388
# Connected Node: SOX9, Edge Weight: 0.312
# Connected Node: SP1, Edge Weight: 0.268
# Connected Node: SP2, Edge Weight: 0.277
# Connected Node: SP3, Edge Weight: 0.344
# Connected Node: SP5, Edge Weight: 0.17
# Connected Node: SP6, Edge Weight: 0.224
# Connected Node: SP7, Edge Weight: 0.37
# Connected Node: SP8, Edge Weight: 0.457
# Connected Node: SP9, Edge Weight: 0.208
# Connected Node: SPDEF, Edge Weight: 0.181
# Connected Node: SPI1, Edge Weight: 0.4
# Connected Node: SRF, Edge Weight: 0.366
# Connected Node: STAT1, Edge Weight: 0.336
# Connected Node: STAT2, Edge Weight: 0.272
# Connected Node: STAT3, Edge Weight: 0.983
# Connected Node: STAT4, Edge Weight: 0.16
# Connected Node: STAT5A, Edge Weight: 0.372
# Connected Node: STAT5B, Edge Weight: 0.358
# Connected Node: STAT6, Edge Weight: 0.937
# Connected Node: T, Edge Weight: 0.606
# Connected Node: TAL1, Edge Weight: 0.444
# Connected Node: TBP, Edge Weight: 0.395
# Connected Node: TBR1, Edge Weight: 0.558
# Connected Node: TBX1, Edge Weight: 0.362
# Connected Node: TBX18, Edge Weight: 0.322
# Connected Node: TBX19, Edge Weight: 0.257
# Connected Node: TBX20, Edge Weight: 0.227
# Connected Node: TBX4, Edge Weight: 0.196
# Connected Node: TBX5, Edge Weight: 0.547
# Connected Node: TBX6, Edge Weight: 0.478
# Connected Node: TCF12, Edge Weight: 0.33
# Connected Node: TCF15, Edge Weight: 0.236
# Connected Node: TCF3, Edge Weight: 0.46
# Connected Node: TCF4, Edge Weight: 0.701
# Connected Node: TCF7, Edge Weight: 0.355
# Connected Node: TCF7L1, Edge Weight: 0.453
# Connected Node: TCF7L2, Edge Weight: 0.385
# Connected Node: TEAD1, Edge Weight: 0.44
# Connected Node: TEAD2, Edge Weight: 0.39
# Connected Node: TEAD3, Edge Weight: 0.217
# Connected Node: TEAD4, Edge Weight: 0.596
# Connected Node: TEF, Edge Weight: 0.202
# Connected Node: TET1, Edge Weight: 0.659
# Connected Node: TFAP2A, Edge Weight: 0.44
# Connected Node: TFAP2B, Edge Weight: 0.222
# Connected Node: TFAP2C, Edge Weight: 0.468
# Connected Node: TFCP2L1, Edge Weight: 0.558
# Connected Node: TFDP1, Edge Weight: 0.186
# Connected Node: TFE3, Edge Weight: 0.24
# Connected Node: TFEB, Edge Weight: 0.191
# Connected Node: TFEC, Edge Weight: 0.17
# Connected Node: TGIF1, Edge Weight: 0.21
# Connected Node: TGIF2, Edge Weight: 0.174
# Connected Node: THRA, Edge Weight: 0.169
# Connected Node: THRB, Edge Weight: 0.172
# Connected Node: TLX1, Edge Weight: 0.394
# Connected Node: TLX2, Edge Weight: 0.276
# Connected Node: TLX3, Edge Weight: 0.305
# Connected Node: TP53, Edge Weight: 0.833
# Connected Node: TP63, Edge Weight: 0.485
# Connected Node: TP73, Edge Weight: 0.55
# Connected Node: TWIST1, Edge Weight: 0.784
# Connected Node: TWIST2, Edge Weight: 0.409
# Connected Node: UNCX, Edge Weight: 0.19
# Connected Node: USF1, Edge Weight: 0.35
# Connected Node: USF2, Edge Weight: 0.262
# Connected Node: VAX1, Edge Weight: 0.556
# Connected Node: VAX2, Edge Weight: 0.217
# Connected Node: VDR, Edge Weight: 0.225
# Connected Node: VENTX, Edge Weight: 0.321
# Connected Node: VSX1, Edge Weight: 0.35
# Connected Node: VSX2, Edge Weight: 0.662
# Connected Node: WT1, Edge Weight: 0.437
# Connected Node: XBP1, Edge Weight: 0.205
# Connected Node: YBX1, Edge Weight: 0.393
# Connected Node: YBX2, Edge Weight: 0.206
# Connected Node: YY1, Edge Weight: 0.734
# Connected Node: YY2, Edge Weight: 0.297
# Connected Node: ZBTB18, Edge Weight: 0.172
# Connected Node: ZBTB20, Edge Weight: 0.179
# Connected Node: ZBTB33, Edge Weight: 0.274
# Connected Node: ZBTB7A, Edge Weight: 0.209
# Connected Node: ZEB1, Edge Weight: 0.703
# Connected Node: ZEB2, Edge Weight: 0.616
# Connected Node: ZFHX3, Edge Weight: 0.167
# Connected Node: ZFHX4, Edge Weight: 0.179
# Connected Node: ZFP1, Edge Weight: 0.166
# Connected Node: ZFP42, Edge Weight: 0.715
# Connected Node: ZFP57, Edge Weight: 0.323
# Connected Node: ZFP64, Edge Weight: 0.154
# Connected Node: ZFX, Edge Weight: 0.622
# Connected Node: ZIC1, Edge Weight: 0.659
# Connected Node: ZIC2, Edge Weight: 0.674
# Connected Node: ZIC3, Edge Weight: 0.967
# Connected Node: ZIC4, Edge Weight: 0.294
# Connected Node: ZIC5, Edge Weight: 0.524
# Connected Node: ZKSCAN2, Edge Weight: 0.16
# Connected Node: ZKSCAN7, Edge Weight: 0.258
# Connected Node: ZNF114, Edge Weight: 0.15
# Connected Node: ZNF143, Edge Weight: 0.265
# Connected Node: ZNF148, Edge Weight: 0.206
# Connected Node: ZNF219, Edge Weight: 0.206
# Connected Node: ZNF235, Edge Weight: 0.15
# Connected Node: ZNF263, Edge Weight: 0.239
# Connected Node: ZNF274, Edge Weight: 0.275
# Connected Node: ZNF281, Edge Weight: 0.6
# Connected Node: ZNF296, Edge Weight: 0.49
# Connected Node: ZNF32, Edge Weight: 0.401
# Connected Node: ZNF334, Edge Weight: 0.155
# Connected Node: ZNF354C, Edge Weight: 0.159
# Connected Node: ZNF384, Edge Weight: 0.209
# Connected Node: ZNF423, Edge Weight: 0.272
# Connected Node: ZNF436, Edge Weight: 0.257
# Connected Node: ZNF44, Edge Weight: 0.245
# Connected Node: ZNF501, Edge Weight: 0.257
# Connected Node: ZNF534, Edge Weight: 0.15
# Connected Node: ZNF589, Edge Weight: 0.213
# Connected Node: ZNF597, Edge Weight: 0.182
# Connected Node: ZNF691, Edge Weight: 0.155
# Connected Node: ZNF711, Edge Weight: 0.167
# Connected Node: ZNF730, Edge Weight: 0.15
# Connected Node: ZNF740, Edge Weight: 0.236
# Connected Node: ZNF75D, Edge Weight: 0.158
# Connected Node: ZNF76, Edge Weight: 0.152
# Connected Node: ZNF766, Edge Weight: 0.15
# Connected Node: ZNF787, Edge Weight: 0.195
# Connected Node: ZNF860, Edge Weight: 0.154
# Connected Node: ZSCAN1, Edge Weight: 0.23
# Connected Node: ZSCAN10, Edge Weight: 0.948
# Connected Node: ZSCAN29, Edge Weight: 0.167
# Connected Node: ZSCAN4, Edge Weight: 0.489

# %% [markdown]
# # **3. Visualize the Hub and Its Connections**
# # You can highlight the hub and its neighbors in a graph visualization:

# %%
import matplotlib.pyplot as plt

# Get the subgraph for the hub and its neighbors
#hub_subgraph_MCF7 = G_combined_MCF7_ppi.subgraph([top_hub_node_MCF7] + list(neighbors.keys()))

# Visualize the subgraph
pos = nx.spring_layout(hub_subgraph_MCF7)  # Layout for visualization
plt.figure(figsize=(8, 6))
nx.draw_networkx_nodes(hub_subgraph_MCF7, pos, node_size=700, node_color="lightblue")
nx.draw_networkx_edges(hub_subgraph_MCF7, pos, width=[d["weight"] for (_, _, d) in hub_subgraph_MCF7.edges(data=True)])
nx.draw_networkx_labels(hub_subgraph_MCF7, pos, font_size=10)
plt.title(f"Hub Node ({top_hub_node_MCF7}) and Its Connections")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-53c9418d1d11> in <cell line: 0>()
#       5
#       6 # Visualize the subgraph
# ----> 7 pos = nx.spring_layout(hub_subgraph_MCF7)  # Layout for visualization
#       8 plt.figure(figsize=(8, 6))
#       9 nx.draw_networkx_nodes(hub_subgraph_MCF7, pos, node_size=700, node_color="lightblue")
#
# NameError: name 'hub_subgraph_MCF7' is not defined

# %%
import matplotlib.pyplot as plt

# Get the subgraph for the hub and its neighbors
#hub_subgraph_MDA = G_combined_MDA_ppi.subgraph([top_hub_node_MDA] + list(neighbors.keys()))

# Visualize the subgraph
pos = nx.spring_layout(hub_subgraph_MDA)  # Layout for visualization
plt.figure(figsize=(8, 6))
nx.draw_networkx_nodes(hub_subgraph_MDA, pos, node_size=700, node_color="lightblue")
nx.draw_networkx_edges(hub_subgraph_MDA, pos, width=[d["weight"] for (_, _, d) in hub_subgraph_MDA.edges(data=True)])
nx.draw_networkx_labels(hub_subgraph_MDA, pos, font_size=10)
plt.title(f"Hub Node ({top_hub_node_MDA}) and Its Connections")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-38eeb18fadec> in <cell line: 0>()
#       5
#       6 # Visualize the subgraph
# ----> 7 pos = nx.spring_layout(hub_subgraph_MDA)  # Layout for visualization
#       8 plt.figure(figsize=(8, 6))
#       9 nx.draw_networkx_nodes(hub_subgraph_MDA, pos, node_size=700, node_color="lightblue")
#
# NameError: name 'hub_subgraph_MDA' is not defined

# %% [markdown]
# # **4. Export Hub Connections for Further Analysis**
# # If you want to analyze this data outside Python, export the hub’s connections to a file:

# %%
import pandas as pd

# Create a DataFrame for the hub's connections
hub_connections_MCF7= pd.DataFrame({
    "TF": [top_hub_node_MCF7] * len(neighbors),
    "Gene": list(neighbors.keys()),
    "Edge Weight": [data["weight"] for _, data in neighbors.items()]
})

# Save to CSV
hub_connections_MCF7.to_csv("hub_connections_MCF7.csv", index=False)
print("\nHub connections exported to 'hub_connections_MCF7.csv'")
# Out:
# Hub connections exported to 'hub_connections_MCF7.csv'

# %%
import pandas as pd

# Create a DataFrame for the hub's connections
hub_connections_MDA= pd.DataFrame({
    "TF": [top_hub_node_MDA] * len(neighbors),
    "Gene": list(neighbors.keys()),
    "Edge Weight": [data["weight"] for _, data in neighbors.items()]
})

# Save to CSV
hub_connections_MDA.to_csv("hub_connections_MDA.csv", index=False)
print("\nHub connections exported to 'hub_connections_MDA.csv'")
# Out:
# Hub connections exported to 'hub_connections_MDA.csv'

# %% [markdown]
# SIMULATIONS
# 1. SIGNAL PROPAGATION
#     a) Diffusion based model
#
#     b) Random walks
#
#     c) wave propagation

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv
import matplotlib.animation as animation

# Function to simulate signal diffusion
def simulate_diffusion(graph, alpha=0.1, num_steps=50):
    """
    Simulate signal diffusion on a graph.

    Parameters:
        graph (nx.Graph): The input graph with edge weights and 'expression' attributes.
        alpha (float): Diffusion rate (default: 0.1).
        num_steps (int): Number of time steps to simulate (default: 50).

    Returns:
        list: A list of dictionaries containing node states at each time step.
    """
    # Initialize node states from the 'expression' attribute
    initial_states = nx.get_node_attributes(graph, 'expression')
    states = {node: initial_states.get(node, 0) for node in graph.nodes}
    history = [states.copy()]

    for step in range(num_steps):
        new_states = {}
        for node in graph.nodes:
            # Get current state of the node
            current_state = states[node]

            # Compute the weighted sum of differences with neighbors
            neighbor_influence = sum(
                graph[node][neighbor]["weight"] * (states[neighbor] - current_state)
                for neighbor in graph.neighbors(node)
            )

            # Update the node's state
            new_states[node] = current_state + alpha * neighbor_influence

        # Update states and store the history
        states.update(new_states)
        history.append(states.copy())

    return history



# Run simulations for both graphs
diffusion_history_mcf7 = simulate_diffusion(G_mcf7_ppi, alpha=0.1, num_steps=50)
diffusion_history_mda = simulate_diffusion(G_mda_ppi, alpha=0.1, num_steps=50)

# Save numerical results to CSV files
def save_numerical_results(history, graph, filename):
    numerical_results = {node: [step[node] for step in history] for node in graph.nodes}
    with open(filename, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Node"] + [f"Time_{t}" for t in range(len(history))])
        for node, values in numerical_results.items():
            writer.writerow([node] + values)

save_numerical_results(diffusion_history_mcf7, G_mcf7_ppi, "diffusion_results_mcf7.csv")
save_numerical_results(diffusion_history_mda, G_mda_ppi, "diffusion_results_mda.csv")

print("Numerical results saved to 'diffusion_results_mcf7.csv' and 'diffusion_results_mda.csv'.")


# Identify key nodes using centrality measures
def identify_key_nodes(graph):
    degree_centrality = nx.degree_centrality(graph)
    betweenness_centrality = nx.betweenness_centrality(graph)

    top_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
    top_betweenness = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]

    print("Top nodes by degree centrality:", top_degree)
    print("Top nodes by betweenness centrality:", top_betweenness)

print("\nKey nodes in G_mcf7_ppi:")
identify_key_nodes(G_mcf7_ppi)

print("\nKey nodes in G_mda_ppi:")
identify_key_nodes(G_mda_ppi)

# Detect functional modules using clustering
def detect_functional_modules(graph, history):
    final_states = history[-1]  # Final RNA-seq levels
    state_matrix = np.array([[final_states[node]] for node in graph.nodes])

    # Apply K-Means clustering
    num_clusters = 3  # Adjust as needed
    kmeans = KMeans(n_clusters=num_clusters).fit(state_matrix)
    cluster_labels = kmeans.labels_

    # Assign cluster labels to nodes
    for i, node in enumerate(graph.nodes):
        graph.nodes[node]["cluster"] = cluster_labels[i]

    print("Cluster assignments completed.")

detect_functional_modules(G_mcf7_ppi, diffusion_history_mcf7)
detect_functional_modules(G_mda_ppi, diffusion_history_mda)
# Out:
# Numerical results saved to 'diffusion_results_mcf7.csv' and 'diffusion_results_mda.csv'.
#
# Key nodes in G_mcf7_ppi:
# Top nodes by degree centrality: [('SOX2', 1.4655963302752293), ('ASCL1', 1.0244648318042813), ('ASCL2', 1.0244648318042813), ('BATF3', 1.0244648318042813), ('CREB5', 1.0244648318042813)]
# Top nodes by betweenness centrality: [('SOX2', 0.40764684994132505), ('LEF1', 0.019627958756279328), ('CREB1', 0.015162674030241578), ('ZBTB7A', 0.014496476048796898), ('CTCF', 0.011560490296526718)]
#
# Key nodes in G_mda_ppi:
# Top nodes by degree centrality: [('SOX2', 1.450849963045085), ('ASCL1', 1.0288248337028825), ('ASCL2', 1.0288248337028825), ('BATF3', 1.0288248337028825), ('CREB5', 1.0288248337028825)]
# Top nodes by betweenness centrality: [('SOX2', 0.3777256444869529), ('LEF1', 0.018339083208081978), ('CREB1', 0.014169635285844995), ('ZBTB7A', 0.013455358217184372), ('CTCF', 0.01071108291689435)]
# Cluster assignments completed.
# Cluster assignments completed.

# %%
##Function to update node colors for animations
def update(frame, graph, pos, node_colors):
    plt.clf()
    nx.draw_networkx_nodes(graph, pos, node_color=node_colors[frame], cmap=plt.cm.viridis, node_size=300)
    nx.draw_networkx_edges(graph, pos, edge_color="gray", width=1)
    nx.draw_networkx_labels(graph, pos, font_size=10, font_color="black")
    plt.title(f"Signal Propagation at Time Step {frame}")
    plt.axis("off")

# Visualize signal propagation for MCF7
pos_mcf7 = nx.spring_layout(G_mcf7_ppi)
node_colors_mcf7 = [[step[node] for node in G_mcf7_ppi.nodes] for step in diffusion_history_mcf7]

fig, ax = plt.subplots()
ani_mcf7 = animation.FuncAnimation(fig, update, frames=len(diffusion_history_mcf7), fargs=(G_mcf7_ppi, pos_mcf7, node_colors_mcf7), interval=200)
plt.show()

# Visualize signal propagation for MDA
pos_mda = nx.spring_layout(G_mda_ppi)
node_colors_mda = [[step[node] for node in G_mda_ppi.nodes] for step in diffusion_history_mda]

fig, ax = plt.subplots()
ani_mda = animation.FuncAnimation(fig, update, frames=len(diffusion_history_mda), fargs=(G_mda_ppi, pos_mda, node_colors_mda), interval=200)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_time_series(diffusion_history, graph_name="Graph"):
    """
    Plot the average RNA-seq level and individual node levels over time.

    Parameters:
        diffusion_history (list): A list of dictionaries containing node states at each time step.
        graph_name (str): Name of the graph (e.g., "MCF7" or "MDA").
    """
    # Compute the average RNA-seq level across all nodes at each time step
    average_levels = [np.mean([step[node] for node in diffusion_history[0].keys()]) for step in diffusion_history]

    # Plot the average RNA-seq level
    plt.figure(figsize=(12, 8))  # Larger figure size for better visibility
    plt.plot(range(len(average_levels)), average_levels, label="Average RNA-seq Level",
             color="blue", linewidth=3, linestyle="-")

    # Optionally plot individual node levels (for a subset of nodes)
    sample_nodes = list(diffusion_history[0].keys())[:5]  # Select 5 nodes for clarity
    for i, node in enumerate(sample_nodes):
        node_levels = [step[node] for step in diffusion_history]

        # Normalize node levels to avoid overlap
        node_levels_normalized = np.array(node_levels) - np.min(node_levels)
        node_levels_normalized /= np.max(node_levels_normalized) if np.max(node_levels_normalized) != 0 else 1

        # Plot normalized node levels
        plt.plot(range(len(node_levels)), node_levels_normalized + i * 0.5,  # Offset each node line
                 linestyle="--", alpha=0.8, label=f"Node {node}", color=plt.cm.tab10(i))

    # Improve plot aesthetics
    plt.xlabel("Time Step", fontsize=14)
    plt.ylabel("RNA-seq Level (Normalized)", fontsize=14)
    plt.title(f"Signal Propagation Over Time in {graph_name}", fontsize=16)
    plt.legend(fontsize=12, loc="upper left")  # Adjust legend font size and position
    plt.grid(alpha=0.5)  # Add grid with reduced opacity
    plt.tight_layout()  # Adjust layout to prevent clipping

    # Show the plot
    plt.show()

# Example usage
plot_time_series(diffusion_history_mcf7, graph_name="MCF7")
plot_time_series(diffusion_history_mda, graph_name="MDA")

# %%
import matplotlib.pyplot as plt

def plot_time_series(diffusion_history, graph_name="Graph"):
    """
    Plot the average RNA-seq level and individual node levels over time.

    Parameters:
        diffusion_history (list): A list of dictionaries containing node states at each time step.
        graph_name (str): Name of the graph (e.g., "MCF7" or "MDA").
    """
    # Compute the average RNA-seq level across all nodes at each time step
    average_levels = [np.mean([step[node] for node in diffusion_history[0].keys()]) for step in diffusion_history]

    # Plot the average RNA-seq level
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(average_levels)), average_levels, label="Average RNA-seq Level", color="blue", linewidth=2)

    # Optionally plot individual node levels (for a subset of nodes)
    sample_nodes = list(diffusion_history[0].keys())[:5]  # Select 5 nodes for clarity
    for node in sample_nodes:
        node_levels = [step[node] for step in diffusion_history]
        plt.plot(range(len(node_levels)), node_levels, linestyle="--", alpha=0.6, label=f"Node {node}")

    plt.xlabel("Time Step")
    plt.ylabel("RNA-seq Level")
    plt.title(f"Signal Propagation Over Time in {graph_name}")
    plt.legend()
    plt.grid()
    plt.show()

# Example usage
plot_time_series(diffusion_history_mcf7, graph_name="MCF7")
plot_time_series(diffusion_history_mda, graph_name="MDA")

# %%
def plot_final_state_histogram(diffusion_history, graph_name="Graph"):
    """
    Plot a histogram of RNA-seq levels at the final time step.

    Parameters:
        diffusion_history (list): A list of dictionaries containing node states at each time step.
        graph_name (str): Name of the graph (e.g., "MCF7" or "MDA").
    """
    # Extract RNA-seq levels at the final time step
    final_states = [diffusion_history[-1][node] for node in diffusion_history[0].keys()]

    # Plot the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(final_states, bins=20, color="green", edgecolor="black", alpha=0.7)
    plt.xlabel("RNA-seq Level")
    plt.ylabel("Number of Nodes")
    plt.title(f"Distribution of Final RNA-seq Levels in {graph_name}")
    plt.grid()
    plt.show()

# Example usage
plot_final_state_histogram(diffusion_history_mcf7, graph_name="MCF7")
plot_final_state_histogram(diffusion_history_mda, graph_name="MDA")

# %%
# Visualize functional modules
def visualize_modules(graph, pos):
    clusters = [graph.nodes[node]["cluster"] for node in graph.nodes]

    plt.figure(figsize=(10, 8))
    nx.draw_networkx_nodes(graph, pos, node_color=clusters, cmap=plt.cm.tab10, node_size=300)
    nx.draw_networkx_edges(graph, pos, edge_color="gray", width=1)
    nx.draw_networkx_labels(graph, pos, font_size=10, font_color="black")
    plt.title("Functional Modules Detected by Clustering")
    plt.axis("off")
    plt.show()

print("\nVisualizing functional modules in G_mcf7_ppi...")
visualize_modules(G_mcf7_ppi, pos_mcf7)

print("\nVisualizing functional modules in G_mda_ppi...")
visualize_modules(G_mda_ppi, pos_mda)
